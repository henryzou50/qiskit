# %%
from qiskit.transpiler import CouplingMap
from qiskit.transpiler.passes import SabreLayout, SabreSwap
from utils import file_to_coupling_map, directory_to_circuits, build_pass_manager
import random
import time
import csv
import os
import numpy as np

# %%
def run_experiment(cm_name, qc_name, layout_trials_list=[1, 10, 100, 1000], heuristic="lookahead", num_pass_trials=5, seed=42, output_csv="experiments/experiment_new.csv"):
    """
    Runs a transpilation experiment using SABRE passes on a set of quantum circuits.

    Parameters:
    - cm_name (str): Name of the coupling map file (without extension) located in 'coupling_maps/' directory.
    - qc_name (str): Name of the directory containing quantum circuits to run the experiment on.
    - layout_trials_list (list): List of layout (and swap) trials to run for each circuit. Default is [1, 10, 100, 1000].
    - heuristic (str): Heuristic to use in SabreSwap. Default is "lookahead".
    - num_pass_trials (int): Number of different seeds for running the whole pass. Default is 1.
    - seed (int): Random seed for reproducibility. Default is 42.
    - output_csv (str): Filename for the CSV file where results will be saved. Default is "experiment_results.csv".
    
    Returns:
    - None (Results are saved to a CSV file)
    """
    
    # Set random seed for reproducibility
    random.seed(seed)

    # Load the coupling map and the quantum circuits
    cm = CouplingMap(file_to_coupling_map(f'coupling_maps/{cm_name}.txt'))
    qc_list = directory_to_circuits(f'{qc_name}')

    # Prepare the CSV file
    with open(output_csv, mode='w', newline='') as csvfile:
        fieldnames = ["num_qubits", "layout_trials", "heuristic", "avg_runtime", "avg_swap_count", "avg_depth", "num_pass_trials"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        # Run trials for each circuit
        for qc in qc_list:
            num_qubits = qc.num_qubits
            print(f"Running experiment for {num_qubits} qubits")

            for layout_trials in layout_trials_list:
                seed_list = random.sample(range(0, 100000), num_pass_trials)

                total_runtime = 0
                total_swap_count = 0
                total_depth = 0

                for trial in range(num_pass_trials):
                    # Create the pass manager with the specified layout trials
                    rp = SabreSwap(coupling_map=cm, heuristic=heuristic, seed=seed_list[trial], trials=layout_trials)
                    lp = SabreLayout(coupling_map=cm, routing_pass=rp, seed=seed_list[trial])
                    pm = build_pass_manager(cm, lp, rp)

                    # Run the transpilation pass
                    time_start = time.time()
                    qc_tr = pm.run(qc)
                    time_end = time.time()

                    # Collect the metrics for this trial
                    runtime = time_end - time_start
                    swap_count = qc_tr.count_ops().get('swap', 0)
                    depth = qc_tr.depth(lambda x: x.operation.num_qubits == 2)  # 2-qubit gates

                    total_runtime += runtime
                    total_swap_count += swap_count
                    total_depth += depth

                    print(f"Layout trials: {layout_trials}, Seed: {seed_list[trial]} - Trial {trial+1}/{num_pass_trials} - Runtime: {runtime:.10f} sec, Swap count: {swap_count}, Depth: {depth}")

                # Calculate averages
                avg_runtime = total_runtime / num_pass_trials
                avg_swap_count = total_swap_count / num_pass_trials
                avg_depth = total_depth / num_pass_trials

                # Store averaged results in CSV
                writer.writerow({
                    "num_qubits": num_qubits,
                    "layout_trials": layout_trials,
                    "heuristic": heuristic,
                    "avg_runtime": avg_runtime,
                    "avg_swap_count": avg_swap_count,
                    "avg_depth": avg_depth,
                    "num_pass_trials": num_pass_trials
                })

    print(f"Results saved to {output_csv}")

# %%
# Example usage:

heuristic = "basic"

# Generate log scale values
log_values = np.linspace(0, 3, 10)
linear_values = np.round(10 ** log_values).astype(int)
unique_values = np.unique(np.clip(linear_values, 0, 1000))
layout_trials_list = unique_values.tolist()

run_experiment(cm_name='heavy_hex_127', qc_name='qft', heuristic=heuristic, layout_trials_list=layout_trials_list, num_pass_trials=3, output_csv=f"experiments/qft_{heuristic}.csv")
# Out:
# Running experiment for 10 qubits
# Layout trials: 1, Seed: 83810 - Trial 1/3 - Runtime: 0.0567131042 sec, Swap count: 78, Depth: 70
# Layout trials: 1, Seed: 14592 - Trial 2/3 - Runtime: 0.0557568073 sec, Swap count: 67, Depth: 57
# Layout trials: 1, Seed: 3278 - Trial 3/3 - Runtime: 0.0570800304 sec, Swap count: 81, Depth: 68
# Layout trials: 2, Seed: 97196 - Trial 1/3 - Runtime: 0.0577189922 sec, Swap count: 85, Depth: 63
# Layout trials: 2, Seed: 36048 - Trial 2/3 - Runtime: 0.0583870411 sec, Swap count: 61, Depth: 43
# Layout trials: 2, Seed: 32098 - Trial 3/3 - Runtime: 0.0568621159 sec, Swap count: 73, Depth: 54
# Layout trials: 5, Seed: 29256 - Trial 1/3 - Runtime: 0.0828521252 sec, Swap count: 70, Depth: 54
# Layout trials: 5, Seed: 18289 - Trial 2/3 - Runtime: 0.0582928658 sec, Swap count: 80, Depth: 65
# Layout trials: 5, Seed: 96530 - Trial 3/3 - Runtime: 0.0583019257 sec, Swap count: 59, Depth: 56
# Layout trials: 10, Seed: 13434 - Trial 1/3 - Runtime: 0.0589728355 sec, Swap count: 61, Depth: 64
# Layout trials: 10, Seed: 88696 - Trial 2/3 - Runtime: 0.0610952377 sec, Swap count: 60, Depth: 63
# Layout trials: 10, Seed: 97080 - Trial 3/3 - Runtime: 0.0619373322 sec, Swap count: 71, Depth: 56
# Layout trials: 22, Seed: 71482 - Trial 1/3 - Runtime: 0.0639772415 sec, Swap count: 60, Depth: 58
# Layout trials: 22, Seed: 11395 - Trial 2/3 - Runtime: 0.0653660297 sec, Swap count: 62, Depth: 48
# Layout trials: 22, Seed: 77397 - Trial 3/3 - Runtime: 0.0668950081 sec, Swap count: 62, Depth: 57
# Layout trials: 46, Seed: 55302 - Trial 1/3 - Runtime: 0.0746109486 sec, Swap count: 56, Depth: 55
# Layout trials: 46, Seed: 4165 - Trial 2/3 - Runtime: 0.0740251541 sec, Swap count: 63, Depth: 47
# Layout trials: 46, Seed: 3905 - Trial 3/3 - Runtime: 0.0729329586 sec, Swap count: 55, Depth: 54
# Layout trials: 100, Seed: 12280 - Trial 1/3 - Runtime: 0.0929520130 sec, Swap count: 49, Depth: 55
# Layout trials: 100, Seed: 28657 - Trial 2/3 - Runtime: 0.1190719604 sec, Swap count: 62, Depth: 60
# Layout trials: 100, Seed: 30495 - Trial 3/3 - Runtime: 0.0953669548 sec, Swap count: 63, Depth: 50
# Layout trials: 215, Seed: 66237 - Trial 1/3 - Runtime: 0.1586928368 sec, Swap count: 52, Depth: 57
# Layout trials: 215, Seed: 78907 - Trial 2/3 - Runtime: 0.1296379566 sec, Swap count: 48, Depth: 51
# Layout trials: 215, Seed: 3478 - Trial 3/3 - Runtime: 0.1433942318 sec, Swap count: 60, Depth: 54
# Layout trials: 464, Seed: 73563 - Trial 1/3 - Runtime: 0.2210488319 sec, Swap count: 56, Depth: 45
# Layout trials: 464, Seed: 26062 - Trial 2/3 - Runtime: 0.2831780910 sec, Swap count: 60, Depth: 48
# Layout trials: 464, Seed: 93850 - Trial 3/3 - Runtime: 0.2311401367 sec, Swap count: 58, Depth: 59
# Layout trials: 1000, Seed: 85181 - Trial 1/3 - Runtime: 0.4070801735 sec, Swap count: 50, Depth: 50
# Layout trials: 1000, Seed: 91924 - Trial 2/3 - Runtime: 0.4459271431 sec, Swap count: 49, Depth: 48
# Layout trials: 1000, Seed: 71426 - Trial 3/3 - Runtime: 0.4164860249 sec, Swap count: 57, Depth: 58
# Running experiment for 29 qubits
# Layout trials: 1, Seed: 54987 - Trial 1/3 - Runtime: 0.2720539570 sec, Swap count: 857, Depth: 257
# Layout trials: 1, Seed: 28893 - Trial 2/3 - Runtime: 0.3207080364 sec, Swap count: 810, Depth: 263
# Layout trials: 1, Seed: 58878 - Trial 3/3 - Runtime: 0.2679600716 sec, Swap count: 823, Depth: 240
# Layout trials: 2, Seed: 77236 - Trial 1/3 - Runtime: 0.2711009979 sec, Swap count: 744, Depth: 356
# Layout trials: 2, Seed: 36463 - Trial 2/3 - Runtime: 0.3054101467 sec, Swap count: 722, Depth: 258
# Layout trials: 2, Seed: 851 - Trial 3/3 - Runtime: 0.2681257725 sec, Swap count: 819, Depth: 356
# Layout trials: 5, Seed: 99458 - Trial 1/3 - Runtime: 0.2751572132 sec, Swap count: 713, Depth: 273
# Layout trials: 5, Seed: 20926 - Trial 2/3 - Runtime: 0.3292348385 sec, Swap count: 716, Depth: 244
# Layout trials: 5, Seed: 91506 - Trial 3/3 - Runtime: 0.2733731270 sec, Swap count: 788, Depth: 288
# Layout trials: 10, Seed: 55392 - Trial 1/3 - Runtime: 0.2956840992 sec, Swap count: 669, Depth: 256
# Layout trials: 10, Seed: 44597 - Trial 2/3 - Runtime: 0.2930688858 sec, Swap count: 689, Depth: 239
# Layout trials: 10, Seed: 36421 - Trial 3/3 - Runtime: 0.3566060066 sec, Swap count: 723, Depth: 249
# Layout trials: 22, Seed: 20379 - Trial 1/3 - Runtime: 0.3559877872 sec, Swap count: 651, Depth: 283
# Layout trials: 22, Seed: 28221 - Trial 2/3 - Runtime: 0.3605029583 sec, Swap count: 718, Depth: 263
# Layout trials: 22, Seed: 44118 - Trial 3/3 - Runtime: 0.3897211552 sec, Swap count: 695, Depth: 259
# Layout trials: 46, Seed: 13396 - Trial 1/3 - Runtime: 0.4832260609 sec, Swap count: 637, Depth: 269
# Layout trials: 46, Seed: 12156 - Trial 2/3 - Runtime: 0.4720261097 sec, Swap count: 658, Depth: 244
# Layout trials: 46, Seed: 49797 - Trial 3/3 - Runtime: 0.5315678120 sec, Swap count: 601, Depth: 204
# Layout trials: 100, Seed: 12676 - Trial 1/3 - Runtime: 0.8057930470 sec, Swap count: 645, Depth: 268
# Layout trials: 100, Seed: 47052 - Trial 2/3 - Runtime: 0.8005681038 sec, Swap count: 626, Depth: 242
# Layout trials: 100, Seed: 45082 - Trial 3/3 - Runtime: 0.8591790199 sec, Swap count: 647, Depth: 250
# Layout trials: 215, Seed: 79131 - Trial 1/3 - Runtime: 1.7952611446 sec, Swap count: 650, Depth: 225
# Layout trials: 215, Seed: 34671 - Trial 2/3 - Runtime: 2.3046693802 sec, Swap count: 621, Depth: 254
# Layout trials: 215, Seed: 5695 - Trial 3/3 - Runtime: 2.4765729904 sec, Swap count: 602, Depth: 272
# Layout trials: 464, Seed: 95647 - Trial 1/3 - Runtime: 7.5466239452 sec, Swap count: 585, Depth: 220
# Layout trials: 464, Seed: 60217 - Trial 2/3 - Runtime: 9.2367882729 sec, Swap count: 659, Depth: 251
# Layout trials: 464, Seed: 70284 - Trial 3/3 - Runtime: 7.5723948479 sec, Swap count: 615, Depth: 260
# Layout trials: 1000, Seed: 16361 - Trial 1/3 - Runtime: 13.5629801750 sec, Swap count: 626, Depth: 210
# Layout trials: 1000, Seed: 49615 - Trial 2/3 - Runtime: 13.2206549644 sec, Swap count: 567, Depth: 259
# Layout trials: 1000, Seed: 10328 - Trial 3/3 - Runtime: 14.4138991833 sec, Swap count: 586, Depth: 219
# Running experiment for 49 qubits
# Layout trials: 1, Seed: 72357 - Trial 1/3 - Runtime: 2.2234177589 sec, Swap count: 2276, Depth: 538
# Layout trials: 1, Seed: 38427 - Trial 2/3 - Runtime: 2.6650590897 sec, Swap count: 2429, Depth: 653
# Layout trials: 1, Seed: 82397 - Trial 3/3 - Runtime: 2.5467510223 sec, Swap count: 2146, Depth: 521
# Layout trials: 2, Seed: 81070 - Trial 1/3 - Runtime: 2.2709159851 sec, Swap count: 2468, Depth: 643
# Layout trials: 2, Seed: 47400 - Trial 2/3 - Runtime: 2.4248440266 sec, Swap count: 2426, Depth: 583
# Layout trials: 2, Seed: 75674 - Trial 3/3 - Runtime: 2.4496030807 sec, Swap count: 2373, Depth: 596
# Layout trials: 5, Seed: 25203 - Trial 1/3 - Runtime: 2.4946188927 sec, Swap count: 2146, Depth: 538
# Layout trials: 5, Seed: 92349 - Trial 2/3 - Runtime: 2.5625627041 sec, Swap count: 2163, Depth: 597
# Layout trials: 5, Seed: 9116 - Trial 3/3 - Runtime: 2.5192599297 sec, Swap count: 2011, Depth: 471
# Layout trials: 10, Seed: 6006 - Trial 1/3 - Runtime: 2.4741418362 sec, Swap count: 2242, Depth: 479
# Layout trials: 10, Seed: 86673 - Trial 2/3 - Runtime: 2.6054029465 sec, Swap count: 2114, Depth: 504
# Layout trials: 10, Seed: 29871 - Trial 3/3 - Runtime: 2.5043241978 sec, Swap count: 2301, Depth: 502
# Layout trials: 22, Seed: 37930 - Trial 1/3 - Runtime: 2.9499318600 sec, Swap count: 2189, Depth: 567
# Layout trials: 22, Seed: 10458 - Trial 2/3 - Runtime: 3.2123060226 sec, Swap count: 2287, Depth: 523
# Layout trials: 22, Seed: 30512 - Trial 3/3 - Runtime: 3.0223510265 sec, Swap count: 2196, Depth: 539
# Layout trials: 46, Seed: 13238 - Trial 1/3 - Runtime: 4.3392491341 sec, Swap count: 2116, Depth: 541
# Layout trials: 46, Seed: 49823 - Trial 2/3 - Runtime: 4.2118327618 sec, Swap count: 1919, Depth: 467
# Layout trials: 46, Seed: 36434 - Trial 3/3 - Runtime: 4.4715068340 sec, Swap count: 2135, Depth: 522
# Layout trials: 100, Seed: 59429 - Trial 1/3 - Runtime: 8.3547739983 sec, Swap count: 2089, Depth: 508
# Layout trials: 100, Seed: 83320 - Trial 2/3 - Runtime: 8.3596630096 sec, Swap count: 2084, Depth: 546
# Layout trials: 100, Seed: 47819 - Trial 3/3 - Runtime: 8.0072109699 sec, Swap count: 2043, Depth: 522
# Layout trials: 215, Seed: 21319 - Trial 1/3 - Runtime: 16.3976109028 sec, Swap count: 2016, Depth: 508
# Layout trials: 215, Seed: 48520 - Trial 2/3 - Runtime: 16.5113341808 sec, Swap count: 1885, Depth: 479
# Layout trials: 215, Seed: 46566 - Trial 3/3 - Runtime: 15.9862372875 sec, Swap count: 1978, Depth: 501
# Layout trials: 464, Seed: 27460 - Trial 1/3 - Runtime: 34.1660020351 sec, Swap count: 1849, Depth: 466
# Layout trials: 464, Seed: 87841 - Trial 2/3 - Runtime: 35.0057008266 sec, Swap count: 1939, Depth: 481
# Layout trials: 464, Seed: 34993 - Trial 3/3 - Runtime: 34.7993929386 sec, Swap count: 1822, Depth: 478
# Layout trials: 1000, Seed: 91988 - Trial 1/3 - Runtime: 64.4286379814 sec, Swap count: 1861, Depth: 461
# Layout trials: 1000, Seed: 89593 - Trial 2/3 - Runtime: 59.9877119064 sec, Swap count: 1985, Depth: 539
# Layout trials: 1000, Seed: 84939 - Trial 3/3 - Runtime: 72.1842660904 sec, Swap count: 1894, Depth: 503
# Running experiment for 68 qubits
# Layout trials: 1, Seed: 9358 - Trial 1/3 - Runtime: 6.0336639881 sec, Swap count: 4933, Depth: 894
# Layout trials: 1, Seed: 79840 - Trial 2/3 - Runtime: 6.3742110729 sec, Swap count: 4910, Depth: 952
# Layout trials: 1, Seed: 83227 - Trial 3/3 - Runtime: 6.3125817776 sec, Swap count: 4739, Depth: 846
# Layout trials: 2, Seed: 22431 - Trial 1/3 - Runtime: 4.7588980198 sec, Swap count: 4737, Depth: 881
# Layout trials: 2, Seed: 70010 - Trial 2/3 - Runtime: 5.0039441586 sec, Swap count: 4679, Depth: 824
# Layout trials: 2, Seed: 95568 - Trial 3/3 - Runtime: 4.4522547722 sec, Swap count: 4176, Depth: 788
# Layout trials: 5, Seed: 32087 - Trial 1/3 - Runtime: 4.9546539783 sec, Swap count: 4339, Depth: 790
# Layout trials: 5, Seed: 21417 - Trial 2/3 - Runtime: 5.1361248493 sec, Swap count: 4593, Depth: 788
# Layout trials: 5, Seed: 60589 - Trial 3/3 - Runtime: 4.7398538589 sec, Swap count: 4213, Depth: 726
# Layout trials: 10, Seed: 49735 - Trial 1/3 - Runtime: 4.9519839287 sec, Swap count: 4037, Depth: 673
# Layout trials: 10, Seed: 35382 - Trial 2/3 - Runtime: 5.4180228710 sec, Swap count: 4295, Depth: 873
# Layout trials: 10, Seed: 83886 - Trial 3/3 - Runtime: 4.9941720963 sec, Swap count: 4177, Depth: 831
# Layout trials: 22, Seed: 90198 - Trial 1/3 - Runtime: 7.1187319756 sec, Swap count: 4351, Depth: 734
# Layout trials: 22, Seed: 73000 - Trial 2/3 - Runtime: 7.1747441292 sec, Swap count: 4153, Depth: 801
# Layout trials: 22, Seed: 28785 - Trial 3/3 - Runtime: 6.8968489170 sec, Swap count: 4117, Depth: 773
# Layout trials: 46, Seed: 89733 - Trial 1/3 - Runtime: 11.0744550228 sec, Swap count: 4085, Depth: 785
# Layout trials: 46, Seed: 42504 - Trial 2/3 - Runtime: 10.8203349113 sec, Swap count: 4201, Depth: 810
# Layout trials: 46, Seed: 7331 - Trial 3/3 - Runtime: 11.1378197670 sec, Swap count: 4154, Depth: 832
# Layout trials: 100, Seed: 30021 - Trial 1/3 - Runtime: 20.1315348148 sec, Swap count: 3982, Depth: 727
# Layout trials: 100, Seed: 4207 - Trial 2/3 - Runtime: 20.6860599518 sec, Swap count: 4060, Depth: 783
# Layout trials: 100, Seed: 41347 - Trial 3/3 - Runtime: 20.2996201515 sec, Swap count: 4206, Depth: 751
# Layout trials: 215, Seed: 52581 - Trial 1/3 - Runtime: 41.3177008629 sec, Swap count: 4017, Depth: 694
# Layout trials: 215, Seed: 35093 - Trial 2/3 - Runtime: 41.4165322781 sec, Swap count: 3976, Depth: 664
# Layout trials: 215, Seed: 8675 - Trial 3/3 - Runtime: 40.3139719963 sec, Swap count: 3940, Depth: 775
# Layout trials: 464, Seed: 27653 - Trial 1/3 - Runtime: 84.3563408852 sec, Swap count: 3831, Depth: 719
# Layout trials: 464, Seed: 74341 - Trial 2/3 - Runtime: 83.6669659615 sec, Swap count: 4157, Depth: 838
# Layout trials: 464, Seed: 94098 - Trial 3/3 - Runtime: 84.4731357098 sec, Swap count: 4115, Depth: 775
# Layout trials: 1000, Seed: 41245 - Trial 1/3 - Runtime: 173.2103059292 sec, Swap count: 3602, Depth: 700
# Layout trials: 1000, Seed: 27869 - Trial 2/3 - Runtime: 176.5215089321 sec, Swap count: 4044, Depth: 717
# Layout trials: 1000, Seed: 85909 - Trial 3/3 - Runtime: 107.4111492634 sec, Swap count: 3977, Depth: 697
# Running experiment for 88 qubits
# Layout trials: 1, Seed: 65435 - Trial 1/3 - Runtime: 7.4859950542 sec, Swap count: 9090, Depth: 1291
# Layout trials: 1, Seed: 51856 - Trial 2/3 - Runtime: 8.5181732178 sec, Swap count: 8420, Depth: 1344
# Layout trials: 1, Seed: 84259 - Trial 3/3 - Runtime: 9.5230808258 sec, Swap count: 7811, Depth: 1191
# Layout trials: 2, Seed: 60142 - Trial 1/3 - Runtime: 7.5273530483 sec, Swap count: 7829, Depth: 1063
# Layout trials: 2, Seed: 18726 - Trial 2/3 - Runtime: 7.8069057465 sec, Swap count: 7446, Depth: 1120
# Layout trials: 2, Seed: 34718 - Trial 3/3 - Runtime: 7.7034549713 sec, Swap count: 8128, Depth: 1242
# Layout trials: 5, Seed: 18301 - Trial 1/3 - Runtime: 8.3381140232 sec, Swap count: 7634, Depth: 1038
# Layout trials: 5, Seed: 32325 - Trial 2/3 - Runtime: 8.3093049526 sec, Swap count: 8203, Depth: 1228
# Layout trials: 5, Seed: 97647 - Trial 3/3 - Runtime: 7.3886520863 sec, Swap count: 7360, Depth: 1093
# Layout trials: 10, Seed: 73579 - Trial 1/3 - Runtime: 8.9612069130 sec, Swap count: 7599, Depth: 1113
# Layout trials: 10, Seed: 70644 - Trial 2/3 - Runtime: 8.9017150402 sec, Swap count: 7532, Depth: 1134
# Layout trials: 10, Seed: 34438 - Trial 3/3 - Runtime: 9.3164730072 sec, Swap count: 7419, Depth: 1116
# Layout trials: 22, Seed: 97912 - Trial 1/3 - Runtime: 13.4803380966 sec, Swap count: 7470, Depth: 1085
# Layout trials: 22, Seed: 76622 - Trial 2/3 - Runtime: 12.9975020885 sec, Swap count: 7179, Depth: 1052
# Layout trials: 22, Seed: 56155 - Trial 3/3 - Runtime: 13.7108101845 sec, Swap count: 7358, Depth: 1064
# Layout trials: 46, Seed: 76484 - Trial 1/3 - Runtime: 22.0682549477 sec, Swap count: 7054, Depth: 927
# Layout trials: 46, Seed: 52350 - Trial 2/3 - Runtime: 20.9628658295 sec, Swap count: 7181, Depth: 991
# Layout trials: 46, Seed: 47447 - Trial 3/3 - Runtime: 21.5915448666 sec, Swap count: 7024, Depth: 1063
# Layout trials: 100, Seed: 28746 - Trial 1/3 - Runtime: 40.3984398842 sec, Swap count: 7189, Depth: 1000
# Layout trials: 100, Seed: 18131 - Trial 2/3 - Runtime: 40.3695750237 sec, Swap count: 7101, Depth: 946
# Layout trials: 100, Seed: 66784 - Trial 3/3 - Runtime: 39.4231607914 sec, Swap count: 6704, Depth: 967
# Layout trials: 215, Seed: 64686 - Trial 1/3 - Runtime: 78.8641958237 sec, Swap count: 6862, Depth: 1060
# Layout trials: 215, Seed: 11915 - Trial 2/3 - Runtime: 81.3305888176 sec, Swap count: 7014, Depth: 991
# Layout trials: 215, Seed: 99061 - Trial 3/3 - Runtime: 77.7591340542 sec, Swap count: 7063, Depth: 980
# Layout trials: 464, Seed: 6175 - Trial 1/3 - Runtime: 161.0763270855 sec, Swap count: 6599, Depth: 1049
# Layout trials: 464, Seed: 14371 - Trial 2/3 - Runtime: 166.1797587872 sec, Swap count: 6774, Depth: 951
# Layout trials: 464, Seed: 20033 - Trial 3/3 - Runtime: 165.2828998566 sec, Swap count: 6808, Depth: 1109
# Layout trials: 1000, Seed: 82240 - Trial 1/3 - Runtime: 350.6548109055 sec, Swap count: 6674, Depth: 893
# Layout trials: 1000, Seed: 20969 - Trial 2/3 - Runtime: 344.8500089645 sec, Swap count: 6840, Depth: 1087
# Layout trials: 1000, Seed: 89192 - Trial 3/3 - Runtime: 293.8348021507 sec, Swap count: 6911, Depth: 1136
# Running experiment for 107 qubits
# Layout trials: 1, Seed: 55333 - Trial 1/3 - Runtime: 10.9071450233 sec, Swap count: 11404, Depth: 1542
# Layout trials: 1, Seed: 78172 - Trial 2/3 - Runtime: 11.1205549240 sec, Swap count: 12069, Depth: 1510
# Layout trials: 1, Seed: 8326 - Trial 3/3 - Runtime: 12.9365961552 sec, Swap count: 11936, Depth: 1662
# Layout trials: 2, Seed: 50432 - Trial 1/3 - Runtime: 11.5352249146 sec, Swap count: 12225, Depth: 1688
# Layout trials: 2, Seed: 50019 - Trial 2/3 - Runtime: 11.2261769772 sec, Swap count: 11594, Depth: 1558
# Layout trials: 2, Seed: 78104 - Trial 3/3 - Runtime: 11.4188201427 sec, Swap count: 11520, Depth: 1464
# Layout trials: 5, Seed: 61348 - Trial 1/3 - Runtime: 13.3591861725 sec, Swap count: 10936, Depth: 1572
# Layout trials: 5, Seed: 69352 - Trial 2/3 - Runtime: 12.8095090389 sec, Swap count: 11489, Depth: 1321
# Layout trials: 5, Seed: 32953 - Trial 3/3 - Runtime: 13.7139720917 sec, Swap count: 11604, Depth: 1342
# Layout trials: 10, Seed: 72512 - Trial 1/3 - Runtime: 13.7911727428 sec, Swap count: 10976, Depth: 1357
# Layout trials: 10, Seed: 1504 - Trial 2/3 - Runtime: 14.7711288929 sec, Swap count: 11362, Depth: 1449
# Layout trials: 10, Seed: 89166 - Trial 3/3 - Runtime: 13.8744587898 sec, Swap count: 11590, Depth: 1345
# Layout trials: 22, Seed: 94466 - Trial 1/3 - Runtime: 22.3855671883 sec, Swap count: 10954, Depth: 1421
# Layout trials: 22, Seed: 15014 - Trial 2/3 - Runtime: 21.5053770542 sec, Swap count: 10850, Depth: 1431
# Layout trials: 22, Seed: 89353 - Trial 3/3 - Runtime: 21.4218418598 sec, Swap count: 11380, Depth: 1495
# Layout trials: 46, Seed: 70381 - Trial 1/3 - Runtime: 35.5961112976 sec, Swap count: 11174, Depth: 1355
# Layout trials: 46, Seed: 98419 - Trial 2/3 - Runtime: 34.3811810017 sec, Swap count: 11023, Depth: 1444
# Layout trials: 46, Seed: 34973 - Trial 3/3 - Runtime: 35.9859321117 sec, Swap count: 11079, Depth: 1491
# Layout trials: 100, Seed: 84012 - Trial 1/3 - Runtime: 69.7129290104 sec, Swap count: 11118, Depth: 1345
# Layout trials: 100, Seed: 44587 - Trial 2/3 - Runtime: 72.8191919327 sec, Swap count: 10705, Depth: 1271
# Layout trials: 100, Seed: 14621 - Trial 3/3 - Runtime: 68.0605010986 sec, Swap count: 10698, Depth: 1394
# Layout trials: 215, Seed: 38469 - Trial 1/3 - Runtime: 134.6363439560 sec, Swap count: 10676, Depth: 1296
# Layout trials: 215, Seed: 56985 - Trial 2/3 - Runtime: 134.9175601006 sec, Swap count: 10660, Depth: 1408
# Layout trials: 215, Seed: 20730 - Trial 3/3 - Runtime: 134.1811499596 sec, Swap count: 10506, Depth: 1394
# Layout trials: 464, Seed: 59470 - Trial 1/3 - Runtime: 279.6805248260 sec, Swap count: 10045, Depth: 1246
# Layout trials: 464, Seed: 425 - Trial 2/3 - Runtime: 281.3636429310 sec, Swap count: 10550, Depth: 1358
# Layout trials: 464, Seed: 94646 - Trial 3/3 - Runtime: 286.2938950062 sec, Swap count: 10281, Depth: 1282
# Layout trials: 1000, Seed: 94329 - Trial 1/3 - Runtime: 600.5011250973 sec, Swap count: 10415, Depth: 1358
# Layout trials: 1000, Seed: 34522 - Trial 2/3 - Runtime: 600.9668202400 sec, Swap count: 10475, Depth: 1350
# Layout trials: 1000, Seed: 65612 - Trial 3/3 - Runtime: 614.9970810413 sec, Swap count: 10672, Depth: 1444
# Running experiment for 127 qubits
# Layout trials: 1, Seed: 99871 - Trial 1/3 - Runtime: 26.6078021526 sec, Swap count: 17679, Depth: 1819
# Layout trials: 1, Seed: 23416 - Trial 2/3 - Runtime: 24.6954710484 sec, Swap count: 15839, Depth: 1801
# Layout trials: 1, Seed: 66542 - Trial 3/3 - Runtime: 24.0558562279 sec, Swap count: 17515, Depth: 1905
# Layout trials: 2, Seed: 13947 - Trial 1/3 - Runtime: 9.1508936882 sec, Swap count: 17767, Depth: 1945
# Layout trials: 2, Seed: 81959 - Trial 2/3 - Runtime: 8.4455170631 sec, Swap count: 16377, Depth: 1759
# Layout trials: 2, Seed: 39117 - Trial 3/3 - Runtime: 8.9332659245 sec, Swap count: 16054, Depth: 1700
# Layout trials: 5, Seed: 83748 - Trial 1/3 - Runtime: 10.7800350189 sec, Swap count: 16532, Depth: 1717
# Layout trials: 5, Seed: 66540 - Trial 2/3 - Runtime: 10.5250420570 sec, Swap count: 16275, Depth: 1760
# Layout trials: 5, Seed: 79818 - Trial 3/3 - Runtime: 11.9048719406 sec, Swap count: 15638, Depth: 1681
# Layout trials: 10, Seed: 26071 - Trial 1/3 - Runtime: 14.2296788692 sec, Swap count: 16244, Depth: 1682
# Layout trials: 10, Seed: 20032 - Trial 2/3 - Runtime: 14.7227418423 sec, Swap count: 14890, Depth: 1594
# Layout trials: 10, Seed: 49009 - Trial 3/3 - Runtime: 17.1170430183 sec, Swap count: 15231, Depth: 1637
# Layout trials: 22, Seed: 99943 - Trial 1/3 - Runtime: 26.2338991165 sec, Swap count: 15340, Depth: 1684
# Layout trials: 22, Seed: 21174 - Trial 2/3 - Runtime: 28.9099550247 sec, Swap count: 15926, Depth: 1736
# Layout trials: 22, Seed: 70697 - Trial 3/3 - Runtime: 28.5291519165 sec, Swap count: 16304, Depth: 1818
# Layout trials: 46, Seed: 69514 - Trial 1/3 - Runtime: 50.8750550747 sec, Swap count: 15976, Depth: 1905
# Layout trials: 46, Seed: 74 - Trial 2/3 - Runtime: 53.2164170742 sec, Swap count: 15723, Depth: 1777
# Layout trials: 46, Seed: 78504 - Trial 3/3 - Runtime: 54.1132941246 sec, Swap count: 16116, Depth: 1782
# Layout trials: 100, Seed: 42487 - Trial 1/3 - Runtime: 105.6637310982 sec, Swap count: 15347, Depth: 1604
# Layout trials: 100, Seed: 64042 - Trial 2/3 - Runtime: 104.0622437000 sec, Swap count: 14854, Depth: 1725
# Layout trials: 100, Seed: 2552 - Trial 3/3 - Runtime: 104.5246767998 sec, Swap count: 15544, Depth: 1715
# Layout trials: 215, Seed: 14662 - Trial 1/3 - Runtime: 210.2061591148 sec, Swap count: 14724, Depth: 1454
# Layout trials: 215, Seed: 47576 - Trial 2/3 - Runtime: 198.2814760208 sec, Swap count: 15684, Depth: 1605
# Layout trials: 215, Seed: 40306 - Trial 3/3 - Runtime: 175.7328588963 sec, Swap count: 16009, Depth: 1743
# Layout trials: 464, Seed: 31385 - Trial 1/3 - Runtime: 408.5669109821 sec, Swap count: 14731, Depth: 1532
# Layout trials: 464, Seed: 7592 - Trial 2/3 - Runtime: 446.5802311897 sec, Swap count: 14949, Depth: 1662
# Layout trials: 464, Seed: 31571 - Trial 3/3 - Runtime: 448.6484611034 sec, Swap count: 14991, Depth: 1656
# Layout trials: 1000, Seed: 74364 - Trial 1/3 - Runtime: 938.8437650204 sec, Swap count: 15106, Depth: 1714
# Layout trials: 1000, Seed: 10322 - Trial 2/3 - Runtime: 974.4668977261 sec, Swap count: 14949, Depth: 1541
# Layout trials: 1000, Seed: 11226 - Trial 3/3 - Runtime: 937.4754080772 sec, Swap count: 14790, Depth: 1543
# Results saved to experiments/qft_basic.csv
