# %%
from qiskit.transpiler import CouplingMap
from qiskit.transpiler.passes import SabreLayout, SabreSwap
from utils import file_to_coupling_map, directory_to_circuits, build_pass_manager
import random
import time
import csv
import os
import numpy as np

# %%
def run_experiment(cm_name, qc_name, layout_trials_list=[1, 10, 100, 1000], heuristic="lookahead", num_pass_trials=5, seed=42, output_csv="experiments/experiment_new.csv"):
    """
    Runs a transpilation experiment using SABRE passes on a set of quantum circuits.

    Parameters:
    - cm_name (str): Name of the coupling map file (without extension) located in 'coupling_maps/' directory.
    - qc_name (str): Name of the directory containing quantum circuits to run the experiment on.
    - layout_trials_list (list): List of layout (and swap) trials to run for each circuit. Default is [1, 10, 100, 1000].
    - heuristic (str): Heuristic to use in SabreSwap. Default is "lookahead".
    - num_pass_trials (int): Number of different seeds for running the whole pass. Default is 1.
    - seed (int): Random seed for reproducibility. Default is 42.
    - output_csv (str): Filename for the CSV file where results will be saved. Default is "experiment_results.csv".
    
    Returns:
    - None (Results are saved to a CSV file)
    """
    
    # Set random seed for reproducibility
    random.seed(seed)

    # Load the coupling map and the quantum circuits
    cm = CouplingMap(file_to_coupling_map(f'coupling_maps/{cm_name}.txt'))
    qc_list = directory_to_circuits(f'{qc_name}')

    # Prepare the CSV file
    with open(output_csv, mode='w', newline='') as csvfile:
        fieldnames = ["num_qubits", "layout_trials", "heuristic", "avg_runtime", "avg_swap_count", "avg_depth", "num_pass_trials"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        # Run trials for each circuit
        for qc in qc_list:
            num_qubits = qc.num_qubits
            print(f"Running experiment for {num_qubits} qubits")

            for layout_trials in layout_trials_list:
                seed_list = random.sample(range(0, 100000), num_pass_trials)

                total_runtime = 0
                total_swap_count = 0
                total_depth = 0

                for trial in range(num_pass_trials):
                    # Create the pass manager with the specified layout trials
                    rp = SabreSwap(coupling_map=cm, heuristic=heuristic, seed=seed_list[trial], trials=layout_trials)
                    lp = SabreLayout(coupling_map=cm, routing_pass=rp, seed=seed_list[trial])
                    pm = build_pass_manager(cm, lp, rp)

                    # Run the transpilation pass
                    time_start = time.time()
                    qc_tr = pm.run(qc)
                    time_end = time.time()

                    # Collect the metrics for this trial
                    runtime = time_end - time_start
                    swap_count = qc_tr.count_ops().get('swap', 0)
                    depth = qc_tr.depth(lambda x: x.operation.num_qubits == 2)  # 2-qubit gates

                    total_runtime += runtime
                    total_swap_count += swap_count
                    total_depth += depth

                    print(f"Layout trials: {layout_trials}, Seed: {seed_list[trial]} - Trial {trial+1}/{num_pass_trials} - Runtime: {runtime:.10f} sec, Swap count: {swap_count}, Depth: {depth}")

                # Calculate averages
                avg_runtime = total_runtime / num_pass_trials
                avg_swap_count = total_swap_count / num_pass_trials
                avg_depth = total_depth / num_pass_trials

                # Store averaged results in CSV
                writer.writerow({
                    "num_qubits": num_qubits,
                    "layout_trials": layout_trials,
                    "heuristic": heuristic,
                    "avg_runtime": avg_runtime,
                    "avg_swap_count": avg_swap_count,
                    "avg_depth": avg_depth,
                    "num_pass_trials": num_pass_trials
                })

    print(f"Results saved to {output_csv}")

# %%
# Example usage:

heuristic = "basic"

# Generate log scale values
log_values = np.linspace(0, 3, 10)
linear_values = np.round(10 ** log_values).astype(int)
unique_values = np.unique(np.clip(linear_values, 0, 1000))
layout_trials_list = unique_values.tolist()

run_experiment(cm_name='heavy_hex_127', qc_name='qft', heuristic=heuristic, layout_trials_list=layout_trials_list, num_pass_trials=1, output_csv=f"experiments/qft_{heuristic}.csv")
# Out:
# Running experiment for 10 qubits
# Layout trials: 1, Seed: 83810 - Trial 1/1 - Runtime: 0.3424191475 sec, Swap count: 78, Depth: 70
# Layout trials: 2, Seed: 14592 - Trial 1/1 - Runtime: 0.1973931789 sec, Swap count: 82, Depth: 53
# Layout trials: 5, Seed: 3278 - Trial 1/1 - Runtime: 0.3487510681 sec, Swap count: 65, Depth: 58
# Layout trials: 10, Seed: 97196 - Trial 1/1 - Runtime: 0.3537378311 sec, Swap count: 54, Depth: 60
# Layout trials: 22, Seed: 36048 - Trial 1/1 - Runtime: 0.2600758076 sec, Swap count: 58, Depth: 58
# Layout trials: 46, Seed: 32098 - Trial 1/1 - Runtime: 0.2596747875 sec, Swap count: 62, Depth: 55
# Layout trials: 100, Seed: 29256 - Trial 1/1 - Runtime: 0.4541718960 sec, Swap count: 56, Depth: 52
# Layout trials: 215, Seed: 18289 - Trial 1/1 - Runtime: 0.4169070721 sec, Swap count: 55, Depth: 56
# Layout trials: 464, Seed: 96530 - Trial 1/1 - Runtime: 0.6452269554 sec, Swap count: 52, Depth: 54
# Layout trials: 1000, Seed: 13434 - Trial 1/1 - Runtime: 1.4301378727 sec, Swap count: 56, Depth: 46
# Running experiment for 29 qubits
# Layout trials: 1, Seed: 88696 - Trial 1/1 - Runtime: 0.8848209381 sec, Swap count: 862, Depth: 310
# Layout trials: 2, Seed: 97080 - Trial 1/1 - Runtime: 0.9357829094 sec, Swap count: 831, Depth: 292
# Layout trials: 5, Seed: 71482 - Trial 1/1 - Runtime: 0.6258580685 sec, Swap count: 761, Depth: 268
# Layout trials: 10, Seed: 11395 - Trial 1/1 - Runtime: 0.4858207703 sec, Swap count: 714, Depth: 265
# Layout trials: 22, Seed: 77397 - Trial 1/1 - Runtime: 0.6662251949 sec, Swap count: 630, Depth: 268
# Layout trials: 46, Seed: 55302 - Trial 1/1 - Runtime: 0.8648011684 sec, Swap count: 652, Depth: 221
# Layout trials: 100, Seed: 4165 - Trial 1/1 - Runtime: 1.6672761440 sec, Swap count: 545, Depth: 245
# Layout trials: 215, Seed: 3905 - Trial 1/1 - Runtime: 3.6597759724 sec, Swap count: 604, Depth: 264
# Layout trials: 464, Seed: 12280 - Trial 1/1 - Runtime: 8.8059380054 sec, Swap count: 651, Depth: 245
# Layout trials: 1000, Seed: 28657 - Trial 1/1 - Runtime: 17.9823839664 sec, Swap count: 576, Depth: 239
# Running experiment for 49 qubits
# Layout trials: 1, Seed: 30495 - Trial 1/1 - Runtime: 3.2338290215 sec, Swap count: 2784, Depth: 626
# Layout trials: 2, Seed: 66237 - Trial 1/1 - Runtime: 2.6458592415 sec, Swap count: 2185, Depth: 554
# Layout trials: 5, Seed: 78907 - Trial 1/1 - Runtime: 2.7705059052 sec, Swap count: 2285, Depth: 528
# Layout trials: 10, Seed: 3478 - Trial 1/1 - Runtime: 2.5894880295 sec, Swap count: 2172, Depth: 492
# Layout trials: 22, Seed: 73563 - Trial 1/1 - Runtime: 3.1570811272 sec, Swap count: 2192, Depth: 568
# Layout trials: 46, Seed: 26062 - Trial 1/1 - Runtime: 4.3255341053 sec, Swap count: 1974, Depth: 482
# Layout trials: 100, Seed: 93850 - Trial 1/1 - Runtime: 8.1737537384 sec, Swap count: 2117, Depth: 536
# Layout trials: 215, Seed: 85181 - Trial 1/1 - Runtime: 15.8929779530 sec, Swap count: 2006, Depth: 502
# Layout trials: 464, Seed: 91924 - Trial 1/1 - Runtime: 29.1500003338 sec, Swap count: 1825, Depth: 481
# Layout trials: 1000, Seed: 71426 - Trial 1/1 - Runtime: 70.4006938934 sec, Swap count: 2062, Depth: 475
# Running experiment for 68 qubits
# Layout trials: 1, Seed: 54987 - Trial 1/1 - Runtime: 6.3789732456 sec, Swap count: 4834, Depth: 872
# Layout trials: 2, Seed: 28893 - Trial 1/1 - Runtime: 4.7895901203 sec, Swap count: 4804, Depth: 930
# Layout trials: 5, Seed: 58878 - Trial 1/1 - Runtime: 5.0768971443 sec, Swap count: 4599, Depth: 822
# Layout trials: 10, Seed: 77236 - Trial 1/1 - Runtime: 5.2411489487 sec, Swap count: 4649, Depth: 864
# Layout trials: 22, Seed: 36463 - Trial 1/1 - Runtime: 6.7532780170 sec, Swap count: 4260, Depth: 781
# Layout trials: 46, Seed: 851 - Trial 1/1 - Runtime: 11.1585967541 sec, Swap count: 4165, Depth: 716
# Layout trials: 100, Seed: 99458 - Trial 1/1 - Runtime: 21.2358531952 sec, Swap count: 4322, Depth: 800
# Layout trials: 215, Seed: 20926 - Trial 1/1 - Runtime: 41.1498961449 sec, Swap count: 4252, Depth: 777
# Layout trials: 464, Seed: 91506 - Trial 1/1 - Runtime: 86.3960030079 sec, Swap count: 4114, Depth: 763
# Layout trials: 1000, Seed: 55392 - Trial 1/1 - Runtime: 146.6499631405 sec, Swap count: 4058, Depth: 751
# Running experiment for 88 qubits
# Layout trials: 1, Seed: 44597 - Trial 1/1 - Runtime: 9.8680510521 sec, Swap count: 7531, Depth: 1080
# Layout trials: 2, Seed: 36421 - Trial 1/1 - Runtime: 7.7345011234 sec, Swap count: 7728, Depth: 1088
# Layout trials: 5, Seed: 20379 - Trial 1/1 - Runtime: 8.8852999210 sec, Swap count: 7547, Depth: 1169
# Layout trials: 10, Seed: 28221 - Trial 1/1 - Runtime: 9.7915830612 sec, Swap count: 7362, Depth: 995
# Layout trials: 22, Seed: 44118 - Trial 1/1 - Runtime: 13.4105279446 sec, Swap count: 7520, Depth: 1088
# Layout trials: 46, Seed: 13396 - Trial 1/1 - Runtime: 21.0785210133 sec, Swap count: 7415, Depth: 1162
# Layout trials: 100, Seed: 12156 - Trial 1/1 - Runtime: 40.8548138142 sec, Swap count: 7612, Depth: 1155
# Layout trials: 215, Seed: 49797 - Trial 1/1 - Runtime: 77.7584569454 sec, Swap count: 6993, Depth: 1026
# Layout trials: 464, Seed: 12676 - Trial 1/1 - Runtime: 166.6724340916 sec, Swap count: 6822, Depth: 1051
# Layout trials: 1000, Seed: 47052 - Trial 1/1 - Runtime: 332.6641659737 sec, Swap count: 6801, Depth: 1054
# Running experiment for 107 qubits
# Layout trials: 1, Seed: 45082 - Trial 1/1 - Runtime: 14.8975207806 sec, Swap count: 12543, Depth: 1512
# Layout trials: 2, Seed: 79131 - Trial 1/1 - Runtime: 12.7500877380 sec, Swap count: 11767, Depth: 1349
# Layout trials: 5, Seed: 34671 - Trial 1/1 - Runtime: 14.8362369537 sec, Swap count: 11401, Depth: 1435
# Layout trials: 10, Seed: 5695 - Trial 1/1 - Runtime: 14.8560061455 sec, Swap count: 11432, Depth: 1491
# Layout trials: 22, Seed: 95647 - Trial 1/1 - Runtime: 22.3036630154 sec, Swap count: 10901, Depth: 1280
# Layout trials: 46, Seed: 60217 - Trial 1/1 - Runtime: 36.2181229591 sec, Swap count: 11239, Depth: 1389
# Layout trials: 100, Seed: 70284 - Trial 1/1 - Runtime: 73.4945342541 sec, Swap count: 11259, Depth: 1384
# Layout trials: 215, Seed: 16361 - Trial 1/1 - Runtime: 134.7773392200 sec, Swap count: 10810, Depth: 1331
# Layout trials: 464, Seed: 49615 - Trial 1/1 - Runtime: 288.7852897644 sec, Swap count: 11004, Depth: 1588
# Layout trials: 1000, Seed: 10328 - Trial 1/1 - Runtime: 594.2849552631 sec, Swap count: 10193, Depth: 1327
# Running experiment for 127 qubits
# Layout trials: 1, Seed: 72357 - Trial 1/1 - Runtime: 11.2724981308 sec, Swap count: 16580, Depth: 1962
# Layout trials: 2, Seed: 38427 - Trial 1/1 - Runtime: 10.2366769314 sec, Swap count: 17093, Depth: 1850
# Layout trials: 5, Seed: 82397 - Trial 1/1 - Runtime: 14.2758159637 sec, Swap count: 15387, Depth: 1623
# Layout trials: 10, Seed: 81070 - Trial 1/1 - Runtime: 19.6402430534 sec, Swap count: 15871, Depth: 1691
# Layout trials: 22, Seed: 47400 - Trial 1/1 - Runtime: 32.3416340351 sec, Swap count: 15444, Depth: 1655
# Layout trials: 46, Seed: 75674 - Trial 1/1 - Runtime: 54.1007139683 sec, Swap count: 15200, Depth: 1708
# Layout trials: 100, Seed: 25203 - Trial 1/1 - Runtime: 108.4730627537 sec, Swap count: 14345, Depth: 1448
# Layout trials: 215, Seed: 92349 - Trial 1/1 - Runtime: 189.6088459492 sec, Swap count: 15297, Depth: 1804
# Layout trials: 464, Seed: 9116 - Trial 1/1 - Runtime: 435.3783011436 sec, Swap count: 14897, Depth: 1672
# Layout trials: 1000, Seed: 6006 - Trial 1/1 - Runtime: 931.2204260826 sec, Swap count: 14674, Depth: 1659
# Results saved to experiments/qft_basic.csv
