# %%
from utils import directory_to_circuits, create_and_save_ghz_circuits, create_and_save_qft_circuits, create_and_save_qv_circuits

# %%
# Create and save GHZ circuits
num_qubits = [10, 13, 16, 20] 
save_dir = 'circuits/paper/qft/'
create_and_save_qft_circuits(num_qubits, save_dir)
# Out:
# QFT circuits saved to circuits/paper/qft/

# %%
# Create and save GHZ circuits
num_qubits = [10, 29, 49, 68, 88, 107, 127] 
save_dir = 'circuits/ghz/'
create_and_save_ghz_circuits(num_qubits, save_dir)
# Out:
# GHZ circuits saved to circuits/ghz/

# %%
# Get the GHZ circuits and check that we have the correct number of circuits and 
# that the circuits are correct by checking the first circuit
ghz_circuits = directory_to_circuits(save_dir)
print(f'Number of GHZ circuits: {len(ghz_circuits)}')
qc = ghz_circuits[0]
qc.draw(output = 'mpl', idle_wires = False, scale = 0.5)
# Out:
# Number of GHZ circuits: 7

# %%
# Create and save QFT circuits
num_qubits = [10, 29, 49, 68, 88, 107, 127]
save_dir = 'circuits/qft/'
create_and_save_qft_circuits(num_qubits, save_dir)
# Out:
# QFT circuits saved to circuits/qft/

# %%
# Get the QFT circuits and check that we have the correct number of circuits and
# that the circuits are correct by checking the first circuit
qft_circuits = directory_to_circuits(save_dir)
print(f'Number of QFT circuits: {len(qft_circuits)}')
qc = qft_circuits[0]
qc.draw(output = 'mpl', idle_wires = False, scale = 0.5)
# Out:
# Number of QFT circuits: 7

# %%
# Create and save QV circuits
num_qubits = [10, 29, 49, 68, 88, 107, 127]
depth_list = [10]
save_dir = 'circuits/qv/'
create_and_save_qv_circuits(num_qubits, depth_list, save_dir=save_dir)
# Out:
# Quantum Volume circuits saved to circuits/qv/

# %%
# Get the QV circuits and check that we have the correct number of circuits and
# that the circuits are correct by checking the first circuit
qv_circuits = directory_to_circuits(save_dir)
print(f'Number of QV circuits: {len(qv_circuits)}')
qc = qv_circuits[0]
qc.draw(output = 'mpl', idle_wires = False, scale = 0.5)
# Out:
# Number of QV circuits: 7
