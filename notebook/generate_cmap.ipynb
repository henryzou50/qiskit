# %%
from utils import file_to_coupling_map
from qiskit.transpiler import CouplingMap

# %%
filepath = 'coupling_maps/toyko_20.txt'
cmap = file_to_coupling_map(filepath)
cmap.draw()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=474x477>

# %%
# All coupling maps are in the directory 'coupling_maps/'
# Example coupling map file: Heavy hex 127 will be in 'coupling_maps/heavy_hex_127.txt'

# Confirm for heavy hex 127
filepath = 'coupling_maps/heavy_hex_127.txt'
cmap = file_to_coupling_map(filepath)
cmap.draw()

# %%
# Confirm for square 144
filepath = 'coupling_maps/square_144.txt'
cmap = file_to_coupling_map(filepath)
cmap.draw()

# %%
# Confirm 127 ring 
filepath = 'coupling_maps/ring_127.txt'
cmap = file_to_coupling_map(filepath)
cmap.draw()

# %%
cmap = CouplingMap.from_ring(127)
print(cmap)
