# %%
from qiskit.transpiler import CouplingMap, PassManager
from qiskit.transpiler.passes import SabreLayout, SabreSwap
from qiskit.transpiler.passes import FullAncillaAllocation, EnlargeWithAncilla, ApplyLayout
from qiskit.converters import circuit_to_dag, dag_to_circuit
from utils import file_to_coupling_map, directory_to_circuits
import random
import time
import os
import numpy as np

# %%
seed = 42
random.seed(seed)

cmap_name= "heavy_hex_127.txt"
cmap = file_to_coupling_map(f"coupling_maps/{cmap_name}")
qc_name = "qft"
heuristic = "basic"
curr_seed = 42
qc_list = directory_to_circuits(f"circuits/{qc_name}")

pass_trials_list = sorted(set(np.logspace(0, 3, num=10, dtype=int)))


# CSV file to store the results
csv_path = f"results/trials_{qc_name}_basic.csv"
# Columns are: "swap_count", "depth", "runtime", "num_qubits", "heuristic", "cmap", "trials", "seed"
with open(csv_path, "w") as f:
    f.write("swap_count,depth,runtime,num_qubits,heuristic,cmap,trials,seed\n")

# %%
# Run the circuits
for qc in qc_list:
    num_qubits = qc.num_qubits
    print(f"    Running {qc.name} ")
    # Run the circuits for different number of trials
    for pass_trials in pass_trials_list:
        print(f"Running {pass_trials} trials")
        # Create the sabre pass
        sabre_pass = SabreLayout(cmap, seed=curr_seed, max_iterations=4, swap_trials=pass_trials, layout_trials=pass_trials )
        dag = circuit_to_dag(qc)
        
        # Execute the pass manager
        start = time.time()
        dag_tr = sabre_pass.run(dag)
        end = time.time()
        # Collect the metrics for this trial
        runtime = end - start

        qc_tr = dag_to_circuit(dag_tr)
        swap_count = qc_tr.count_ops().get("swap", 0)
        depth = qc_tr.depth(lambda x: x.operation.num_qubits == 2)

        # Write the results to the CSV file
        # Columns are: "swap_count", "depth", "runtime", "num_qubits", "heuristic", "cmap", "trials", "seed"
        with open(csv_path, "a") as f:
            f.write(f"{swap_count},{depth},{runtime},{num_qubits},{heuristic},{cmap_name},{pass_trials},{curr_seed}\n")
        print(f"            Swap count: {swap_count}, Depth: {depth}, Runtime: {runtime}")
# Out:
#     Running qft_10.qasm
# Running 1 trials
#             Swap count: 57, Depth: 54, Runtime: 0.09294795989990234
# Running 2 trials
#             Swap count: 57, Depth: 54, Runtime: 0.11118507385253906
# Running 4 trials
#             Swap count: 57, Depth: 54, Runtime: 0.14569497108459473
# Running 10 trials
#             Swap count: 54, Depth: 49, Runtime: 0.14858102798461914
# Running 21 trials
#             Swap count: 54, Depth: 49, Runtime: 0.3039836883544922
# Running 46 trials
#             Swap count: 45, Depth: 54, Runtime: 1.0688340663909912
# Running 100 trials
#             Swap count: 45, Depth: 54, Runtime: 4.273427963256836
# Running 215 trials
#             Swap count: 45, Depth: 54, Runtime: 18.419265031814575
# Running 464 trials
#             Swap count: 45, Depth: 54, Runtime: 81.68789672851562
# Running 1000 trials
#             Swap count: 45, Depth: 54, Runtime: 373.1924452781677
#     Running qft_29.qasm
# Running 1 trials
#             Swap count: 670, Depth: 314, Runtime: 0.4887979030609131
# Running 2 trials
#             Swap count: 570, Depth: 297, Runtime: 0.40158700942993164
# Running 4 trials
#             Swap count: 570, Depth: 297, Runtime: 0.42059779167175293
# Running 10 trials
#             Swap count: 531, Depth: 229, Runtime: 0.9818098545074463
# Running 21 trials
#             Swap count: 498, Depth: 301, Runtime: 3.004924774169922
# Running 46 trials
#             Swap count: 498, Depth: 301, Runtime: 11.149003028869629
# Running 100 trials
#             Swap count: 497, Depth: 261, Runtime: 47.477274894714355
# Running 215 trials
#             Swap count: 476, Depth: 247, Runtime: 208.0200309753418
# Running 464 trials
#             Swap count: 464, Depth: 238, Runtime: 944.5802819728851
# Running 1000 trials
#             Swap count: 456, Depth: 236, Runtime: 4333.629837036133
#     Running qft_49.qasm
# Running 1 trials
#             Swap count: 1869, Depth: 673, Runtime: 1.0059447288513184
# Running 2 trials
#             Swap count: 1764, Depth: 660, Runtime: 1.1296980381011963
# Running 4 trials
#             Swap count: 1716, Depth: 616, Runtime: 1.2872602939605713
# Running 10 trials
#             Swap count: 1695, Depth: 522, Runtime: 3.080609083175659
# Running 21 trials
#             Swap count: 1580, Depth: 619, Runtime: 9.073667049407959
# Running 46 trials
#             Swap count: 1514, Depth: 469, Runtime: 34.51214289665222
# Running 100 trials
#             Swap count: 1514, Depth: 469, Runtime: 147.3162772655487
# Running 215 trials
#             Swap count: 1399, Depth: 336, Runtime: 648.223112821579
# Running 464 trials
#             Swap count: 1354, Depth: 524, Runtime: 2958.7701408863068
# Running 1000 trials
#             Swap count: 1354, Depth: 524, Runtime: 13578.089781999588
#     Running qft_68.qasm
# Running 1 trials
#             Swap count: 3945, Depth: 1451, Runtime: 1.9365780353546143
# Running 2 trials
#             Swap count: 3585, Depth: 1166, Runtime: 2.0896809101104736
# Running 4 trials
#             Swap count: 3244, Depth: 1127, Runtime: 2.6046059131622314
# Running 10 trials
#             Swap count: 3185, Depth: 1078, Runtime: 6.00493597984314
# Running 21 trials
#             Swap count: 3142, Depth: 1045, Runtime: 17.917658805847168
# Running 46 trials
#             Swap count: 3075, Depth: 870, Runtime: 70.44585108757019
# Running 100 trials
#             Swap count: 2917, Depth: 868, Runtime: 299.39364671707153
# Running 215 trials
#             Swap count: 2718, Depth: 781, Runtime: 1312.6124217510223
# Running 464 trials
