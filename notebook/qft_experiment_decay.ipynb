# %%
from qiskit.transpiler import CouplingMap
from qiskit.transpiler.passes import SabreLayout, SabreSwap
from utils import file_to_coupling_map, directory_to_circuits, build_pass_manager
import random
import time
import csv
import os
import numpy as np

# %%
def run_experiment(cm_name, qc_name, layout_trials_list=[1, 10, 100, 1000], heuristic="lookahead", num_pass_trials=5, seed=42, output_csv="experiments/experiment_new.csv"):
    """
    Runs a transpilation experiment using SABRE passes on a set of quantum circuits.

    Parameters:
    - cm_name (str): Name of the coupling map file (without extension) located in 'coupling_maps/' directory.
    - qc_name (str): Name of the directory containing quantum circuits to run the experiment on.
    - layout_trials_list (list): List of layout (and swap) trials to run for each circuit. Default is [1, 10, 100, 1000].
    - heuristic (str): Heuristic to use in SabreSwap. Default is "lookahead".
    - num_pass_trials (int): Number of different seeds for running the whole pass. Default is 1.
    - seed (int): Random seed for reproducibility. Default is 42.
    - output_csv (str): Filename for the CSV file where results will be saved. Default is "experiment_results.csv".
    
    Returns:
    - None (Results are saved to a CSV file)
    """
    
    # Set random seed for reproducibility
    random.seed(seed)

    # Load the coupling map and the quantum circuits
    cm = CouplingMap(file_to_coupling_map(f'coupling_maps/{cm_name}.txt'))
    qc_list = directory_to_circuits(f'{qc_name}')

    # Prepare the CSV file
    with open(output_csv, mode='w', newline='') as csvfile:
        fieldnames = ["num_qubits", "layout_trials", "heuristic", "avg_runtime", "avg_swap_count", "avg_depth", "num_pass_trials"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        # Run trials for each circuit
        for qc in qc_list:
            num_qubits = qc.num_qubits
            print(f"Running experiment for {num_qubits} qubits")

            for layout_trials in layout_trials_list:
                seed_list = random.sample(range(0, 100000), num_pass_trials)

                total_runtime = 0
                total_swap_count = 0
                total_depth = 0

                for trial in range(num_pass_trials):
                    # Create the pass manager with the specified layout trials
                    rp = SabreSwap(coupling_map=cm, heuristic=heuristic, seed=seed_list[trial], trials=layout_trials)
                    lp = SabreLayout(coupling_map=cm, routing_pass=rp, seed=seed_list[trial])
                    pm = build_pass_manager(cm, lp, rp)

                    # Run the transpilation pass
                    time_start = time.time()
                    qc_tr = pm.run(qc)
                    time_end = time.time()

                    # Collect the metrics for this trial
                    runtime = time_end - time_start
                    swap_count = qc_tr.count_ops().get('swap', 0)
                    depth = qc_tr.depth(lambda x: x.operation.num_qubits == 2)  # 2-qubit gates

                    total_runtime += runtime
                    total_swap_count += swap_count
                    total_depth += depth

                    print(f"Layout trials: {layout_trials}, Seed: {seed_list[trial]} - Trial {trial+1}/{num_pass_trials} - Runtime: {runtime:.10f} sec, Swap count: {swap_count}, Depth: {depth}")

                # Calculate averages
                avg_runtime = total_runtime / num_pass_trials
                avg_swap_count = total_swap_count / num_pass_trials
                avg_depth = total_depth / num_pass_trials

                # Store averaged results in CSV
                writer.writerow({
                    "num_qubits": num_qubits,
                    "layout_trials": layout_trials,
                    "heuristic": heuristic,
                    "avg_runtime": avg_runtime,
                    "avg_swap_count": avg_swap_count,
                    "avg_depth": avg_depth,
                    "num_pass_trials": num_pass_trials
                })

    print(f"Results saved to {output_csv}")

# %%
# Example usage:

heuristic = "decay"

# Generate log scale values
log_values = np.linspace(0, 3, 10)
linear_values = np.round(10 ** log_values).astype(int)
unique_values = np.unique(np.clip(linear_values, 0, 1000))
layout_trials_list = unique_values.tolist()

run_experiment(cm_name='heavy_hex_127', qc_name='qft', heuristic=heuristic, layout_trials_list=layout_trials_list, num_pass_trials=3, output_csv=f"experiments/qft_{heuristic}.csv")
# Out:
# Running experiment for 10 qubits
# Layout trials: 1, Seed: 83810 - Trial 1/3 - Runtime: 0.1138486862 sec, Swap count: 65, Depth: 63
# Layout trials: 1, Seed: 14592 - Trial 2/3 - Runtime: 0.0767452717 sec, Swap count: 73, Depth: 61
# Layout trials: 1, Seed: 3278 - Trial 3/3 - Runtime: 0.1063098907 sec, Swap count: 59, Depth: 57
# Layout trials: 2, Seed: 97196 - Trial 1/3 - Runtime: 0.1457550526 sec, Swap count: 72, Depth: 68
# Layout trials: 2, Seed: 36048 - Trial 2/3 - Runtime: 0.0769391060 sec, Swap count: 66, Depth: 67
# Layout trials: 2, Seed: 32098 - Trial 3/3 - Runtime: 0.1557359695 sec, Swap count: 55, Depth: 51
# Layout trials: 5, Seed: 29256 - Trial 1/3 - Runtime: 0.1765470505 sec, Swap count: 56, Depth: 58
# Layout trials: 5, Seed: 18289 - Trial 2/3 - Runtime: 0.1022460461 sec, Swap count: 59, Depth: 54
# Layout trials: 5, Seed: 96530 - Trial 3/3 - Runtime: 0.1597092152 sec, Swap count: 50, Depth: 54
# Layout trials: 10, Seed: 13434 - Trial 1/3 - Runtime: 0.2187399864 sec, Swap count: 60, Depth: 64
# Layout trials: 10, Seed: 88696 - Trial 2/3 - Runtime: 0.1497271061 sec, Swap count: 68, Depth: 61
# Layout trials: 10, Seed: 97080 - Trial 3/3 - Runtime: 0.1607379913 sec, Swap count: 54, Depth: 54
# Layout trials: 22, Seed: 71482 - Trial 1/3 - Runtime: 0.1990520954 sec, Swap count: 54, Depth: 58
# Layout trials: 22, Seed: 11395 - Trial 2/3 - Runtime: 0.1429851055 sec, Swap count: 45, Depth: 56
# Layout trials: 22, Seed: 77397 - Trial 3/3 - Runtime: 0.1443212032 sec, Swap count: 58, Depth: 50
# Layout trials: 46, Seed: 55302 - Trial 1/3 - Runtime: 0.1948988438 sec, Swap count: 48, Depth: 54
# Layout trials: 46, Seed: 4165 - Trial 2/3 - Runtime: 0.2056877613 sec, Swap count: 54, Depth: 52
# Layout trials: 46, Seed: 3905 - Trial 3/3 - Runtime: 0.2258508205 sec, Swap count: 52, Depth: 57
# Layout trials: 100, Seed: 12280 - Trial 1/3 - Runtime: 0.3260419369 sec, Swap count: 55, Depth: 58
# Layout trials: 100, Seed: 28657 - Trial 2/3 - Runtime: 0.4204328060 sec, Swap count: 59, Depth: 64
# Layout trials: 100, Seed: 30495 - Trial 3/3 - Runtime: 0.3541078568 sec, Swap count: 56, Depth: 59
# Layout trials: 215, Seed: 66237 - Trial 1/3 - Runtime: 0.6493949890 sec, Swap count: 50, Depth: 51
# Layout trials: 215, Seed: 78907 - Trial 2/3 - Runtime: 0.7413921356 sec, Swap count: 51, Depth: 56
# Layout trials: 215, Seed: 3478 - Trial 3/3 - Runtime: 0.8289179802 sec, Swap count: 54, Depth: 61
# Layout trials: 464, Seed: 73563 - Trial 1/3 - Runtime: 1.6622002125 sec, Swap count: 55, Depth: 54
# Layout trials: 464, Seed: 26062 - Trial 2/3 - Runtime: 2.0394239426 sec, Swap count: 56, Depth: 52
# Layout trials: 464, Seed: 93850 - Trial 3/3 - Runtime: 2.3720180988 sec, Swap count: 54, Depth: 61
# Layout trials: 1000, Seed: 85181 - Trial 1/3 - Runtime: 5.6529653072 sec, Swap count: 62, Depth: 62
# Layout trials: 1000, Seed: 91924 - Trial 2/3 - Runtime: 5.7132947445 sec, Swap count: 65, Depth: 60
# Layout trials: 1000, Seed: 71426 - Trial 3/3 - Runtime: 4.5889949799 sec, Swap count: 45, Depth: 53
# Running experiment for 29 qubits
# Layout trials: 1, Seed: 54987 - Trial 1/3 - Runtime: 1.2447862625 sec, Swap count: 672, Depth: 273
# Layout trials: 1, Seed: 28893 - Trial 2/3 - Runtime: 1.4761838913 sec, Swap count: 671, Depth: 317
# Layout trials: 1, Seed: 58878 - Trial 3/3 - Runtime: 1.5181748867 sec, Swap count: 660, Depth: 302
# Layout trials: 2, Seed: 77236 - Trial 1/3 - Runtime: 0.9198451042 sec, Swap count: 671, Depth: 304
# Layout trials: 2, Seed: 36463 - Trial 2/3 - Runtime: 1.1517541409 sec, Swap count: 579, Depth: 281
# Layout trials: 2, Seed: 851 - Trial 3/3 - Runtime: 0.9614238739 sec, Swap count: 676, Depth: 298
# Layout trials: 5, Seed: 99458 - Trial 1/3 - Runtime: 1.0307600498 sec, Swap count: 582, Depth: 269
# Layout trials: 5, Seed: 20926 - Trial 2/3 - Runtime: 1.1401860714 sec, Swap count: 611, Depth: 283
# Layout trials: 5, Seed: 91506 - Trial 3/3 - Runtime: 1.2301318645 sec, Swap count: 531, Depth: 201
# Layout trials: 10, Seed: 55392 - Trial 1/3 - Runtime: 0.8342819214 sec, Swap count: 553, Depth: 265
# Layout trials: 10, Seed: 44597 - Trial 2/3 - Runtime: 0.9107992649 sec, Swap count: 564, Depth: 240
# Layout trials: 10, Seed: 36421 - Trial 3/3 - Runtime: 0.8652269840 sec, Swap count: 558, Depth: 245
# Layout trials: 22, Seed: 20379 - Trial 1/3 - Runtime: 1.1804690361 sec, Swap count: 540, Depth: 266
# Layout trials: 22, Seed: 28221 - Trial 2/3 - Runtime: 1.2928669453 sec, Swap count: 546, Depth: 215
# Layout trials: 22, Seed: 44118 - Trial 3/3 - Runtime: 1.3936550617 sec, Swap count: 528, Depth: 304
# Layout trials: 46, Seed: 13396 - Trial 1/3 - Runtime: 2.5791859627 sec, Swap count: 534, Depth: 236
# Layout trials: 46, Seed: 12156 - Trial 2/3 - Runtime: 2.7459700108 sec, Swap count: 555, Depth: 335
# Layout trials: 46, Seed: 49797 - Trial 3/3 - Runtime: 2.5015690327 sec, Swap count: 595, Depth: 264
# Layout trials: 100, Seed: 12676 - Trial 1/3 - Runtime: 4.5982661247 sec, Swap count: 523, Depth: 242
# Layout trials: 100, Seed: 47052 - Trial 2/3 - Runtime: 4.9636220932 sec, Swap count: 547, Depth: 257
# Layout trials: 100, Seed: 45082 - Trial 3/3 - Runtime: 5.2877759933 sec, Swap count: 533, Depth: 195
# Layout trials: 215, Seed: 79131 - Trial 1/3 - Runtime: 9.5683379173 sec, Swap count: 591, Depth: 323
# Layout trials: 215, Seed: 34671 - Trial 2/3 - Runtime: 9.7846550941 sec, Swap count: 524, Depth: 267
# Layout trials: 215, Seed: 5695 - Trial 3/3 - Runtime: 10.3761641979 sec, Swap count: 523, Depth: 248
# Layout trials: 464, Seed: 95647 - Trial 1/3 - Runtime: 24.4454841614 sec, Swap count: 556, Depth: 288
# Layout trials: 464, Seed: 60217 - Trial 2/3 - Runtime: 26.4362301826 sec, Swap count: 487, Depth: 205
# Layout trials: 464, Seed: 70284 - Trial 3/3 - Runtime: 27.3455910683 sec, Swap count: 489, Depth: 214
# Layout trials: 1000, Seed: 16361 - Trial 1/3 - Runtime: 60.7144980431 sec, Swap count: 518, Depth: 258
# Layout trials: 1000, Seed: 49615 - Trial 2/3 - Runtime: 62.7928259373 sec, Swap count: 547, Depth: 270
# Layout trials: 1000, Seed: 10328 - Trial 3/3 - Runtime: 56.9076690674 sec, Swap count: 474, Depth: 194
# Running experiment for 49 qubits
# Layout trials: 1, Seed: 72357 - Trial 1/3 - Runtime: 3.8346669674 sec, Swap count: 1983, Depth: 725
# Layout trials: 1, Seed: 38427 - Trial 2/3 - Runtime: 4.3639752865 sec, Swap count: 1928, Depth: 645
# Layout trials: 1, Seed: 82397 - Trial 3/3 - Runtime: 2.9905259609 sec, Swap count: 2046, Depth: 781
# Layout trials: 2, Seed: 81070 - Trial 1/3 - Runtime: 1.8413548470 sec, Swap count: 1913, Depth: 710
# Layout trials: 2, Seed: 47400 - Trial 2/3 - Runtime: 1.9096810818 sec, Swap count: 1920, Depth: 669
# Layout trials: 2, Seed: 75674 - Trial 3/3 - Runtime: 1.8245279789 sec, Swap count: 1851, Depth: 587
# Layout trials: 5, Seed: 25203 - Trial 1/3 - Runtime: 2.1160078049 sec, Swap count: 1742, Depth: 626
# Layout trials: 5, Seed: 92349 - Trial 2/3 - Runtime: 2.0276710987 sec, Swap count: 1567, Depth: 553
# Layout trials: 5, Seed: 9116 - Trial 3/3 - Runtime: 2.1247332096 sec, Swap count: 1888, Depth: 759
# Layout trials: 10, Seed: 6006 - Trial 1/3 - Runtime: 2.6152968407 sec, Swap count: 1739, Depth: 535
# Layout trials: 10, Seed: 86673 - Trial 2/3 - Runtime: 2.5135638714 sec, Swap count: 1697, Depth: 602
# Layout trials: 10, Seed: 29871 - Trial 3/3 - Runtime: 2.5265889168 sec, Swap count: 1872, Depth: 724
# Layout trials: 22, Seed: 37930 - Trial 1/3 - Runtime: 4.5141072273 sec, Swap count: 1555, Depth: 658
# Layout trials: 22, Seed: 10458 - Trial 2/3 - Runtime: 4.5838088989 sec, Swap count: 1497, Depth: 492
# Layout trials: 22, Seed: 30512 - Trial 3/3 - Runtime: 5.0107131004 sec, Swap count: 1580, Depth: 607
# Layout trials: 46, Seed: 13238 - Trial 1/3 - Runtime: 9.4476518631 sec, Swap count: 1549, Depth: 493
# Layout trials: 46, Seed: 49823 - Trial 2/3 - Runtime: 9.8178617954 sec, Swap count: 1787, Depth: 682
# Layout trials: 46, Seed: 36434 - Trial 3/3 - Runtime: 9.4830191135 sec, Swap count: 1581, Depth: 572
# Layout trials: 100, Seed: 59429 - Trial 1/3 - Runtime: 19.4135718346 sec, Swap count: 1480, Depth: 677
# Layout trials: 100, Seed: 83320 - Trial 2/3 - Runtime: 20.5638699532 sec, Swap count: 1604, Depth: 563
# Layout trials: 100, Seed: 47819 - Trial 3/3 - Runtime: 19.5820841789 sec, Swap count: 1600, Depth: 534
# Layout trials: 215, Seed: 21319 - Trial 1/3 - Runtime: 33.7256829739 sec, Swap count: 1520, Depth: 584
# Layout trials: 215, Seed: 48520 - Trial 2/3 - Runtime: 33.2379291058 sec, Swap count: 1422, Depth: 381
# Layout trials: 215, Seed: 46566 - Trial 3/3 - Runtime: 35.4468431473 sec, Swap count: 1492, Depth: 578
# Layout trials: 464, Seed: 27460 - Trial 1/3 - Runtime: 81.5808019638 sec, Swap count: 1621, Depth: 639
# Layout trials: 464, Seed: 87841 - Trial 2/3 - Runtime: 87.1746580601 sec, Swap count: 1633, Depth: 497
# Layout trials: 464, Seed: 34993 - Trial 3/3 - Runtime: 86.7090249062 sec, Swap count: 1477, Depth: 635
# Layout trials: 1000, Seed: 91988 - Trial 1/3 - Runtime: 184.3276622295 sec, Swap count: 1447, Depth: 363
# Layout trials: 1000, Seed: 89593 - Trial 2/3 - Runtime: 187.7601900101 sec, Swap count: 1492, Depth: 458
# Layout trials: 1000, Seed: 84939 - Trial 3/3 - Runtime: 186.4596071243 sec, Swap count: 1367, Depth: 376
# Running experiment for 68 qubits
# Layout trials: 1, Seed: 9358 - Trial 1/3 - Runtime: 7.8487720490 sec, Swap count: 4069, Depth: 1834
# Layout trials: 1, Seed: 79840 - Trial 2/3 - Runtime: 5.9526960850 sec, Swap count: 3879, Depth: 1315
# Layout trials: 1, Seed: 83227 - Trial 3/3 - Runtime: 5.6702208519 sec, Swap count: 4159, Depth: 1364
# Layout trials: 2, Seed: 22431 - Trial 1/3 - Runtime: 3.7325029373 sec, Swap count: 3867, Depth: 1219
# Layout trials: 2, Seed: 70010 - Trial 2/3 - Runtime: 3.6765098572 sec, Swap count: 3278, Depth: 952
# Layout trials: 2, Seed: 95568 - Trial 3/3 - Runtime: 3.0308101177 sec, Swap count: 3976, Depth: 1322
# Layout trials: 5, Seed: 32087 - Trial 1/3 - Runtime: 2.7686710358 sec, Swap count: 3496, Depth: 1002
# Layout trials: 5, Seed: 21417 - Trial 2/3 - Runtime: 2.6956000328 sec, Swap count: 3747, Depth: 1166
# Layout trials: 5, Seed: 60589 - Trial 3/3 - Runtime: 2.8989577293 sec, Swap count: 3436, Depth: 965
# Layout trials: 10, Seed: 49735 - Trial 1/3 - Runtime: 3.5362477303 sec, Swap count: 3321, Depth: 986
# Layout trials: 10, Seed: 35382 - Trial 2/3 - Runtime: 3.7619106770 sec, Swap count: 3202, Depth: 900
# Layout trials: 10, Seed: 83886 - Trial 3/3 - Runtime: 4.2915799618 sec, Swap count: 3910, Depth: 1458
# Layout trials: 22, Seed: 90198 - Trial 1/3 - Runtime: 7.6581101418 sec, Swap count: 3805, Depth: 1145
# Layout trials: 22, Seed: 73000 - Trial 2/3 - Runtime: 7.8686161041 sec, Swap count: 3327, Depth: 1123
# Layout trials: 22, Seed: 28785 - Trial 3/3 - Runtime: 7.7268102169 sec, Swap count: 3233, Depth: 1069
# Layout trials: 46, Seed: 89733 - Trial 1/3 - Runtime: 14.1835379601 sec, Swap count: 2844, Depth: 987
# Layout trials: 46, Seed: 42504 - Trial 2/3 - Runtime: 16.1447138786 sec, Swap count: 3193, Depth: 851
# Layout trials: 46, Seed: 7331 - Trial 3/3 - Runtime: 14.0529100895 sec, Swap count: 3253, Depth: 1026
# Layout trials: 100, Seed: 30021 - Trial 1/3 - Runtime: 27.6495900154 sec, Swap count: 3265, Depth: 1163
# Layout trials: 100, Seed: 4207 - Trial 2/3 - Runtime: 29.0597331524 sec, Swap count: 3193, Depth: 1142
# Layout trials: 100, Seed: 41347 - Trial 3/3 - Runtime: 31.3763389587 sec, Swap count: 3414, Depth: 1187
# Layout trials: 215, Seed: 52581 - Trial 1/3 - Runtime: 74.4475519657 sec, Swap count: 3050, Depth: 899
# Layout trials: 215, Seed: 35093 - Trial 2/3 - Runtime: 76.6457440853 sec, Swap count: 3048, Depth: 891
# Layout trials: 215, Seed: 8675 - Trial 3/3 - Runtime: 79.7948479652 sec, Swap count: 3319, Depth: 1206
# Layout trials: 464, Seed: 27653 - Trial 1/3 - Runtime: 173.5223989487 sec, Swap count: 3048, Depth: 821
# Layout trials: 464, Seed: 74341 - Trial 2/3 - Runtime: 175.2426152229 sec, Swap count: 3299, Depth: 1427
# Layout trials: 464, Seed: 94098 - Trial 3/3 - Runtime: 172.5464670658 sec, Swap count: 3125, Depth: 919
# Layout trials: 1000, Seed: 41245 - Trial 1/3 - Runtime: 383.1515331268 sec, Swap count: 3164, Depth: 1067
# Layout trials: 1000, Seed: 27869 - Trial 2/3 - Runtime: 374.4084270000 sec, Swap count: 2844, Depth: 733
# Layout trials: 1000, Seed: 85909 - Trial 3/3 - Runtime: 380.0748066902 sec, Swap count: 2762, Depth: 769
# Running experiment for 88 qubits
# Layout trials: 1, Seed: 65435 - Trial 1/3 - Runtime: 10.1385629177 sec, Swap count: 6882, Depth: 2177
# Layout trials: 1, Seed: 51856 - Trial 2/3 - Runtime: 9.9743092060 sec, Swap count: 7523, Depth: 2113
# Layout trials: 1, Seed: 84259 - Trial 3/3 - Runtime: 9.9165508747 sec, Swap count: 7686, Depth: 2391
# Layout trials: 2, Seed: 60142 - Trial 1/3 - Runtime: 7.8373389244 sec, Swap count: 6357, Depth: 1961
# Layout trials: 2, Seed: 18726 - Trial 2/3 - Runtime: 7.5100789070 sec, Swap count: 6667, Depth: 1879
# Layout trials: 2, Seed: 34718 - Trial 3/3 - Runtime: 8.1299378872 sec, Swap count: 6668, Depth: 1984
# Layout trials: 5, Seed: 18301 - Trial 1/3 - Runtime: 8.9565932751 sec, Swap count: 5341, Depth: 1572
# Layout trials: 5, Seed: 32325 - Trial 2/3 - Runtime: 8.3982379436 sec, Swap count: 5805, Depth: 1853
# Layout trials: 5, Seed: 97647 - Trial 3/3 - Runtime: 5.4293220043 sec, Swap count: 5956, Depth: 1612
# Layout trials: 10, Seed: 73579 - Trial 1/3 - Runtime: 7.6923661232 sec, Swap count: 5897, Depth: 2408
# Layout trials: 10, Seed: 70644 - Trial 2/3 - Runtime: 7.4050717354 sec, Swap count: 6260, Depth: 2042
# Layout trials: 10, Seed: 34438 - Trial 3/3 - Runtime: 7.6166148186 sec, Swap count: 5628, Depth: 1398
# Layout trials: 22, Seed: 97912 - Trial 1/3 - Runtime: 13.7588260174 sec, Swap count: 6070, Depth: 1460
# Layout trials: 22, Seed: 76622 - Trial 2/3 - Runtime: 14.3179941177 sec, Swap count: 5604, Depth: 1887
# Layout trials: 22, Seed: 56155 - Trial 3/3 - Runtime: 14.1153469086 sec, Swap count: 5806, Depth: 1822
# Layout trials: 46, Seed: 76484 - Trial 1/3 - Runtime: 27.2458639145 sec, Swap count: 5636, Depth: 1606
# Layout trials: 46, Seed: 52350 - Trial 2/3 - Runtime: 29.1898071766 sec, Swap count: 5590, Depth: 1302
# Layout trials: 46, Seed: 47447 - Trial 3/3 - Runtime: 28.4643578529 sec, Swap count: 5146, Depth: 1285
# Layout trials: 100, Seed: 28746 - Trial 1/3 - Runtime: 61.7824130058 sec, Swap count: 5182, Depth: 1283
# Layout trials: 100, Seed: 18131 - Trial 2/3 - Runtime: 66.8430039883 sec, Swap count: 5364, Depth: 1526
# Layout trials: 100, Seed: 66784 - Trial 3/3 - Runtime: 65.5421259403 sec, Swap count: 5077, Depth: 1676
# Layout trials: 215, Seed: 64686 - Trial 1/3 - Runtime: 139.4945328236 sec, Swap count: 5347, Depth: 1521
# Layout trials: 215, Seed: 11915 - Trial 2/3 - Runtime: 144.3080639839 sec, Swap count: 5780, Depth: 2169
# Layout trials: 215, Seed: 99061 - Trial 3/3 - Runtime: 146.5957510471 sec, Swap count: 5181, Depth: 1552
# Layout trials: 464, Seed: 6175 - Trial 1/3 - Runtime: 304.7401967049 sec, Swap count: 4479, Depth: 907
# Layout trials: 464, Seed: 14371 - Trial 2/3 - Runtime: 314.0172038078 sec, Swap count: 5156, Depth: 1113
# Layout trials: 464, Seed: 20033 - Trial 3/3 - Runtime: 308.7998530865 sec, Swap count: 4879, Depth: 1334
# Layout trials: 1000, Seed: 82240 - Trial 1/3 - Runtime: 668.2881700993 sec, Swap count: 4978, Depth: 1246
# Layout trials: 1000, Seed: 20969 - Trial 2/3 - Runtime: 660.4444777966 sec, Swap count: 4647, Depth: 1274
# Layout trials: 1000, Seed: 89192 - Trial 3/3 - Runtime: 651.2779068947 sec, Swap count: 5282, Depth: 1407
# Running experiment for 107 qubits
# Layout trials: 1, Seed: 55333 - Trial 1/3 - Runtime: 12.9084932804 sec, Swap count: 10679, Depth: 3464
# Layout trials: 1, Seed: 78172 - Trial 2/3 - Runtime: 9.2116699219 sec, Swap count: 9894, Depth: 3882
# Layout trials: 1, Seed: 8326 - Trial 3/3 - Runtime: 9.3455221653 sec, Swap count: 9533, Depth: 2657
# Layout trials: 2, Seed: 50432 - Trial 1/3 - Runtime: 8.1956450939 sec, Swap count: 10003, Depth: 2785
# Layout trials: 2, Seed: 50019 - Trial 2/3 - Runtime: 8.1884317398 sec, Swap count: 8649, Depth: 2341
# Layout trials: 2, Seed: 78104 - Trial 3/3 - Runtime: 8.2285230160 sec, Swap count: 10766, Depth: 2642
# Layout trials: 5, Seed: 61348 - Trial 1/3 - Runtime: 10.0336399078 sec, Swap count: 8899, Depth: 2812
# Layout trials: 5, Seed: 69352 - Trial 2/3 - Runtime: 10.9494299889 sec, Swap count: 9476, Depth: 3003
# Layout trials: 5, Seed: 32953 - Trial 3/3 - Runtime: 10.7830219269 sec, Swap count: 9383, Depth: 2740
# Layout trials: 10, Seed: 72512 - Trial 1/3 - Runtime: 13.7029690742 sec, Swap count: 9551, Depth: 2976
# Layout trials: 10, Seed: 1504 - Trial 2/3 - Runtime: 13.9244022369 sec, Swap count: 9638, Depth: 2823
# Layout trials: 10, Seed: 89166 - Trial 3/3 - Runtime: 15.9589822292 sec, Swap count: 8559, Depth: 2395
# Layout trials: 22, Seed: 94466 - Trial 1/3 - Runtime: 26.4519019127 sec, Swap count: 8535, Depth: 2375
# Layout trials: 22, Seed: 15014 - Trial 2/3 - Runtime: 26.7422001362 sec, Swap count: 8812, Depth: 2213
# Layout trials: 22, Seed: 89353 - Trial 3/3 - Runtime: 20.4936268330 sec, Swap count: 8933, Depth: 1949
# Layout trials: 46, Seed: 70381 - Trial 1/3 - Runtime: 52.4008920193 sec, Swap count: 8266, Depth: 2134
# Layout trials: 46, Seed: 98419 - Trial 2/3 - Runtime: 50.3688161373 sec, Swap count: 8942, Depth: 2326
# Layout trials: 46, Seed: 34973 - Trial 3/3 - Runtime: 49.5299990177 sec, Swap count: 7626, Depth: 2482
# Layout trials: 100, Seed: 84012 - Trial 1/3 - Runtime: 109.3658370972 sec, Swap count: 8075, Depth: 2133
# Layout trials: 100, Seed: 44587 - Trial 2/3 - Runtime: 106.3040590286 sec, Swap count: 7085, Depth: 1544
# Layout trials: 100, Seed: 14621 - Trial 3/3 - Runtime: 104.7629041672 sec, Swap count: 7172, Depth: 2128
# Layout trials: 215, Seed: 38469 - Trial 1/3 - Runtime: 222.7337439060 sec, Swap count: 7735, Depth: 1810
# Layout trials: 215, Seed: 56985 - Trial 2/3 - Runtime: 199.6959049702 sec, Swap count: 8038, Depth: 1822
# Layout trials: 215, Seed: 20730 - Trial 3/3 - Runtime: 183.3959779739 sec, Swap count: 8552, Depth: 2375
# Layout trials: 464, Seed: 59470 - Trial 1/3 - Runtime: 449.6513130665 sec, Swap count: 7871, Depth: 2108
# Layout trials: 464, Seed: 425 - Trial 2/3 - Runtime: 475.9815599918 sec, Swap count: 7982, Depth: 2259
# Layout trials: 464, Seed: 94646 - Trial 3/3 - Runtime: 476.4620149136 sec, Swap count: 7374, Depth: 1511
# Layout trials: 1000, Seed: 94329 - Trial 1/3 - Runtime: 1012.5755620003 sec, Swap count: 6798, Depth: 1247
# Layout trials: 1000, Seed: 34522 - Trial 2/3 - Runtime: 1072.3981387615 sec, Swap count: 7992, Depth: 1799
# Layout trials: 1000, Seed: 65612 - Trial 3/3 - Runtime: 940.1186149120 sec, Swap count: 8264, Depth: 2208
# Running experiment for 127 qubits
# Layout trials: 1, Seed: 99871 - Trial 1/3 - Runtime: 11.4967691898 sec, Swap count: 16393, Depth: 4360
# Layout trials: 1, Seed: 23416 - Trial 2/3 - Runtime: 11.6866958141 sec, Swap count: 15219, Depth: 4320
# Layout trials: 1, Seed: 66542 - Trial 3/3 - Runtime: 12.0758249760 sec, Swap count: 15261, Depth: 6109
# Layout trials: 2, Seed: 13947 - Trial 1/3 - Runtime: 10.0067012310 sec, Swap count: 13179, Depth: 3158
# Layout trials: 2, Seed: 81959 - Trial 2/3 - Runtime: 10.5454697609 sec, Swap count: 15058, Depth: 3802
# Layout trials: 2, Seed: 39117 - Trial 3/3 - Runtime: 11.2697410583 sec, Swap count: 14808, Depth: 4218
# Layout trials: 5, Seed: 83748 - Trial 1/3 - Runtime: 12.7393658161 sec, Swap count: 13545, Depth: 3690
# Layout trials: 5, Seed: 66540 - Trial 2/3 - Runtime: 13.1744487286 sec, Swap count: 14322, Depth: 4163
# Layout trials: 5, Seed: 79818 - Trial 3/3 - Runtime: 15.1656188965 sec, Swap count: 14563, Depth: 3309
# Layout trials: 10, Seed: 26071 - Trial 1/3 - Runtime: 17.4185829163 sec, Swap count: 12563, Depth: 2761
# Layout trials: 10, Seed: 20032 - Trial 2/3 - Runtime: 17.4325189590 sec, Swap count: 11964, Depth: 2757
# Layout trials: 10, Seed: 49009 - Trial 3/3 - Runtime: 18.8395383358 sec, Swap count: 14117, Depth: 3434
# Layout trials: 22, Seed: 99943 - Trial 1/3 - Runtime: 30.6799333096 sec, Swap count: 12632, Depth: 3326
# Layout trials: 22, Seed: 21174 - Trial 2/3 - Runtime: 30.8296780586 sec, Swap count: 12585, Depth: 3106
# Layout trials: 22, Seed: 70697 - Trial 3/3 - Runtime: 32.8284919262 sec, Swap count: 13373, Depth: 3035
# Layout trials: 46, Seed: 69514 - Trial 1/3 - Runtime: 60.6821200848 sec, Swap count: 13752, Depth: 3533
# Layout trials: 46, Seed: 74 - Trial 2/3 - Runtime: 56.9274618626 sec, Swap count: 11244, Depth: 2078
# Layout trials: 46, Seed: 78504 - Trial 3/3 - Runtime: 59.1824150085 sec, Swap count: 12414, Depth: 2964
# Layout trials: 100, Seed: 42487 - Trial 1/3 - Runtime: 125.1399421692 sec, Swap count: 12308, Depth: 2712
# Layout trials: 100, Seed: 64042 - Trial 2/3 - Runtime: 120.4945640564 sec, Swap count: 10567, Depth: 2360
# Layout trials: 100, Seed: 2552 - Trial 3/3 - Runtime: 120.8945627213 sec, Swap count: 10855, Depth: 2070
# Layout trials: 215, Seed: 14662 - Trial 1/3 - Runtime: 251.5212609768 sec, Swap count: 12151, Depth: 2885
# Layout trials: 215, Seed: 47576 - Trial 2/3 - Runtime: 253.0492742062 sec, Swap count: 11821, Depth: 3436
# Layout trials: 215, Seed: 40306 - Trial 3/3 - Runtime: 247.7402770519 sec, Swap count: 11877, Depth: 2367
# Layout trials: 464, Seed: 31385 - Trial 1/3 - Runtime: 530.9226679802 sec, Swap count: 10793, Depth: 1936
# Layout trials: 464, Seed: 7592 - Trial 2/3 - Runtime: 530.5703978539 sec, Swap count: 11479, Depth: 2770
# Layout trials: 464, Seed: 31571 - Trial 3/3 - Runtime: 538.8689601421 sec, Swap count: 12514, Depth: 3411
# Layout trials: 1000, Seed: 74364 - Trial 1/3 - Runtime: 1134.9998130798 sec, Swap count: 10954, Depth: 2365
# Layout trials: 1000, Seed: 10322 - Trial 2/3 - Runtime: 1149.5732550621 sec, Swap count: 9964, Depth: 2262
# Layout trials: 1000, Seed: 11226 - Trial 3/3 - Runtime: 1172.8079497814 sec, Swap count: 12609, Depth: 3003
# Results saved to experiments/qft_decay.csv
