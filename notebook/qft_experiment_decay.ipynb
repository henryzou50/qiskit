# %%
from qiskit.transpiler import CouplingMap
from qiskit.transpiler.passes import SabreLayout, SabreSwap
from utils import file_to_coupling_map, directory_to_circuits, build_pass_manager
import random
import time
import csv
import os
import numpy as np

# %%
def run_experiment(cm_name, qc_name, layout_trials_list=[1, 10, 100, 1000], heuristic="lookahead", num_pass_trials=5, seed=42, output_csv="experiments/experiment_new.csv"):
    """
    Runs a transpilation experiment using SABRE passes on a set of quantum circuits.

    Parameters:
    - cm_name (str): Name of the coupling map file (without extension) located in 'coupling_maps/' directory.
    - qc_name (str): Name of the directory containing quantum circuits to run the experiment on.
    - layout_trials_list (list): List of layout (and swap) trials to run for each circuit. Default is [1, 10, 100, 1000].
    - heuristic (str): Heuristic to use in SabreSwap. Default is "lookahead".
    - num_pass_trials (int): Number of different seeds for running the whole pass. Default is 1.
    - seed (int): Random seed for reproducibility. Default is 42.
    - output_csv (str): Filename for the CSV file where results will be saved. Default is "experiment_results.csv".
    
    Returns:
    - None (Results are saved to a CSV file)
    """
    
    # Set random seed for reproducibility
    random.seed(seed)

    # Load the coupling map and the quantum circuits
    cm = CouplingMap(file_to_coupling_map(f'coupling_maps/{cm_name}.txt'))
    qc_list = directory_to_circuits(f'{qc_name}')

    # Prepare the CSV file
    with open(output_csv, mode='w', newline='') as csvfile:
        fieldnames = ["num_qubits", "layout_trials", "heuristic", "avg_runtime", "avg_swap_count", "avg_depth", "num_pass_trials"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        # Run trials for each circuit
        for qc in qc_list:
            num_qubits = qc.num_qubits
            print(f"Running experiment for {num_qubits} qubits")

            for layout_trials in layout_trials_list:
                seed_list = random.sample(range(0, 100000), num_pass_trials)

                total_runtime = 0
                total_swap_count = 0
                total_depth = 0

                for trial in range(num_pass_trials):
                    # Create the pass manager with the specified layout trials
                    rp = SabreSwap(coupling_map=cm, heuristic=heuristic, seed=seed_list[trial], trials=layout_trials)
                    lp = SabreLayout(coupling_map=cm, routing_pass=rp, seed=seed_list[trial])
                    pm = build_pass_manager(cm, lp, rp)

                    # Run the transpilation pass
                    time_start = time.time()
                    qc_tr = pm.run(qc)
                    time_end = time.time()

                    # Collect the metrics for this trial
                    runtime = time_end - time_start
                    swap_count = qc_tr.count_ops().get('swap', 0)
                    depth = qc_tr.depth(lambda x: x.operation.num_qubits == 2)  # 2-qubit gates

                    total_runtime += runtime
                    total_swap_count += swap_count
                    total_depth += depth

                    print(f"Layout trials: {layout_trials}, Seed: {seed_list[trial]} - Trial {trial+1}/{num_pass_trials} - Runtime: {runtime:.10f} sec, Swap count: {swap_count}, Depth: {depth}")

                # Calculate averages
                avg_runtime = total_runtime / num_pass_trials
                avg_swap_count = total_swap_count / num_pass_trials
                avg_depth = total_depth / num_pass_trials

                # Store averaged results in CSV
                writer.writerow({
                    "num_qubits": num_qubits,
                    "layout_trials": layout_trials,
                    "heuristic": heuristic,
                    "avg_runtime": avg_runtime,
                    "avg_swap_count": avg_swap_count,
                    "avg_depth": avg_depth,
                    "num_pass_trials": num_pass_trials
                })

    print(f"Results saved to {output_csv}")

# %%
# Example usage:

heuristic = "decay"

# Generate log scale values
log_values = np.linspace(0, 3, 10)
linear_values = np.round(10 ** log_values).astype(int)
unique_values = np.unique(np.clip(linear_values, 0, 1000))
layout_trials_list = unique_values.tolist()

run_experiment(cm_name='heavy_hex_127', qc_name='qft', heuristic=heuristic, layout_trials_list=layout_trials_list, num_pass_trials=1, output_csv=f"experiments/qft_{heuristic}.csv")
# Out:
# Running experiment for 10 qubits
# Layout trials: 1, Seed: 83810 - Trial 1/1 - Runtime: 0.0979480743 sec, Swap count: 65, Depth: 63
# Layout trials: 2, Seed: 14592 - Trial 1/1 - Runtime: 0.2831048965 sec, Swap count: 69, Depth: 62
# Layout trials: 5, Seed: 3278 - Trial 1/1 - Runtime: 0.2037267685 sec, Swap count: 62, Depth: 56
# Layout trials: 10, Seed: 97196 - Trial 1/1 - Runtime: 0.2334549427 sec, Swap count: 61, Depth: 59
# Layout trials: 22, Seed: 36048 - Trial 1/1 - Runtime: 0.3151617050 sec, Swap count: 53, Depth: 58
# Layout trials: 46, Seed: 32098 - Trial 1/1 - Runtime: 0.3435502052 sec, Swap count: 58, Depth: 55
# Layout trials: 100, Seed: 29256 - Trial 1/1 - Runtime: 0.5499489307 sec, Swap count: 53, Depth: 59
# Layout trials: 215, Seed: 18289 - Trial 1/1 - Runtime: 0.9854128361 sec, Swap count: 53, Depth: 53
# Layout trials: 464, Seed: 96530 - Trial 1/1 - Runtime: 2.0390746593 sec, Swap count: 52, Depth: 55
# Layout trials: 1000, Seed: 13434 - Trial 1/1 - Runtime: 4.6902239323 sec, Swap count: 54, Depth: 65
# Running experiment for 29 qubits
# Layout trials: 1, Seed: 88696 - Trial 1/1 - Runtime: 0.5725603104 sec, Swap count: 677, Depth: 264
# Layout trials: 2, Seed: 97080 - Trial 1/1 - Runtime: 0.5322611332 sec, Swap count: 711, Depth: 328
# Layout trials: 5, Seed: 71482 - Trial 1/1 - Runtime: 0.7166831493 sec, Swap count: 602, Depth: 333
# Layout trials: 10, Seed: 11395 - Trial 1/1 - Runtime: 0.8767950535 sec, Swap count: 575, Depth: 333
# Layout trials: 22, Seed: 77397 - Trial 1/1 - Runtime: 1.2803220749 sec, Swap count: 525, Depth: 266
# Layout trials: 46, Seed: 55302 - Trial 1/1 - Runtime: 2.8607978821 sec, Swap count: 536, Depth: 261
# Layout trials: 100, Seed: 4165 - Trial 1/1 - Runtime: 6.0865910053 sec, Swap count: 501, Depth: 197
# Layout trials: 215, Seed: 3905 - Trial 1/1 - Runtime: 12.7257070541 sec, Swap count: 493, Depth: 196
# Layout trials: 464, Seed: 12280 - Trial 1/1 - Runtime: 24.6702919006 sec, Swap count: 509, Depth: 255
# Layout trials: 1000, Seed: 28657 - Trial 1/1 - Runtime: 54.4977231026 sec, Swap count: 498, Depth: 271
# Running experiment for 49 qubits
# Layout trials: 1, Seed: 30495 - Trial 1/1 - Runtime: 3.7536411285 sec, Swap count: 1870, Depth: 699
# Layout trials: 2, Seed: 66237 - Trial 1/1 - Runtime: 2.6599128246 sec, Swap count: 2082, Depth: 889
# Layout trials: 5, Seed: 78907 - Trial 1/1 - Runtime: 3.1505968571 sec, Swap count: 1861, Depth: 711
# Layout trials: 10, Seed: 3478 - Trial 1/1 - Runtime: 3.0229041576 sec, Swap count: 1818, Depth: 680
# Layout trials: 22, Seed: 73563 - Trial 1/1 - Runtime: 5.3946349621 sec, Swap count: 1666, Depth: 664
# Layout trials: 46, Seed: 26062 - Trial 1/1 - Runtime: 10.1543550491 sec, Swap count: 1702, Depth: 512
# Layout trials: 100, Seed: 93850 - Trial 1/1 - Runtime: 19.1976239681 sec, Swap count: 1508, Depth: 476
# Layout trials: 215, Seed: 85181 - Trial 1/1 - Runtime: 36.1388778687 sec, Swap count: 1494, Depth: 493
# Layout trials: 464, Seed: 91924 - Trial 1/1 - Runtime: 81.2759680748 sec, Swap count: 1493, Depth: 462
# Layout trials: 1000, Seed: 71426 - Trial 1/1 - Runtime: 182.2173519135 sec, Swap count: 1538, Depth: 497
# Running experiment for 68 qubits
# Layout trials: 1, Seed: 54987 - Trial 1/1 - Runtime: 7.2120802402 sec, Swap count: 4058, Depth: 1293
# Layout trials: 2, Seed: 28893 - Trial 1/1 - Runtime: 3.7985479832 sec, Swap count: 3546, Depth: 1491
# Layout trials: 5, Seed: 58878 - Trial 1/1 - Runtime: 4.2881469727 sec, Swap count: 3908, Depth: 1439
# Layout trials: 10, Seed: 77236 - Trial 1/1 - Runtime: 4.8087370396 sec, Swap count: 3455, Depth: 993
# Layout trials: 22, Seed: 36463 - Trial 1/1 - Runtime: 8.7118082047 sec, Swap count: 2986, Depth: 720
# Layout trials: 46, Seed: 851 - Trial 1/1 - Runtime: 18.0996942520 sec, Swap count: 3415, Depth: 943
# Layout trials: 100, Seed: 99458 - Trial 1/1 - Runtime: 33.2489337921 sec, Swap count: 2948, Depth: 1118
# Layout trials: 215, Seed: 20926 - Trial 1/1 - Runtime: 73.4300012589 sec, Swap count: 3120, Depth: 1072
# Layout trials: 464, Seed: 91506 - Trial 1/1 - Runtime: 172.0573670864 sec, Swap count: 2801, Depth: 968
# Layout trials: 1000, Seed: 55392 - Trial 1/1 - Runtime: 365.4789090157 sec, Swap count: 2926, Depth: 863
# Running experiment for 88 qubits
# Layout trials: 1, Seed: 44597 - Trial 1/1 - Runtime: 11.6157808304 sec, Swap count: 7862, Depth: 2565
# Layout trials: 2, Seed: 36421 - Trial 1/1 - Runtime: 8.8052079678 sec, Swap count: 6974, Depth: 2177
# Layout trials: 5, Seed: 20379 - Trial 1/1 - Runtime: 11.2714431286 sec, Swap count: 5901, Depth: 1546
# Layout trials: 10, Seed: 28221 - Trial 1/1 - Runtime: 12.1756453514 sec, Swap count: 5979, Depth: 1837
# Layout trials: 22, Seed: 44118 - Trial 1/1 - Runtime: 19.9706292152 sec, Swap count: 6025, Depth: 2172
# Layout trials: 46, Seed: 13396 - Trial 1/1 - Runtime: 26.6845777035 sec, Swap count: 5496, Depth: 2093
# Layout trials: 100, Seed: 12156 - Trial 1/1 - Runtime: 63.1520140171 sec, Swap count: 4983, Depth: 1197
# Layout trials: 215, Seed: 49797 - Trial 1/1 - Runtime: 142.0631971359 sec, Swap count: 5053, Depth: 1275
# Layout trials: 464, Seed: 12676 - Trial 1/1 - Runtime: 317.6078488827 sec, Swap count: 4835, Depth: 966
# Layout trials: 1000, Seed: 47052 - Trial 1/1 - Runtime: 665.2437469959 sec, Swap count: 5012, Depth: 978
# Running experiment for 107 qubits
# Layout trials: 1, Seed: 45082 - Trial 1/1 - Runtime: 9.0014519691 sec, Swap count: 9919, Depth: 3077
# Layout trials: 2, Seed: 79131 - Trial 1/1 - Runtime: 8.3408741951 sec, Swap count: 9685, Depth: 2618
# Layout trials: 5, Seed: 34671 - Trial 1/1 - Runtime: 11.2009930611 sec, Swap count: 10543, Depth: 3825
# Layout trials: 10, Seed: 5695 - Trial 1/1 - Runtime: 14.3953359127 sec, Swap count: 8796, Depth: 2401
# Layout trials: 22, Seed: 95647 - Trial 1/1 - Runtime: 25.9985678196 sec, Swap count: 8786, Depth: 2183
# Layout trials: 46, Seed: 60217 - Trial 1/1 - Runtime: 50.2247118950 sec, Swap count: 8133, Depth: 1953
# Layout trials: 100, Seed: 70284 - Trial 1/1 - Runtime: 111.7892389297 sec, Swap count: 8907, Depth: 1878
# Layout trials: 215, Seed: 16361 - Trial 1/1 - Runtime: 194.8383259773 sec, Swap count: 7488, Depth: 1564
# Layout trials: 464, Seed: 49615 - Trial 1/1 - Runtime: 474.0034182072 sec, Swap count: 8135, Depth: 1956
# Layout trials: 1000, Seed: 10328 - Trial 1/1 - Runtime: 983.2306668758 sec, Swap count: 6781, Depth: 1767
# Running experiment for 127 qubits
# Layout trials: 1, Seed: 72357 - Trial 1/1 - Runtime: 12.1127848625 sec, Swap count: 15137, Depth: 3932
# Layout trials: 2, Seed: 38427 - Trial 1/1 - Runtime: 11.5788867474 sec, Swap count: 15475, Depth: 4843
# Layout trials: 5, Seed: 82397 - Trial 1/1 - Runtime: 14.9631218910 sec, Swap count: 12594, Depth: 2675
# Layout trials: 10, Seed: 81070 - Trial 1/1 - Runtime: 19.3314919472 sec, Swap count: 11529, Depth: 2345
# Layout trials: 22, Seed: 47400 - Trial 1/1 - Runtime: 32.9017970562 sec, Swap count: 12351, Depth: 3214
# Layout trials: 46, Seed: 75674 - Trial 1/1 - Runtime: 59.2879972458 sec, Swap count: 11979, Depth: 2839
# Layout trials: 100, Seed: 25203 - Trial 1/1 - Runtime: 121.7799868584 sec, Swap count: 11481, Depth: 2626
# Layout trials: 215, Seed: 92349 - Trial 1/1 - Runtime: 246.5135021210 sec, Swap count: 11246, Depth: 2257
# Layout trials: 464, Seed: 9116 - Trial 1/1 - Runtime: 524.2098119259 sec, Swap count: 9974, Depth: 2329
# Layout trials: 1000, Seed: 6006 - Trial 1/1 - Runtime: 1176.8575091362 sec, Swap count: 11593, Depth: 2401
# Results saved to experiments/qft_decay.csv
