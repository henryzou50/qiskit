# %%
from qiskit.transpiler import CouplingMap
from qiskit.transpiler.passes import SabreLayout, SabreSwap
from utils import file_to_coupling_map, directory_to_circuits, build_pass_manager
import random
import time
import csv
import os
import numpy as np

# %%
def run_experiment(cm_name, qc_name, layout_trials_list=[1, 10, 100, 1000], heuristic="lookahead", num_pass_trials=5, seed=42, output_csv="experiments/experiment_new.csv"):
    """
    Runs a transpilation experiment using SABRE passes on a set of quantum circuits.

    Parameters:
    - cm_name (str): Name of the coupling map file (without extension) located in 'coupling_maps/' directory.
    - qc_name (str): Name of the directory containing quantum circuits to run the experiment on.
    - layout_trials_list (list): List of layout (and swap) trials to run for each circuit. Default is [1, 10, 100, 1000].
    - heuristic (str): Heuristic to use in SabreSwap. Default is "lookahead".
    - num_pass_trials (int): Number of different seeds for running the whole pass. Default is 1.
    - seed (int): Random seed for reproducibility. Default is 42.
    - output_csv (str): Filename for the CSV file where results will be saved. Default is "experiment_results.csv".
    
    Returns:
    - None (Results are saved to a CSV file)
    """
    
    # Set random seed for reproducibility
    random.seed(seed)

    # Load the coupling map and the quantum circuits
    cm = CouplingMap(file_to_coupling_map(f'coupling_maps/{cm_name}.txt'))
    qc_list = directory_to_circuits(f'{qc_name}')

    # Prepare the CSV file
    with open(output_csv, mode='w', newline='') as csvfile:
        fieldnames = ["num_qubits", "layout_trials", "heuristic", "avg_runtime", "avg_swap_count", "avg_depth", "num_pass_trials"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        # Run trials for each circuit
        for qc in qc_list:
            num_qubits = qc.num_qubits
            print(f"Running experiment for {num_qubits} qubits")

            for layout_trials in layout_trials_list:
                seed_list = random.sample(range(0, 100000), num_pass_trials)

                total_runtime = 0
                total_swap_count = 0
                total_depth = 0

                for trial in range(num_pass_trials):
                    # Create the pass manager with the specified layout trials
                    rp = SabreSwap(coupling_map=cm, heuristic=heuristic, seed=seed_list[trial], trials=layout_trials)
                    lp = SabreLayout(coupling_map=cm, routing_pass=rp, seed=seed_list[trial])
                    pm = build_pass_manager(cm, lp, rp)

                    # Run the transpilation pass
                    time_start = time.time()
                    qc_tr = pm.run(qc)
                    time_end = time.time()

                    # Collect the metrics for this trial
                    runtime = time_end - time_start
                    swap_count = qc_tr.count_ops().get('swap', 0)
                    depth = qc_tr.depth(lambda x: x.operation.num_qubits == 2)  # 2-qubit gates

                    total_runtime += runtime
                    total_swap_count += swap_count
                    total_depth += depth

                    print(f"Layout trials: {layout_trials}, Seed: {seed_list[trial]} - Trial {trial+1}/{num_pass_trials} - Runtime: {runtime:.10f} sec, Swap count: {swap_count}, Depth: {depth}")

                # Calculate averages
                avg_runtime = total_runtime / num_pass_trials
                avg_swap_count = total_swap_count / num_pass_trials
                avg_depth = total_depth / num_pass_trials

                # Store averaged results in CSV
                writer.writerow({
                    "num_qubits": num_qubits,
                    "layout_trials": layout_trials,
                    "heuristic": heuristic,
                    "avg_runtime": avg_runtime,
                    "avg_swap_count": avg_swap_count,
                    "avg_depth": avg_depth,
                    "num_pass_trials": num_pass_trials
                })

    print(f"Results saved to {output_csv}")

# %%
# Example usage:

heuristic = "lookahead"

# Generate log scale values
log_values = np.linspace(0, 3, 10)
linear_values = np.round(10 ** log_values).astype(int)
unique_values = np.unique(np.clip(linear_values, 0, 1000))
layout_trials_list = unique_values.tolist()

run_experiment(cm_name='heavy_hex_127', qc_name='qft', heuristic=heuristic, layout_trials_list=layout_trials_list, num_pass_trials=1, output_csv=f"experiments/qft_{heuristic}.csv")
# Out:
# Running experiment for 10 qubits
# Layout trials: 1, Seed: 83810 - Trial 1/1 - Runtime: 0.0685870647 sec, Swap count: 67, Depth: 64
# Layout trials: 2, Seed: 14592 - Trial 1/1 - Runtime: 0.0679497719 sec, Swap count: 60, Depth: 62
# Layout trials: 5, Seed: 3278 - Trial 1/1 - Runtime: 0.0945363045 sec, Swap count: 67, Depth: 57
# Layout trials: 10, Seed: 97196 - Trial 1/1 - Runtime: 0.1012053490 sec, Swap count: 63, Depth: 63
# Layout trials: 22, Seed: 36048 - Trial 1/1 - Runtime: 0.0924680233 sec, Swap count: 53, Depth: 58
# Layout trials: 46, Seed: 32098 - Trial 1/1 - Runtime: 0.1236798763 sec, Swap count: 47, Depth: 52
# Layout trials: 100, Seed: 29256 - Trial 1/1 - Runtime: 0.2183759212 sec, Swap count: 53, Depth: 60
# Layout trials: 215, Seed: 18289 - Trial 1/1 - Runtime: 0.3419899940 sec, Swap count: 47, Depth: 52
# Layout trials: 464, Seed: 96530 - Trial 1/1 - Runtime: 0.6940071583 sec, Swap count: 51, Depth: 52
# Layout trials: 1000, Seed: 13434 - Trial 1/1 - Runtime: 1.3184680939 sec, Swap count: 54, Depth: 60
# Running experiment for 29 qubits
# Layout trials: 1, Seed: 88696 - Trial 1/1 - Runtime: 0.3741908073 sec, Swap count: 664, Depth: 344
# Layout trials: 2, Seed: 97080 - Trial 1/1 - Runtime: 0.3866720200 sec, Swap count: 613, Depth: 258
# Layout trials: 5, Seed: 71482 - Trial 1/1 - Runtime: 0.4041976929 sec, Swap count: 635, Depth: 304
# Layout trials: 10, Seed: 11395 - Trial 1/1 - Runtime: 0.4342048168 sec, Swap count: 532, Depth: 274
# Layout trials: 22, Seed: 77397 - Trial 1/1 - Runtime: 0.6432430744 sec, Swap count: 549, Depth: 242
# Layout trials: 46, Seed: 55302 - Trial 1/1 - Runtime: 1.1860139370 sec, Swap count: 545, Depth: 293
# Layout trials: 100, Seed: 4165 - Trial 1/1 - Runtime: 3.4702970982 sec, Swap count: 579, Depth: 304
# Layout trials: 215, Seed: 3905 - Trial 1/1 - Runtime: 10.0049321651 sec, Swap count: 539, Depth: 278
# Layout trials: 464, Seed: 12280 - Trial 1/1 - Runtime: 23.2512187958 sec, Swap count: 557, Depth: 279
# Layout trials: 1000, Seed: 28657 - Trial 1/1 - Runtime: 53.9832892418 sec, Swap count: 493, Depth: 247
# Running experiment for 49 qubits
# Layout trials: 1, Seed: 30495 - Trial 1/1 - Runtime: 3.9202270508 sec, Swap count: 1996, Depth: 687
# Layout trials: 2, Seed: 66237 - Trial 1/1 - Runtime: 2.6705770493 sec, Swap count: 1823, Depth: 575
# Layout trials: 5, Seed: 78907 - Trial 1/1 - Runtime: 2.9481642246 sec, Swap count: 1646, Depth: 695
# Layout trials: 10, Seed: 3478 - Trial 1/1 - Runtime: 3.2998979092 sec, Swap count: 1852, Depth: 846
# Layout trials: 22, Seed: 73563 - Trial 1/1 - Runtime: 5.1242899895 sec, Swap count: 1635, Depth: 565
# Layout trials: 46, Seed: 26062 - Trial 1/1 - Runtime: 9.3280289173 sec, Swap count: 1709, Depth: 687
# Layout trials: 100, Seed: 93850 - Trial 1/1 - Runtime: 17.1823463440 sec, Swap count: 1632, Depth: 600
# Layout trials: 215, Seed: 85181 - Trial 1/1 - Runtime: 41.6519649029 sec, Swap count: 1713, Depth: 516
# Layout trials: 464, Seed: 91924 - Trial 1/1 - Runtime: 76.9093830585 sec, Swap count: 1417, Depth: 389
# Layout trials: 1000, Seed: 71426 - Trial 1/1 - Runtime: 182.2031261921 sec, Swap count: 1389, Depth: 408
# Running experiment for 68 qubits
# Layout trials: 1, Seed: 54987 - Trial 1/1 - Runtime: 7.8460779190 sec, Swap count: 4305, Depth: 1352
# Layout trials: 2, Seed: 28893 - Trial 1/1 - Runtime: 6.1194510460 sec, Swap count: 3798, Depth: 1270
# Layout trials: 5, Seed: 58878 - Trial 1/1 - Runtime: 6.3647868633 sec, Swap count: 3541, Depth: 997
# Layout trials: 10, Seed: 77236 - Trial 1/1 - Runtime: 6.9791750908 sec, Swap count: 3020, Depth: 892
# Layout trials: 22, Seed: 36463 - Trial 1/1 - Runtime: 8.1216897964 sec, Swap count: 3542, Depth: 1090
# Layout trials: 46, Seed: 851 - Trial 1/1 - Runtime: 12.0824360847 sec, Swap count: 3351, Depth: 972
# Layout trials: 100, Seed: 99458 - Trial 1/1 - Runtime: 33.2644541264 sec, Swap count: 3090, Depth: 899
# Layout trials: 215, Seed: 20926 - Trial 1/1 - Runtime: 66.1406350136 sec, Swap count: 3055, Depth: 1217
# Layout trials: 464, Seed: 91506 - Trial 1/1 - Runtime: 168.3078169823 sec, Swap count: 2889, Depth: 852
# Layout trials: 1000, Seed: 55392 - Trial 1/1 - Runtime: 376.7280621529 sec, Swap count: 3060, Depth: 836
# Running experiment for 88 qubits
# Layout trials: 1, Seed: 44597 - Trial 1/1 - Runtime: 14.1180689335 sec, Swap count: 7170, Depth: 2052
# Layout trials: 2, Seed: 36421 - Trial 1/1 - Runtime: 11.0060019493 sec, Swap count: 6587, Depth: 2441
# Layout trials: 5, Seed: 20379 - Trial 1/1 - Runtime: 8.5737519264 sec, Swap count: 6108, Depth: 1730
# Layout trials: 10, Seed: 28221 - Trial 1/1 - Runtime: 9.4204518795 sec, Swap count: 6001, Depth: 1785
# Layout trials: 22, Seed: 44118 - Trial 1/1 - Runtime: 16.5392320156 sec, Swap count: 5549, Depth: 1507
# Layout trials: 46, Seed: 13396 - Trial 1/1 - Runtime: 32.7503979206 sec, Swap count: 6056, Depth: 1661
# Layout trials: 100, Seed: 12156 - Trial 1/1 - Runtime: 57.5760121346 sec, Swap count: 5695, Depth: 1590
# Layout trials: 215, Seed: 49797 - Trial 1/1 - Runtime: 138.4773089886 sec, Swap count: 4690, Depth: 1021
# Layout trials: 464, Seed: 12676 - Trial 1/1 - Runtime: 321.6387009621 sec, Swap count: 5239, Depth: 1508
# Layout trials: 1000, Seed: 47052 - Trial 1/1 - Runtime: 681.3984508514 sec, Swap count: 5749, Depth: 1656
# Running experiment for 107 qubits
# Layout trials: 1, Seed: 45082 - Trial 1/1 - Runtime: 17.1223168373 sec, Swap count: 10890, Depth: 3317
# Layout trials: 2, Seed: 79131 - Trial 1/1 - Runtime: 6.8438279629 sec, Swap count: 10615, Depth: 3569
# Layout trials: 5, Seed: 34671 - Trial 1/1 - Runtime: 8.3894746304 sec, Swap count: 10412, Depth: 3753
# Layout trials: 10, Seed: 5695 - Trial 1/1 - Runtime: 11.6102151871 sec, Swap count: 9643, Depth: 3269
# Layout trials: 22, Seed: 95647 - Trial 1/1 - Runtime: 23.9178130627 sec, Swap count: 9422, Depth: 2208
# Layout trials: 46, Seed: 60217 - Trial 1/1 - Runtime: 47.1123569012 sec, Swap count: 8349, Depth: 2529
# Layout trials: 100, Seed: 70284 - Trial 1/1 - Runtime: 106.3738980293 sec, Swap count: 8766, Depth: 2209
# Layout trials: 215, Seed: 16361 - Trial 1/1 - Runtime: 193.1300749779 sec, Swap count: 7805, Depth: 1751
# Layout trials: 464, Seed: 49615 - Trial 1/1 - Runtime: 455.0648648739 sec, Swap count: 8065, Depth: 2111
# Layout trials: 1000, Seed: 10328 - Trial 1/1 - Runtime: 1011.8178961277 sec, Swap count: 7627, Depth: 1681
# Running experiment for 127 qubits
# Layout trials: 1, Seed: 72357 - Trial 1/1 - Runtime: 17.9657421112 sec, Swap count: 17356, Depth: 4777
# Layout trials: 2, Seed: 38427 - Trial 1/1 - Runtime: 9.8085198402 sec, Swap count: 15378, Depth: 4496
# Layout trials: 5, Seed: 82397 - Trial 1/1 - Runtime: 11.3750920296 sec, Swap count: 13132, Depth: 2837
# Layout trials: 10, Seed: 81070 - Trial 1/1 - Runtime: 15.4077799320 sec, Swap count: 12665, Depth: 2923
# Layout trials: 22, Seed: 47400 - Trial 1/1 - Runtime: 29.9696152210 sec, Swap count: 13605, Depth: 3713
# Layout trials: 46, Seed: 75674 - Trial 1/1 - Runtime: 56.8826718330 sec, Swap count: 12428, Depth: 3216
# Layout trials: 100, Seed: 25203 - Trial 1/1 - Runtime: 120.4226119518 sec, Swap count: 12642, Depth: 3394
# Layout trials: 215, Seed: 92349 - Trial 1/1 - Runtime: 245.0167300701 sec, Swap count: 10621, Depth: 2245
# Layout trials: 464, Seed: 9116 - Trial 1/1 - Runtime: 533.8466846943 sec, Swap count: 12213, Depth: 2465
# Layout trials: 1000, Seed: 6006 - Trial 1/1 - Runtime: 1172.3516371250 sec, Swap count: 11431, Depth: 2387
# Results saved to experiments/qft_lookahead.csv
