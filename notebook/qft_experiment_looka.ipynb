# %%
from qiskit.transpiler import CouplingMap
from qiskit.transpiler.passes import SabreLayout, SabreSwap
from utils import file_to_coupling_map, directory_to_circuits, build_pass_manager
import random
import time
import csv
import os
import numpy as np

# %%
def run_experiment(cm_name, qc_name, layout_trials_list=[1, 10, 100, 1000], heuristic="lookahead", num_pass_trials=5, seed=42, output_csv="experiments/experiment_new.csv"):
    """
    Runs a transpilation experiment using SABRE passes on a set of quantum circuits.

    Parameters:
    - cm_name (str): Name of the coupling map file (without extension) located in 'coupling_maps/' directory.
    - qc_name (str): Name of the directory containing quantum circuits to run the experiment on.
    - layout_trials_list (list): List of layout (and swap) trials to run for each circuit. Default is [1, 10, 100, 1000].
    - heuristic (str): Heuristic to use in SabreSwap. Default is "lookahead".
    - num_pass_trials (int): Number of different seeds for running the whole pass. Default is 1.
    - seed (int): Random seed for reproducibility. Default is 42.
    - output_csv (str): Filename for the CSV file where results will be saved. Default is "experiment_results.csv".
    
    Returns:
    - None (Results are saved to a CSV file)
    """
    
    # Set random seed for reproducibility
    random.seed(seed)

    # Load the coupling map and the quantum circuits
    cm = CouplingMap(file_to_coupling_map(f'coupling_maps/{cm_name}.txt'))
    qc_list = directory_to_circuits(f'{qc_name}')

    # Prepare the CSV file
    with open(output_csv, mode='w', newline='') as csvfile:
        fieldnames = ["num_qubits", "layout_trials", "heuristic", "avg_runtime", "avg_swap_count", "avg_depth", "num_pass_trials"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        # Run trials for each circuit
        for qc in qc_list:
            num_qubits = qc.num_qubits
            print(f"Running experiment for {num_qubits} qubits")

            for layout_trials in layout_trials_list:
                seed_list = random.sample(range(0, 100000), num_pass_trials)

                total_runtime = 0
                total_swap_count = 0
                total_depth = 0

                for trial in range(num_pass_trials):
                    # Create the pass manager with the specified layout trials
                    rp = SabreSwap(coupling_map=cm, heuristic=heuristic, seed=seed_list[trial], trials=layout_trials)
                    lp = SabreLayout(coupling_map=cm, routing_pass=rp, seed=seed_list[trial])
                    pm = build_pass_manager(cm, lp, rp)

                    # Run the transpilation pass
                    time_start = time.time()
                    qc_tr = pm.run(qc)
                    time_end = time.time()

                    # Collect the metrics for this trial
                    runtime = time_end - time_start
                    swap_count = qc_tr.count_ops().get('swap', 0)
                    depth = qc_tr.depth(lambda x: x.operation.num_qubits == 2)  # 2-qubit gates

                    total_runtime += runtime
                    total_swap_count += swap_count
                    total_depth += depth

                    print(f"Layout trials: {layout_trials}, Seed: {seed_list[trial]} - Trial {trial+1}/{num_pass_trials} - Runtime: {runtime:.10f} sec, Swap count: {swap_count}, Depth: {depth}")

                # Calculate averages
                avg_runtime = total_runtime / num_pass_trials
                avg_swap_count = total_swap_count / num_pass_trials
                avg_depth = total_depth / num_pass_trials

                # Store averaged results in CSV
                writer.writerow({
                    "num_qubits": num_qubits,
                    "layout_trials": layout_trials,
                    "heuristic": heuristic,
                    "avg_runtime": avg_runtime,
                    "avg_swap_count": avg_swap_count,
                    "avg_depth": avg_depth,
                    "num_pass_trials": num_pass_trials
                })

    print(f"Results saved to {output_csv}")

# %%
# Example usage:

heuristic = "lookahead"

# Generate log scale values
log_values = np.linspace(0, 3, 10)
linear_values = np.round(10 ** log_values).astype(int)
unique_values = np.unique(np.clip(linear_values, 0, 1000))
layout_trials_list = unique_values.tolist()

run_experiment(cm_name='heavy_hex_127', qc_name='qft', heuristic=heuristic, layout_trials_list=layout_trials_list, num_pass_trials=3, output_csv=f"experiments/qft_{heuristic}.csv")
# Out:
# Running experiment for 10 qubits
# Layout trials: 1, Seed: 83810 - Trial 1/3 - Runtime: 0.2883160114 sec, Swap count: 67, Depth: 64
# Layout trials: 1, Seed: 14592 - Trial 2/3 - Runtime: 0.2268249989 sec, Swap count: 58, Depth: 60
# Layout trials: 1, Seed: 3278 - Trial 3/3 - Runtime: 0.2225852013 sec, Swap count: 72, Depth: 66
# Layout trials: 2, Seed: 97196 - Trial 1/3 - Runtime: 0.2572820187 sec, Swap count: 65, Depth: 62
# Layout trials: 2, Seed: 36048 - Trial 2/3 - Runtime: 0.2484507561 sec, Swap count: 66, Depth: 63
# Layout trials: 2, Seed: 32098 - Trial 3/3 - Runtime: 0.2034749985 sec, Swap count: 62, Depth: 57
# Layout trials: 5, Seed: 29256 - Trial 1/3 - Runtime: 0.2771790028 sec, Swap count: 54, Depth: 61
# Layout trials: 5, Seed: 18289 - Trial 2/3 - Runtime: 0.3104507923 sec, Swap count: 57, Depth: 55
# Layout trials: 5, Seed: 96530 - Trial 3/3 - Runtime: 0.2430000305 sec, Swap count: 50, Depth: 61
# Layout trials: 10, Seed: 13434 - Trial 1/3 - Runtime: 0.3397297859 sec, Swap count: 57, Depth: 56
# Layout trials: 10, Seed: 88696 - Trial 2/3 - Runtime: 0.3480277061 sec, Swap count: 55, Depth: 55
# Layout trials: 10, Seed: 97080 - Trial 3/3 - Runtime: 0.3174090385 sec, Swap count: 55, Depth: 66
# Layout trials: 22, Seed: 71482 - Trial 1/3 - Runtime: 0.3398301601 sec, Swap count: 51, Depth: 55
# Layout trials: 22, Seed: 11395 - Trial 2/3 - Runtime: 0.2777340412 sec, Swap count: 45, Depth: 57
# Layout trials: 22, Seed: 77397 - Trial 3/3 - Runtime: 0.4480118752 sec, Swap count: 61, Depth: 62
# Layout trials: 46, Seed: 55302 - Trial 1/3 - Runtime: 0.4828791618 sec, Swap count: 54, Depth: 59
# Layout trials: 46, Seed: 4165 - Trial 2/3 - Runtime: 0.4540810585 sec, Swap count: 54, Depth: 53
# Layout trials: 46, Seed: 3905 - Trial 3/3 - Runtime: 0.2982461452 sec, Swap count: 53, Depth: 61
# Layout trials: 100, Seed: 12280 - Trial 1/3 - Runtime: 0.6620700359 sec, Swap count: 59, Depth: 58
# Layout trials: 100, Seed: 28657 - Trial 2/3 - Runtime: 0.6117413044 sec, Swap count: 59, Depth: 62
# Layout trials: 100, Seed: 30495 - Trial 3/3 - Runtime: 0.5344867706 sec, Swap count: 53, Depth: 62
# Layout trials: 215, Seed: 66237 - Trial 1/3 - Runtime: 1.0994439125 sec, Swap count: 56, Depth: 58
# Layout trials: 215, Seed: 78907 - Trial 2/3 - Runtime: 1.2244150639 sec, Swap count: 57, Depth: 63
# Layout trials: 215, Seed: 3478 - Trial 3/3 - Runtime: 1.2042231560 sec, Swap count: 49, Depth: 52
# Layout trials: 464, Seed: 73563 - Trial 1/3 - Runtime: 2.7488467693 sec, Swap count: 56, Depth: 60
# Layout trials: 464, Seed: 26062 - Trial 2/3 - Runtime: 2.6982848644 sec, Swap count: 55, Depth: 54
# Layout trials: 464, Seed: 93850 - Trial 3/3 - Runtime: 2.6410219669 sec, Swap count: 50, Depth: 54
# Layout trials: 1000, Seed: 85181 - Trial 1/3 - Runtime: 4.8307511806 sec, Swap count: 56, Depth: 62
# Layout trials: 1000, Seed: 91924 - Trial 2/3 - Runtime: 4.7771971226 sec, Swap count: 61, Depth: 52
# Layout trials: 1000, Seed: 71426 - Trial 3/3 - Runtime: 4.6198039055 sec, Swap count: 63, Depth: 58
# Running experiment for 29 qubits
# Layout trials: 1, Seed: 54987 - Trial 1/3 - Runtime: 1.0503411293 sec, Swap count: 742, Depth: 375
# Layout trials: 1, Seed: 28893 - Trial 2/3 - Runtime: 1.2088756561 sec, Swap count: 624, Depth: 308
# Layout trials: 1, Seed: 58878 - Trial 3/3 - Runtime: 1.4169559479 sec, Swap count: 894, Depth: 463
# Layout trials: 2, Seed: 77236 - Trial 1/3 - Runtime: 0.8629469872 sec, Swap count: 635, Depth: 268
# Layout trials: 2, Seed: 36463 - Trial 2/3 - Runtime: 1.0496358871 sec, Swap count: 641, Depth: 286
# Layout trials: 2, Seed: 851 - Trial 3/3 - Runtime: 0.8870477676 sec, Swap count: 668, Depth: 308
# Layout trials: 5, Seed: 99458 - Trial 1/3 - Runtime: 0.8968470097 sec, Swap count: 605, Depth: 339
# Layout trials: 5, Seed: 20926 - Trial 2/3 - Runtime: 1.2280199528 sec, Swap count: 572, Depth: 313
# Layout trials: 5, Seed: 91506 - Trial 3/3 - Runtime: 1.1025938988 sec, Swap count: 605, Depth: 296
# Layout trials: 10, Seed: 55392 - Trial 1/3 - Runtime: 1.2095401287 sec, Swap count: 529, Depth: 248
# Layout trials: 10, Seed: 44597 - Trial 2/3 - Runtime: 1.0329279900 sec, Swap count: 536, Depth: 287
# Layout trials: 10, Seed: 36421 - Trial 3/3 - Runtime: 0.9432420731 sec, Swap count: 558, Depth: 290
# Layout trials: 22, Seed: 20379 - Trial 1/3 - Runtime: 1.2057809830 sec, Swap count: 493, Depth: 214
# Layout trials: 22, Seed: 28221 - Trial 2/3 - Runtime: 1.2586989403 sec, Swap count: 642, Depth: 297
# Layout trials: 22, Seed: 44118 - Trial 3/3 - Runtime: 1.2917549610 sec, Swap count: 583, Depth: 267
# Layout trials: 46, Seed: 13396 - Trial 1/3 - Runtime: 2.2980208397 sec, Swap count: 515, Depth: 281
# Layout trials: 46, Seed: 12156 - Trial 2/3 - Runtime: 2.5014200211 sec, Swap count: 605, Depth: 275
# Layout trials: 46, Seed: 49797 - Trial 3/3 - Runtime: 2.6156787872 sec, Swap count: 612, Depth: 339
# Layout trials: 100, Seed: 12676 - Trial 1/3 - Runtime: 5.2512841225 sec, Swap count: 608, Depth: 264
# Layout trials: 100, Seed: 47052 - Trial 2/3 - Runtime: 4.6704468727 sec, Swap count: 548, Depth: 282
# Layout trials: 100, Seed: 45082 - Trial 3/3 - Runtime: 4.4826202393 sec, Swap count: 517, Depth: 237
# Layout trials: 215, Seed: 79131 - Trial 1/3 - Runtime: 10.1861240864 sec, Swap count: 529, Depth: 215
# Layout trials: 215, Seed: 34671 - Trial 2/3 - Runtime: 10.3710401058 sec, Swap count: 535, Depth: 285
# Layout trials: 215, Seed: 5695 - Trial 3/3 - Runtime: 11.0775959492 sec, Swap count: 546, Depth: 289
# Layout trials: 464, Seed: 95647 - Trial 1/3 - Runtime: 26.3386301994 sec, Swap count: 592, Depth: 282
# Layout trials: 464, Seed: 60217 - Trial 2/3 - Runtime: 27.5733919144 sec, Swap count: 537, Depth: 274
# Layout trials: 464, Seed: 70284 - Trial 3/3 - Runtime: 27.2187199593 sec, Swap count: 510, Depth: 235
# Layout trials: 1000, Seed: 16361 - Trial 1/3 - Runtime: 60.5490128994 sec, Swap count: 498, Depth: 246
# Layout trials: 1000, Seed: 49615 - Trial 2/3 - Runtime: 57.6883511543 sec, Swap count: 444, Depth: 203
# Layout trials: 1000, Seed: 10328 - Trial 3/3 - Runtime: 55.5120151043 sec, Swap count: 488, Depth: 242
# Running experiment for 49 qubits
# Layout trials: 1, Seed: 72357 - Trial 1/3 - Runtime: 2.8132138252 sec, Swap count: 2008, Depth: 800
# Layout trials: 1, Seed: 38427 - Trial 2/3 - Runtime: 2.9626240730 sec, Swap count: 2024, Depth: 842
# Layout trials: 1, Seed: 82397 - Trial 3/3 - Runtime: 3.0070788860 sec, Swap count: 1928, Depth: 753
# Layout trials: 2, Seed: 81070 - Trial 1/3 - Runtime: 2.1895461082 sec, Swap count: 2025, Depth: 975
# Layout trials: 2, Seed: 47400 - Trial 2/3 - Runtime: 2.0485990047 sec, Swap count: 2071, Depth: 996
# Layout trials: 2, Seed: 75674 - Trial 3/3 - Runtime: 2.1169559956 sec, Swap count: 1927, Depth: 678
# Layout trials: 5, Seed: 25203 - Trial 1/3 - Runtime: 2.6590051651 sec, Swap count: 1930, Depth: 935
# Layout trials: 5, Seed: 92349 - Trial 2/3 - Runtime: 2.5221271515 sec, Swap count: 1844, Depth: 628
# Layout trials: 5, Seed: 9116 - Trial 3/3 - Runtime: 2.5052480698 sec, Swap count: 1828, Depth: 716
# Layout trials: 10, Seed: 6006 - Trial 1/3 - Runtime: 3.4070169926 sec, Swap count: 1653, Depth: 744
# Layout trials: 10, Seed: 86673 - Trial 2/3 - Runtime: 2.9374778271 sec, Swap count: 1671, Depth: 680
# Layout trials: 10, Seed: 29871 - Trial 3/3 - Runtime: 3.1986730099 sec, Swap count: 1725, Depth: 636
# Layout trials: 22, Seed: 37930 - Trial 1/3 - Runtime: 4.8630559444 sec, Swap count: 1565, Depth: 506
# Layout trials: 22, Seed: 10458 - Trial 2/3 - Runtime: 5.4621970654 sec, Swap count: 1873, Depth: 670
# Layout trials: 22, Seed: 30512 - Trial 3/3 - Runtime: 5.0495648384 sec, Swap count: 1605, Depth: 609
# Layout trials: 46, Seed: 13238 - Trial 1/3 - Runtime: 9.4551529884 sec, Swap count: 1769, Depth: 594
# Layout trials: 46, Seed: 49823 - Trial 2/3 - Runtime: 9.6320331097 sec, Swap count: 1714, Depth: 563
# Layout trials: 46, Seed: 36434 - Trial 3/3 - Runtime: 9.7132120132 sec, Swap count: 1616, Depth: 572
# Layout trials: 100, Seed: 59429 - Trial 1/3 - Runtime: 20.1695530415 sec, Swap count: 1638, Depth: 619
# Layout trials: 100, Seed: 83320 - Trial 2/3 - Runtime: 19.5107660294 sec, Swap count: 1457, Depth: 544
# Layout trials: 100, Seed: 47819 - Trial 3/3 - Runtime: 19.3209040165 sec, Swap count: 1454, Depth: 538
# Layout trials: 215, Seed: 21319 - Trial 1/3 - Runtime: 32.3312652111 sec, Swap count: 1795, Depth: 547
# Layout trials: 215, Seed: 48520 - Trial 2/3 - Runtime: 33.3569252491 sec, Swap count: 1640, Depth: 542
# Layout trials: 215, Seed: 46566 - Trial 3/3 - Runtime: 36.6293489933 sec, Swap count: 1723, Depth: 657
# Layout trials: 464, Seed: 27460 - Trial 1/3 - Runtime: 83.0165712833 sec, Swap count: 1535, Depth: 573
# Layout trials: 464, Seed: 87841 - Trial 2/3 - Runtime: 85.0740051270 sec, Swap count: 1525, Depth: 573
# Layout trials: 464, Seed: 34993 - Trial 3/3 - Runtime: 85.6915817261 sec, Swap count: 1522, Depth: 536
# Layout trials: 1000, Seed: 91988 - Trial 1/3 - Runtime: 185.2377471924 sec, Swap count: 1584, Depth: 708
# Layout trials: 1000, Seed: 89593 - Trial 2/3 - Runtime: 189.6004343033 sec, Swap count: 1512, Depth: 502
# Layout trials: 1000, Seed: 84939 - Trial 3/3 - Runtime: 185.4714531898 sec, Swap count: 1544, Depth: 542
# Running experiment for 68 qubits
# Layout trials: 1, Seed: 9358 - Trial 1/3 - Runtime: 5.1292340755 sec, Swap count: 3391, Depth: 883
# Layout trials: 1, Seed: 79840 - Trial 2/3 - Runtime: 5.7265739441 sec, Swap count: 3567, Depth: 1261
# Layout trials: 1, Seed: 83227 - Trial 3/3 - Runtime: 5.8966619968 sec, Swap count: 4148, Depth: 1625
# Layout trials: 2, Seed: 22431 - Trial 1/3 - Runtime: 2.8026731014 sec, Swap count: 3767, Depth: 1510
# Layout trials: 2, Seed: 70010 - Trial 2/3 - Runtime: 2.7035171986 sec, Swap count: 3495, Depth: 1208
# Layout trials: 2, Seed: 95568 - Trial 3/3 - Runtime: 2.6606159210 sec, Swap count: 3670, Depth: 1089
# Layout trials: 5, Seed: 32087 - Trial 1/3 - Runtime: 2.9451651573 sec, Swap count: 3593, Depth: 1074
# Layout trials: 5, Seed: 21417 - Trial 2/3 - Runtime: 3.5256898403 sec, Swap count: 3178, Depth: 1160
# Layout trials: 5, Seed: 60589 - Trial 3/3 - Runtime: 3.4616088867 sec, Swap count: 3724, Depth: 1162
# Layout trials: 10, Seed: 49735 - Trial 1/3 - Runtime: 4.1394631863 sec, Swap count: 3210, Depth: 747
# Layout trials: 10, Seed: 35382 - Trial 2/3 - Runtime: 4.5213680267 sec, Swap count: 3348, Depth: 980
# Layout trials: 10, Seed: 83886 - Trial 3/3 - Runtime: 4.7121579647 sec, Swap count: 3318, Depth: 1026
# Layout trials: 22, Seed: 90198 - Trial 1/3 - Runtime: 7.7952089310 sec, Swap count: 3367, Depth: 927
# Layout trials: 22, Seed: 73000 - Trial 2/3 - Runtime: 8.0576870441 sec, Swap count: 3453, Depth: 1266
# Layout trials: 22, Seed: 28785 - Trial 3/3 - Runtime: 8.5175068378 sec, Swap count: 3443, Depth: 1377
# Layout trials: 46, Seed: 89733 - Trial 1/3 - Runtime: 16.0493159294 sec, Swap count: 3534, Depth: 1098
# Layout trials: 46, Seed: 42504 - Trial 2/3 - Runtime: 15.2148952484 sec, Swap count: 3339, Depth: 1358
# Layout trials: 46, Seed: 7331 - Trial 3/3 - Runtime: 12.4273967743 sec, Swap count: 2901, Depth: 815
# Layout trials: 100, Seed: 30021 - Trial 1/3 - Runtime: 28.4280319214 sec, Swap count: 3073, Depth: 839
# Layout trials: 100, Seed: 4207 - Trial 2/3 - Runtime: 30.3336360455 sec, Swap count: 2900, Depth: 781
# Layout trials: 100, Seed: 41347 - Trial 3/3 - Runtime: 31.8390972614 sec, Swap count: 2777, Depth: 749
# Layout trials: 215, Seed: 52581 - Trial 1/3 - Runtime: 71.7480139732 sec, Swap count: 2822, Depth: 819
# Layout trials: 215, Seed: 35093 - Trial 2/3 - Runtime: 77.8277511597 sec, Swap count: 3280, Depth: 872
# Layout trials: 215, Seed: 8675 - Trial 3/3 - Runtime: 79.4551842213 sec, Swap count: 3043, Depth: 878
# Layout trials: 464, Seed: 27653 - Trial 1/3 - Runtime: 175.2606000900 sec, Swap count: 3124, Depth: 807
# Layout trials: 464, Seed: 74341 - Trial 2/3 - Runtime: 172.5466878414 sec, Swap count: 3138, Depth: 985
# Layout trials: 464, Seed: 94098 - Trial 3/3 - Runtime: 171.2303030491 sec, Swap count: 2724, Depth: 643
# Layout trials: 1000, Seed: 41245 - Trial 1/3 - Runtime: 367.7668240070 sec, Swap count: 2747, Depth: 681
# Layout trials: 1000, Seed: 27869 - Trial 2/3 - Runtime: 377.8775949478 sec, Swap count: 2916, Depth: 715
# Layout trials: 1000, Seed: 85909 - Trial 3/3 - Runtime: 383.8141899109 sec, Swap count: 3014, Depth: 852
# Running experiment for 88 qubits
# Layout trials: 1, Seed: 65435 - Trial 1/3 - Runtime: 9.9125270844 sec, Swap count: 6641, Depth: 2610
# Layout trials: 1, Seed: 51856 - Trial 2/3 - Runtime: 9.4345500469 sec, Swap count: 6723, Depth: 1808
# Layout trials: 1, Seed: 84259 - Trial 3/3 - Runtime: 9.7912952900 sec, Swap count: 6481, Depth: 1723
# Layout trials: 2, Seed: 60142 - Trial 1/3 - Runtime: 7.8183679581 sec, Swap count: 6803, Depth: 2422
# Layout trials: 2, Seed: 18726 - Trial 2/3 - Runtime: 7.6850059032 sec, Swap count: 6215, Depth: 1837
# Layout trials: 2, Seed: 34718 - Trial 3/3 - Runtime: 7.8453691006 sec, Swap count: 6214, Depth: 2249
# Layout trials: 5, Seed: 18301 - Trial 1/3 - Runtime: 9.3506491184 sec, Swap count: 6559, Depth: 2012
# Layout trials: 5, Seed: 32325 - Trial 2/3 - Runtime: 9.0442559719 sec, Swap count: 6820, Depth: 2258
# Layout trials: 5, Seed: 97647 - Trial 3/3 - Runtime: 5.7029860020 sec, Swap count: 5880, Depth: 1675
# Layout trials: 10, Seed: 73579 - Trial 1/3 - Runtime: 7.6378180981 sec, Swap count: 6095, Depth: 1618
# Layout trials: 10, Seed: 70644 - Trial 2/3 - Runtime: 7.6665871143 sec, Swap count: 6343, Depth: 1770
# Layout trials: 10, Seed: 34438 - Trial 3/3 - Runtime: 7.4037029743 sec, Swap count: 5438, Depth: 1482
# Layout trials: 22, Seed: 97912 - Trial 1/3 - Runtime: 13.9761819839 sec, Swap count: 5562, Depth: 1472
# Layout trials: 22, Seed: 76622 - Trial 2/3 - Runtime: 14.1939179897 sec, Swap count: 5522, Depth: 1755
# Layout trials: 22, Seed: 56155 - Trial 3/3 - Runtime: 14.1157271862 sec, Swap count: 5059, Depth: 1414
# Layout trials: 46, Seed: 76484 - Trial 1/3 - Runtime: 26.5917539597 sec, Swap count: 5670, Depth: 2091
# Layout trials: 46, Seed: 52350 - Trial 2/3 - Runtime: 28.2425417900 sec, Swap count: 6420, Depth: 1853
# Layout trials: 46, Seed: 47447 - Trial 3/3 - Runtime: 28.8699388504 sec, Swap count: 5824, Depth: 1710
# Layout trials: 100, Seed: 28746 - Trial 1/3 - Runtime: 62.3826348782 sec, Swap count: 5095, Depth: 1341
# Layout trials: 100, Seed: 18131 - Trial 2/3 - Runtime: 65.3515977859 sec, Swap count: 5338, Depth: 1409
# Layout trials: 100, Seed: 66784 - Trial 3/3 - Runtime: 64.1917088032 sec, Swap count: 4791, Depth: 916
# Layout trials: 215, Seed: 64686 - Trial 1/3 - Runtime: 142.3521969318 sec, Swap count: 5426, Depth: 1473
# Layout trials: 215, Seed: 11915 - Trial 2/3 - Runtime: 144.9422647953 sec, Swap count: 5262, Depth: 1377
# Layout trials: 215, Seed: 99061 - Trial 3/3 - Runtime: 146.9198820591 sec, Swap count: 5963, Depth: 1679
# Layout trials: 464, Seed: 6175 - Trial 1/3 - Runtime: 306.0536632538 sec, Swap count: 5616, Depth: 1542
# Layout trials: 464, Seed: 14371 - Trial 2/3 - Runtime: 311.2878887653 sec, Swap count: 5140, Depth: 1528
# Layout trials: 464, Seed: 20033 - Trial 3/3 - Runtime: 316.4301156998 sec, Swap count: 5057, Depth: 1418
# Layout trials: 1000, Seed: 82240 - Trial 1/3 - Runtime: 680.8788588047 sec, Swap count: 5441, Depth: 1658
# Layout trials: 1000, Seed: 20969 - Trial 2/3 - Runtime: 658.7973871231 sec, Swap count: 4642, Depth: 1037
# Layout trials: 1000, Seed: 89192 - Trial 3/3 - Runtime: 642.9634039402 sec, Swap count: 5663, Depth: 1453
# Running experiment for 107 qubits
# Layout trials: 1, Seed: 55333 - Trial 1/3 - Runtime: 9.4335422516 sec, Swap count: 10158, Depth: 2523
# Layout trials: 1, Seed: 78172 - Trial 2/3 - Runtime: 8.9732558727 sec, Swap count: 10089, Depth: 2810
# Layout trials: 1, Seed: 8326 - Trial 3/3 - Runtime: 9.5215578079 sec, Swap count: 10180, Depth: 3452
# Layout trials: 2, Seed: 50432 - Trial 1/3 - Runtime: 8.5157139301 sec, Swap count: 10897, Depth: 3708
# Layout trials: 2, Seed: 50019 - Trial 2/3 - Runtime: 8.3116571903 sec, Swap count: 10625, Depth: 3172
# Layout trials: 2, Seed: 78104 - Trial 3/3 - Runtime: 8.5155739784 sec, Swap count: 9680, Depth: 2574
# Layout trials: 5, Seed: 61348 - Trial 1/3 - Runtime: 10.0529112816 sec, Swap count: 9690, Depth: 2617
# Layout trials: 5, Seed: 69352 - Trial 2/3 - Runtime: 10.7139079571 sec, Swap count: 8989, Depth: 2484
# Layout trials: 5, Seed: 32953 - Trial 3/3 - Runtime: 12.6303915977 sec, Swap count: 10099, Depth: 3163
# Layout trials: 10, Seed: 72512 - Trial 1/3 - Runtime: 14.2071340084 sec, Swap count: 9421, Depth: 2900
# Layout trials: 10, Seed: 1504 - Trial 2/3 - Runtime: 14.6771430969 sec, Swap count: 10041, Depth: 3190
# Layout trials: 10, Seed: 89166 - Trial 3/3 - Runtime: 15.5592958927 sec, Swap count: 9362, Depth: 2119
# Layout trials: 22, Seed: 94466 - Trial 1/3 - Runtime: 26.9710779190 sec, Swap count: 8685, Depth: 2511
# Layout trials: 22, Seed: 15014 - Trial 2/3 - Runtime: 25.8930311203 sec, Swap count: 8890, Depth: 2098
# Layout trials: 22, Seed: 89353 - Trial 3/3 - Runtime: 22.6718192101 sec, Swap count: 8621, Depth: 2037
# Layout trials: 46, Seed: 70381 - Trial 1/3 - Runtime: 51.0255010128 sec, Swap count: 9145, Depth: 2823
# Layout trials: 46, Seed: 98419 - Trial 2/3 - Runtime: 50.9943819046 sec, Swap count: 9325, Depth: 2948
# Layout trials: 46, Seed: 34973 - Trial 3/3 - Runtime: 50.3140399456 sec, Swap count: 9183, Depth: 2183
# Layout trials: 100, Seed: 84012 - Trial 1/3 - Runtime: 106.7568178177 sec, Swap count: 8202, Depth: 1783
# Layout trials: 100, Seed: 44587 - Trial 2/3 - Runtime: 108.8071329594 sec, Swap count: 8912, Depth: 2131
# Layout trials: 100, Seed: 14621 - Trial 3/3 - Runtime: 107.0985291004 sec, Swap count: 7754, Depth: 1877
# Layout trials: 215, Seed: 38469 - Trial 1/3 - Runtime: 218.8275759220 sec, Swap count: 7207, Depth: 2127
# Layout trials: 215, Seed: 56985 - Trial 2/3 - Runtime: 198.9515728951 sec, Swap count: 8659, Depth: 1819
# Layout trials: 215, Seed: 20730 - Trial 3/3 - Runtime: 187.2862489223 sec, Swap count: 8638, Depth: 2322
# Layout trials: 464, Seed: 59470 - Trial 1/3 - Runtime: 452.3564531803 sec, Swap count: 8354, Depth: 2404
# Layout trials: 464, Seed: 425 - Trial 2/3 - Runtime: 464.6462390423 sec, Swap count: 8389, Depth: 2248
# Layout trials: 464, Seed: 94646 - Trial 3/3 - Runtime: 483.9284279346 sec, Swap count: 8439, Depth: 2560
# Layout trials: 1000, Seed: 94329 - Trial 1/3 - Runtime: 998.7801990509 sec, Swap count: 7269, Depth: 1472
# Layout trials: 1000, Seed: 34522 - Trial 2/3 - Runtime: 1075.4093821049 sec, Swap count: 8741, Depth: 2375
# Layout trials: 1000, Seed: 65612 - Trial 3/3 - Runtime: 925.4201710224 sec, Swap count: 7489, Depth: 2117
# Running experiment for 127 qubits
# Layout trials: 1, Seed: 99871 - Trial 1/3 - Runtime: 17.4176521301 sec, Swap count: 16546, Depth: 4970
# Layout trials: 1, Seed: 23416 - Trial 2/3 - Runtime: 11.6666381359 sec, Swap count: 16514, Depth: 4566
# Layout trials: 1, Seed: 66542 - Trial 3/3 - Runtime: 11.3737421036 sec, Swap count: 14719, Depth: 4164
# Layout trials: 2, Seed: 13947 - Trial 1/3 - Runtime: 9.7509019375 sec, Swap count: 14103, Depth: 3402
# Layout trials: 2, Seed: 81959 - Trial 2/3 - Runtime: 10.3762781620 sec, Swap count: 14542, Depth: 4862
# Layout trials: 2, Seed: 39117 - Trial 3/3 - Runtime: 10.7572979927 sec, Swap count: 16777, Depth: 4100
# Layout trials: 5, Seed: 83748 - Trial 1/3 - Runtime: 11.6884150505 sec, Swap count: 14328, Depth: 4093
# Layout trials: 5, Seed: 66540 - Trial 2/3 - Runtime: 12.1782042980 sec, Swap count: 13856, Depth: 2717
# Layout trials: 5, Seed: 79818 - Trial 3/3 - Runtime: 12.6701860428 sec, Swap count: 11928, Depth: 3211
# Layout trials: 10, Seed: 26071 - Trial 1/3 - Runtime: 15.0883610249 sec, Swap count: 12544, Depth: 3021
# Layout trials: 10, Seed: 20032 - Trial 2/3 - Runtime: 17.5265951157 sec, Swap count: 14235, Depth: 3492
# Layout trials: 10, Seed: 49009 - Trial 3/3 - Runtime: 17.3898189068 sec, Swap count: 12684, Depth: 3393
# Layout trials: 22, Seed: 99943 - Trial 1/3 - Runtime: 28.8958239555 sec, Swap count: 12416, Depth: 3341
# Layout trials: 22, Seed: 21174 - Trial 2/3 - Runtime: 31.1638000011 sec, Swap count: 13290, Depth: 3191
# Layout trials: 22, Seed: 70697 - Trial 3/3 - Runtime: 32.6645040512 sec, Swap count: 12991, Depth: 3208
# Layout trials: 46, Seed: 69514 - Trial 1/3 - Runtime: 57.3388080597 sec, Swap count: 11903, Depth: 2842
# Layout trials: 46, Seed: 74 - Trial 2/3 - Runtime: 57.8166527748 sec, Swap count: 12782, Depth: 3277
# Layout trials: 46, Seed: 78504 - Trial 3/3 - Runtime: 58.0654296875 sec, Swap count: 11895, Depth: 2847
# Layout trials: 100, Seed: 42487 - Trial 1/3 - Runtime: 121.7838950157 sec, Swap count: 11581, Depth: 2983
# Layout trials: 100, Seed: 64042 - Trial 2/3 - Runtime: 117.7558977604 sec, Swap count: 11422, Depth: 2351
# Layout trials: 100, Seed: 2552 - Trial 3/3 - Runtime: 123.9075820446 sec, Swap count: 13438, Depth: 3908
# Layout trials: 215, Seed: 14662 - Trial 1/3 - Runtime: 254.4729609489 sec, Swap count: 12950, Depth: 3503
# Layout trials: 215, Seed: 47576 - Trial 2/3 - Runtime: 250.7968320847 sec, Swap count: 13227, Depth: 3640
# Layout trials: 215, Seed: 40306 - Trial 3/3 - Runtime: 263.0182390213 sec, Swap count: 11880, Depth: 3548
# Layout trials: 464, Seed: 31385 - Trial 1/3 - Runtime: 517.7163660526 sec, Swap count: 11538, Depth: 2750
# Layout trials: 464, Seed: 7592 - Trial 2/3 - Runtime: 525.1892881393 sec, Swap count: 11332, Depth: 2693
# Layout trials: 464, Seed: 31571 - Trial 3/3 - Runtime: 524.8850686550 sec, Swap count: 11981, Depth: 2889
# Layout trials: 1000, Seed: 74364 - Trial 1/3 - Runtime: 1162.3224129677 sec, Swap count: 12163, Depth: 2698
# Layout trials: 1000, Seed: 10322 - Trial 2/3 - Runtime: 1177.7914631367 sec, Swap count: 10934, Depth: 1941
# Layout trials: 1000, Seed: 11226 - Trial 3/3 - Runtime: 1164.6611850262 sec, Swap count: 11264, Depth: 2754
# Results saved to experiments/qft_lookahead.csv
