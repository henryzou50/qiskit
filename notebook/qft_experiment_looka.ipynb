# %%
from qiskit.transpiler import CouplingMap
from qiskit.transpiler.passes import SabreLayout, SabreSwap
from utils import file_to_coupling_map, directory_to_circuits, build_pass_manager
import random
import time
import csv
import os
import numpy as np
# Out:
# [1, 2, 5, 10, 22, 46, 100, 215, 464, 1000]

# %%
def run_experiment(cm_name, qc_name, layout_trials_list=[1, 10, 100, 1000], heuristic="lookahead", num_pass_trials=5, seed=42, output_csv="experiments/experiment_new.csv"):
    """
    Runs a transpilation experiment using SABRE passes on a set of quantum circuits.

    Parameters:
    - cm_name (str): Name of the coupling map file (without extension) located in 'coupling_maps/' directory.
    - qc_name (str): Name of the directory containing quantum circuits to run the experiment on.
    - layout_trials_list (list): List of layout (and swap) trials to run for each circuit. Default is [1, 10, 100, 1000].
    - heuristic (str): Heuristic to use in SabreSwap. Default is "lookahead".
    - num_pass_trials (int): Number of different seeds for running the whole pass. Default is 1.
    - seed (int): Random seed for reproducibility. Default is 42.
    - output_csv (str): Filename for the CSV file where results will be saved. Default is "experiment_results.csv".
    
    Returns:
    - None (Results are saved to a CSV file)
    """
    
    # Set random seed for reproducibility
    random.seed(seed)

    # Load the coupling map and the quantum circuits
    cm = CouplingMap(file_to_coupling_map(f'coupling_maps/{cm_name}.txt'))
    qc_list = directory_to_circuits(f'{qc_name}')

    # Prepare the CSV file
    with open(output_csv, mode='w', newline='') as csvfile:
        fieldnames = ["num_qubits", "layout_trials", "heuristic", "avg_runtime", "avg_swap_count", "avg_depth", "num_pass_trials"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        # Run trials for each circuit
        for qc in qc_list:
            num_qubits = qc.num_qubits
            print(f"Running experiment for {num_qubits} qubits")

            for layout_trials in layout_trials_list:
                seed_list = random.sample(range(0, 100000), num_pass_trials)

                total_runtime = 0
                total_swap_count = 0
                total_depth = 0

                for trial in range(num_pass_trials):
                    # Create the pass manager with the specified layout trials
                    rp = SabreSwap(coupling_map=cm, heuristic=heuristic, seed=seed_list[trial], trials=layout_trials)
                    lp = SabreLayout(coupling_map=cm, routing_pass=rp, seed=seed_list[trial])
                    pm = build_pass_manager(cm, lp, rp)

                    # Run the transpilation pass
                    time_start = time.time()
                    qc_tr = pm.run(qc)
                    time_end = time.time()

                    # Collect the metrics for this trial
                    runtime = time_end - time_start
                    swap_count = qc_tr.count_ops().get('swap', 0)
                    depth = qc_tr.depth(lambda x: x.operation.num_qubits == 2)  # 2-qubit gates

                    total_runtime += runtime
                    total_swap_count += swap_count
                    total_depth += depth

                    print(f"Layout trials: {layout_trials}, Seed: {seed_list[trial]} - Trial {trial+1}/{num_pass_trials} - Runtime: {runtime:.10f} sec, Swap count: {swap_count}, Depth: {depth}")

                # Calculate averages
                avg_runtime = total_runtime / num_pass_trials
                avg_swap_count = total_swap_count / num_pass_trials
                avg_depth = total_depth / num_pass_trials

                # Store averaged results in CSV
                writer.writerow({
                    "num_qubits": num_qubits,
                    "layout_trials": layout_trials,
                    "heuristic": heuristic,
                    "avg_runtime": avg_runtime,
                    "avg_swap_count": avg_swap_count,
                    "avg_depth": avg_depth,
                    "num_pass_trials": num_pass_trials
                })

    print(f"Results saved to {output_csv}")

# %%
# Example usage:

heuristic = "lookahead"

# Generate log scale values
log_values = np.linspace(0, 3, 10)
linear_values = np.round(10 ** log_values).astype(int)
unique_values = np.unique(np.clip(linear_values, 0, 1000))
layout_trials_list = unique_values.tolist()

run_experiment(cm_name='heavy_hex_127', qc_name='qft', heuristic=heuristic, layout_trials_list=layout_trials_list, num_pass_trials=3, output_csv=f"experiments/qft_{heuristic}.csv")
# Out:
# Running experiment for 10 qubits
# Layout trials: 1, Seed: 83810 - Trial 1/5 - Runtime: 0.0623238087 sec, Swap count: 78, Depth: 70
# Layout trials: 1, Seed: 14592 - Trial 2/5 - Runtime: 0.0590829849 sec, Swap count: 67, Depth: 57
# Layout trials: 1, Seed: 3278 - Trial 3/5 - Runtime: 0.0570299625 sec, Swap count: 81, Depth: 68
# Layout trials: 1, Seed: 97196 - Trial 4/5 - Runtime: 0.0579581261 sec, Swap count: 80, Depth: 50
# Layout trials: 1, Seed: 36048 - Trial 5/5 - Runtime: 0.0594270229 sec, Swap count: 95, Depth: 66
# Layout trials: 6, Seed: 32098 - Trial 1/5 - Runtime: 0.0576758385 sec, Swap count: 62, Depth: 49
# Layout trials: 6, Seed: 29256 - Trial 2/5 - Runtime: 0.0809719563 sec, Swap count: 67, Depth: 56
# Layout trials: 6, Seed: 18289 - Trial 3/5 - Runtime: 0.0591187477 sec, Swap count: 63, Depth: 56
# Layout trials: 6, Seed: 96530 - Trial 4/5 - Runtime: 0.0603129864 sec, Swap count: 86, Depth: 58
# Layout trials: 6, Seed: 13434 - Trial 5/5 - Runtime: 0.0786941051 sec, Swap count: 68, Depth: 57
# Layout trials: 32, Seed: 88696 - Trial 1/5 - Runtime: 0.0706110001 sec, Swap count: 58, Depth: 61
# Layout trials: 32, Seed: 97080 - Trial 2/5 - Runtime: 0.0708849430 sec, Swap count: 62, Depth: 55
# Layout trials: 32, Seed: 71482 - Trial 3/5 - Runtime: 0.0687890053 sec, Swap count: 54, Depth: 58
# Layout trials: 32, Seed: 11395 - Trial 4/5 - Runtime: 0.0699646473 sec, Swap count: 62, Depth: 48
# Layout trials: 32, Seed: 77397 - Trial 5/5 - Runtime: 0.0689179897 sec, Swap count: 60, Depth: 44
# Layout trials: 178, Seed: 55302 - Trial 1/5 - Runtime: 0.1227629185 sec, Swap count: 62, Depth: 47
# Layout trials: 178, Seed: 4165 - Trial 2/5 - Runtime: 0.1332862377 sec, Swap count: 58, Depth: 50
# Layout trials: 178, Seed: 3905 - Trial 3/5 - Runtime: 0.1264760494 sec, Swap count: 59, Depth: 47
# Layout trials: 178, Seed: 12280 - Trial 4/5 - Runtime: 0.1201961040 sec, Swap count: 51, Depth: 55
# Layout trials: 178, Seed: 28657 - Trial 5/5 - Runtime: 0.1232330799 sec, Swap count: 63, Depth: 57
# Layout trials: 1000, Seed: 30495 - Trial 1/5 - Runtime: 0.3893249035 sec, Swap count: 54, Depth: 50
# Layout trials: 1000, Seed: 66237 - Trial 2/5 - Runtime: 0.4161908627 sec, Swap count: 52, Depth: 49
# Layout trials: 1000, Seed: 78907 - Trial 3/5 - Runtime: 0.4235119820 sec, Swap count: 58, Depth: 45
# Layout trials: 1000, Seed: 3478 - Trial 4/5 - Runtime: 0.4035346508 sec, Swap count: 57, Depth: 59
# Layout trials: 1000, Seed: 73563 - Trial 5/5 - Runtime: 0.4051702023 sec, Swap count: 59, Depth: 41
# Running experiment for 29 qubits
# Layout trials: 1, Seed: 26062 - Trial 1/5 - Runtime: 0.2702007294 sec, Swap count: 742, Depth: 257
# Layout trials: 1, Seed: 93850 - Trial 2/5 - Runtime: 0.2618608475 sec, Swap count: 680, Depth: 252
# Layout trials: 1, Seed: 85181 - Trial 3/5 - Runtime: 0.2945868969 sec, Swap count: 798, Depth: 266
# Layout trials: 1, Seed: 91924 - Trial 4/5 - Runtime: 0.2671029568 sec, Swap count: 853, Depth: 310
# Layout trials: 1, Seed: 71426 - Trial 5/5 - Runtime: 0.2680549622 sec, Swap count: 865, Depth: 290
# Layout trials: 6, Seed: 54987 - Trial 1/5 - Runtime: 0.3075728416 sec, Swap count: 763, Depth: 307
# Layout trials: 6, Seed: 28893 - Trial 2/5 - Runtime: 0.2746589184 sec, Swap count: 759, Depth: 270
# Layout trials: 6, Seed: 58878 - Trial 3/5 - Runtime: 0.2747888565 sec, Swap count: 722, Depth: 266
# Layout trials: 6, Seed: 77236 - Trial 4/5 - Runtime: 0.3028228283 sec, Swap count: 711, Depth: 270
# Layout trials: 6, Seed: 36463 - Trial 5/5 - Runtime: 0.2721140385 sec, Swap count: 693, Depth: 243
# Layout trials: 32, Seed: 851 - Trial 1/5 - Runtime: 0.3956160545 sec, Swap count: 657, Depth: 263
# Layout trials: 32, Seed: 99458 - Trial 2/5 - Runtime: 0.3921539783 sec, Swap count: 616, Depth: 268
# Layout trials: 32, Seed: 20926 - Trial 3/5 - Runtime: 0.4255199432 sec, Swap count: 635, Depth: 247
# Layout trials: 32, Seed: 91506 - Trial 4/5 - Runtime: 0.4039962292 sec, Swap count: 717, Depth: 285
# Layout trials: 32, Seed: 55392 - Trial 5/5 - Runtime: 0.3943181038 sec, Swap count: 581, Depth: 227
# Layout trials: 178, Seed: 44597 - Trial 1/5 - Runtime: 1.1477520466 sec, Swap count: 639, Depth: 273
# Layout trials: 178, Seed: 36421 - Trial 2/5 - Runtime: 1.0273630619 sec, Swap count: 561, Depth: 223
# Layout trials: 178, Seed: 20379 - Trial 3/5 - Runtime: 1.0600199699 sec, Swap count: 660, Depth: 254
# Layout trials: 178, Seed: 28221 - Trial 4/5 - Runtime: 1.1175830364 sec, Swap count: 610, Depth: 248
# Layout trials: 178, Seed: 44118 - Trial 5/5 - Runtime: 1.0637402534 sec, Swap count: 599, Depth: 212
# Layout trials: 1000, Seed: 13396 - Trial 1/5 - Runtime: 4.6047189236 sec, Swap count: 562, Depth: 241
# Layout trials: 1000, Seed: 12156 - Trial 2/5 - Runtime: 4.8081729412 sec, Swap count: 597, Depth: 239
# Layout trials: 1000, Seed: 49797 - Trial 3/5 - Runtime: 4.9629130363 sec, Swap count: 635, Depth: 221
# Layout trials: 1000, Seed: 12676 - Trial 4/5 - Runtime: 4.8806848526 sec, Swap count: 628, Depth: 218
# Layout trials: 1000, Seed: 47052 - Trial 5/5 - Runtime: 4.7810797691 sec, Swap count: 584, Depth: 236
# Running experiment for 49 qubits
# Layout trials: 1, Seed: 45082 - Trial 1/5 - Runtime: 0.7840931416 sec, Swap count: 2397, Depth: 532
# Layout trials: 1, Seed: 79131 - Trial 2/5 - Runtime: 0.7908730507 sec, Swap count: 2301, Depth: 638
# Layout trials: 1, Seed: 34671 - Trial 3/5 - Runtime: 0.7953970432 sec, Swap count: 2270, Depth: 533
# Layout trials: 1, Seed: 5695 - Trial 4/5 - Runtime: 0.8036048412 sec, Swap count: 2696, Depth: 641
# Layout trials: 1, Seed: 95647 - Trial 5/5 - Runtime: 0.7939777374 sec, Swap count: 2375, Depth: 564
# Layout trials: 6, Seed: 60217 - Trial 1/5 - Runtime: 0.8183927536 sec, Swap count: 2333, Depth: 580
# Layout trials: 6, Seed: 70284 - Trial 2/5 - Runtime: 0.8109610081 sec, Swap count: 2091, Depth: 466
# Layout trials: 6, Seed: 16361 - Trial 3/5 - Runtime: 0.7997241020 sec, Swap count: 2211, Depth: 522
# Layout trials: 6, Seed: 49615 - Trial 4/5 - Runtime: 0.8095149994 sec, Swap count: 2215, Depth: 515
# Layout trials: 6, Seed: 10328 - Trial 5/5 - Runtime: 0.8147079945 sec, Swap count: 2331, Depth: 568
# Layout trials: 32, Seed: 72357 - Trial 1/5 - Runtime: 1.2722840309 sec, Swap count: 1960, Depth: 581
# Layout trials: 32, Seed: 38427 - Trial 2/5 - Runtime: 1.2658050060 sec, Swap count: 2078, Depth: 530
# Layout trials: 32, Seed: 82397 - Trial 3/5 - Runtime: 1.2741980553 sec, Swap count: 2087, Depth: 510
# Layout trials: 32, Seed: 81070 - Trial 4/5 - Runtime: 1.3112809658 sec, Swap count: 2307, Depth: 610
# Layout trials: 32, Seed: 47400 - Trial 5/5 - Runtime: 1.2857139111 sec, Swap count: 2064, Depth: 527
# Layout trials: 178, Seed: 75674 - Trial 1/5 - Runtime: 3.9496359825 sec, Swap count: 1888, Depth: 470
# Layout trials: 178, Seed: 25203 - Trial 2/5 - Runtime: 3.8834841251 sec, Swap count: 1916, Depth: 475
# Layout trials: 178, Seed: 92349 - Trial 3/5 - Runtime: 3.9902288914 sec, Swap count: 1947, Depth: 487
# Layout trials: 178, Seed: 9116 - Trial 4/5 - Runtime: 3.8728587627 sec, Swap count: 2030, Depth: 518
# Layout trials: 178, Seed: 6006 - Trial 5/5 - Runtime: 3.9314749241 sec, Swap count: 1970, Depth: 519
# Layout trials: 1000, Seed: 86673 - Trial 1/5 - Runtime: 19.1785809994 sec, Swap count: 1926, Depth: 461
# Layout trials: 1000, Seed: 29871 - Trial 2/5 - Runtime: 18.5316526890 sec, Swap count: 1871, Depth: 457
# Layout trials: 1000, Seed: 37930 - Trial 3/5 - Runtime: 19.0311920643 sec, Swap count: 2021, Depth: 466
# Layout trials: 1000, Seed: 10458 - Trial 4/5 - Runtime: 19.2472231388 sec, Swap count: 1921, Depth: 536
# Layout trials: 1000, Seed: 30512 - Trial 5/5 - Runtime: 19.0188901424 sec, Swap count: 1980, Depth: 532
# Running experiment for 68 qubits
# Layout trials: 1, Seed: 13238 - Trial 1/5 - Runtime: 1.5518159866 sec, Swap count: 4724, Depth: 832
# Layout trials: 1, Seed: 49823 - Trial 2/5 - Runtime: 1.6197850704 sec, Swap count: 5512, Depth: 938
# Layout trials: 1, Seed: 36434 - Trial 3/5 - Runtime: 1.5456631184 sec, Swap count: 4555, Depth: 863
# Layout trials: 1, Seed: 59429 - Trial 4/5 - Runtime: 1.5612399578 sec, Swap count: 4397, Depth: 744
# Layout trials: 1, Seed: 83320 - Trial 5/5 - Runtime: 1.5589649677 sec, Swap count: 5069, Depth: 931
# Layout trials: 6, Seed: 47819 - Trial 1/5 - Runtime: 1.5966019630 sec, Swap count: 4338, Depth: 826
# Layout trials: 6, Seed: 21319 - Trial 2/5 - Runtime: 1.5925979614 sec, Swap count: 4402, Depth: 765
# Layout trials: 6, Seed: 48520 - Trial 3/5 - Runtime: 1.5814900398 sec, Swap count: 4503, Depth: 839
# Layout trials: 6, Seed: 46566 - Trial 4/5 - Runtime: 1.5685119629 sec, Swap count: 4343, Depth: 776
# Layout trials: 6, Seed: 27460 - Trial 5/5 - Runtime: 1.5849599838 sec, Swap count: 4489, Depth: 789
# Layout trials: 32, Seed: 87841 - Trial 1/5 - Runtime: 2.6430051327 sec, Swap count: 4158, Depth: 732
# Layout trials: 32, Seed: 34993 - Trial 2/5 - Runtime: 2.6485679150 sec, Swap count: 4294, Depth: 757
# Layout trials: 32, Seed: 91988 - Trial 3/5 - Runtime: 2.6549010277 sec, Swap count: 4426, Depth: 792
# Layout trials: 32, Seed: 89593 - Trial 4/5 - Runtime: 2.6692440510 sec, Swap count: 4123, Depth: 827
# Layout trials: 32, Seed: 84939 - Trial 5/5 - Runtime: 2.6472499371 sec, Swap count: 4118, Depth: 736
# Layout trials: 178, Seed: 9358 - Trial 1/5 - Runtime: 9.0017616749 sec, Swap count: 4019, Depth: 868
# Layout trials: 178, Seed: 79840 - Trial 2/5 - Runtime: 8.9305059910 sec, Swap count: 4075, Depth: 709
# Layout trials: 178, Seed: 83227 - Trial 3/5 - Runtime: 9.0301439762 sec, Swap count: 3974, Depth: 697
# Layout trials: 178, Seed: 22431 - Trial 4/5 - Runtime: 9.0507547855 sec, Swap count: 4060, Depth: 702
# Layout trials: 178, Seed: 70010 - Trial 5/5 - Runtime: 8.7824158669 sec, Swap count: 4031, Depth: 803
# Layout trials: 1000, Seed: 95568 - Trial 1/5 - Runtime: 44.9199991226 sec, Swap count: 3848, Depth: 676
# Layout trials: 1000, Seed: 32087 - Trial 2/5 - Runtime: 44.3397140503 sec, Swap count: 3984, Depth: 723
# Layout trials: 1000, Seed: 21417 - Trial 3/5 - Runtime: 44.9617400169 sec, Swap count: 4099, Depth: 784
# Layout trials: 1000, Seed: 60589 - Trial 4/5 - Runtime: 45.2328441143 sec, Swap count: 3994, Depth: 684
# Layout trials: 1000, Seed: 49735 - Trial 5/5 - Runtime: 43.8592438698 sec, Swap count: 3954, Depth: 788
# Running experiment for 88 qubits
# Layout trials: 1, Seed: 35382 - Trial 1/5 - Runtime: 2.7688779831 sec, Swap count: 8744, Depth: 1010
# Layout trials: 1, Seed: 83886 - Trial 2/5 - Runtime: 2.7009260654 sec, Swap count: 8089, Depth: 1151
# Layout trials: 1, Seed: 90198 - Trial 3/5 - Runtime: 2.7475960255 sec, Swap count: 8122, Depth: 1151
# Layout trials: 1, Seed: 73000 - Trial 4/5 - Runtime: 2.6651980877 sec, Swap count: 7232, Depth: 1158
# Layout trials: 1, Seed: 28785 - Trial 5/5 - Runtime: 2.7795510292 sec, Swap count: 7545, Depth: 1116
# Layout trials: 6, Seed: 89733 - Trial 1/5 - Runtime: 2.7979929447 sec, Swap count: 7568, Depth: 1086
# Layout trials: 6, Seed: 42504 - Trial 2/5 - Runtime: 2.7742819786 sec, Swap count: 7513, Depth: 1033
# Layout trials: 6, Seed: 7331 - Trial 3/5 - Runtime: 2.8136940002 sec, Swap count: 8166, Depth: 1274
# Layout trials: 6, Seed: 30021 - Trial 4/5 - Runtime: 2.8061690331 sec, Swap count: 7427, Depth: 992
# Layout trials: 6, Seed: 4207 - Trial 5/5 - Runtime: 2.7621710300 sec, Swap count: 7687, Depth: 1099
# Layout trials: 32, Seed: 41347 - Trial 1/5 - Runtime: 4.9020700455 sec, Swap count: 7382, Depth: 1089
# Layout trials: 32, Seed: 52581 - Trial 2/5 - Runtime: 4.9179878235 sec, Swap count: 7277, Depth: 1071
# Layout trials: 32, Seed: 35093 - Trial 3/5 - Runtime: 4.8841552734 sec, Swap count: 7041, Depth: 1029
# Layout trials: 32, Seed: 8675 - Trial 4/5 - Runtime: 5.0121810436 sec, Swap count: 7285, Depth: 964
# Layout trials: 32, Seed: 27653 - Trial 5/5 - Runtime: 4.8637769222 sec, Swap count: 7209, Depth: 1071
# Layout trials: 178, Seed: 74341 - Trial 1/5 - Runtime: 17.9623761177 sec, Swap count: 7025, Depth: 1033
# Layout trials: 178, Seed: 94098 - Trial 2/5 - Runtime: 17.9271271229 sec, Swap count: 7314, Depth: 1228
# Layout trials: 178, Seed: 41245 - Trial 3/5 - Runtime: 17.8092610836 sec, Swap count: 7241, Depth: 1097
# Layout trials: 178, Seed: 27869 - Trial 4/5 - Runtime: 18.0001468658 sec, Swap count: 7107, Depth: 1087
# Layout trials: 178, Seed: 85909 - Trial 5/5 - Runtime: 18.2509951591 sec, Swap count: 6882, Depth: 981
# Layout trials: 1000, Seed: 65435 - Trial 1/5 - Runtime: 89.5335223675 sec, Swap count: 6720, Depth: 937
# Layout trials: 1000, Seed: 51856 - Trial 2/5 - Runtime: 90.7031280994 sec, Swap count: 6756, Depth: 922
# Layout trials: 1000, Seed: 84259 - Trial 3/5 - Runtime: 86.7710192204 sec, Swap count: 6433, Depth: 903
