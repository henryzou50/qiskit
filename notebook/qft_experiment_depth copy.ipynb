# %%
from qiskit.transpiler import CouplingMap
from qiskit.transpiler.passes import SabreLayout, SabreSwap
from utils import file_to_coupling_map, directory_to_circuits, build_pass_manager
import random
import time
import csv
import os
import numpy as np

# %%
def run_experiment(cm_name, qc_name, layout_trials_list=[1, 10, 100, 1000], heuristic="lookahead", num_pass_trials=5, seed=42, output_csv="experiments/experiment_new.csv"):
    """
    Runs a transpilation experiment using SABRE passes on a set of quantum circuits.

    Parameters:
    - cm_name (str): Name of the coupling map file (without extension) located in 'coupling_maps/' directory.
    - qc_name (str): Name of the directory containing quantum circuits to run the experiment on.
    - layout_trials_list (list): List of layout (and swap) trials to run for each circuit. Default is [1, 10, 100, 1000].
    - heuristic (str): Heuristic to use in SabreSwap. Default is "lookahead".
    - num_pass_trials (int): Number of different seeds for running the whole pass. Default is 1.
    - seed (int): Random seed for reproducibility. Default is 42.
    - output_csv (str): Filename for the CSV file where results will be saved. Default is "experiment_results.csv".
    
    Returns:
    - None (Results are saved to a CSV file)
    """
    
    # Set random seed for reproducibility
    random.seed(seed)

    # Load the coupling map and the quantum circuits
    cm = CouplingMap(file_to_coupling_map(f'coupling_maps/{cm_name}.txt'))
    qc_list = directory_to_circuits(f'{qc_name}')

    # Prepare the CSV file
    with open(output_csv, mode='w', newline='') as csvfile:
        fieldnames = ["num_qubits", "layout_trials", "heuristic", "avg_runtime", "avg_swap_count", "avg_depth", "num_pass_trials"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        # Run trials for each circuit
        for qc in qc_list:
            num_qubits = qc.num_qubits
            print(f"Running experiment for {num_qubits} qubits")

            for layout_trials in layout_trials_list:
                seed_list = random.sample(range(0, 100000), num_pass_trials)

                total_runtime = 0
                total_swap_count = 0
                total_depth = 0

                for trial in range(num_pass_trials):
                    # Create the pass manager with the specified layout trials
                    rp = SabreSwap(coupling_map=cm, heuristic=heuristic, seed=seed_list[trial], trials=layout_trials)
                    lp = SabreLayout(coupling_map=cm, routing_pass=rp, seed=seed_list[trial])
                    pm = build_pass_manager(cm, lp, rp)

                    # Run the transpilation pass
                    time_start = time.time()
                    qc_tr = pm.run(qc)
                    time_end = time.time()

                    # Collect the metrics for this trial
                    runtime = time_end - time_start
                    swap_count = qc_tr.count_ops().get('swap', 0)
                    depth = qc_tr.depth(lambda x: x.operation.num_qubits == 2)  # 2-qubit gates

                    total_runtime += runtime
                    total_swap_count += swap_count
                    total_depth += depth

                    print(f"Layout trials: {layout_trials}, Seed: {seed_list[trial]} - Trial {trial+1}/{num_pass_trials} - Runtime: {runtime:.10f} sec, Swap count: {swap_count}, Depth: {depth}")

                # Calculate averages
                avg_runtime = total_runtime / num_pass_trials
                avg_swap_count = total_swap_count / num_pass_trials
                avg_depth = total_depth / num_pass_trials

                # Store averaged results in CSV
                writer.writerow({
                    "num_qubits": num_qubits,
                    "layout_trials": layout_trials,
                    "heuristic": heuristic,
                    "avg_runtime": avg_runtime,
                    "avg_swap_count": avg_swap_count,
                    "avg_depth": avg_depth,
                    "num_pass_trials": num_pass_trials
                })

    print(f"Results saved to {output_csv}")

# %%
# Example usage:

heuristic = "depth"

# Generate log scale values
log_values = np.linspace(0, 3, 10)
linear_values = np.round(10 ** log_values).astype(int)
unique_values = np.unique(np.clip(linear_values, 0, 1000))
layout_trials_list = unique_values.tolist()

run_experiment(cm_name='heavy_hex_127', qc_name='qft', heuristic=heuristic, layout_trials_list=layout_trials_list, num_pass_trials=3, output_csv=f"experiments/qft_{heuristic}.csv")
# Out:
# Running experiment for 10 qubits
# Layout trials: 1, Seed: 83810 - Trial 1/3 - Runtime: 0.1748688221 sec, Swap count: 68, Depth: 53
# Layout trials: 1, Seed: 14592 - Trial 2/3 - Runtime: 0.2258818150 sec, Swap count: 69, Depth: 50
# Layout trials: 1, Seed: 3278 - Trial 3/3 - Runtime: 0.2397050858 sec, Swap count: 60, Depth: 48
# Layout trials: 2, Seed: 97196 - Trial 1/3 - Runtime: 0.1821820736 sec, Swap count: 62, Depth: 61
# Layout trials: 2, Seed: 36048 - Trial 2/3 - Runtime: 0.1885561943 sec, Swap count: 95, Depth: 54
# Layout trials: 2, Seed: 32098 - Trial 3/3 - Runtime: 0.1850271225 sec, Swap count: 67, Depth: 53
# Layout trials: 5, Seed: 29256 - Trial 1/3 - Runtime: 0.3226323128 sec, Swap count: 54, Depth: 50
# Layout trials: 5, Seed: 18289 - Trial 2/3 - Runtime: 0.2747418880 sec, Swap count: 55, Depth: 48
# Layout trials: 5, Seed: 96530 - Trial 3/3 - Runtime: 0.1833281517 sec, Swap count: 62, Depth: 44
# Layout trials: 10, Seed: 13434 - Trial 1/3 - Runtime: 0.2710070610 sec, Swap count: 58, Depth: 53
# Layout trials: 10, Seed: 88696 - Trial 2/3 - Runtime: 0.2848267555 sec, Swap count: 58, Depth: 53
# Layout trials: 10, Seed: 97080 - Trial 3/3 - Runtime: 0.3598661423 sec, Swap count: 58, Depth: 48
# Layout trials: 22, Seed: 71482 - Trial 1/3 - Runtime: 0.3477699757 sec, Swap count: 56, Depth: 49
# Layout trials: 22, Seed: 11395 - Trial 2/3 - Runtime: 0.3118050098 sec, Swap count: 53, Depth: 49
# Layout trials: 22, Seed: 77397 - Trial 3/3 - Runtime: 0.4070699215 sec, Swap count: 55, Depth: 50
# Layout trials: 46, Seed: 55302 - Trial 1/3 - Runtime: 0.4193139076 sec, Swap count: 55, Depth: 46
# Layout trials: 46, Seed: 4165 - Trial 2/3 - Runtime: 0.5470938683 sec, Swap count: 56, Depth: 58
# Layout trials: 46, Seed: 3905 - Trial 3/3 - Runtime: 0.3923158646 sec, Swap count: 52, Depth: 47
# Layout trials: 100, Seed: 12280 - Trial 1/3 - Runtime: 0.9083409309 sec, Swap count: 53, Depth: 49
# Layout trials: 100, Seed: 28657 - Trial 2/3 - Runtime: 0.8039038181 sec, Swap count: 53, Depth: 53
# Layout trials: 100, Seed: 30495 - Trial 3/3 - Runtime: 0.8692140579 sec, Swap count: 53, Depth: 48
# Layout trials: 215, Seed: 66237 - Trial 1/3 - Runtime: 1.9243779182 sec, Swap count: 56, Depth: 47
# Layout trials: 215, Seed: 78907 - Trial 2/3 - Runtime: 2.3220241070 sec, Swap count: 56, Depth: 54
# Layout trials: 215, Seed: 3478 - Trial 3/3 - Runtime: 2.4384529591 sec, Swap count: 56, Depth: 47
# Layout trials: 464, Seed: 73563 - Trial 1/3 - Runtime: 4.4556720257 sec, Swap count: 49, Depth: 44
# Layout trials: 464, Seed: 26062 - Trial 2/3 - Runtime: 4.8245110512 sec, Swap count: 55, Depth: 49
# Layout trials: 464, Seed: 93850 - Trial 3/3 - Runtime: 3.8916530609 sec, Swap count: 57, Depth: 57
# Layout trials: 1000, Seed: 85181 - Trial 1/3 - Runtime: 7.6634478569 sec, Swap count: 54, Depth: 50
# Layout trials: 1000, Seed: 91924 - Trial 2/3 - Runtime: 7.0076229572 sec, Swap count: 54, Depth: 49
# Layout trials: 1000, Seed: 71426 - Trial 3/3 - Runtime: 7.2207100391 sec, Swap count: 51, Depth: 48
# Running experiment for 29 qubits
# Layout trials: 1, Seed: 54987 - Trial 1/3 - Runtime: 2.6302132607 sec, Swap count: 783, Depth: 230
# Layout trials: 1, Seed: 28893 - Trial 2/3 - Runtime: 2.8505449295 sec, Swap count: 727, Depth: 224
# Layout trials: 1, Seed: 58878 - Trial 3/3 - Runtime: 3.3252100945 sec, Swap count: 891, Depth: 289
# Layout trials: 2, Seed: 77236 - Trial 1/3 - Runtime: 1.7165329456 sec, Swap count: 728, Depth: 245
# Layout trials: 2, Seed: 36463 - Trial 2/3 - Runtime: 1.9563810825 sec, Swap count: 701, Depth: 210
# Layout trials: 2, Seed: 851 - Trial 3/3 - Runtime: 2.5765156746 sec, Swap count: 695, Depth: 214
# Layout trials: 5, Seed: 99458 - Trial 1/3 - Runtime: 2.4227647781 sec, Swap count: 745, Depth: 233
# Layout trials: 5, Seed: 20926 - Trial 2/3 - Runtime: 2.4113070965 sec, Swap count: 748, Depth: 238
# Layout trials: 5, Seed: 91506 - Trial 3/3 - Runtime: 2.0034430027 sec, Swap count: 723, Depth: 265
# Layout trials: 10, Seed: 55392 - Trial 1/3 - Runtime: 2.4208881855 sec, Swap count: 807, Depth: 229
# Layout trials: 10, Seed: 44597 - Trial 2/3 - Runtime: 2.4867742062 sec, Swap count: 661, Depth: 204
# Layout trials: 10, Seed: 36421 - Trial 3/3 - Runtime: 2.5543050766 sec, Swap count: 669, Depth: 208
# Layout trials: 22, Seed: 20379 - Trial 1/3 - Runtime: 4.4538609982 sec, Swap count: 679, Depth: 235
# Layout trials: 22, Seed: 28221 - Trial 2/3 - Runtime: 4.8041951656 sec, Swap count: 604, Depth: 211
# Layout trials: 22, Seed: 44118 - Trial 3/3 - Runtime: 4.8456149101 sec, Swap count: 589, Depth: 179
# Layout trials: 46, Seed: 13396 - Trial 1/3 - Runtime: 10.1930880547 sec, Swap count: 620, Depth: 222
# Layout trials: 46, Seed: 12156 - Trial 2/3 - Runtime: 11.0896430016 sec, Swap count: 614, Depth: 237
# Layout trials: 46, Seed: 49797 - Trial 3/3 - Runtime: 11.5957870483 sec, Swap count: 616, Depth: 208
# Layout trials: 100, Seed: 12676 - Trial 1/3 - Runtime: 25.9023518562 sec, Swap count: 584, Depth: 181
# Layout trials: 100, Seed: 47052 - Trial 2/3 - Runtime: 26.8396008015 sec, Swap count: 537, Depth: 170
# Layout trials: 100, Seed: 45082 - Trial 3/3 - Runtime: 25.6091022491 sec, Swap count: 515, Depth: 183
# Layout trials: 215, Seed: 79131 - Trial 1/3 - Runtime: 58.9634160995 sec, Swap count: 556, Depth: 178
# Layout trials: 215, Seed: 34671 - Trial 2/3 - Runtime: 56.1061110497 sec, Swap count: 593, Depth: 187
# Layout trials: 215, Seed: 5695 - Trial 3/3 - Runtime: 49.7148590088 sec, Swap count: 592, Depth: 199
# Layout trials: 464, Seed: 95647 - Trial 1/3 - Runtime: 96.2159607410 sec, Swap count: 538, Depth: 190
# Layout trials: 464, Seed: 60217 - Trial 2/3 - Runtime: 103.1209821701 sec, Swap count: 596, Depth: 195
# Layout trials: 464, Seed: 70284 - Trial 3/3 - Runtime: 110.6354959011 sec, Swap count: 580, Depth: 186
# Layout trials: 1000, Seed: 16361 - Trial 1/3 - Runtime: 249.7625799179 sec, Swap count: 524, Depth: 174
# Layout trials: 1000, Seed: 49615 - Trial 2/3 - Runtime: 262.6059238911 sec, Swap count: 537, Depth: 187
# Layout trials: 1000, Seed: 10328 - Trial 3/3 - Runtime: 245.4050178528 sec, Swap count: 551, Depth: 198
# Running experiment for 49 qubits
# Layout trials: 1, Seed: 72357 - Trial 1/3 - Runtime: 7.2375609875 sec, Swap count: 2345, Depth: 472
# Layout trials: 1, Seed: 38427 - Trial 2/3 - Runtime: 9.7961208820 sec, Swap count: 2760, Depth: 573
# Layout trials: 1, Seed: 82397 - Trial 3/3 - Runtime: 10.3283150196 sec, Swap count: 2319, Depth: 504
# Layout trials: 2, Seed: 81070 - Trial 1/3 - Runtime: 10.9023926258 sec, Swap count: 2179, Depth: 431
# Layout trials: 2, Seed: 47400 - Trial 2/3 - Runtime: 11.2968389988 sec, Swap count: 2203, Depth: 478
# Layout trials: 2, Seed: 75674 - Trial 3/3 - Runtime: 11.0288100243 sec, Swap count: 2312, Depth: 521
# Layout trials: 5, Seed: 25203 - Trial 1/3 - Runtime: 12.6538751125 sec, Swap count: 2226, Depth: 450
# Layout trials: 5, Seed: 92349 - Trial 2/3 - Runtime: 12.2449550629 sec, Swap count: 2412, Depth: 502
# Layout trials: 5, Seed: 9116 - Trial 3/3 - Runtime: 9.0742139816 sec, Swap count: 2410, Depth: 510
# Layout trials: 10, Seed: 6006 - Trial 1/3 - Runtime: 10.9530730247 sec, Swap count: 2153, Depth: 467
# Layout trials: 10, Seed: 86673 - Trial 2/3 - Runtime: 12.0877020359 sec, Swap count: 2139, Depth: 396
# Layout trials: 10, Seed: 29871 - Trial 3/3 - Runtime: 12.0133891106 sec, Swap count: 2142, Depth: 431
# Layout trials: 22, Seed: 37930 - Trial 1/3 - Runtime: 24.9411909580 sec, Swap count: 2107, Depth: 466
# Layout trials: 22, Seed: 10458 - Trial 2/3 - Runtime: 24.7997887135 sec, Swap count: 2124, Depth: 460
# Layout trials: 22, Seed: 30512 - Trial 3/3 - Runtime: 27.0695958138 sec, Swap count: 2234, Depth: 468
# Layout trials: 46, Seed: 13238 - Trial 1/3 - Runtime: 56.7781398296 sec, Swap count: 1954, Depth: 404
# Layout trials: 46, Seed: 49823 - Trial 2/3 - Runtime: 58.4268312454 sec, Swap count: 2087, Depth: 416
# Layout trials: 46, Seed: 36434 - Trial 3/3 - Runtime: 57.4098281860 sec, Swap count: 1820, Depth: 370
# Layout trials: 100, Seed: 59429 - Trial 1/3 - Runtime: 135.5964231491 sec, Swap count: 1954, Depth: 359
# Layout trials: 100, Seed: 83320 - Trial 2/3 - Runtime: 136.0523250103 sec, Swap count: 1725, Depth: 328
# Layout trials: 100, Seed: 47819 - Trial 3/3 - Runtime: 138.9788930416 sec, Swap count: 2075, Depth: 415
# Layout trials: 215, Seed: 21319 - Trial 1/3 - Runtime: 282.3700790405 sec, Swap count: 1817, Depth: 384
# Layout trials: 215, Seed: 48520 - Trial 2/3 - Runtime: 282.8364121914 sec, Swap count: 1812, Depth: 407
# Layout trials: 215, Seed: 46566 - Trial 3/3 - Runtime: 282.8230967522 sec, Swap count: 2013, Depth: 438
# Layout trials: 464, Seed: 27460 - Trial 1/3 - Runtime: 518.9265351295 sec, Swap count: 1894, Depth: 449
# Layout trials: 464, Seed: 87841 - Trial 2/3 - Runtime: 490.8467271328 sec, Swap count: 1795, Depth: 346
# Layout trials: 464, Seed: 34993 - Trial 3/3 - Runtime: 600.9331047535 sec, Swap count: 2018, Depth: 436
# Layout trials: 1000, Seed: 91988 - Trial 1/3 - Runtime: 1305.0284230709 sec, Swap count: 1823, Depth: 400
# Layout trials: 1000, Seed: 89593 - Trial 2/3 - Runtime: 1259.0307562351 sec, Swap count: 1963, Depth: 419
# Layout trials: 1000, Seed: 84939 - Trial 3/3 - Runtime: 1043.0868480206 sec, Swap count: 1911, Depth: 424
# Running experiment for 68 qubits
# Layout trials: 1, Seed: 9358 - Trial 1/3 - Runtime: 35.9646470547 sec, Swap count: 4710, Depth: 705
# Layout trials: 1, Seed: 79840 - Trial 2/3 - Runtime: 36.8791189194 sec, Swap count: 4253, Depth: 712
# Layout trials: 1, Seed: 83227 - Trial 3/3 - Runtime: 33.7605633736 sec, Swap count: 4872, Depth: 755
# Layout trials: 2, Seed: 22431 - Trial 1/3 - Runtime: 36.0624401569 sec, Swap count: 4813, Depth: 823
# Layout trials: 2, Seed: 70010 - Trial 2/3 - Runtime: 37.2468290329 sec, Swap count: 4758, Depth: 720
# Layout trials: 2, Seed: 95568 - Trial 3/3 - Runtime: 36.4064769745 sec, Swap count: 4805, Depth: 788
# Layout trials: 5, Seed: 32087 - Trial 1/3 - Runtime: 39.3487708569 sec, Swap count: 4750, Depth: 742
# Layout trials: 5, Seed: 21417 - Trial 2/3 - Runtime: 37.9999587536 sec, Swap count: 4347, Depth: 748
# Layout trials: 5, Seed: 60589 - Trial 3/3 - Runtime: 41.2696740627 sec, Swap count: 4429, Depth: 675
# Layout trials: 10, Seed: 49735 - Trial 1/3 - Runtime: 44.9127039909 sec, Swap count: 4331, Depth: 678
# Layout trials: 10, Seed: 35382 - Trial 2/3 - Runtime: 47.5905897617 sec, Swap count: 4492, Depth: 700
# Layout trials: 10, Seed: 83886 - Trial 3/3 - Runtime: 47.6983559132 sec, Swap count: 4254, Depth: 745
# Layout trials: 22, Seed: 90198 - Trial 1/3 - Runtime: 88.2861371040 sec, Swap count: 4114, Depth: 609
# Layout trials: 22, Seed: 73000 - Trial 2/3 - Runtime: 91.6669750214 sec, Swap count: 4413, Depth: 694
# Layout trials: 22, Seed: 28785 - Trial 3/3 - Runtime: 85.7879600525 sec, Swap count: 4419, Depth: 711
# Layout trials: 46, Seed: 89733 - Trial 1/3 - Runtime: 180.5398797989 sec, Swap count: 4618, Depth: 738
# Layout trials: 46, Seed: 42504 - Trial 2/3 - Runtime: 178.7198369503 sec, Swap count: 4194, Depth: 652
# Layout trials: 46, Seed: 7331 - Trial 3/3 - Runtime: 173.3422641754 sec, Swap count: 4352, Depth: 664
# Layout trials: 100, Seed: 30021 - Trial 1/3 - Runtime: 372.8779809475 sec, Swap count: 3872, Depth: 590
# Layout trials: 100, Seed: 4207 - Trial 2/3 - Runtime: 380.5345909595 sec, Swap count: 4065, Depth: 632
# Layout trials: 100, Seed: 41347 - Trial 3/3 - Runtime: 381.0039019585 sec, Swap count: 4237, Depth: 685
# Layout trials: 215, Seed: 52581 - Trial 1/3 - Runtime: 760.6416149139 sec, Swap count: 4068, Depth: 647
# Layout trials: 215, Seed: 35093 - Trial 2/3 - Runtime: 798.6932218075 sec, Swap count: 4174, Depth: 646
# Layout trials: 215, Seed: 8675 - Trial 3/3 - Runtime: 701.9654617310 sec, Swap count: 4197, Depth: 708
# Layout trials: 464, Seed: 27653 - Trial 1/3 - Runtime: 1052.5832829475 sec, Swap count: 3924, Depth: 571
# Layout trials: 464, Seed: 74341 - Trial 2/3 - Runtime: 1221.4699091911 sec, Swap count: 3932, Depth: 649
# Layout trials: 464, Seed: 94098 - Trial 3/3 - Runtime: 1228.9327001572 sec, Swap count: 3895, Depth: 657
# Layout trials: 1000, Seed: 41245 - Trial 1/3 - Runtime: 2668.5936148167 sec, Swap count: 3765, Depth: 582
# Layout trials: 1000, Seed: 27869 - Trial 2/3 - Runtime: 1255.6772332191 sec, Swap count: 3604, Depth: 543
# Layout trials: 1000, Seed: 85909 - Trial 3/3 - Runtime: 894.7787032127 sec, Swap count: 3779, Depth: 601
# Running experiment for 88 qubits
# Layout trials: 1, Seed: 65435 - Trial 1/3 - Runtime: 20.0927700996 sec, Swap count: 7840, Depth: 948
# Layout trials: 1, Seed: 51856 - Trial 2/3 - Runtime: 20.9434020519 sec, Swap count: 8801, Depth: 1049
# Layout trials: 1, Seed: 84259 - Trial 3/3 - Runtime: 20.8146429062 sec, Swap count: 8297, Depth: 1016
# Layout trials: 2, Seed: 60142 - Trial 1/3 - Runtime: 21.4522840977 sec, Swap count: 7769, Depth: 922
# Layout trials: 2, Seed: 18726 - Trial 2/3 - Runtime: 20.7722687721 sec, Swap count: 7485, Depth: 935
# Layout trials: 2, Seed: 34718 - Trial 3/3 - Runtime: 20.4874219894 sec, Swap count: 7814, Depth: 971
# Layout trials: 5, Seed: 18301 - Trial 1/3 - Runtime: 21.8748030663 sec, Swap count: 7578, Depth: 1011
# Layout trials: 5, Seed: 32325 - Trial 2/3 - Runtime: 21.2029340267 sec, Swap count: 7969, Depth: 1003
# Layout trials: 5, Seed: 97647 - Trial 3/3 - Runtime: 21.6004922390 sec, Swap count: 8066, Depth: 968
# Layout trials: 10, Seed: 73579 - Trial 1/3 - Runtime: 24.4417781830 sec, Swap count: 7166, Depth: 885
# Layout trials: 10, Seed: 70644 - Trial 2/3 - Runtime: 25.1862201691 sec, Swap count: 7579, Depth: 988
# Layout trials: 10, Seed: 34438 - Trial 3/3 - Runtime: 24.4290201664 sec, Swap count: 7714, Depth: 1023
# Layout trials: 22, Seed: 97912 - Trial 1/3 - Runtime: 50.1730921268 sec, Swap count: 7690, Depth: 987
# Layout trials: 22, Seed: 76622 - Trial 2/3 - Runtime: 49.4267621040 sec, Swap count: 6978, Depth: 924
# Layout trials: 22, Seed: 56155 - Trial 3/3 - Runtime: 49.7622311115 sec, Swap count: 7461, Depth: 975
# Layout trials: 46, Seed: 76484 - Trial 1/3 - Runtime: 97.2439212799 sec, Swap count: 7276, Depth: 946
# Layout trials: 46, Seed: 52350 - Trial 2/3 - Runtime: 97.9333419800 sec, Swap count: 7272, Depth: 946
# Layout trials: 46, Seed: 47447 - Trial 3/3 - Runtime: 99.3241848946 sec, Swap count: 7446, Depth: 954
# Layout trials: 100, Seed: 28746 - Trial 1/3 - Runtime: 212.5097501278 sec, Swap count: 7036, Depth: 975
# Layout trials: 100, Seed: 18131 - Trial 2/3 - Runtime: 213.3560771942 sec, Swap count: 7243, Depth: 915
# Layout trials: 100, Seed: 66784 - Trial 3/3 - Runtime: 207.0806100368 sec, Swap count: 6634, Depth: 947
# Layout trials: 215, Seed: 64686 - Trial 1/3 - Runtime: 437.1731829643 sec, Swap count: 7005, Depth: 919
# Layout trials: 215, Seed: 11915 - Trial 2/3 - Runtime: 448.1216909885 sec, Swap count: 7090, Depth: 863
# Layout trials: 215, Seed: 99061 - Trial 3/3 - Runtime: 434.9037208557 sec, Swap count: 7318, Depth: 1006
# Layout trials: 464, Seed: 6175 - Trial 1/3 - Runtime: 947.4279420376 sec, Swap count: 7014, Depth: 896
# Layout trials: 464, Seed: 14371 - Trial 2/3 - Runtime: 924.3153016567 sec, Swap count: 7048, Depth: 951
# Layout trials: 464, Seed: 20033 - Trial 3/3 - Runtime: 923.8480489254 sec, Swap count: 6811, Depth: 990
# Layout trials: 1000, Seed: 82240 - Trial 1/3 - Runtime: 2004.0673279762 sec, Swap count: 6743, Depth: 893
# Layout trials: 1000, Seed: 20969 - Trial 2/3 - Runtime: 2034.7759571075 sec, Swap count: 6903, Depth: 854
# Layout trials: 1000, Seed: 89192 - Trial 3/3 - Runtime: 2075.4828169346 sec, Swap count: 6705, Depth: 838
# Running experiment for 107 qubits
# Layout trials: 1, Seed: 55333 - Trial 1/3 - Runtime: 36.8375606537 sec, Swap count: 12767, Depth: 1370
# Layout trials: 1, Seed: 78172 - Trial 2/3 - Runtime: 35.7219460011 sec, Swap count: 11488, Depth: 1239
# Layout trials: 1, Seed: 8326 - Trial 3/3 - Runtime: 36.9557888508 sec, Swap count: 11580, Depth: 1191
# Layout trials: 2, Seed: 50432 - Trial 1/3 - Runtime: 38.2934167385 sec, Swap count: 12201, Depth: 1369
# Layout trials: 2, Seed: 50019 - Trial 2/3 - Runtime: 37.7369861603 sec, Swap count: 11691, Depth: 1321
# Layout trials: 2, Seed: 78104 - Trial 3/3 - Runtime: 38.3928728104 sec, Swap count: 11709, Depth: 1370
# Layout trials: 5, Seed: 61348 - Trial 1/3 - Runtime: 39.5849919319 sec, Swap count: 12773, Depth: 1365
# Layout trials: 5, Seed: 69352 - Trial 2/3 - Runtime: 38.9226057529 sec, Swap count: 12262, Depth: 1393
# Layout trials: 5, Seed: 32953 - Trial 3/3 - Runtime: 38.5345151424 sec, Swap count: 11472, Depth: 1221
# Layout trials: 10, Seed: 72512 - Trial 1/3 - Runtime: 46.7453680038 sec, Swap count: 11215, Depth: 1122
# Layout trials: 10, Seed: 1504 - Trial 2/3 - Runtime: 44.0289139748 sec, Swap count: 11343, Depth: 1265
# Layout trials: 10, Seed: 89166 - Trial 3/3 - Runtime: 45.2713100910 sec, Swap count: 10877, Depth: 1199
# Layout trials: 22, Seed: 94466 - Trial 1/3 - Runtime: 90.4660768509 sec, Swap count: 11158, Depth: 1332
# Layout trials: 22, Seed: 15014 - Trial 2/3 - Runtime: 90.3172473907 sec, Swap count: 10790, Depth: 1131
# Layout trials: 22, Seed: 89353 - Trial 3/3 - Runtime: 92.8838262558 sec, Swap count: 11067, Depth: 1231
# Layout trials: 46, Seed: 70381 - Trial 1/3 - Runtime: 182.0753409863 sec, Swap count: 10833, Depth: 1233
# Layout trials: 46, Seed: 98419 - Trial 2/3 - Runtime: 180.5537562370 sec, Swap count: 10974, Depth: 1230
# Layout trials: 46, Seed: 34973 - Trial 3/3 - Runtime: 184.2220690250 sec, Swap count: 10546, Depth: 1205
# Layout trials: 100, Seed: 84012 - Trial 1/3 - Runtime: 401.6309990883 sec, Swap count: 10826, Depth: 1132
# Layout trials: 100, Seed: 44587 - Trial 2/3 - Runtime: 404.9663898945 sec, Swap count: 10355, Depth: 1120
# Layout trials: 100, Seed: 14621 - Trial 3/3 - Runtime: 403.3619718552 sec, Swap count: 11185, Depth: 1276
# Layout trials: 215, Seed: 38469 - Trial 1/3 - Runtime: 809.5669901371 sec, Swap count: 9794, Depth: 1032
# Layout trials: 215, Seed: 56985 - Trial 2/3 - Runtime: 819.7984321117 sec, Swap count: 10726, Depth: 1176
# Layout trials: 215, Seed: 20730 - Trial 3/3 - Runtime: 836.2016968727 sec, Swap count: 10967, Depth: 1223
# Layout trials: 464, Seed: 59470 - Trial 1/3 - Runtime: 1701.0669329166 sec, Swap count: 10293, Depth: 1067
# Layout trials: 464, Seed: 425 - Trial 2/3 - Runtime: 1721.0603001118 sec, Swap count: 10362, Depth: 1188
