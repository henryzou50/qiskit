# %%
from qiskit.transpiler import CouplingMap, PassManager
from qiskit.transpiler.passes import SabreLayout, SabreSwap
from qiskit.transpiler.passes import FullAncillaAllocation, EnlargeWithAncilla, ApplyLayout
from qiskit.converters import circuit_to_dag, dag_to_circuit
from utils import file_to_coupling_map, directory_to_circuits
import random
import time
import os
import numpy as np

# %%
seed = 42
random.seed(seed)

cmap_name= "heavy_hex_127.txt"
cmap = file_to_coupling_map(f"coupling_maps/{cmap_name}")
qc_name = "qft"
heuristic = "decay"
curr_seed = 42
qc_list = directory_to_circuits(f"circuits/{qc_name}")

pass_trials_list = sorted(set(np.logspace(0, 3, num=10, dtype=int)))


# CSV file to store the results
csv_path = f"results/trials_{qc_name}_10.csv"
# Columns are: "swap_count", "depth", "runtime", "num_qubits", "heuristic", "cmap", "trials", "seed"
with open(csv_path, "w") as f:
    f.write("swap_count,depth,runtime,num_qubits,heuristic,cmap,trials,seed\n")

# %%
# Run the circuits
for qc in qc_list:
    num_qubits = qc.num_qubits
    print(f"    Running {qc.name} ")
    # Run the circuits for different number of trials
    for pass_trials in pass_trials_list:
        print(f"Running {pass_trials} trials")
        # Create the sabre pass
        sabre_pass = SabreLayout(cmap, seed=curr_seed, max_iterations=4, swap_trials=pass_trials, layout_trials=pass_trials )
        dag = circuit_to_dag(qc)
        
        # Execute the pass manager
        start = time.time()
        dag_tr = sabre_pass.run(dag)
        end = time.time()
        # Collect the metrics for this trial
        runtime = end - start

        qc_tr = dag_to_circuit(dag_tr)
        swap_count = qc_tr.count_ops().get("swap", 0)
        depth = qc_tr.depth(lambda x: x.operation.num_qubits == 2)

        # Write the results to the CSV file
        # Columns are: "swap_count", "depth", "runtime", "num_qubits", "heuristic", "cmap", "trials", "seed"
        with open(csv_path, "a") as f:
            f.write(f"{swap_count},{depth},{runtime},{num_qubits},{heuristic},{cmap_name},{pass_trials},{curr_seed}\n")
        print(f"            Swap count: {swap_count}, Depth: {depth}, Runtime: {runtime}")
# Out:
#     Running qft_10.qasm
# Running 1 trials
#             Swap count: 57, Depth: 54, Runtime: 0.04242300987243652
# Running 2 trials
#             Swap count: 57, Depth: 54, Runtime: 0.04108691215515137
# Running 4 trials
#             Swap count: 57, Depth: 54, Runtime: 0.044603824615478516
# Running 10 trials
#             Swap count: 54, Depth: 49, Runtime: 0.07099294662475586
# Running 21 trials
#             Swap count: 54, Depth: 49, Runtime: 0.16066288948059082
# Running 46 trials
#             Swap count: 45, Depth: 54, Runtime: 0.5298759937286377
# Running 100 trials
#             Swap count: 45, Depth: 54, Runtime: 2.1651382446289062
# Running 215 trials
#             Swap count: 45, Depth: 54, Runtime: 9.352107048034668
# Running 464 trials
#             Swap count: 45, Depth: 54, Runtime: 43.357731103897095
# Running 1000 trials
#             Swap count: 45, Depth: 54, Runtime: 192.14918398857117
#     Running qft_29.qasm
# Running 1 trials
#             Swap count: 670, Depth: 314, Runtime: 0.23488712310791016
# Running 2 trials
#             Swap count: 570, Depth: 297, Runtime: 0.2313690185546875
# Running 4 trials
#             Swap count: 570, Depth: 297, Runtime: 0.25133800506591797
# Running 10 trials
#             Swap count: 531, Depth: 229, Runtime: 0.48729395866394043
# Running 21 trials
#             Swap count: 498, Depth: 301, Runtime: 1.413898229598999
# Running 46 trials
#             Swap count: 498, Depth: 301, Runtime: 5.455058813095093
# Running 100 trials
#             Swap count: 497, Depth: 261, Runtime: 23.764641761779785
# Running 215 trials
#             Swap count: 476, Depth: 247, Runtime: 104.92831110954285
# Running 464 trials
#             Swap count: 464, Depth: 238, Runtime: 471.46922183036804
# Running 1000 trials
#             Swap count: 456, Depth: 236, Runtime: 2176.3783209323883
#     Running qft_49.qasm
# Running 1 trials
#             Swap count: 1869, Depth: 673, Runtime: 0.6619400978088379
# Running 2 trials
#             Swap count: 1764, Depth: 660, Runtime: 0.6676678657531738
# Running 4 trials
#             Swap count: 1716, Depth: 616, Runtime: 0.7323439121246338
# Running 10 trials
#             Swap count: 1695, Depth: 522, Runtime: 1.485537052154541
# Running 21 trials
#             Swap count: 1580, Depth: 619, Runtime: 4.456063985824585
# Running 46 trials
#             Swap count: 1514, Depth: 469, Runtime: 17.220317840576172
# Running 100 trials
#             Swap count: 1514, Depth: 469, Runtime: 73.61890912055969
# Running 215 trials
#             Swap count: 1399, Depth: 336, Runtime: 326.3371741771698
# Running 464 trials
#             Swap count: 1354, Depth: 524, Runtime: 1486.7939882278442
# Running 1000 trials
#             Swap count: 1354, Depth: 524, Runtime: 8142.991993665695
#     Running qft_68.qasm
# Running 1 trials
#             Swap count: 3945, Depth: 1451, Runtime: 1.8758080005645752
# Running 2 trials
#             Swap count: 3585, Depth: 1166, Runtime: 2.014281988143921
# Running 4 trials
#             Swap count: 3244, Depth: 1127, Runtime: 2.5240461826324463
# Running 10 trials
#             Swap count: 3185, Depth: 1078, Runtime: 5.8165507316589355
# Running 21 trials
#             Swap count: 3142, Depth: 1045, Runtime: 18.004242181777954
# Running 46 trials
#             Swap count: 3075, Depth: 870, Runtime: 70.40136694908142
# Running 100 trials
#             Swap count: 2917, Depth: 868, Runtime: 300.21716499328613
# Running 215 trials
#             Swap count: 2718, Depth: 781, Runtime: 1307.3299050331116
# Running 464 trials
#             Swap count: 2718, Depth: 781, Runtime: 5986.223114013672
# Running 1000 trials
#             Swap count: 2666, Depth: 583, Runtime: 32127.421293258667
#     Running qft_88.qasm
# Running 1 trials
#             Swap count: 5766, Depth: 1403, Runtime: 3.5022897720336914
# Running 2 trials
#             Swap count: 6224, Depth: 1751, Runtime: 3.835041046142578
# Running 4 trials
#             Swap count: 6224, Depth: 1751, Runtime: 4.563015937805176
# Running 10 trials
#             Swap count: 6008, Depth: 1566, Runtime: 10.534815311431885
# Running 21 trials
#             Swap count: 5505, Depth: 1740, Runtime: 32.05731511116028
# Running 46 trials
#             Swap count: 5264, Depth: 1416, Runtime: 124.69703507423401
# Running 100 trials
#             Swap count: 5000, Depth: 1277, Runtime: 531.1263749599457
# Running 215 trials
