# %%
from experiments.utils.pass_managers import run_circuits, build_pm
from experiments.utils.coupling_maps import file_to_coupling_map
from experiments.utils.circuits      import directory_to_circuits, rename_circuits

# Parameters for general experiments
from qiskit.transpiler.passes.routing.sabre_swap_0_20  import SabreSwap_v0_20   
from qiskit.transpiler.passes.routing.sabre_swap_0_20_depth  import SabreSwap_v0_20_Depth
from qiskit.transpiler.passes.routing.sabre_swap_0_20_depth_ties import SabreSwap_v0_20_DepthTies
from qiskit.transpiler.passes.routing.sabre_swap_0_20_depth_crit import SabreSwap_v0_20_DepthCrit

from qiskit.transpiler.passes.layout.sabre_layout import SabreLayout as LP
from qiskit.transpiler.passes.routing.sabre_swap  import SabreSwap as RP

# %%
# List of routing passes
rp_list = [SabreSwap_v0_20, SabreSwap_v0_20_Depth, SabreSwap_v0_20_DepthTies]
skip_list = []

# Main parameters for experiments
qc_type     = 'red_queen'
cm_type     = 'hex_027'
seed        = 42
num_times   = 1
max_iter    = 3

# Other parameters for sabre_mods
beam        = 1
look        = 1
crit        = 1

# %%
# Runs the experiments
coupling_map     = file_to_coupling_map(f'experiments/coupling_maps/{cm_type}.txt')
circuits, files  = directory_to_circuits(f'experiments/circuits/{qc_type}/')
circuits         = rename_circuits(circuits, files)

# %%
for rp in rp_list:
    if rp in skip_list:
        continue
    routing_pass     = rp(coupling_map, seed=seed)
    layout_pass      = LP(coupling_map, RP(coupling_map, seed=seed), seed=seed, max_iterations=max_iter)
    pass_manager     = build_pm(coupling_map, layout_pass, routing_pass)
    rp_name = routing_pass.__class__.__name__
    filename = f'experiments/results/{qc_type}/{rp_name}.csv'
    df = run_circuits(filename, circuits, pass_manager, num_times, max_iter, beam, look, crit)
# Out:
#     Running the experiment for circuit qec_en_n5.qasm...
#         Depths: 22,
#     Circuit qec_en_n5.qasm transpiled with best depth 22 and time 0.013652801513671875.
#     Running the experiment for circuit basis_change_n3.qasm...
#         Depths: 10,
#     Circuit basis_change_n3.qasm transpiled with best depth 10 and time 0.012540102005004883.
#     Running the experiment for circuit qpe.qasm...
#         Depths: 22,
#     Circuit qpe.qasm transpiled with best depth 22 and time 0.014081716537475586.
#     Running the experiment for circuit qft_n4.qasm...
#         Depths: 22,
#     Circuit qft_n4.qasm transpiled with best depth 22 and time 0.013979196548461914.
#     Running the experiment for circuit variational_n4.qasm...
#         Depths: 12,
#     Circuit variational_n4.qasm transpiled with best depth 12 and time 0.013879060745239258.
#     Running the experiment for circuit cat_state_n22.qasm...
#         Depths: 78,
#     Circuit cat_state_n22.qasm transpiled with best depth 78 and time 0.02512216567993164.
#     Running the experiment for circuit ghz_state_n23.qasm...
#         Depths: 87,
#     Circuit ghz_state_n23.qasm transpiled with best depth 87 and time 0.026524782180786133.
#     Running the experiment for circuit simon_n6.qasm...
#         Depths: 35,
#     Circuit simon_n6.qasm transpiled with best depth 35 and time 0.01665496826171875.
#     Running the experiment for circuit bv_n14.qasm...
#         Depths: 53,
#     Circuit bv_n14.qasm transpiled with best depth 53 and time 0.020069122314453125.
#     Running the experiment for circuit cc_n12.qasm...
#         Depths: 78,
#     Circuit cc_n12.qasm transpiled with best depth 78 and time 0.02766704559326172.
#     Running the experiment for circuit qec9xz_n17.qasm...
#         Depths: 94,
#     Circuit qec9xz_n17.qasm transpiled with best depth 94 and time 0.027339935302734375.
#     Running the experiment for circuit bv_n19.qasm...
#         Depths: 79,
#     Circuit bv_n19.qasm transpiled with best depth 79 and time 0.02725505828857422.
#     Running the experiment for circuit multiply_n13.qasm...
#         Depths: 93,
#     Circuit multiply_n13.qasm transpiled with best depth 93 and time 0.03234505653381348.
#     Running the experiment for circuit error_correctiond3_n5.qasm...
#         Depths: 77,
#     Circuit error_correctiond3_n5.qasm transpiled with best depth 77 and time 0.02787303924560547.
#     Running the experiment for circuit qpe_n9.qasm...
#         Depths: 106,
#     Circuit qpe_n9.qasm transpiled with best depth 106 and time 0.03332996368408203.
#     Running the experiment for circuit wstate_n27.qasm...
#         Depths: 145,
#     Circuit wstate_n27.qasm transpiled with best depth 145 and time 0.05269503593444824.
#     Running the experiment for circuit adder_n10.qasm...
#         Depths: 112,
#     Circuit adder_n10.qasm transpiled with best depth 112 and time 0.03815412521362305.
#     Running the experiment for circuit ft_2.qasm...
#         Depths: 56,
#     Circuit ft_2.qasm transpiled with best depth 56 and time 0.06063508987426758.
#     Running the experiment for circuit vqe_uccsd_n4.qasm...
#         Depths: 87,
#     Circuit vqe_uccsd_n4.qasm transpiled with best depth 87 and time 0.02789616584777832.
#     Running the experiment for circuit sat_n7.qasm...
#         Depths: 164,
#     Circuit sat_n7.qasm transpiled with best depth 164 and time 0.04031109809875488.
#     Running the experiment for circuit qaoa_n6.qasm...
#         Depths: 69,
#     Circuit qaoa_n6.qasm transpiled with best depth 69 and time 0.03337502479553223.
#     Running the experiment for circuit grover.qasm...
#         Depths: 222,
#     Circuit grover.qasm transpiled with best depth 222 and time 0.048223018646240234.
#     Running the experiment for circuit seca_n11.qasm...
#         Depths: 136,
#     Circuit seca_n11.qasm transpiled with best depth 136 and time 0.04963207244873047.
#     Running the experiment for circuit knn_n25.qasm...
#         Depths: 214,
#     Circuit knn_n25.qasm transpiled with best depth 214 and time 0.05564093589782715.
#     Running the experiment for circuit swap_test_n25.qasm...
#         Depths: 217,
#     Circuit swap_test_n25.qasm transpiled with best depth 217 and time 0.05675077438354492.
#     Running the experiment for circuit ising_n10.qasm...
#         Depths: 57,
#     Circuit ising_n10.qasm transpiled with best depth 57 and time 0.04717612266540527.
#     Running the experiment for circuit ft_1.qasm...
#         Depths: 72,
#     Circuit ft_1.qasm transpiled with best depth 72 and time 0.07123398780822754.
#     Running the experiment for circuit bigadder_n18.qasm...
#         Depths: 216,
#     Circuit bigadder_n18.qasm transpiled with best depth 216 and time 0.07293701171875.
#     Running the experiment for circuit qram_n20.qasm...
#         Depths: 264,
#     Circuit qram_n20.qasm transpiled with best depth 264 and time 0.08253812789916992.
#     Running the experiment for circuit qf21_n15.qasm...
#         Depths: 333,
#     Circuit qf21_n15.qasm transpiled with best depth 333 and time 0.07462120056152344.
#     Running the experiment for circuit multiplier_n15.qasm...
#         Depths: 455,
#     Circuit multiplier_n15.qasm transpiled with best depth 455 and time 0.13073301315307617.
#     Running the experiment for circuit sat_n11.qasm...
#         Depths: 611,
#     Circuit sat_n11.qasm transpiled with best depth 611 and time 0.1680450439453125.
#     Running the experiment for circuit qft_n18.qasm...
#         Depths: 346,
#     Circuit qft_n18.qasm transpiled with best depth 346 and time 0.19219517707824707.
#     Running the experiment for circuit qec_en_n5.qasm...
#         Depths: 21,
#     Circuit qec_en_n5.qasm transpiled with best depth 21 and time 0.011051177978515625.
#     Running the experiment for circuit basis_change_n3.qasm...
#         Depths: 10,
#     Circuit basis_change_n3.qasm transpiled with best depth 10 and time 0.010973930358886719.
#     Running the experiment for circuit qpe.qasm...
#         Depths: 24,
#     Circuit qpe.qasm transpiled with best depth 24 and time 0.011739015579223633.
#     Running the experiment for circuit qft_n4.qasm...
#         Depths: 19,
#     Circuit qft_n4.qasm transpiled with best depth 19 and time 0.012300968170166016.
#     Running the experiment for circuit variational_n4.qasm...
#         Depths: 12,
#     Circuit variational_n4.qasm transpiled with best depth 12 and time 0.012058734893798828.
#     Running the experiment for circuit cat_state_n22.qasm...
#         Depths: 60,
#     Circuit cat_state_n22.qasm transpiled with best depth 60 and time 0.04632210731506348.
#     Running the experiment for circuit ghz_state_n23.qasm...
#         Depths: 66,
#     Circuit ghz_state_n23.qasm transpiled with best depth 66 and time 0.026412010192871094.
#     Running the experiment for circuit simon_n6.qasm...
#         Depths: 47,
#     Circuit simon_n6.qasm transpiled with best depth 47 and time 0.01482081413269043.
#     Running the experiment for circuit bv_n14.qasm...
#         Depths: 41,
#     Circuit bv_n14.qasm transpiled with best depth 41 and time 0.019243955612182617.
#     Running the experiment for circuit cc_n12.qasm...
#         Depths: 65,
#     Circuit cc_n12.qasm transpiled with best depth 65 and time 0.024860382080078125.
#     Running the experiment for circuit qec9xz_n17.qasm...
#         Depths: 60,
#     Circuit qec9xz_n17.qasm transpiled with best depth 60 and time 0.030124187469482422.
#     Running the experiment for circuit bv_n19.qasm...
#         Depths: 63,
#     Circuit bv_n19.qasm transpiled with best depth 63 and time 0.02611994743347168.
#     Running the experiment for circuit multiply_n13.qasm...
#         Depths: 95,
#     Circuit multiply_n13.qasm transpiled with best depth 95 and time 0.03165698051452637.
#     Running the experiment for circuit error_correctiond3_n5.qasm...
#         Depths: 95,
#     Circuit error_correctiond3_n5.qasm transpiled with best depth 95 and time 0.0286102294921875.
#     Running the experiment for circuit qpe_n9.qasm...
#         Depths: 100,
#     Circuit qpe_n9.qasm transpiled with best depth 100 and time 0.031219959259033203.
#     Running the experiment for circuit wstate_n27.qasm...
#         Depths: 97,
#     Circuit wstate_n27.qasm transpiled with best depth 97 and time 0.05418992042541504.
#     Running the experiment for circuit adder_n10.qasm...
#         Depths: 151,
#     Circuit adder_n10.qasm transpiled with best depth 151 and time 0.03663992881774902.
#     Running the experiment for circuit ft_2.qasm...
#         Depths: 70,
#     Circuit ft_2.qasm transpiled with best depth 70 and time 0.031064748764038086.
#     Running the experiment for circuit vqe_uccsd_n4.qasm...
#         Depths: 87,
#     Circuit vqe_uccsd_n4.qasm transpiled with best depth 87 and time 0.0272219181060791.
#     Running the experiment for circuit sat_n7.qasm...
#         Depths: 162,
#     Circuit sat_n7.qasm transpiled with best depth 162 and time 0.04026389122009277.
#     Running the experiment for circuit qaoa_n6.qasm...
#         Depths: 81,
#     Circuit qaoa_n6.qasm transpiled with best depth 81 and time 0.034181833267211914.
#     Running the experiment for circuit grover.qasm...
#         Depths: 270,
#     Circuit grover.qasm transpiled with best depth 270 and time 0.048439979553222656.
#     Running the experiment for circuit seca_n11.qasm...
#         Depths: 181,
#     Circuit seca_n11.qasm transpiled with best depth 181 and time 0.07721304893493652.
#     Running the experiment for circuit knn_n25.qasm...
#         Depths: 160,
#     Circuit knn_n25.qasm transpiled with best depth 160 and time 0.05837106704711914.
#     Running the experiment for circuit swap_test_n25.qasm...
#         Depths: 144,
#     Circuit swap_test_n25.qasm transpiled with best depth 144 and time 0.058157920837402344.
#     Running the experiment for circuit ising_n10.qasm...
#         Depths: 60,
#     Circuit ising_n10.qasm transpiled with best depth 60 and time 0.04639101028442383.
#     Running the experiment for circuit ft_1.qasm...
#         Depths: 72,
#     Circuit ft_1.qasm transpiled with best depth 72 and time 0.04702496528625488.
#     Running the experiment for circuit bigadder_n18.qasm...
#         Depths: 248,
#     Circuit bigadder_n18.qasm transpiled with best depth 248 and time 0.07510662078857422.
#     Running the experiment for circuit qram_n20.qasm...
#         Depths: 258,
#     Circuit qram_n20.qasm transpiled with best depth 258 and time 0.09174609184265137.
#     Running the experiment for circuit qf21_n15.qasm...
#         Depths: 224,
#     Circuit qf21_n15.qasm transpiled with best depth 224 and time 0.10418295860290527.
#     Running the experiment for circuit multiplier_n15.qasm...
#         Depths: 557,
#     Circuit multiplier_n15.qasm transpiled with best depth 557 and time 0.15487313270568848.
#     Running the experiment for circuit sat_n11.qasm...
#         Depths: 649,
#     Circuit sat_n11.qasm transpiled with best depth 649 and time 0.15278196334838867.
#     Running the experiment for circuit qft_n18.qasm...
#         Depths: 328,
#     Circuit qft_n18.qasm transpiled with best depth 328 and time 0.26488399505615234.
#     Running the experiment for circuit qec_en_n5.qasm...
#         Depths: 21,
#     Circuit qec_en_n5.qasm transpiled with best depth 21 and time 0.011730194091796875.
#     Running the experiment for circuit basis_change_n3.qasm...
#         Depths: 10,
#     Circuit basis_change_n3.qasm transpiled with best depth 10 and time 0.010727167129516602.
#     Running the experiment for circuit qpe.qasm...
#         Depths: 24,
#     Circuit qpe.qasm transpiled with best depth 24 and time 0.011772871017456055.
#     Running the experiment for circuit qft_n4.qasm...
#         Depths: 19,
#     Circuit qft_n4.qasm transpiled with best depth 19 and time 0.013387680053710938.
#     Running the experiment for circuit variational_n4.qasm...
#         Depths: 12,
#     Circuit variational_n4.qasm transpiled with best depth 12 and time 0.011741876602172852.
#     Running the experiment for circuit cat_state_n22.qasm...
#         Depths: 60,
#     Circuit cat_state_n22.qasm transpiled with best depth 60 and time 0.022722959518432617.
#     Running the experiment for circuit ghz_state_n23.qasm...
#         Depths: 66,
#     Circuit ghz_state_n23.qasm transpiled with best depth 66 and time 0.026257991790771484.
#     Running the experiment for circuit simon_n6.qasm...
#         Depths: 47,
#     Circuit simon_n6.qasm transpiled with best depth 47 and time 0.015279054641723633.
#     Running the experiment for circuit bv_n14.qasm...
#         Depths: 41,
#     Circuit bv_n14.qasm transpiled with best depth 41 and time 0.019070863723754883.
#     Running the experiment for circuit cc_n12.qasm...
#         Depths: 65,
#     Circuit cc_n12.qasm transpiled with best depth 65 and time 0.024580717086791992.
#     Running the experiment for circuit qec9xz_n17.qasm...
#         Depths: 58,
#     Circuit qec9xz_n17.qasm transpiled with best depth 58 and time 0.02732682228088379.
#     Running the experiment for circuit bv_n19.qasm...
#         Depths: 63,
#     Circuit bv_n19.qasm transpiled with best depth 63 and time 0.0268402099609375.
#     Running the experiment for circuit multiply_n13.qasm...
#         Depths: 91,
#     Circuit multiply_n13.qasm transpiled with best depth 91 and time 0.030308246612548828.
#     Running the experiment for circuit error_correctiond3_n5.qasm...
#         Depths: 95,
#     Circuit error_correctiond3_n5.qasm transpiled with best depth 95 and time 0.027168989181518555.
#     Running the experiment for circuit qpe_n9.qasm...
#         Depths: 96,
#     Circuit qpe_n9.qasm transpiled with best depth 96 and time 0.03191399574279785.
#     Running the experiment for circuit wstate_n27.qasm...
#         Depths: 98,
#     Circuit wstate_n27.qasm transpiled with best depth 98 and time 0.05198192596435547.
#     Running the experiment for circuit adder_n10.qasm...
#         Depths: 155,
#     Circuit adder_n10.qasm transpiled with best depth 155 and time 0.036743879318237305.
#     Running the experiment for circuit ft_2.qasm...
#         Depths: 70,
#     Circuit ft_2.qasm transpiled with best depth 70 and time 0.0553281307220459.
#     Running the experiment for circuit vqe_uccsd_n4.qasm...
#         Depths: 87,
#     Circuit vqe_uccsd_n4.qasm transpiled with best depth 87 and time 0.027264833450317383.
#     Running the experiment for circuit sat_n7.qasm...
#         Depths: 171,
#     Circuit sat_n7.qasm transpiled with best depth 171 and time 0.039288997650146484.
#     Running the experiment for circuit qaoa_n6.qasm...
#         Depths: 72,
#     Circuit qaoa_n6.qasm transpiled with best depth 72 and time 0.03245091438293457.
#     Running the experiment for circuit grover.qasm...
#         Depths: 273,
#     Circuit grover.qasm transpiled with best depth 273 and time 0.04875588417053223.
#     Running the experiment for circuit seca_n11.qasm...
#         Depths: 204,
#     Circuit seca_n11.qasm transpiled with best depth 204 and time 0.05200910568237305.
#     Running the experiment for circuit knn_n25.qasm...
#         Depths: 159,
#     Circuit knn_n25.qasm transpiled with best depth 159 and time 0.0557098388671875.
#     Running the experiment for circuit swap_test_n25.qasm...
#         Depths: 147,
#     Circuit swap_test_n25.qasm transpiled with best depth 147 and time 0.057311058044433594.
#     Running the experiment for circuit ising_n10.qasm...
#         Depths: 57,
#     Circuit ising_n10.qasm transpiled with best depth 57 and time 0.0481109619140625.
#     Running the experiment for circuit ft_1.qasm...
#         Depths: 72,
#     Circuit ft_1.qasm transpiled with best depth 72 and time 0.07074475288391113.
#     Running the experiment for circuit bigadder_n18.qasm...
#         Depths: 274,
#     Circuit bigadder_n18.qasm transpiled with best depth 274 and time 0.0733649730682373.
#     Running the experiment for circuit qram_n20.qasm...
#         Depths: 240,
#     Circuit qram_n20.qasm transpiled with best depth 240 and time 0.08346319198608398.
#     Running the experiment for circuit qf21_n15.qasm...
#         Depths: 229,
#     Circuit qf21_n15.qasm transpiled with best depth 229 and time 0.07409095764160156.
#     Running the experiment for circuit multiplier_n15.qasm...
#         Depths: 487,
#     Circuit multiplier_n15.qasm transpiled with best depth 487 and time 0.13594508171081543.
#     Running the experiment for circuit sat_n11.qasm...
#         Depths: 632,
#     Circuit sat_n11.qasm transpiled with best depth 632 and time 0.1709589958190918.
#     Running the experiment for circuit qft_n18.qasm...
#         Depths: 311,
#     Circuit qft_n18.qasm transpiled with best depth 311 and time 0.2009737491607666.

# %% [markdown]
# Run experiment for Sabre_v0_20_extended

# %%
rp_list = [SabreSwap_v0_20]
for rp in rp_list: 
    if rp in skip_list:
        continue
    routing_pass     = rp(coupling_map, seed=seed, heuristic="lookahead")
    layout_pass      = LP(coupling_map, routing_pass, seed=seed, max_iterations=max_iter)
    pass_manager     = build_pm(coupling_map, layout_pass, routing_pass)
    rp_name = routing_pass.__class__.__name__ + "_extended"
    filename = f'experiments/results/{qc_type}/{rp_name}.csv'
    df = run_circuits(filename, circuits, pass_manager, num_times, max_iter, beam, look, crit)
# Out:
#     Running the experiment for circuit qec_en_n5.qasm...
#         Depths: 16,
#     Circuit qec_en_n5.qasm transpiled with best depth 16 and time 0.012130975723266602.
#     Running the experiment for circuit basis_change_n3.qasm...
#         Depths: 10,
#     Circuit basis_change_n3.qasm transpiled with best depth 10 and time 0.010857105255126953.
#     Running the experiment for circuit qpe.qasm...
#         Depths: 22,
#     Circuit qpe.qasm transpiled with best depth 22 and time 0.013583898544311523.
#     Running the experiment for circuit qft_n4.qasm...
#         Depths: 21,
#     Circuit qft_n4.qasm transpiled with best depth 21 and time 0.013444662094116211.
#     Running the experiment for circuit variational_n4.qasm...
#         Depths: 12,
#     Circuit variational_n4.qasm transpiled with best depth 12 and time 0.012810945510864258.
#     Running the experiment for circuit cat_state_n22.qasm...
#         Depths: 57,
#     Circuit cat_state_n22.qasm transpiled with best depth 57 and time 0.04841279983520508.
#     Running the experiment for circuit ghz_state_n23.qasm...
#         Depths: 67,
#     Circuit ghz_state_n23.qasm transpiled with best depth 67 and time 0.02781391143798828.
#     Running the experiment for circuit simon_n6.qasm...
#         Depths: 32,
#     Circuit simon_n6.qasm transpiled with best depth 32 and time 0.016401290893554688.
#     Running the experiment for circuit bv_n14.qasm...
#         Depths: 41,
#     Circuit bv_n14.qasm transpiled with best depth 41 and time 0.022845745086669922.
#     Running the experiment for circuit cc_n12.qasm...
#         Depths: 62,
#     Circuit cc_n12.qasm transpiled with best depth 62 and time 0.03044605255126953.
#     Running the experiment for circuit qec9xz_n17.qasm...
#         Depths: 56,
#     Circuit qec9xz_n17.qasm transpiled with best depth 56 and time 0.04633688926696777.
#     Running the experiment for circuit bv_n19.qasm...
#         Depths: 72,
#     Circuit bv_n19.qasm transpiled with best depth 72 and time 0.03545403480529785.
#     Running the experiment for circuit multiply_n13.qasm...
#         Depths: 67,
#     Circuit multiply_n13.qasm transpiled with best depth 67 and time 0.04113411903381348.
#     Running the experiment for circuit error_correctiond3_n5.qasm...
#         Depths: 72,
#     Circuit error_correctiond3_n5.qasm transpiled with best depth 72 and time 0.03144502639770508.
#     Running the experiment for circuit qpe_n9.qasm...
#         Depths: 91,
#     Circuit qpe_n9.qasm transpiled with best depth 91 and time 0.03878974914550781.
#     Running the experiment for circuit wstate_n27.qasm...
#         Depths: 121,
#     Circuit wstate_n27.qasm transpiled with best depth 121 and time 0.06472396850585938.
#     Running the experiment for circuit adder_n10.qasm...
#         Depths: 155,
#     Circuit adder_n10.qasm transpiled with best depth 155 and time 0.04817008972167969.
#     Running the experiment for circuit ft_2.qasm...
#         Depths: 45,
#     Circuit ft_2.qasm transpiled with best depth 45 and time 0.03238487243652344.
#     Running the experiment for circuit vqe_uccsd_n4.qasm...
#         Depths: 87,
#     Circuit vqe_uccsd_n4.qasm transpiled with best depth 87 and time 0.02829599380493164.
#     Running the experiment for circuit sat_n7.qasm...
#         Depths: 129,
#     Circuit sat_n7.qasm transpiled with best depth 129 and time 0.053347110748291016.
#     Running the experiment for circuit qaoa_n6.qasm...
#         Depths: 66,
#     Circuit qaoa_n6.qasm transpiled with best depth 66 and time 0.03889608383178711.
#     Running the experiment for circuit grover.qasm...
#         Depths: 208,
#     Circuit grover.qasm transpiled with best depth 208 and time 0.07497978210449219.
#     Running the experiment for circuit seca_n11.qasm...
#         Depths: 94,
#     Circuit seca_n11.qasm transpiled with best depth 94 and time 0.06681394577026367.
#     Running the experiment for circuit knn_n25.qasm...
#         Depths: 165,
#     Circuit knn_n25.qasm transpiled with best depth 165 and time 0.08009195327758789.
#     Running the experiment for circuit swap_test_n25.qasm...
#         Depths: 210,
#     Circuit swap_test_n25.qasm transpiled with best depth 210 and time 0.07944488525390625.
#     Running the experiment for circuit ising_n10.qasm...
#         Depths: 62,
#     Circuit ising_n10.qasm transpiled with best depth 62 and time 0.06704115867614746.
#     Running the experiment for circuit ft_1.qasm...
#         Depths: 72,
#     Circuit ft_1.qasm transpiled with best depth 72 and time 0.051026105880737305.
#     Running the experiment for circuit bigadder_n18.qasm...
#         Depths: 217,
#     Circuit bigadder_n18.qasm transpiled with best depth 217 and time 0.12204408645629883.
#     Running the experiment for circuit qram_n20.qasm...
#         Depths: 257,
#     Circuit qram_n20.qasm transpiled with best depth 257 and time 0.129075288772583.
#     Running the experiment for circuit qf21_n15.qasm...
#         Depths: 266,
#     Circuit qf21_n15.qasm transpiled with best depth 266 and time 0.09780311584472656.
#     Running the experiment for circuit multiplier_n15.qasm...
#         Depths: 390,
#     Circuit multiplier_n15.qasm transpiled with best depth 390 and time 0.19769001007080078.
#     Running the experiment for circuit sat_n11.qasm...
#         Depths: 518,
#     Circuit sat_n11.qasm transpiled with best depth 518 and time 0.1982569694519043.
#     Running the experiment for circuit qft_n18.qasm...
#         Depths: 310,
#     Circuit qft_n18.qasm transpiled with best depth 310 and time 0.35769176483154297.

# %%
rp_list = [SabreSwap_v0_20_DepthCrit]
for rp in rp_list: 
    if rp in skip_list:
        continue
    routing_pass     = rp(coupling_map, seed=seed, crit_weight=crit)
    layout_pass      = LP(coupling_map, RP(coupling_map, seed=seed), seed=seed, max_iterations=max_iter)
    pass_manager     = build_pm(coupling_map, layout_pass, routing_pass)
    rp_name = routing_pass.__class__.__name__ + "_extended"
    filename = f'experiments/results/{qc_type}/{rp_name}.csv'
    df = run_circuits(filename, circuits, pass_manager, num_times, max_iter, beam, look, crit)
# Out:
#     Running the experiment for circuit qec_en_n5.qasm...
#         Depths: 21,
#     Circuit qec_en_n5.qasm transpiled with best depth 21 and time 0.013740062713623047.
#     Running the experiment for circuit basis_change_n3.qasm...
#         Depths: 10,
#     Circuit basis_change_n3.qasm transpiled with best depth 10 and time 0.013304948806762695.
#     Running the experiment for circuit qpe.qasm...
#         Depths: 24,
#     Circuit qpe.qasm transpiled with best depth 24 and time 0.037841081619262695.
#     Running the experiment for circuit qft_n4.qasm...
#         Depths: 19,
#     Circuit qft_n4.qasm transpiled with best depth 19 and time 0.01772904396057129.
#     Running the experiment for circuit variational_n4.qasm...
#         Depths: 12,
#     Circuit variational_n4.qasm transpiled with best depth 12 and time 0.014652013778686523.
#     Running the experiment for circuit cat_state_n22.qasm...
#         Depths: 60,
#     Circuit cat_state_n22.qasm transpiled with best depth 60 and time 0.02798295021057129.
#     Running the experiment for circuit ghz_state_n23.qasm...
#         Depths: 66,
#     Circuit ghz_state_n23.qasm transpiled with best depth 66 and time 0.027039051055908203.
#     Running the experiment for circuit simon_n6.qasm...
#         Depths: 39,
#     Circuit simon_n6.qasm transpiled with best depth 39 and time 0.017783164978027344.
#     Running the experiment for circuit bv_n14.qasm...
#         Depths: 47,
#     Circuit bv_n14.qasm transpiled with best depth 47 and time 0.020617961883544922.
#     Running the experiment for circuit cc_n12.qasm...
#         Depths: 65,
#     Circuit cc_n12.qasm transpiled with best depth 65 and time 0.027827978134155273.
#     Running the experiment for circuit qec9xz_n17.qasm...
#         Depths: 66,
#     Circuit qec9xz_n17.qasm transpiled with best depth 66 and time 0.03056192398071289.
#     Running the experiment for circuit bv_n19.qasm...
#         Depths: 63,
#     Circuit bv_n19.qasm transpiled with best depth 63 and time 0.02806711196899414.
#     Running the experiment for circuit multiply_n13.qasm...
#         Depths: 100,
#     Circuit multiply_n13.qasm transpiled with best depth 100 and time 0.03296303749084473.
#     Running the experiment for circuit error_correctiond3_n5.qasm...
#         Depths: 98,
#     Circuit error_correctiond3_n5.qasm transpiled with best depth 98 and time 0.0293729305267334.
#     Running the experiment for circuit qpe_n9.qasm...
#         Depths: 91,
#     Circuit qpe_n9.qasm transpiled with best depth 91 and time 0.03383326530456543.
#     Running the experiment for circuit wstate_n27.qasm...
#         Depths: 95,
#     Circuit wstate_n27.qasm transpiled with best depth 95 and time 0.05943036079406738.
#     Running the experiment for circuit adder_n10.qasm...
#         Depths: 148,
#     Circuit adder_n10.qasm transpiled with best depth 148 and time 0.04104304313659668.
#     Running the experiment for circuit ft_2.qasm...
#         Depths: 73,
#     Circuit ft_2.qasm transpiled with best depth 73 and time 0.061203956604003906.
#     Running the experiment for circuit vqe_uccsd_n4.qasm...
#         Depths: 87,
#     Circuit vqe_uccsd_n4.qasm transpiled with best depth 87 and time 0.029601097106933594.
#     Running the experiment for circuit sat_n7.qasm...
#         Depths: 151,
#     Circuit sat_n7.qasm transpiled with best depth 151 and time 0.04259610176086426.
#     Running the experiment for circuit qaoa_n6.qasm...
#         Depths: 78,
#     Circuit qaoa_n6.qasm transpiled with best depth 78 and time 0.036271095275878906.
#     Running the experiment for circuit grover.qasm...
#         Depths: 294,
#     Circuit grover.qasm transpiled with best depth 294 and time 0.05261635780334473.
#     Running the experiment for circuit seca_n11.qasm...
#         Depths: 186,
#     Circuit seca_n11.qasm transpiled with best depth 186 and time 0.05845522880554199.
#     Running the experiment for circuit knn_n25.qasm...
#         Depths: 154,
#     Circuit knn_n25.qasm transpiled with best depth 154 and time 0.06214594841003418.
#     Running the experiment for circuit swap_test_n25.qasm...
#         Depths: 144,
#     Circuit swap_test_n25.qasm transpiled with best depth 144 and time 0.06097722053527832.
#     Running the experiment for circuit ising_n10.qasm...
#         Depths: 79,
#     Circuit ising_n10.qasm transpiled with best depth 79 and time 0.05367898941040039.
#     Running the experiment for circuit ft_1.qasm...
#         Depths: 72,
#     Circuit ft_1.qasm transpiled with best depth 72 and time 0.07825779914855957.
#     Running the experiment for circuit bigadder_n18.qasm...
#         Depths: 251,
#     Circuit bigadder_n18.qasm transpiled with best depth 251 and time 0.0793769359588623.
#     Running the experiment for circuit qram_n20.qasm...
#         Depths: 254,
#     Circuit qram_n20.qasm transpiled with best depth 254 and time 0.09615087509155273.
#     Running the experiment for circuit qf21_n15.qasm...
#         Depths: 223,
#     Circuit qf21_n15.qasm transpiled with best depth 223 and time 0.07893013954162598.
#     Running the experiment for circuit multiplier_n15.qasm...
#         Depths: 478,
#     Circuit multiplier_n15.qasm transpiled with best depth 478 and time 0.15875625610351562.
#     Running the experiment for circuit sat_n11.qasm...
#         Depths: 658,
#     Circuit sat_n11.qasm transpiled with best depth 658 and time 0.18532133102416992.
#     Running the experiment for circuit qft_n18.qasm...
#         Depths: 260,
#     Circuit qft_n18.qasm transpiled with best depth 260 and time 0.22016477584838867.
