# %%
from experiments.utils.pass_managers import run_circuits, build_pm
from experiments.utils.coupling_maps import file_to_coupling_map
from experiments.utils.circuits      import directory_to_circuits, rename_circuits

# Parameters for general experiments
from qiskit.transpiler.passes.routing.sabre_swap_0_20  import SabreSwap_v0_20   
from qiskit.transpiler.passes.routing.sabre_swap_0_20_depth  import SabreSwap_v0_20_Depth
from qiskit.transpiler.passes.routing.sabre_swap_0_20_depth_ties import SabreSwap_v0_20_DepthTies
from qiskit.transpiler.passes.routing.sabre_swap_0_20_depth_crit import SabreSwap_v0_20_DepthCrit

from qiskit.transpiler.passes.layout.sabre_layout import SabreLayout as LP
from qiskit.transpiler.passes.routing.sabre_swap  import SabreSwap as RP

# %%
# List of routing passes
rp_list = [SabreSwap_v0_20, SabreSwap_v0_20_Depth, SabreSwap_v0_20_DepthTies]
skip_list = []

# Main parameters for experiments
qc_type     = 'synthetic/ring_027_prob'
cm_type     = 'ring_027'
seed        = 42
num_times   = 1
max_iter    = 3

# Other parameters for sabre_mods
beam        = 1
look        = 1
crit        = 1

# %%
# Runs the experiments
coupling_map     = file_to_coupling_map(f'experiments/coupling_maps/{cm_type}.txt')
circuits, files  = directory_to_circuits(f'experiments/circuits/{qc_type}/')
circuits         = rename_circuits(circuits, files)

# %%
for rp in rp_list:
    if rp in skip_list:
        continue
    routing_pass     = rp(coupling_map, seed=seed)
    layout_pass      = LP(coupling_map, RP(coupling_map, seed=seed), seed=seed, max_iterations=max_iter)
    pass_manager     = build_pm(coupling_map, layout_pass, routing_pass)
    rp_name = routing_pass.__class__.__name__
    filename = f'experiments/results/{qc_type}/{rp_name}.csv'
    df = run_circuits(filename, circuits, pass_manager, num_times, max_iter, beam, look, crit)
# Out:
#     Running the experiment for circuit _10_prob.qasm...
#         Depths: 59,
#     Circuit _10_prob.qasm transpiled with best depth 59 and time 0.06637382507324219.
#     Running the experiment for circuit _20_prob.qasm...
#         Depths: 37,
#     Circuit _20_prob.qasm transpiled with best depth 37 and time 0.044476985931396484.
#     Running the experiment for circuit _30_prob.qasm...
#         Depths: 83,
#     Circuit _30_prob.qasm transpiled with best depth 83 and time 0.07515597343444824.
#     Running the experiment for circuit _40_prob.qasm...
#         Depths: 106,
#     Circuit _40_prob.qasm transpiled with best depth 106 and time 0.08725595474243164.
#     Running the experiment for circuit _50_prob.qasm...
#         Depths: 164,
#     Circuit _50_prob.qasm transpiled with best depth 164 and time 0.13253998756408691.
#     Running the experiment for circuit _60_prob.qasm...
#         Depths: 154,
#     Circuit _60_prob.qasm transpiled with best depth 154 and time 0.12241005897521973.
#     Running the experiment for circuit _70_prob.qasm...
#         Depths: 330,
#     Circuit _70_prob.qasm transpiled with best depth 330 and time 0.2572453022003174.
#     Running the experiment for circuit _80_prob.qasm...
#         Depths: 434,
#     Circuit _80_prob.qasm transpiled with best depth 434 and time 0.28249692916870117.
#     Running the experiment for circuit _90_prob.qasm...
#         Depths: 481,
#     Circuit _90_prob.qasm transpiled with best depth 481 and time 0.30488133430480957.
#     Running the experiment for circuit _100_prob.qasm...
#         Depths: 240,
#     Circuit _100_prob.qasm transpiled with best depth 240 and time 0.3258981704711914.
#     Running the experiment for circuit _10_prob.qasm...
#         Depths: 49,
#     Circuit _10_prob.qasm transpiled with best depth 49 and time 0.05901694297790527.
#     Running the experiment for circuit _20_prob.qasm...
#         Depths: 30,
#     Circuit _20_prob.qasm transpiled with best depth 30 and time 0.05441403388977051.
#     Running the experiment for circuit _30_prob.qasm...
#         Depths: 86,
#     Circuit _30_prob.qasm transpiled with best depth 86 and time 0.08856391906738281.
#     Running the experiment for circuit _40_prob.qasm...
#         Depths: 127,
#     Circuit _40_prob.qasm transpiled with best depth 127 and time 0.10568618774414062.
#     Running the experiment for circuit _50_prob.qasm...
#         Depths: 241,
#     Circuit _50_prob.qasm transpiled with best depth 241 and time 0.22684192657470703.
#     Running the experiment for circuit _60_prob.qasm...
#         Depths: 149,
#     Circuit _60_prob.qasm transpiled with best depth 149 and time 0.15737438201904297.
#     Running the experiment for circuit _70_prob.qasm...
#         Depths: 341,
#     Circuit _70_prob.qasm transpiled with best depth 341 and time 0.33767199516296387.
#     Running the experiment for circuit _80_prob.qasm...
#         Depths: 351,
#     Circuit _80_prob.qasm transpiled with best depth 351 and time 0.42268800735473633.
#     Running the experiment for circuit _90_prob.qasm...
#         Depths: 396,
#     Circuit _90_prob.qasm transpiled with best depth 396 and time 0.46915102005004883.
#     Running the experiment for circuit _100_prob.qasm...
#         Depths: 292,
#     Circuit _100_prob.qasm transpiled with best depth 292 and time 0.3063507080078125.
#     Running the experiment for circuit _10_prob.qasm...
#         Depths: 60,
#     Circuit _10_prob.qasm transpiled with best depth 60 and time 0.04190397262573242.
#     Running the experiment for circuit _20_prob.qasm...
#         Depths: 45,
#     Circuit _20_prob.qasm transpiled with best depth 45 and time 0.0443272590637207.
#     Running the experiment for circuit _30_prob.qasm...
#         Depths: 72,
#     Circuit _30_prob.qasm transpiled with best depth 72 and time 0.07700610160827637.
#     Running the experiment for circuit _40_prob.qasm...
#         Depths: 84,
#     Circuit _40_prob.qasm transpiled with best depth 84 and time 0.08757567405700684.
#     Running the experiment for circuit _50_prob.qasm...
#         Depths: 222,
#     Circuit _50_prob.qasm transpiled with best depth 222 and time 0.15935897827148438.
#     Running the experiment for circuit _60_prob.qasm...
#         Depths: 129,
#     Circuit _60_prob.qasm transpiled with best depth 129 and time 0.1293041706085205.
#     Running the experiment for circuit _70_prob.qasm...
#         Depths: 289,
#     Circuit _70_prob.qasm transpiled with best depth 289 and time 0.38471388816833496.
#     Running the experiment for circuit _80_prob.qasm...
#         Depths: 381,
#     Circuit _80_prob.qasm transpiled with best depth 381 and time 0.3371429443359375.
#     Running the experiment for circuit _90_prob.qasm...
#         Depths: 383,
#     Circuit _90_prob.qasm transpiled with best depth 383 and time 0.36527180671691895.
#     Running the experiment for circuit _100_prob.qasm...
#         Depths: 211,
#     Circuit _100_prob.qasm transpiled with best depth 211 and time 0.2228078842163086.

# %% [markdown]
# Run experiment for Sabre_v0_20_extended

# %%
rp_list = [SabreSwap_v0_20]
for rp in rp_list: 
    if rp in skip_list:
        continue
    routing_pass     = rp(coupling_map, seed=seed, heuristic="lookahead")
    layout_pass      = LP(coupling_map, routing_pass, seed=seed, max_iterations=max_iter)
    pass_manager     = build_pm(coupling_map, layout_pass, routing_pass)
    rp_name = routing_pass.__class__.__name__ + "_extended"
    filename = f'experiments/results/{qc_type}/{rp_name}.csv'
    df = run_circuits(filename, circuits, pass_manager, num_times, max_iter, beam, look, crit)
# Out:
#     Running the experiment for circuit _10_prob.qasm...
#         Depths: 59,
#     Circuit _10_prob.qasm transpiled with best depth 59 and time 0.10840892791748047.
#     Running the experiment for circuit _20_prob.qasm...
#         Depths: 31,
#     Circuit _20_prob.qasm transpiled with best depth 31 and time 0.09096288681030273.
#     Running the experiment for circuit _30_prob.qasm...
#         Depths: 62,
#     Circuit _30_prob.qasm transpiled with best depth 62 and time 0.18381476402282715.
#     Running the experiment for circuit _40_prob.qasm...
#         Depths: 65,
#     Circuit _40_prob.qasm transpiled with best depth 65 and time 0.15723800659179688.
#     Running the experiment for circuit _50_prob.qasm...
#         Depths: 97,
#     Circuit _50_prob.qasm transpiled with best depth 97 and time 0.1855909824371338.
#     Running the experiment for circuit _60_prob.qasm...
#         Depths: 102,
#     Circuit _60_prob.qasm transpiled with best depth 102 and time 0.18512415885925293.
#     Running the experiment for circuit _70_prob.qasm...
#         Depths: 297,
#     Circuit _70_prob.qasm transpiled with best depth 297 and time 0.5946598052978516.
#     Running the experiment for circuit _80_prob.qasm...
#         Depths: 121,
#     Circuit _80_prob.qasm transpiled with best depth 121 and time 0.33880186080932617.
#     Running the experiment for circuit _90_prob.qasm...
#         Depths: 154,
#     Circuit _90_prob.qasm transpiled with best depth 154 and time 0.2571120262145996.
#     Running the experiment for circuit _100_prob.qasm...
#         Depths: 164,
#     Circuit _100_prob.qasm transpiled with best depth 164 and time 0.5339159965515137.

# %%
rp_list = [SabreSwap_v0_20_DepthCrit]
for rp in rp_list: 
    if rp in skip_list:
        continue
    routing_pass     = rp(coupling_map, seed=seed, crit_weight=crit)
    layout_pass      = LP(coupling_map, RP(coupling_map, seed=seed), seed=seed, max_iterations=max_iter)
    pass_manager     = build_pm(coupling_map, layout_pass, routing_pass)
    rp_name = routing_pass.__class__.__name__ + "_extended"
    filename = f'experiments/results/{qc_type}/{rp_name}.csv'
    df = run_circuits(filename, circuits, pass_manager, num_times, max_iter, beam, look, crit)
# Out:
#     Running the experiment for circuit _10_prob.qasm...
#         Depths: 65,
#     Circuit _10_prob.qasm transpiled with best depth 65 and time 0.05525708198547363.
#     Running the experiment for circuit _20_prob.qasm...
#         Depths: 37,
#     Circuit _20_prob.qasm transpiled with best depth 37 and time 0.04594707489013672.
#     Running the experiment for circuit _30_prob.qasm...
#         Depths: 114,
#     Circuit _30_prob.qasm transpiled with best depth 114 and time 0.08728909492492676.
#     Running the experiment for circuit _40_prob.qasm...
#         Depths: 99,
#     Circuit _40_prob.qasm transpiled with best depth 99 and time 0.12703490257263184.
#     Running the experiment for circuit _50_prob.qasm...
#         Depths: 165,
#     Circuit _50_prob.qasm transpiled with best depth 165 and time 0.17802906036376953.
#     Running the experiment for circuit _60_prob.qasm...
#         Depths: 165,
#     Circuit _60_prob.qasm transpiled with best depth 165 and time 0.15824508666992188.
#     Running the experiment for circuit _70_prob.qasm...
#         Depths: 295,
#     Circuit _70_prob.qasm transpiled with best depth 295 and time 0.3492300510406494.
#     Running the experiment for circuit _80_prob.qasm...
#         Depths: 373,
#     Circuit _80_prob.qasm transpiled with best depth 373 and time 0.48058390617370605.
#     Running the experiment for circuit _90_prob.qasm...
#         Depths: 451,
#     Circuit _90_prob.qasm transpiled with best depth 451 and time 0.4911618232727051.
#     Running the experiment for circuit _100_prob.qasm...
#         Depths: 245,
#     Circuit _100_prob.qasm transpiled with best depth 245 and time 0.30736804008483887.
