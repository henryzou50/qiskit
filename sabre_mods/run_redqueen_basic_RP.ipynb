# %%
from experiments.utils.pass_managers import run_circuits, build_pm
from experiments.utils.coupling_maps import file_to_coupling_map
from experiments.utils.circuits      import directory_to_circuits, rename_circuits

# Parameters for general experiments
from qiskit.transpiler.passes.routing.sabre_swap_0_20  import SabreSwap_v0_20   
from qiskit.transpiler.passes.routing.sabre_swap_0_20_depth  import SabreSwap_v0_20_Depth
from qiskit.transpiler.passes.routing.sabre_swap_0_20_depth_ties  import SabreSwap_v0_20_DepthTies

from qiskit.transpiler.passes.layout.sabre_layout import SabreLayout as LP

# %%
# List of routing passes
rp_list = [SabreSwap_v0_20, SabreSwap_v0_20_Depth, SabreSwap_v0_20_DepthTies]
skip_list = []

# Main parameters for experiments
qc_type     = 'red_queen'
cm_type     = 'hex_027'
seed        = 42
num_times   = 4
max_iter    = 3

# Other parameters for sabre_mods
beam        = 1
look        = 1
crit        = 1

# %%
# Runs the experiments
coupling_map     = file_to_coupling_map(f'experiments/coupling_maps/{cm_type}.txt')
circuits, files  = directory_to_circuits(f'experiments/circuits/{qc_type}/')
circuits         = rename_circuits(circuits, files)

for rp in rp_list:
    if rp in skip_list:
        continue
    routing_pass     = rp(coupling_map, seed=seed)
    layout_pass      = LP(coupling_map, routing_pass, seed=seed, max_iterations=max_iter)
    pass_manager     = build_pm(coupling_map, layout_pass, routing_pass)
    rp_name = routing_pass.__class__.__name__
    filename = f'experiments/results/{qc_type}/{rp_name}.csv'
    df = run_circuits(filename, circuits, pass_manager, num_times, max_iter, beam, look, crit)
# Out:
#     Running the experiment for circuit qec_en_n5.qasm...
#         Depths: 19, 22, 30, 23,
#     Circuit qec_en_n5.qasm transpiled with best depth 19 and time 0.012964010238647461.
#     Running the experiment for circuit basis_change_n3.qasm...
#         Depths: 10, 10, 10, 10,
#     Circuit basis_change_n3.qasm transpiled with best depth 10 and time 0.01146388053894043.
#     Running the experiment for circuit qpe.qasm...
#         Depths: 22, 27, 34, 34,
#     Circuit qpe.qasm transpiled with best depth 22 and time 0.013292074203491211.
#     Running the experiment for circuit qft_n4.qasm...
#         Depths: 20, 19, 19, 19,
#     Circuit qft_n4.qasm transpiled with best depth 19 and time 0.013100862503051758.
#     Running the experiment for circuit variational_n4.qasm...
#         Depths: 18, 12, 12, 18,
#     Circuit variational_n4.qasm transpiled with best depth 12 and time 0.01189422607421875.
#     Running the experiment for circuit cat_state_n22.qasm...
#         Depths: 83, 81, 67, 96,
#     Circuit cat_state_n22.qasm transpiled with best depth 67 and time 0.0366060733795166.
#     Running the experiment for circuit ghz_state_n23.qasm...
#         Depths: 78, 86, 82, 73,
#     Circuit ghz_state_n23.qasm transpiled with best depth 73 and time 0.03395509719848633.
#     Running the experiment for circuit simon_n6.qasm...
#         Depths: 38, 26, 38, 32,
#     Circuit simon_n6.qasm transpiled with best depth 26 and time 0.016587018966674805.
#     Running the experiment for circuit bv_n14.qasm...
#         Depths: 67, 58, 47, 55,
#     Circuit bv_n14.qasm transpiled with best depth 47 and time 0.02639007568359375.
#     Running the experiment for circuit cc_n12.qasm...
#         Depths: 77, 79, 63, 81,
#     Circuit cc_n12.qasm transpiled with best depth 63 and time 0.032095909118652344.
#     Running the experiment for circuit qec9xz_n17.qasm...
#         Depths: 46, 76, 85, 68,
#     Circuit qec9xz_n17.qasm transpiled with best depth 46 and time 0.049881696701049805.
#     Running the experiment for circuit bv_n19.qasm...
#         Depths: 101, 102, 79, 108,
#     Circuit bv_n19.qasm transpiled with best depth 79 and time 0.04081225395202637.
#     Running the experiment for circuit multiply_n13.qasm...
#         Depths: 104, 104, 97, 82,
#     Circuit multiply_n13.qasm transpiled with best depth 82 and time 0.045352935791015625.
#     Running the experiment for circuit error_correctiond3_n5.qasm...
#         Depths: 71, 54, 89, 71,
#     Circuit error_correctiond3_n5.qasm transpiled with best depth 54 and time 0.026731014251708984.
#     Running the experiment for circuit qpe_n9.qasm...
#         Depths: 115, 91, 99, 98,
#     Circuit qpe_n9.qasm transpiled with best depth 91 and time 0.04351997375488281.
#     Running the experiment for circuit wstate_n27.qasm...
#         Depths: 139, 150, 135, 130,
#     Circuit wstate_n27.qasm transpiled with best depth 130 and time 0.08315539360046387.
#     Running the experiment for circuit adder_n10.qasm...
#         Depths: 136, 132, 119, 151,
#     Circuit adder_n10.qasm transpiled with best depth 119 and time 0.047955989837646484.
#     Running the experiment for circuit ft_2.qasm...
#         Depths: 36, 41, 53, 77,
#     Circuit ft_2.qasm transpiled with best depth 36 and time 0.030953168869018555.
#     Running the experiment for circuit vqe_uccsd_n4.qasm...
#         Depths: 87, 87, 87, 87,
#     Circuit vqe_uccsd_n4.qasm transpiled with best depth 87 and time 0.029841899871826172.
#     Running the experiment for circuit sat_n7.qasm...
#         Depths: 138, 131, 126, 149,
#     Circuit sat_n7.qasm transpiled with best depth 126 and time 0.05211687088012695.
#     Running the experiment for circuit qaoa_n6.qasm...
#         Depths: 69, 75, 66, 78,
#     Circuit qaoa_n6.qasm transpiled with best depth 66 and time 0.039227962493896484.
#     Running the experiment for circuit grover.qasm...
#         Depths: 220, 207, 239, 230,
#     Circuit grover.qasm transpiled with best depth 207 and time 0.06680607795715332.
#     Running the experiment for circuit seca_n11.qasm...
#         Depths: 140, 139, 145, 128,
#     Circuit seca_n11.qasm transpiled with best depth 128 and time 0.07173919677734375.
#     Running the experiment for circuit knn_n25.qasm...
#         Depths: 205, 235, 219, 188,
#     Circuit knn_n25.qasm transpiled with best depth 188 and time 0.08859896659851074.
#     Running the experiment for circuit swap_test_n25.qasm...
#         Depths: 225, 304, 228, 194,
#     Circuit swap_test_n25.qasm transpiled with best depth 194 and time 0.0872807502746582.
#     Running the experiment for circuit ising_n10.qasm...
#         Depths: 47, 20, 60, 41,
#     Circuit ising_n10.qasm transpiled with best depth 20 and time 0.05857515335083008.
#     Running the experiment for circuit ft_1.qasm...
#         Depths: 78, 78, 145, 82,
#     Circuit ft_1.qasm transpiled with best depth 78 and time 0.051154136657714844.
#     Running the experiment for circuit bigadder_n18.qasm...
#         Depths: 222, 221, 236, 242,
#     Circuit bigadder_n18.qasm transpiled with best depth 221 and time 0.10756301879882812.
#     Running the experiment for circuit qram_n20.qasm...
#         Depths: 336, 336, 358, 334,
#     Circuit qram_n20.qasm transpiled with best depth 334 and time 0.1536247730255127.
#     Running the experiment for circuit qf21_n15.qasm...
#         Depths: 325, 358, 288, 309,
#     Circuit qf21_n15.qasm transpiled with best depth 288 and time 0.11001801490783691.
#     Running the experiment for circuit multiplier_n15.qasm...
#         Depths: 456, 483, 453, 487,
#     Circuit multiplier_n15.qasm transpiled with best depth 453 and time 0.20864224433898926.
#     Running the experiment for circuit sat_n11.qasm...
#         Depths: 570, 579, 680, 626,
#     Circuit sat_n11.qasm transpiled with best depth 570 and time 0.2072157859802246.
#     Running the experiment for circuit qft_n18.qasm...
#         Depths: 376, 428, 376, 294,
#     Circuit qft_n18.qasm transpiled with best depth 294 and time 0.3649160861968994.
#     Running the experiment for circuit qec_en_n5.qasm...
#         Depths: 25, 19, 19, 19,
#     Circuit qec_en_n5.qasm transpiled with best depth 19 and time 0.012251138687133789.
#     Running the experiment for circuit basis_change_n3.qasm...
#         Depths: 10, 10, 22, 22,
#     Circuit basis_change_n3.qasm transpiled with best depth 10 and time 0.010673046112060547.
#     Running the experiment for circuit qpe.qasm...
#         Depths: 24, 27, 24, 33,
#     Circuit qpe.qasm transpiled with best depth 24 and time 0.012650012969970703.
#     Running the experiment for circuit qft_n4.qasm...
#         Depths: 19, 19, 19, 22,
#     Circuit qft_n4.qasm transpiled with best depth 19 and time 0.013058185577392578.
#     Running the experiment for circuit variational_n4.qasm...
#         Depths: 22, 15, 12, 22,
#     Circuit variational_n4.qasm transpiled with best depth 12 and time 0.01273488998413086.
#     Running the experiment for circuit cat_state_n22.qasm...
#         Depths: 57, 60, 65, 59,
#     Circuit cat_state_n22.qasm transpiled with best depth 57 and time 0.029010772705078125.
#     Running the experiment for circuit ghz_state_n23.qasm...
#         Depths: 60, 67, 69, 67,
#     Circuit ghz_state_n23.qasm transpiled with best depth 60 and time 0.03780508041381836.
#     Running the experiment for circuit simon_n6.qasm...
#         Depths: 37, 40, 43, 49,
#     Circuit simon_n6.qasm transpiled with best depth 37 and time 0.018255233764648438.
#     Running the experiment for circuit bv_n14.qasm...
#         Depths: 31, 37, 33, 35,
#     Circuit bv_n14.qasm transpiled with best depth 31 and time 0.024084091186523438.
#     Running the experiment for circuit cc_n12.qasm...
#         Depths: 54, 57, 61, 54,
#     Circuit cc_n12.qasm transpiled with best depth 54 and time 0.027350902557373047.
#     Running the experiment for circuit qec9xz_n17.qasm...
#         Depths: 58, 47, 52, 66,
#     Circuit qec9xz_n17.qasm transpiled with best depth 47 and time 0.06865096092224121.
#     Running the experiment for circuit bv_n19.qasm...
#         Depths: 48, 50, 48, 50,
#     Circuit bv_n19.qasm transpiled with best depth 48 and time 0.03628706932067871.
#     Running the experiment for circuit multiply_n13.qasm...
#         Depths: 97, 67, 82, 89,
#     Circuit multiply_n13.qasm transpiled with best depth 67 and time 0.05062413215637207.
#     Running the experiment for circuit error_correctiond3_n5.qasm...
#         Depths: 91, 98, 97, 96,
#     Circuit error_correctiond3_n5.qasm transpiled with best depth 91 and time 0.03601574897766113.
#     Running the experiment for circuit qpe_n9.qasm...
#         Depths: 89, 84, 80, 99,
#     Circuit qpe_n9.qasm transpiled with best depth 80 and time 0.03982377052307129.
#     Running the experiment for circuit wstate_n27.qasm...
#         Depths: 104, 97, 108, 127,
#     Circuit wstate_n27.qasm transpiled with best depth 97 and time 0.07147908210754395.
#     Running the experiment for circuit adder_n10.qasm...
#         Depths: 172, 188, 192, 168,
#     Circuit adder_n10.qasm transpiled with best depth 168 and time 0.05537819862365723.
#     Running the experiment for circuit ft_2.qasm...
#         Depths: 36, 79, 78, 73,
#     Circuit ft_2.qasm transpiled with best depth 36 and time 0.02962517738342285.
#     Running the experiment for circuit vqe_uccsd_n4.qasm...
#         Depths: 87, 197, 237, 87,
#     Circuit vqe_uccsd_n4.qasm transpiled with best depth 87 and time 0.0400090217590332.
#     Running the experiment for circuit sat_n7.qasm...
#         Depths: 175, 143, 141, 144,
#     Circuit sat_n7.qasm transpiled with best depth 141 and time 0.05481696128845215.
#     Running the experiment for circuit qaoa_n6.qasm...
#         Depths: 75, 84, 75, 57,
#     Circuit qaoa_n6.qasm transpiled with best depth 57 and time 0.044996023178100586.
#     Running the experiment for circuit grover.qasm...
#         Depths: 271, 282, 267, 266,
#     Circuit grover.qasm transpiled with best depth 266 and time 0.06418395042419434.
#     Running the experiment for circuit seca_n11.qasm...
#         Depths: 163, 169, 152, 141,
#     Circuit seca_n11.qasm transpiled with best depth 141 and time 0.09525609016418457.
#     Running the experiment for circuit knn_n25.qasm...
#         Depths: 147, 156, 147, 159,
#     Circuit knn_n25.qasm transpiled with best depth 147 and time 0.09460973739624023.
#     Running the experiment for circuit swap_test_n25.qasm...
#         Depths: 165, 150, 145, 150,
#     Circuit swap_test_n25.qasm transpiled with best depth 145 and time 0.11504507064819336.
#     Running the experiment for circuit ising_n10.qasm...
#         Depths: 79, 20, 73, 56,
#     Circuit ising_n10.qasm transpiled with best depth 20 and time 0.0630960464477539.
#     Running the experiment for circuit ft_1.qasm...
#         Depths: 177, 186, 150, 72,
#     Circuit ft_1.qasm transpiled with best depth 72 and time 0.0522608757019043.
#     Running the experiment for circuit bigadder_n18.qasm...
#         Depths: 315, 253, 289, 291,
#     Circuit bigadder_n18.qasm transpiled with best depth 253 and time 0.14517617225646973.
#     Running the experiment for circuit qram_n20.qasm...
#         Depths: 324, 292, 297, 252,
#     Circuit qram_n20.qasm transpiled with best depth 252 and time 0.17535996437072754.
#     Running the experiment for circuit qf21_n15.qasm...
#         Depths: 228, 242, 237, 239,
#     Circuit qf21_n15.qasm transpiled with best depth 228 and time 0.10219693183898926.
#     Running the experiment for circuit multiplier_n15.qasm...
#         Depths: 535, 465, 492, 540,
#     Circuit multiplier_n15.qasm transpiled with best depth 465 and time 0.3011188507080078.
#     Running the experiment for circuit sat_n11.qasm...
#         Depths: 684, 694, 673, 681,
#     Circuit sat_n11.qasm transpiled with best depth 673 and time 0.2360241413116455.
#     Running the experiment for circuit qft_n18.qasm...
#         Depths: 261, 287, 337, 287,
#     Circuit qft_n18.qasm transpiled with best depth 261 and time 0.5265753269195557.
#     Running the experiment for circuit qec_en_n5.qasm...
#         Depths: 25, 19, 19, 19,
#     Circuit qec_en_n5.qasm transpiled with best depth 19 and time 0.01208806037902832.
#     Running the experiment for circuit basis_change_n3.qasm...
#         Depths: 10, 10, 22, 22,
#     Circuit basis_change_n3.qasm transpiled with best depth 10 and time 0.010660171508789062.
#     Running the experiment for circuit qpe.qasm...
#         Depths: 24, 27, 24, 33,
#     Circuit qpe.qasm transpiled with best depth 24 and time 0.012527227401733398.
#     Running the experiment for circuit qft_n4.qasm...
#         Depths: 21, 19, 19, 19,
#     Circuit qft_n4.qasm transpiled with best depth 19 and time 0.013446807861328125.
#     Running the experiment for circuit variational_n4.qasm...
#         Depths: 22, 15, 15, 22,
#     Circuit variational_n4.qasm transpiled with best depth 15 and time 0.014312028884887695.
#     Running the experiment for circuit cat_state_n22.qasm...
#         Depths: 57, 60, 61, 55,
#     Circuit cat_state_n22.qasm transpiled with best depth 55 and time 0.0357508659362793.
#     Running the experiment for circuit ghz_state_n23.qasm...
#         Depths: 60, 69, 69, 67,
#     Circuit ghz_state_n23.qasm transpiled with best depth 60 and time 0.035491228103637695.
#     Running the experiment for circuit simon_n6.qasm...
#         Depths: 45, 40, 43, 40,
#     Circuit simon_n6.qasm transpiled with best depth 40 and time 0.01706719398498535.
#     Running the experiment for circuit bv_n14.qasm...
#         Depths: 31, 37, 33, 35,
#     Circuit bv_n14.qasm transpiled with best depth 31 and time 0.023638010025024414.
#     Running the experiment for circuit cc_n12.qasm...
#         Depths: 54, 57, 61, 54,
#     Circuit cc_n12.qasm transpiled with best depth 54 and time 0.026022911071777344.
#     Running the experiment for circuit qec9xz_n17.qasm...
#         Depths: 70, 54, 69, 66,
#     Circuit qec9xz_n17.qasm transpiled with best depth 54 and time 0.05465126037597656.
#     Running the experiment for circuit bv_n19.qasm...
#         Depths: 48, 50, 48, 50,
#     Circuit bv_n19.qasm transpiled with best depth 48 and time 0.0345311164855957.
#     Running the experiment for circuit multiply_n13.qasm...
#         Depths: 103, 98, 103, 72,
#     Circuit multiply_n13.qasm transpiled with best depth 72 and time 0.044741153717041016.
#     Running the experiment for circuit error_correctiond3_n5.qasm...
#         Depths: 82, 94, 82, 96,
#     Circuit error_correctiond3_n5.qasm transpiled with best depth 82 and time 0.032653093338012695.
#     Running the experiment for circuit qpe_n9.qasm...
#         Depths: 92, 84, 94, 93,
#     Circuit qpe_n9.qasm transpiled with best depth 84 and time 0.03938794136047363.
#     Running the experiment for circuit wstate_n27.qasm...
#         Depths: 126, 83, 98, 110,
#     Circuit wstate_n27.qasm transpiled with best depth 83 and time 0.06792211532592773.
#     Running the experiment for circuit adder_n10.qasm...
#         Depths: 161, 185, 181, 170,
#     Circuit adder_n10.qasm transpiled with best depth 161 and time 0.05172300338745117.
#     Running the experiment for circuit ft_2.qasm...
#         Depths: 36, 85, 80, 70,
#     Circuit ft_2.qasm transpiled with best depth 36 and time 0.028633832931518555.
#     Running the experiment for circuit vqe_uccsd_n4.qasm...
#         Depths: 87, 181, 181, 87,
#     Circuit vqe_uccsd_n4.qasm transpiled with best depth 87 and time 0.03292489051818848.
#     Running the experiment for circuit sat_n7.qasm...
#         Depths: 164, 140, 155, 150,
#     Circuit sat_n7.qasm transpiled with best depth 140 and time 0.0549321174621582.
#     Running the experiment for circuit qaoa_n6.qasm...
#         Depths: 57, 87, 75, 72,
#     Circuit qaoa_n6.qasm transpiled with best depth 57 and time 0.04081892967224121.
#     Running the experiment for circuit grover.qasm...
#         Depths: 274, 292, 265, 275,
#     Circuit grover.qasm transpiled with best depth 265 and time 0.06466317176818848.
#     Running the experiment for circuit seca_n11.qasm...
#         Depths: 150, 155, 160, 152,
#     Circuit seca_n11.qasm transpiled with best depth 150 and time 0.09106731414794922.
#     Running the experiment for circuit knn_n25.qasm...
#         Depths: 141, 152, 147, 165,
#     Circuit knn_n25.qasm transpiled with best depth 141 and time 0.09100890159606934.
#     Running the experiment for circuit swap_test_n25.qasm...
#         Depths: 158, 150, 143, 161,
#     Circuit swap_test_n25.qasm transpiled with best depth 143 and time 0.09549593925476074.
#     Running the experiment for circuit ising_n10.qasm...
#         Depths: 65, 47, 57, 51,
#     Circuit ising_n10.qasm transpiled with best depth 47 and time 0.06590604782104492.
#     Running the experiment for circuit ft_1.qasm...
#         Depths: 133, 158, 176, 72,
#     Circuit ft_1.qasm transpiled with best depth 72 and time 0.051258087158203125.
#     Running the experiment for circuit bigadder_n18.qasm...
#         Depths: 292, 297, 288, 296,
#     Circuit bigadder_n18.qasm transpiled with best depth 288 and time 0.13546490669250488.
#     Running the experiment for circuit qram_n20.qasm...
#         Depths: 269, 278, 341, 298,
#     Circuit qram_n20.qasm transpiled with best depth 269 and time 0.1464250087738037.
#     Running the experiment for circuit qf21_n15.qasm...
#         Depths: 241, 219, 207, 219,
#     Circuit qf21_n15.qasm transpiled with best depth 207 and time 0.10076785087585449.
#     Running the experiment for circuit multiplier_n15.qasm...
#         Depths: 476, 472, 533, 490,
#     Circuit multiplier_n15.qasm transpiled with best depth 472 and time 0.23331308364868164.
#     Running the experiment for circuit sat_n11.qasm...
#         Depths: 668, 714, 649, 685,
#     Circuit sat_n11.qasm transpiled with best depth 649 and time 0.209763765335083.
#     Running the experiment for circuit qft_n18.qasm...
#         Depths: 332, 311, 310, 311,
#     Circuit qft_n18.qasm transpiled with best depth 310 and time 0.416762113571167.

# %% [markdown]
# Run experiment for Sabre_v0_20_extended

# %%
rp_list = [SabreSwap_v0_20]
for rp in rp_list: 
    if rp in skip_list:
        continue
    routing_pass     = rp(coupling_map, seed=seed, heuristic="lookahead")
    layout_pass      = LP(coupling_map, routing_pass, seed=seed, max_iterations=max_iter)
    pass_manager     = build_pm(coupling_map, layout_pass, routing_pass)
    rp_name = routing_pass.__class__.__name__ + "_extended"
    filename = f'experiments/results/{qc_type}/{rp_name}.csv'
    df = run_circuits(filename, circuits, pass_manager, num_times, max_iter, beam, look, crit)
# Out:
#     Running the experiment for circuit qec_en_n5.qasm...
#         Depths: 16, 17, 22, 22,
#     Circuit qec_en_n5.qasm transpiled with best depth 16 and time 0.012040853500366211.
#     Running the experiment for circuit basis_change_n3.qasm...
#         Depths: 10, 10, 10, 10,
#     Circuit basis_change_n3.qasm transpiled with best depth 10 and time 0.010892152786254883.
#     Running the experiment for circuit qpe.qasm...
#         Depths: 22, 22, 22, 22,
#     Circuit qpe.qasm transpiled with best depth 22 and time 0.012794017791748047.
#     Running the experiment for circuit qft_n4.qasm...
#         Depths: 18, 19, 19, 19,
#     Circuit qft_n4.qasm transpiled with best depth 18 and time 0.012691974639892578.
#     Running the experiment for circuit variational_n4.qasm...
#         Depths: 19, 12, 18, 19,
#     Circuit variational_n4.qasm transpiled with best depth 12 and time 0.011926889419555664.
#     Running the experiment for circuit cat_state_n22.qasm...
#         Depths: 66, 81, 78, 66,
#     Circuit cat_state_n22.qasm transpiled with best depth 66 and time 0.025493144989013672.
#     Running the experiment for circuit ghz_state_n23.qasm...
#         Depths: 76, 52, 94, 88,
#     Circuit ghz_state_n23.qasm transpiled with best depth 52 and time 0.026341915130615234.
#     Running the experiment for circuit simon_n6.qasm...
#         Depths: 29, 35, 38, 35,
#     Circuit simon_n6.qasm transpiled with best depth 29 and time 0.01650404930114746.
#     Running the experiment for circuit bv_n14.qasm...
#         Depths: 39, 36, 37, 41,
#     Circuit bv_n14.qasm transpiled with best depth 36 and time 0.024218082427978516.
#     Running the experiment for circuit cc_n12.qasm...
#         Depths: 70, 64, 57, 55,
#     Circuit cc_n12.qasm transpiled with best depth 55 and time 0.029249906539916992.
#     Running the experiment for circuit qec9xz_n17.qasm...
#         Depths: 59, 60, 79, 56,
#     Circuit qec9xz_n17.qasm transpiled with best depth 56 and time 0.049195051193237305.
#     Running the experiment for circuit bv_n19.qasm...
#         Depths: 63, 60, 68, 65,
#     Circuit bv_n19.qasm transpiled with best depth 60 and time 0.0328669548034668.
#     Running the experiment for circuit multiply_n13.qasm...
#         Depths: 70, 76, 87, 81,
#     Circuit multiply_n13.qasm transpiled with best depth 70 and time 0.043814897537231445.
#     Running the experiment for circuit error_correctiond3_n5.qasm...
#         Depths: 75, 54, 54, 57,
#     Circuit error_correctiond3_n5.qasm transpiled with best depth 54 and time 0.02815699577331543.
#     Running the experiment for circuit qpe_n9.qasm...
#         Depths: 82, 89, 80, 81,
#     Circuit qpe_n9.qasm transpiled with best depth 80 and time 0.037728071212768555.
#     Running the experiment for circuit wstate_n27.qasm...
#         Depths: 127, 76, 74, 96,
#     Circuit wstate_n27.qasm transpiled with best depth 74 and time 0.06404399871826172.
#     Running the experiment for circuit adder_n10.qasm...
#         Depths: 143, 119, 109, 124,
#     Circuit adder_n10.qasm transpiled with best depth 109 and time 0.04586195945739746.
#     Running the experiment for circuit ft_2.qasm...
#         Depths: 36, 39, 39, 47,
#     Circuit ft_2.qasm transpiled with best depth 36 and time 0.03212881088256836.
#     Running the experiment for circuit vqe_uccsd_n4.qasm...
#         Depths: 87, 87, 87, 87,
#     Circuit vqe_uccsd_n4.qasm transpiled with best depth 87 and time 0.029631853103637695.
#     Running the experiment for circuit sat_n7.qasm...
#         Depths: 106, 134, 134, 129,
#     Circuit sat_n7.qasm transpiled with best depth 106 and time 0.04920506477355957.
#     Running the experiment for circuit qaoa_n6.qasm...
#         Depths: 69, 66, 57, 69,
#     Circuit qaoa_n6.qasm transpiled with best depth 57 and time 0.0376741886138916.
#     Running the experiment for circuit grover.qasm...
#         Depths: 209, 135, 209, 208,
#     Circuit grover.qasm transpiled with best depth 135 and time 0.04644608497619629.
#     Running the experiment for circuit seca_n11.qasm...
#         Depths: 94, 120, 135, 97,
#     Circuit seca_n11.qasm transpiled with best depth 94 and time 0.06843113899230957.
#     Running the experiment for circuit knn_n25.qasm...
#         Depths: 167, 171, 193, 175,
#     Circuit knn_n25.qasm transpiled with best depth 167 and time 0.08142995834350586.
#     Running the experiment for circuit swap_test_n25.qasm...
#         Depths: 188, 172, 135, 178,
#     Circuit swap_test_n25.qasm transpiled with best depth 135 and time 0.0792999267578125.
#     Running the experiment for circuit ising_n10.qasm...
#         Depths: 79, 20, 50, 39,
#     Circuit ising_n10.qasm transpiled with best depth 20 and time 0.05379796028137207.
#     Running the experiment for circuit ft_1.qasm...
#         Depths: 72, 78, 98, 72,
#     Circuit ft_1.qasm transpiled with best depth 72 and time 0.04877424240112305.
#     Running the experiment for circuit bigadder_n18.qasm...
#         Depths: 221, 221, 277, 271,
#     Circuit bigadder_n18.qasm transpiled with best depth 221 and time 0.09390807151794434.
#     Running the experiment for circuit qram_n20.qasm...
#         Depths: 244, 288, 241, 293,
#     Circuit qram_n20.qasm transpiled with best depth 241 and time 0.13866114616394043.
#     Running the experiment for circuit qf21_n15.qasm...
#         Depths: 265, 242, 249, 245,
#     Circuit qf21_n15.qasm transpiled with best depth 242 and time 0.1001279354095459.
#     Running the experiment for circuit multiplier_n15.qasm...
#         Depths: 468, 385, 418, 376,
#     Circuit multiplier_n15.qasm transpiled with best depth 376 and time 0.1986398696899414.
#     Running the experiment for circuit sat_n11.qasm...
#         Depths: 530, 569, 543, 565,
#     Circuit sat_n11.qasm transpiled with best depth 530 and time 0.21962285041809082.
#     Running the experiment for circuit qft_n18.qasm...
#         Depths: 260, 332, 347, 258,
#     Circuit qft_n18.qasm transpiled with best depth 258 and time 0.3317298889160156.
