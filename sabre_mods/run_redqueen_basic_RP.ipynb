# %%
from experiments.utils.pass_managers import run_circuits, build_pm
from experiments.utils.coupling_maps import file_to_coupling_map
from experiments.utils.circuits      import directory_to_circuits, rename_circuits

# Parameters for general experiments
from qiskit.transpiler.passes.routing.sabre_swap_0_20  import SabreSwap_v0_20   
from qiskit.transpiler.passes.routing.sabre_swap_0_20_depth  import SabreSwap_v0_20_Depth
from qiskit.transpiler.passes.routing.sabre_swap_0_20_depth_ties  import SabreSwap_v0_20_DepthTies

from qiskit.transpiler.passes.layout.sabre_layout import SabreLayout as LP

# %%
# List of routing passes
rp_list = [SabreSwap_v0_20, SabreSwap_v0_20_Depth, SabreSwap_v0_20_DepthTies]
skip_list = []

# Main parameters for experiments
qc_type     = 'red_queen'
cm_type     = 'hex_027'
seed        = 42
num_times   = 4
max_iter    = 3

# Other parameters for sabre_mods
beam        = 1
look        = 1
crit        = 1

# %%
# Runs the experiments
coupling_map     = file_to_coupling_map(f'experiments/coupling_maps/{cm_type}.txt')
circuits, files  = directory_to_circuits(f'experiments/circuits/{qc_type}/')
circuits         = rename_circuits(circuits, files)

for rp in rp_list:
    if rp in skip_list:
        continue
    routing_pass     = rp(coupling_map, seed=seed)
    layout_pass      = LP(coupling_map, routing_pass, seed=seed, max_iterations=max_iter)
    pass_manager     = build_pm(coupling_map, layout_pass, routing_pass)
    rp_name = routing_pass.__class__.__name__
    filename = f'experiments/results/{qc_type}/{rp_name}.csv'
    df = run_circuits(filename, circuits, pass_manager, num_times, max_iter, beam, look, crit)
# Out:
#     Running the experiment for circuit qec_en_n5.qasm...
#         Depths: 25, 19, 19, 19,
#     Circuit qec_en_n5.qasm transpiled with best depth 19 and time 0.012962102890014648.
#     Running the experiment for circuit basis_change_n3.qasm...
#         Depths: 10, 10, 22, 22,
#     Circuit basis_change_n3.qasm transpiled with best depth 10 and time 0.011069774627685547.
#     Running the experiment for circuit qpe.qasm...
#         Depths: 24, 27, 24, 33,
#     Circuit qpe.qasm transpiled with best depth 24 and time 0.013094186782836914.
#     Running the experiment for circuit qft_n4.qasm...
#         Depths: 19, 19, 19, 22,
#     Circuit qft_n4.qasm transpiled with best depth 19 and time 0.013714075088500977.
#     Running the experiment for circuit variational_n4.qasm...
#         Depths: 22, 15, 12, 22,
#     Circuit variational_n4.qasm transpiled with best depth 12 and time 0.013422012329101562.
#     Running the experiment for circuit cat_state_n22.qasm...
#         Depths: 57, 60, 65, 59,
#     Circuit cat_state_n22.qasm transpiled with best depth 57 and time 0.031238317489624023.
#     Running the experiment for circuit ghz_state_n23.qasm...
#         Depths: 60, 67, 69, 67,
#     Circuit ghz_state_n23.qasm transpiled with best depth 60 and time 0.03777480125427246.
#     Running the experiment for circuit simon_n6.qasm...
#         Depths: 37, 40, 43, 49,
#     Circuit simon_n6.qasm transpiled with best depth 37 and time 0.01879286766052246.
#     Running the experiment for circuit bv_n14.qasm...
#         Depths: 31, 37, 33, 35,
#     Circuit bv_n14.qasm transpiled with best depth 31 and time 0.02378702163696289.
#     Running the experiment for circuit cc_n12.qasm...
#         Depths: 54, 57, 61, 54,
#     Circuit cc_n12.qasm transpiled with best depth 54 and time 0.027968883514404297.
#     Running the experiment for circuit qec9xz_n17.qasm...
#         Depths: 58, 47, 52, 66,
#     Circuit qec9xz_n17.qasm transpiled with best depth 47 and time 0.07212710380554199.
#     Running the experiment for circuit bv_n19.qasm...
#         Depths: 48, 50, 48, 50,
#     Circuit bv_n19.qasm transpiled with best depth 48 and time 0.03649592399597168.
#     Running the experiment for circuit multiply_n13.qasm...
#         Depths: 97, 67, 82, 89,
#     Circuit multiply_n13.qasm transpiled with best depth 67 and time 0.05314373970031738.
#     Running the experiment for circuit error_correctiond3_n5.qasm...
#         Depths: 91, 98, 97, 96,
#     Circuit error_correctiond3_n5.qasm transpiled with best depth 91 and time 0.03855586051940918.
#     Running the experiment for circuit qpe_n9.qasm...
#         Depths: 89, 84, 80, 99,
#     Circuit qpe_n9.qasm transpiled with best depth 80 and time 0.04125213623046875.
#     Running the experiment for circuit wstate_n27.qasm...
#         Depths: 104, 97, 108, 127,
#     Circuit wstate_n27.qasm transpiled with best depth 97 and time 0.07161927223205566.
#     Running the experiment for circuit adder_n10.qasm...
#         Depths: 172, 188, 192, 168,
#     Circuit adder_n10.qasm transpiled with best depth 168 and time 0.054409027099609375.
#     Running the experiment for circuit ft_2.qasm...
#         Depths: 36, 79, 78, 73,
#     Circuit ft_2.qasm transpiled with best depth 36 and time 0.029048681259155273.
#     Running the experiment for circuit vqe_uccsd_n4.qasm...
#         Depths: 87, 197, 237, 87,
#     Circuit vqe_uccsd_n4.qasm transpiled with best depth 87 and time 0.040598154067993164.
#     Running the experiment for circuit sat_n7.qasm...
#         Depths: 175, 143, 141, 144,
#     Circuit sat_n7.qasm transpiled with best depth 141 and time 0.055477142333984375.
#     Running the experiment for circuit qaoa_n6.qasm...
#         Depths: 75, 84, 75, 57,
#     Circuit qaoa_n6.qasm transpiled with best depth 57 and time 0.04484391212463379.
#     Running the experiment for circuit grover.qasm...
#         Depths: 271, 282, 267, 266,
#     Circuit grover.qasm transpiled with best depth 266 and time 0.06799721717834473.
#     Running the experiment for circuit seca_n11.qasm...
#         Depths: 163, 169, 152, 141,
#     Circuit seca_n11.qasm transpiled with best depth 141 and time 0.09400296211242676.
#     Running the experiment for circuit knn_n25.qasm...
#         Depths: 147, 156, 147, 159,
#     Circuit knn_n25.qasm transpiled with best depth 147 and time 0.09944510459899902.
#     Running the experiment for circuit swap_test_n25.qasm...
#         Depths: 165, 150, 145, 150,
#     Circuit swap_test_n25.qasm transpiled with best depth 145 and time 0.11902117729187012.
#     Running the experiment for circuit ising_n10.qasm...
#         Depths: 79, 20, 73, 56,
#     Circuit ising_n10.qasm transpiled with best depth 20 and time 0.06539297103881836.
#     Running the experiment for circuit ft_1.qasm...
#         Depths: 177, 186, 150, 72,
#     Circuit ft_1.qasm transpiled with best depth 72 and time 0.05276918411254883.
#     Running the experiment for circuit bigadder_n18.qasm...
#         Depths: 315, 253, 289, 291,
#     Circuit bigadder_n18.qasm transpiled with best depth 253 and time 0.1466670036315918.
#     Running the experiment for circuit qram_n20.qasm...
#         Depths: 324, 292, 297, 252,
#     Circuit qram_n20.qasm transpiled with best depth 252 and time 0.17476582527160645.
#     Running the experiment for circuit qf21_n15.qasm...
#         Depths: 228, 242, 237, 239,
#     Circuit qf21_n15.qasm transpiled with best depth 228 and time 0.10373616218566895.
#     Running the experiment for circuit multiplier_n15.qasm...
#         Depths: 535, 465, 492, 540,
#     Circuit multiplier_n15.qasm transpiled with best depth 465 and time 0.30441808700561523.
#     Running the experiment for circuit sat_n11.qasm...
#         Depths: 684, 694, 673, 681,
#     Circuit sat_n11.qasm transpiled with best depth 673 and time 0.23703980445861816.
#     Running the experiment for circuit qft_n18.qasm...
#         Depths: 261, 287, 337, 287,
#     Circuit qft_n18.qasm transpiled with best depth 261 and time 0.6539168357849121.
#     Running the experiment for circuit vqe_uccsd_n6.qasm...
#         Depths: 2582, 2644, 2609, 2604,
#     Circuit vqe_uccsd_n6.qasm transpiled with best depth 2582 and time 0.9571759700775146.
#     Running the experiment for circuit vqe_uccsd_n8.qasm...
#         Depths: 14180, 13757, 13874, 13820,
#     Circuit vqe_uccsd_n8.qasm transpiled with best depth 13757 and time 8.52255892753601.
#     Running the experiment for circuit qec_en_n5.qasm...
#         Depths: 19, 22, 30, 23,
#     Circuit qec_en_n5.qasm transpiled with best depth 19 and time 0.012112140655517578.
#     Running the experiment for circuit basis_change_n3.qasm...
#         Depths: 10, 10, 10, 10,
#     Circuit basis_change_n3.qasm transpiled with best depth 10 and time 0.010416984558105469.
#     Running the experiment for circuit qpe.qasm...
#         Depths: 22, 27, 34, 34,
#     Circuit qpe.qasm transpiled with best depth 22 and time 0.012354850769042969.
#     Running the experiment for circuit qft_n4.qasm...
#         Depths: 20, 19, 19, 19,
#     Circuit qft_n4.qasm transpiled with best depth 19 and time 0.014194011688232422.
#     Running the experiment for circuit variational_n4.qasm...
#         Depths: 18, 12, 12, 18,
#     Circuit variational_n4.qasm transpiled with best depth 12 and time 0.012484073638916016.
#     Running the experiment for circuit cat_state_n22.qasm...
#         Depths: 83, 81, 67, 96,
#     Circuit cat_state_n22.qasm transpiled with best depth 67 and time 0.03303980827331543.
#     Running the experiment for circuit ghz_state_n23.qasm...
#         Depths: 78, 86, 82, 73,
#     Circuit ghz_state_n23.qasm transpiled with best depth 73 and time 0.03171086311340332.
#     Running the experiment for circuit simon_n6.qasm...
#         Depths: 38, 26, 38, 32,
#     Circuit simon_n6.qasm transpiled with best depth 26 and time 0.01564812660217285.
#     Running the experiment for circuit bv_n14.qasm...
#         Depths: 67, 58, 47, 55,
#     Circuit bv_n14.qasm transpiled with best depth 47 and time 0.028237104415893555.
#     Running the experiment for circuit cc_n12.qasm...
#         Depths: 77, 79, 63, 81,
#     Circuit cc_n12.qasm transpiled with best depth 63 and time 0.030318021774291992.
#     Running the experiment for circuit qec9xz_n17.qasm...
#         Depths: 46, 76, 85, 68,
#     Circuit qec9xz_n17.qasm transpiled with best depth 46 and time 0.04635810852050781.
#     Running the experiment for circuit bv_n19.qasm...
#         Depths: 101, 102, 79, 108,
#     Circuit bv_n19.qasm transpiled with best depth 79 and time 0.03763914108276367.
#     Running the experiment for circuit multiply_n13.qasm...
#         Depths: 104, 104, 97, 82,
#     Circuit multiply_n13.qasm transpiled with best depth 82 and time 0.04829883575439453.
#     Running the experiment for circuit error_correctiond3_n5.qasm...
#         Depths: 71, 54, 89, 71,
#     Circuit error_correctiond3_n5.qasm transpiled with best depth 54 and time 0.02695298194885254.
#     Running the experiment for circuit qpe_n9.qasm...
#         Depths: 115, 91, 99, 98,
#     Circuit qpe_n9.qasm transpiled with best depth 91 and time 0.044184207916259766.
#     Running the experiment for circuit wstate_n27.qasm...
#         Depths: 139, 150, 135, 130,
#     Circuit wstate_n27.qasm transpiled with best depth 130 and time 0.08378887176513672.
#     Running the experiment for circuit adder_n10.qasm...
#         Depths: 136, 132, 119, 151,
#     Circuit adder_n10.qasm transpiled with best depth 119 and time 0.048265933990478516.
#     Running the experiment for circuit ft_2.qasm...
#         Depths: 36, 41, 53, 77,
#     Circuit ft_2.qasm transpiled with best depth 36 and time 0.030364990234375.
#     Running the experiment for circuit vqe_uccsd_n4.qasm...
#         Depths: 87, 87, 87, 87,
#     Circuit vqe_uccsd_n4.qasm transpiled with best depth 87 and time 0.02974390983581543.
#     Running the experiment for circuit sat_n7.qasm...
#         Depths: 138, 131, 126, 149,
#     Circuit sat_n7.qasm transpiled with best depth 126 and time 0.05161929130554199.
#     Running the experiment for circuit qaoa_n6.qasm...
#         Depths: 69, 75, 66, 78,
#     Circuit qaoa_n6.qasm transpiled with best depth 66 and time 0.03790402412414551.
#     Running the experiment for circuit grover.qasm...
#         Depths: 220, 207, 239, 230,
#     Circuit grover.qasm transpiled with best depth 207 and time 0.0668940544128418.
#     Running the experiment for circuit seca_n11.qasm...
#         Depths: 140, 139, 145, 128,
#     Circuit seca_n11.qasm transpiled with best depth 128 and time 0.07041215896606445.
#     Running the experiment for circuit knn_n25.qasm...
#         Depths: 205, 235, 219, 188,
#     Circuit knn_n25.qasm transpiled with best depth 188 and time 0.08961200714111328.
#     Running the experiment for circuit swap_test_n25.qasm...
#         Depths: 225, 304, 228, 194,
#     Circuit swap_test_n25.qasm transpiled with best depth 194 and time 0.0863039493560791.
#     Running the experiment for circuit ising_n10.qasm...
#         Depths: 47, 20, 60, 41,
#     Circuit ising_n10.qasm transpiled with best depth 20 and time 0.05772709846496582.
#     Running the experiment for circuit ft_1.qasm...
#         Depths: 78, 78, 145, 82,
#     Circuit ft_1.qasm transpiled with best depth 78 and time 0.05078005790710449.
#     Running the experiment for circuit bigadder_n18.qasm...
#         Depths: 222, 221, 236, 242,
#     Circuit bigadder_n18.qasm transpiled with best depth 221 and time 0.10595083236694336.
#     Running the experiment for circuit qram_n20.qasm...
#         Depths: 336, 336, 358, 334,
#     Circuit qram_n20.qasm transpiled with best depth 334 and time 0.15177321434020996.
#     Running the experiment for circuit qf21_n15.qasm...
#         Depths: 325, 358, 288, 309,
#     Circuit qf21_n15.qasm transpiled with best depth 288 and time 0.11014914512634277.
#     Running the experiment for circuit multiplier_n15.qasm...
#         Depths: 456, 483, 453, 487,
#     Circuit multiplier_n15.qasm transpiled with best depth 453 and time 0.20700478553771973.
#     Running the experiment for circuit sat_n11.qasm...
#         Depths: 570, 579, 680, 626,
#     Circuit sat_n11.qasm transpiled with best depth 570 and time 0.20215392112731934.
#     Running the experiment for circuit qft_n18.qasm...
#         Depths: 376, 428, 376, 294,
#     Circuit qft_n18.qasm transpiled with best depth 294 and time 0.3618030548095703.
#     Running the experiment for circuit vqe_uccsd_n6.qasm...
#         Depths: 2107, 1132, 1623, 1413,
#     Circuit vqe_uccsd_n6.qasm transpiled with best depth 1132 and time 0.27727317810058594.
#     Running the experiment for circuit vqe_uccsd_n8.qasm...
#         Depths: 11793, 7174, 9959, 9417,
#     Circuit vqe_uccsd_n8.qasm transpiled with best depth 7174 and time 1.4649248123168945.
#     Running the experiment for circuit qec_en_n5.qasm...
#         Depths: 25, 19, 19, 19,
#     Circuit qec_en_n5.qasm transpiled with best depth 19 and time 0.012782096862792969.
#     Running the experiment for circuit basis_change_n3.qasm...
#         Depths: 10, 10, 22, 22,
#     Circuit basis_change_n3.qasm transpiled with best depth 10 and time 0.01081395149230957.
#     Running the experiment for circuit qpe.qasm...
#         Depths: 24, 27, 24, 33,
#     Circuit qpe.qasm transpiled with best depth 24 and time 0.01297307014465332.
#     Running the experiment for circuit qft_n4.qasm...
#         Depths: 21, 19, 19, 19,
#     Circuit qft_n4.qasm transpiled with best depth 19 and time 0.014422893524169922.
#     Running the experiment for circuit variational_n4.qasm...
#         Depths: 22, 15, 15, 22,
#     Circuit variational_n4.qasm transpiled with best depth 15 and time 0.014316082000732422.
#     Running the experiment for circuit cat_state_n22.qasm...
#         Depths: 57, 60, 61, 55,
#     Circuit cat_state_n22.qasm transpiled with best depth 55 and time 0.03720211982727051.
#     Running the experiment for circuit ghz_state_n23.qasm...
#         Depths: 60, 69, 69, 67,
#     Circuit ghz_state_n23.qasm transpiled with best depth 60 and time 0.03706479072570801.
#     Running the experiment for circuit simon_n6.qasm...
#         Depths: 45, 40, 43, 40,
#     Circuit simon_n6.qasm transpiled with best depth 40 and time 0.017253875732421875.
#     Running the experiment for circuit bv_n14.qasm...
#         Depths: 31, 37, 33, 35,
#     Circuit bv_n14.qasm transpiled with best depth 31 and time 0.024169206619262695.
#     Running the experiment for circuit cc_n12.qasm...
#         Depths: 54, 57, 61, 54,
#     Circuit cc_n12.qasm transpiled with best depth 54 and time 0.025901079177856445.
#     Running the experiment for circuit qec9xz_n17.qasm...
#         Depths: 70, 54, 69, 66,
#     Circuit qec9xz_n17.qasm transpiled with best depth 54 and time 0.059407949447631836.
#     Running the experiment for circuit bv_n19.qasm...
#         Depths: 48, 50, 48, 50,
#     Circuit bv_n19.qasm transpiled with best depth 48 and time 0.03498506546020508.
#     Running the experiment for circuit multiply_n13.qasm...
#         Depths: 103, 98, 103, 72,
#     Circuit multiply_n13.qasm transpiled with best depth 72 and time 0.04529714584350586.
#     Running the experiment for circuit error_correctiond3_n5.qasm...
#         Depths: 82, 94, 82, 96,
#     Circuit error_correctiond3_n5.qasm transpiled with best depth 82 and time 0.0330960750579834.
#     Running the experiment for circuit qpe_n9.qasm...
#         Depths: 92, 84, 94, 93,
#     Circuit qpe_n9.qasm transpiled with best depth 84 and time 0.038802146911621094.
#     Running the experiment for circuit wstate_n27.qasm...
#         Depths: 126, 83, 98, 110,
#     Circuit wstate_n27.qasm transpiled with best depth 83 and time 0.06662511825561523.
#     Running the experiment for circuit adder_n10.qasm...
#         Depths: 161, 185, 181, 170,
#     Circuit adder_n10.qasm transpiled with best depth 161 and time 0.05104804039001465.
#     Running the experiment for circuit ft_2.qasm...
#         Depths: 36, 85, 80, 70,
#     Circuit ft_2.qasm transpiled with best depth 36 and time 0.028693199157714844.
#     Running the experiment for circuit vqe_uccsd_n4.qasm...
#         Depths: 87, 181, 181, 87,
#     Circuit vqe_uccsd_n4.qasm transpiled with best depth 87 and time 0.032817840576171875.
#     Running the experiment for circuit sat_n7.qasm...
#         Depths: 164, 140, 155, 150,
#     Circuit sat_n7.qasm transpiled with best depth 140 and time 0.052819013595581055.
#     Running the experiment for circuit qaoa_n6.qasm...
#         Depths: 57, 87, 75, 72,
#     Circuit qaoa_n6.qasm transpiled with best depth 57 and time 0.039273977279663086.
#     Running the experiment for circuit grover.qasm...
#         Depths: 274, 292, 265, 275,
#     Circuit grover.qasm transpiled with best depth 265 and time 0.0614011287689209.
#     Running the experiment for circuit seca_n11.qasm...
#         Depths: 150, 155, 160, 152,
#     Circuit seca_n11.qasm transpiled with best depth 150 and time 0.09004974365234375.
#     Running the experiment for circuit knn_n25.qasm...
#         Depths: 141, 152, 147, 165,
#     Circuit knn_n25.qasm transpiled with best depth 141 and time 0.09113097190856934.
#     Running the experiment for circuit swap_test_n25.qasm...
#         Depths: 158, 150, 143, 161,
#     Circuit swap_test_n25.qasm transpiled with best depth 143 and time 0.09220194816589355.
#     Running the experiment for circuit ising_n10.qasm...
#         Depths: 65, 47, 57, 51,
#     Circuit ising_n10.qasm transpiled with best depth 47 and time 0.05345892906188965.
#     Running the experiment for circuit ft_1.qasm...
#         Depths: 133, 158, 176, 72,
#     Circuit ft_1.qasm transpiled with best depth 72 and time 0.04937291145324707.
#     Running the experiment for circuit bigadder_n18.qasm...
#         Depths: 292, 297, 288, 296,
#     Circuit bigadder_n18.qasm transpiled with best depth 288 and time 0.12639999389648438.
#     Running the experiment for circuit qram_n20.qasm...
#         Depths: 269, 278, 341, 298,
#     Circuit qram_n20.qasm transpiled with best depth 269 and time 0.1408088207244873.
#     Running the experiment for circuit qf21_n15.qasm...
#         Depths: 241, 219, 207, 219,
#     Circuit qf21_n15.qasm transpiled with best depth 207 and time 0.0989081859588623.
#     Running the experiment for circuit multiplier_n15.qasm...
#         Depths: 476, 472, 533, 490,
#     Circuit multiplier_n15.qasm transpiled with best depth 472 and time 0.23096179962158203.
#     Running the experiment for circuit sat_n11.qasm...
#         Depths: 668, 714, 649, 685,
#     Circuit sat_n11.qasm transpiled with best depth 649 and time 0.20456194877624512.
#     Running the experiment for circuit qft_n18.qasm...
#         Depths: 332, 311, 310, 311,
#     Circuit qft_n18.qasm transpiled with best depth 310 and time 0.4118971824645996.
#     Running the experiment for circuit vqe_uccsd_n6.qasm...
#         Depths: 2497, 2504, 2464, 2510,
#     Circuit vqe_uccsd_n6.qasm transpiled with best depth 2464 and time 0.857562780380249.
#     Running the experiment for circuit vqe_uccsd_n8.qasm...
#         Depths: 14091, 13861, 13947, 13686,
#     Circuit vqe_uccsd_n8.qasm transpiled with best depth 13686 and time 7.028209924697876.

# %% [markdown]
# Run experiment for Sabre_v0_20_extended

# %%
rp_list = [SabreSwap_v0_20]
for rp in rp_list: 
    if rp in skip_list:
        continue
    routing_pass     = rp(coupling_map, seed=seed, heuristic="lookahead")
    layout_pass      = LP(coupling_map, routing_pass, seed=seed, max_iterations=max_iter)
    pass_manager     = build_pm(coupling_map, layout_pass, routing_pass)
    rp_name = routing_pass.__class__.__name__ + "_extended"
    filename = f'experiments/results/{qc_type}/{rp_name}.csv'
    df = run_circuits(filename, circuits, pass_manager, num_times, max_iter, beam, look, crit)
# Out:
#     Running the experiment for circuit qec_en_n5.qasm...
#         Depths: 16, 17, 22, 22,
#     Circuit qec_en_n5.qasm transpiled with best depth 16 and time 0.013077974319458008.
#     Running the experiment for circuit basis_change_n3.qasm...
#         Depths: 10, 10, 10, 10,
#     Circuit basis_change_n3.qasm transpiled with best depth 10 and time 0.011131763458251953.
#     Running the experiment for circuit qpe.qasm...
#         Depths: 22, 22, 22, 22,
#     Circuit qpe.qasm transpiled with best depth 22 and time 0.012559890747070312.
#     Running the experiment for circuit qft_n4.qasm...
#         Depths: 18, 19, 19, 19,
#     Circuit qft_n4.qasm transpiled with best depth 18 and time 0.012980222702026367.
#     Running the experiment for circuit variational_n4.qasm...
#         Depths: 19, 12, 18, 19,
#     Circuit variational_n4.qasm transpiled with best depth 12 and time 0.012226104736328125.
#     Running the experiment for circuit cat_state_n22.qasm...
#         Depths: 66, 81, 78, 66,
#     Circuit cat_state_n22.qasm transpiled with best depth 66 and time 0.027486085891723633.
#     Running the experiment for circuit ghz_state_n23.qasm...
#         Depths: 76, 52, 94, 88,
#     Circuit ghz_state_n23.qasm transpiled with best depth 52 and time 0.02688288688659668.
#     Running the experiment for circuit simon_n6.qasm...
#         Depths: 29, 35, 38, 35,
#     Circuit simon_n6.qasm transpiled with best depth 29 and time 0.026051044464111328.
#     Running the experiment for circuit bv_n14.qasm...
#         Depths: 39, 36, 37, 41,
#     Circuit bv_n14.qasm transpiled with best depth 36 and time 0.025257349014282227.
#     Running the experiment for circuit cc_n12.qasm...
#         Depths: 70, 64, 57, 55,
#     Circuit cc_n12.qasm transpiled with best depth 55 and time 0.02945995330810547.
#     Running the experiment for circuit qec9xz_n17.qasm...
#         Depths: 59, 60, 79, 56,
#     Circuit qec9xz_n17.qasm transpiled with best depth 56 and time 0.05213212966918945.
#     Running the experiment for circuit bv_n19.qasm...
#         Depths: 63, 60, 68, 65,
#     Circuit bv_n19.qasm transpiled with best depth 60 and time 0.03229832649230957.
#     Running the experiment for circuit multiply_n13.qasm...
#         Depths: 70, 76, 87, 81,
#     Circuit multiply_n13.qasm transpiled with best depth 70 and time 0.04192185401916504.
#     Running the experiment for circuit error_correctiond3_n5.qasm...
#         Depths: 75, 54, 54, 57,
#     Circuit error_correctiond3_n5.qasm transpiled with best depth 54 and time 0.026664257049560547.
#     Running the experiment for circuit qpe_n9.qasm...
#         Depths: 82, 89, 80, 81,
#     Circuit qpe_n9.qasm transpiled with best depth 80 and time 0.037661075592041016.
#     Running the experiment for circuit wstate_n27.qasm...
#         Depths: 127, 76, 74, 96,
#     Circuit wstate_n27.qasm transpiled with best depth 74 and time 0.06694889068603516.
#     Running the experiment for circuit adder_n10.qasm...
#         Depths: 143, 119, 109, 124,
#     Circuit adder_n10.qasm transpiled with best depth 109 and time 0.04680204391479492.
#     Running the experiment for circuit ft_2.qasm...
#         Depths: 36, 39, 39, 47,
#     Circuit ft_2.qasm transpiled with best depth 36 and time 0.030952930450439453.
#     Running the experiment for circuit vqe_uccsd_n4.qasm...
#         Depths: 87, 87, 87, 87,
#     Circuit vqe_uccsd_n4.qasm transpiled with best depth 87 and time 0.03228020668029785.
#     Running the experiment for circuit sat_n7.qasm...
#         Depths: 106, 134, 134, 129,
#     Circuit sat_n7.qasm transpiled with best depth 106 and time 0.05016207695007324.
#     Running the experiment for circuit qaoa_n6.qasm...
#         Depths: 69, 66, 57, 69,
#     Circuit qaoa_n6.qasm transpiled with best depth 57 and time 0.03681492805480957.
#     Running the experiment for circuit grover.qasm...
#         Depths: 209, 135, 209, 208,
#     Circuit grover.qasm transpiled with best depth 135 and time 0.04707002639770508.
#     Running the experiment for circuit seca_n11.qasm...
#         Depths: 94, 120, 135, 97,
#     Circuit seca_n11.qasm transpiled with best depth 94 and time 0.06992006301879883.
#     Running the experiment for circuit knn_n25.qasm...
#         Depths: 167, 171, 193, 175,
#     Circuit knn_n25.qasm transpiled with best depth 167 and time 0.08115196228027344.
#     Running the experiment for circuit swap_test_n25.qasm...
#         Depths: 188, 172, 135, 178,
#     Circuit swap_test_n25.qasm transpiled with best depth 135 and time 0.07849907875061035.
#     Running the experiment for circuit ising_n10.qasm...
#         Depths: 79, 20, 50, 39,
#     Circuit ising_n10.qasm transpiled with best depth 20 and time 0.053503990173339844.
#     Running the experiment for circuit ft_1.qasm...
#         Depths: 72, 78, 98, 72,
#     Circuit ft_1.qasm transpiled with best depth 72 and time 0.04947400093078613.
#     Running the experiment for circuit bigadder_n18.qasm...
#         Depths: 221, 221, 277, 271,
#     Circuit bigadder_n18.qasm transpiled with best depth 221 and time 0.09341883659362793.
#     Running the experiment for circuit qram_n20.qasm...
#         Depths: 244, 288, 241, 293,
#     Circuit qram_n20.qasm transpiled with best depth 241 and time 0.1382291316986084.
#     Running the experiment for circuit qf21_n15.qasm...
#         Depths: 265, 242, 249, 245,
#     Circuit qf21_n15.qasm transpiled with best depth 242 and time 0.10048794746398926.
#     Running the experiment for circuit multiplier_n15.qasm...
#         Depths: 468, 385, 418, 376,
#     Circuit multiplier_n15.qasm transpiled with best depth 376 and time 0.3376150131225586.
#     Running the experiment for circuit sat_n11.qasm...
#         Depths: 530, 569, 543, 565,
#     Circuit sat_n11.qasm transpiled with best depth 530 and time 0.20601606369018555.
#     Running the experiment for circuit qft_n18.qasm...
#         Depths: 260, 332, 347, 258,
#     Circuit qft_n18.qasm transpiled with best depth 258 and time 0.33959102630615234.
#     Running the experiment for circuit vqe_uccsd_n6.qasm...
#         Depths: 1074, 1424, 1675, 1424,
#     Circuit vqe_uccsd_n6.qasm transpiled with best depth 1074 and time 0.25675296783447266.
#     Running the experiment for circuit vqe_uccsd_n8.qasm...
#         Depths: 8036, 5508, 9000, 6573,
#     Circuit vqe_uccsd_n8.qasm transpiled with best depth 5508 and time 1.3399858474731445.
