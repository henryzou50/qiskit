# %%
from experiments.utils.pass_managers import run_circuits, build_pm
from experiments.utils.coupling_maps import file_to_coupling_map
from experiments.utils.circuits      import directory_to_circuits, rename_circuits

# Parameters for general experiments
from qiskit.transpiler.passes.routing.sabre_swap_0_20  import SabreSwap_v0_20   
from qiskit.transpiler.passes.routing.sabre_swap_0_20_depth  import SabreSwap_v0_20_Depth
from qiskit.transpiler.passes.routing.sabre_swap_0_20_depth_ties import SabreSwap_v0_20_DepthTies
from qiskit.transpiler.passes.routing.sabre_swap_0_20_depth_crit import SabreSwap_v0_20_DepthCrit

from qiskit.transpiler.passes.layout.sabre_layout import SabreLayout as LP
from qiskit.transpiler.passes.routing.sabre_swap  import SabreSwap as RP

# %%
# List of routing passes
rp_list = [SabreSwap_v0_20, SabreSwap_v0_20_Depth, SabreSwap_v0_20_DepthTies]
skip_list = []

# Main parameters for experiments
qc_type     = 'synthetic/hex_027_prob'
cm_type     = 'hex_027'
seed        = 42
num_times   = 1
max_iter    = 3

# Other parameters for sabre_mods
beam        = 1
look        = 1
crit        = 1

# %%
# Runs the experiments
coupling_map     = file_to_coupling_map(f'experiments/coupling_maps/{cm_type}.txt')
circuits, files  = directory_to_circuits(f'experiments/circuits/{qc_type}/')
circuits         = rename_circuits(circuits, files)

# %%
for rp in rp_list:
    if rp in skip_list:
        continue
    routing_pass     = rp(coupling_map, seed=seed)
    layout_pass      = LP(coupling_map, RP(coupling_map, seed=seed), seed=seed, max_iterations=max_iter)
    pass_manager     = build_pm(coupling_map, layout_pass, routing_pass)
    rp_name = routing_pass.__class__.__name__
    filename = f'experiments/results/{qc_type}/{rp_name}.csv'
    df = run_circuits(filename, circuits, pass_manager, num_times, max_iter, beam, look, crit)
# Out:
#     Running the experiment for circuit _10_prob.qasm...
#         Depths: 51,
#     Circuit _10_prob.qasm transpiled with best depth 51 and time 0.05629301071166992.
#     Running the experiment for circuit _20_prob.qasm...
#         Depths: 104,
#     Circuit _20_prob.qasm transpiled with best depth 104 and time 0.05590105056762695.
#     Running the experiment for circuit _30_prob.qasm...
#         Depths: 129,
#     Circuit _30_prob.qasm transpiled with best depth 129 and time 0.08022594451904297.
#     Running the experiment for circuit _40_prob.qasm...
#         Depths: 219,
#     Circuit _40_prob.qasm transpiled with best depth 219 and time 0.10331177711486816.
#     Running the experiment for circuit _50_prob.qasm...
#         Depths: 141,
#     Circuit _50_prob.qasm transpiled with best depth 141 and time 0.1132972240447998.
#     Running the experiment for circuit _60_prob.qasm...
#         Depths: 291,
#     Circuit _60_prob.qasm transpiled with best depth 291 and time 0.16332411766052246.
#     Running the experiment for circuit _70_prob.qasm...
#         Depths: 501,
#     Circuit _70_prob.qasm transpiled with best depth 501 and time 0.24957919120788574.
#     Running the experiment for circuit _80_prob.qasm...
#         Depths: 396,
#     Circuit _80_prob.qasm transpiled with best depth 396 and time 0.248687744140625.
#     Running the experiment for circuit _90_prob.qasm...
#         Depths: 526,
#     Circuit _90_prob.qasm transpiled with best depth 526 and time 0.2759392261505127.
#     Running the experiment for circuit _100_prob.qasm...
#         Depths: 696,
#     Circuit _100_prob.qasm transpiled with best depth 696 and time 0.29048705101013184.
#     Running the experiment for circuit _10_prob.qasm...
#         Depths: 45,
#     Circuit _10_prob.qasm transpiled with best depth 45 and time 0.03279900550842285.
#     Running the experiment for circuit _20_prob.qasm...
#         Depths: 94,
#     Circuit _20_prob.qasm transpiled with best depth 94 and time 0.09510993957519531.
#     Running the experiment for circuit _30_prob.qasm...
#         Depths: 131,
#     Circuit _30_prob.qasm transpiled with best depth 131 and time 0.09881711006164551.
#     Running the experiment for circuit _40_prob.qasm...
#         Depths: 218,
#     Circuit _40_prob.qasm transpiled with best depth 218 and time 0.15309882164001465.
#     Running the experiment for circuit _50_prob.qasm...
#         Depths: 281,
#     Circuit _50_prob.qasm transpiled with best depth 281 and time 0.16789507865905762.
#     Running the experiment for circuit _60_prob.qasm...
#         Depths: 321,
#     Circuit _60_prob.qasm transpiled with best depth 321 and time 0.2349681854248047.
#     Running the experiment for circuit _70_prob.qasm...
#         Depths: 473,
#     Circuit _70_prob.qasm transpiled with best depth 473 and time 0.3226931095123291.
#     Running the experiment for circuit _80_prob.qasm...
#         Depths: 413,
#     Circuit _80_prob.qasm transpiled with best depth 413 and time 0.34813499450683594.
#     Running the experiment for circuit _90_prob.qasm...
#         Depths: 549,
#     Circuit _90_prob.qasm transpiled with best depth 549 and time 0.41407108306884766.
#     Running the experiment for circuit _100_prob.qasm...
#         Depths: 513,
#     Circuit _100_prob.qasm transpiled with best depth 513 and time 0.414884090423584.
#     Running the experiment for circuit _10_prob.qasm...
#         Depths: 46,
#     Circuit _10_prob.qasm transpiled with best depth 46 and time 0.032533884048461914.
#     Running the experiment for circuit _20_prob.qasm...
#         Depths: 85,
#     Circuit _20_prob.qasm transpiled with best depth 85 and time 0.0644838809967041.
#     Running the experiment for circuit _30_prob.qasm...
#         Depths: 141,
#     Circuit _30_prob.qasm transpiled with best depth 141 and time 0.09859895706176758.
#     Running the experiment for circuit _40_prob.qasm...
#         Depths: 164,
#     Circuit _40_prob.qasm transpiled with best depth 164 and time 0.12422609329223633.
#     Running the experiment for circuit _50_prob.qasm...
#         Depths: 189,
#     Circuit _50_prob.qasm transpiled with best depth 189 and time 0.13271498680114746.
#     Running the experiment for circuit _60_prob.qasm...
#         Depths: 269,
#     Circuit _60_prob.qasm transpiled with best depth 269 and time 0.18950676918029785.
#     Running the experiment for circuit _70_prob.qasm...
#         Depths: 433,
#     Circuit _70_prob.qasm transpiled with best depth 433 and time 0.2725088596343994.
#     Running the experiment for circuit _80_prob.qasm...
#         Depths: 385,
#     Circuit _80_prob.qasm transpiled with best depth 385 and time 0.26194000244140625.
#     Running the experiment for circuit _90_prob.qasm...
#         Depths: 559,
#     Circuit _90_prob.qasm transpiled with best depth 559 and time 0.35001492500305176.
#     Running the experiment for circuit _100_prob.qasm...
#         Depths: 633,
#     Circuit _100_prob.qasm transpiled with best depth 633 and time 0.39035534858703613.

# %% [markdown]
# Run experiment for Sabre_v0_20_extended

# %%
rp_list = [SabreSwap_v0_20]
for rp in rp_list: 
    if rp in skip_list:
        continue
    routing_pass     = rp(coupling_map, seed=seed, heuristic="lookahead")
    layout_pass      = LP(coupling_map, routing_pass, seed=seed, max_iterations=max_iter)
    pass_manager     = build_pm(coupling_map, layout_pass, routing_pass)
    rp_name = routing_pass.__class__.__name__ + "_extended"
    filename = f'experiments/results/{qc_type}/{rp_name}.csv'
    df = run_circuits(filename, circuits, pass_manager, num_times, max_iter, beam, look, crit)
# Out:
#     Running the experiment for circuit _10_prob.qasm...
#         Depths: 51,
#     Circuit _10_prob.qasm transpiled with best depth 51 and time 0.08674001693725586.
#     Running the experiment for circuit _20_prob.qasm...
#         Depths: 79,
#     Circuit _20_prob.qasm transpiled with best depth 79 and time 0.10731387138366699.
#     Running the experiment for circuit _30_prob.qasm...
#         Depths: 171,
#     Circuit _30_prob.qasm transpiled with best depth 171 and time 0.23066210746765137.
#     Running the experiment for circuit _40_prob.qasm...
#         Depths: 171,
#     Circuit _40_prob.qasm transpiled with best depth 171 and time 0.20093703269958496.
#     Running the experiment for circuit _50_prob.qasm...
#         Depths: 277,
#     Circuit _50_prob.qasm transpiled with best depth 277 and time 0.287045955657959.
#     Running the experiment for circuit _60_prob.qasm...
#         Depths: 390,
#     Circuit _60_prob.qasm transpiled with best depth 390 and time 0.4191889762878418.
#     Running the experiment for circuit _70_prob.qasm...
#         Depths: 398,
#     Circuit _70_prob.qasm transpiled with best depth 398 and time 0.38898801803588867.
#     Running the experiment for circuit _80_prob.qasm...
#         Depths: 454,
#     Circuit _80_prob.qasm transpiled with best depth 454 and time 0.428023099899292.
#     Running the experiment for circuit _90_prob.qasm...
#         Depths: 309,
#     Circuit _90_prob.qasm transpiled with best depth 309 and time 0.5109388828277588.
#     Running the experiment for circuit _100_prob.qasm...
#         Depths: 517,
#     Circuit _100_prob.qasm transpiled with best depth 517 and time 0.7678558826446533.

# %%
rp_list = [SabreSwap_v0_20_DepthCrit]
for rp in rp_list: 
    if rp in skip_list:
        continue
    routing_pass     = rp(coupling_map, seed=seed, crit_weight=crit)
    layout_pass      = LP(coupling_map, RP(coupling_map, seed=seed), seed=seed, max_iterations=max_iter)
    pass_manager     = build_pm(coupling_map, layout_pass, routing_pass)
    rp_name = routing_pass.__class__.__name__ + "_extended"
    filename = f'experiments/results/{qc_type}/{rp_name}.csv'
    df = run_circuits(filename, circuits, pass_manager, num_times, max_iter, beam, look, crit)
# Out:
#     Running the experiment for circuit _10_prob.qasm...
#         Depths: 42,
#     Circuit _10_prob.qasm transpiled with best depth 42 and time 0.040232181549072266.
#     Running the experiment for circuit _20_prob.qasm...
#         Depths: 63,
#     Circuit _20_prob.qasm transpiled with best depth 63 and time 0.06963205337524414.
#     Running the experiment for circuit _30_prob.qasm...
#         Depths: 135,
#     Circuit _30_prob.qasm transpiled with best depth 135 and time 0.11379814147949219.
#     Running the experiment for circuit _40_prob.qasm...
#         Depths: 191,
#     Circuit _40_prob.qasm transpiled with best depth 191 and time 0.15193486213684082.
#     Running the experiment for circuit _50_prob.qasm...
#         Depths: 151,
#     Circuit _50_prob.qasm transpiled with best depth 151 and time 0.1513829231262207.
#     Running the experiment for circuit _60_prob.qasm...
#         Depths: 272,
#     Circuit _60_prob.qasm transpiled with best depth 272 and time 0.2541801929473877.
#     Running the experiment for circuit _70_prob.qasm...
#         Depths: 414,
#     Circuit _70_prob.qasm transpiled with best depth 414 and time 0.32724785804748535.
#     Running the experiment for circuit _80_prob.qasm...
#         Depths: 306,
#     Circuit _80_prob.qasm transpiled with best depth 306 and time 0.3167989253997803.
#     Running the experiment for circuit _90_prob.qasm...
#         Depths: 518,
#     Circuit _90_prob.qasm transpiled with best depth 518 and time 0.46566009521484375.
#     Running the experiment for circuit _100_prob.qasm...
#         Depths: 615,
#     Circuit _100_prob.qasm transpiled with best depth 615 and time 0.5365259647369385.
