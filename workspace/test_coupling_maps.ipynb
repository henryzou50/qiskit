# %% [markdown]
# This notebook tests the coupling maps we are using for the experiments
#
# We will be using the coupling maps of:
# - 27 qubits, heavy hex
# - 127 qubits, heavy hex

# %%
from ulti.coupling_maps import file_to_coupling_map

# %%
cm_7 = file_to_coupling_map('coupling_maps/hex_7.txt')
print(cm_7)
cm_7.draw()
# Out:
# [[5, 4], [4, 5], [1, 3], [3, 1], [6, 5], [5, 6], [3, 5], [5, 3], [2, 1], [1, 2], [0, 1], [1, 0]]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=454x381>

# %%
cm_27 = file_to_coupling_map('coupling_maps/hex_27.txt')
print(cm_27)
cm_27.draw()
# Out:
# [[6, 7], [7, 6], [12, 13], [13, 12], [7, 10], [10, 7], [8, 11], [11, 8], [3, 2], [2, 3], [4, 7], [7, 4], [9, 8], [8, 9], [17, 18], [18, 17], [1, 0], [0, 1], [15, 12], [12, 15], [1, 4], [4, 1], [20, 19], [19, 20], [26, 25], [25, 26], [21, 23], [23, 21], [21, 18], [18, 21], [16, 14], [14, 16], [13, 14], [14, 13], [24, 25], [25, 24], [11, 14], [14, 11], [24, 23], [23, 24], [10, 12], [12, 10], [22, 19], [19, 22], [5, 8], [8, 5], [22, 25], [25, 22], [3, 5], [5, 3], [16, 19], [19, 16], [18, 15], [15, 18], [1, 2], [2, 1]]
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=741x1063>

# %%
cm_127 = file_to_coupling_map('coupling_maps/hex_127.txt')
print(cm_127)
cm_127.draw()
# Out:
# [[55, 49], [73, 66], [92, 83], [99, 100], [117, 116], [22, 15], [26, 16], [31, 30], [33, 39], [35, 47], [43, 34], [53, 60], [64, 54], [71, 77], [81, 72], [93, 87], [98, 91], [111, 104], [114, 109], [5, 4], [16, 8], [17, 12], [21, 20], [34, 24], [35, 28], [41, 40], [50, 51], [54, 45], [61, 62], [69, 68], [71, 58], [73, 85], [80, 79], [89, 88], [92, 102], [107, 106], [109, 96], [110, 118], [122, 111], [126, 125], [4, 3], [8, 9], [12, 13], [14, 0], [20, 33], [23, 24], [28, 27], [31, 32], [42, 41], [45, 46], [49, 50], [52, 37], [59, 58], [66, 65], [69, 70], [72, 62], [78, 79], [83, 84], [87, 88], [90, 75], [97, 96], [104, 103], [107, 108], [110, 100], [120, 121], [125, 124], [3, 2], [7, 6], [10, 11], [14, 18], [21, 22], [26, 25], [29, 30], [40, 39], [43, 44], [47, 48], [56, 52], [59, 60], [63, 64], [68, 67], [78, 77], [81, 82], [86, 85], [90, 94], [97, 98], [101, 102], [106, 105], [114, 115], [119, 118], [123, 122], [1, 2], [6, 5], [10, 9], [17, 30], [18, 19], [23, 22], [26, 27], [36, 51
# ...
