# %% [markdown]
# # Summary plots

# %%
from ulti.graphs import compare_single_metric, analyze_metric

# %% [markdown]
# ### Comparing lookahead results to Sabre 0.20 to Sabre 0.20 Lookahead 1
# GHZ Circuit (2 qubits to 127 qubits)
#
# Examining depth

# %%
dir = "data/ghz_2-127"
file1 = f'{dir}/sabre_v020.csv'
file2 = f'{dir}/sabre_look_1_v020.csv'
compare_single_metric('depth', file1, file2, "Sabre 0.20 Lookahead 1", "Sabre 0.20", "Compilation Output Depth for GHZ circuit on Sherbrooke", "Number of GHZ Qubits")

# %% [markdown]
# Examining number of CNOTS

# %%
compare_single_metric('cx_gates', file1, file2, "Sabre 0.20 Lookahead 1", "Sabre 0.20", "Compilation Output CNOT Gate count for GHZ circuit on Sherbrooke", "Number of GHZ Qubits")

# %%
dir = "data/ghz_2-127"
baseline_file = 'sabre_v020.csv'
x_label = 'Number of GHZ Qubits'

metric = 'depth'
title = f'{metric} Analysis Across Circuits'
summary_depth = analyze_metric(dir, metric, baseline_file, title, x_label)
print(summary_depth)

metric = 'time'
title = f'{metric} Analysis Across Circuits'
summary_time = analyze_metric(dir, metric, baseline_file, title, x_label)
print(summary_time)

metric = 'cx_gates'
title = f'{metric} Analysis Across Circuits'
summary_cx_gates = analyze_metric(dir, metric, baseline_file, title, x_label)
print(summary_cx_gates)
# Out:
#                               depth  % Difference from Baseline
# file
# sabre_depth_v020.csv     180.275000                  -56.069605
# sabre_extended_v020.csv  257.206349                  -37.322554
# sabre_look_0_v020.csv    182.809524                  -55.451978
# sabre_look_1_v020.csv    201.558333                  -50.883166
# sabre_look_2_v020.csv    213.491667                  -47.975187
# sabre_look_3_v020.csv    218.208333                  -46.825804
# sabre_look_4_v020.csv    224.666667                  -45.252002
# sabre_look_5_v020.csv    229.283333                  -44.126987
# sabre_look_6_v020.csv    230.458333                  -43.840657
# sabre_look_7_v020.csv    235.275000                  -42.666905
# sabre_look_8_v020.csv    236.516667                  -42.364329
# sabre_look_9_v020.csv    241.041667                  -41.261652
# sabre_v020.csv           410.365079                    0.000000
# sabre_v025.csv           382.460317                   -6.799985
#                              time  % Difference from Baseline
# file
# sabre_depth_v020.csv     2.066067                 1159.881220
# sabre_extended_v020.csv  0.152724                   -6.869232
# sabre_look_0_v020.csv    2.127299                 1197.220337
# sabre_look_1_v020.csv    2.436179                 1385.574677
# sabre_look_2_v020.csv    2.960360                 1705.218557
# sabre_look_3_v020.csv    3.349005                 1942.212942
# sabre_look_4_v020.csv    3.834203                 2238.085329
# sabre_look_5_v020.csv    4.336168                 2544.181846
# sabre_look_6_v020.csv    4.804367                 2829.688338
# sabre_look_7_v020.csv    5.323788                 3146.429840
# sabre_look_8_v020.csv    5.790173                 3430.829990
# sabre_look_9_v020.csv    6.244554                 3707.910069
# sabre_v020.csv           0.163989                    0.000000
# sabre_v025.csv           0.027312                  -83.345022
#                            cx_gates  % Difference from Baseline
# file
# sabre_depth_v020.csv     938.158333                   31.812297
# sabre_extended_v020.csv  411.333333                  -42.207206
# sabre_look_0_v020.csv    966.309524                   35.767571
# sabre_look_1_v020.csv    873.483333                   22.725387
# sabre_look_2_v020.csv    899.558333                   26.388954
# sabre_look_3_v020.csv    906.158333                   27.316261
# sabre_look_4_v020.csv    919.683333                   29.216539
# sabre_look_5_v020.csv    929.058333                   30.533737
# sabre_look_6_v020.csv    930.258333                   30.702338
# sabre_look_7_v020.csv    943.083333                   32.504265
# sabre_look_8_v020.csv    944.083333                   32.644766
# sabre_look_9_v020.csv    939.808333                   32.044124
# sabre_v020.csv           711.738095                    0.000000
# sabre_v025.csv           624.571429                  -12.247014

# %% [markdown]
# QVOL circuit (5 qubits, original depth {10, 20, ... 500})
# Examining Depth

# %%
dir = "data/size5_depth_10-500"
file1 = f'{dir}/sabre_v020.csv'
file2 = f'{dir}/sabre_look_1_v020.csv'
compare_single_metric('depth', file1, file2, "Sabre 0.20 Lookahead 1", "Sabre 0.20", "Compilation output depth for QVOL 5 circuit on Perth", "Original Depth of Circuit")

# %%
compare_single_metric('cx_gates', file1, file2, "Sabre 0.20 Lookahead 0", "Sabre 0.20", "Compilation output CNOT for QVOL 5 circuit on Perth", "Original Depth of Circuit")

# %%
dir = "data/size5_depth_10-500"
baseline_file = 'sabre_v020.csv'
x_label = 'Orginal Depth of Circuit'

metric = 'depth'
title = f'{metric} Analysis Across Circuits'
summary_depth = analyze_metric(dir, metric, baseline_file, title, x_label)
print(summary_depth)

metric = 'time'
title = f'{metric} Analysis Across Circuits'
summary_time = analyze_metric(dir, metric, baseline_file, title, x_label)
print(summary_time)

metric = 'cx_gates'
title = f'{metric} Analysis Across Circuits'
summary_cx_gates = analyze_metric(dir, metric, baseline_file, title, x_label)
print(summary_cx_gates)
# Out:
#                                depth  % Difference from Baseline
# file
# sabre_depth_v020.csv     1021.775510                   -7.576009
# sabre_extended_v020.csv  1018.040816                   -7.913828
# sabre_look_0_v020.csv    1035.163265                   -6.365029
# sabre_look_1_v020.csv    1029.755102                   -6.854221
# sabre_look_2_v020.csv     999.979592                   -9.547544
# sabre_look_3_v020.csv    1027.163265                   -7.088664
# sabre_look_4_v020.csv    1045.285714                   -5.449410
# sabre_look_5_v020.csv    1052.020408                   -4.840228
# sabre_look_6_v020.csv    1055.122449                   -4.559635
# sabre_look_7_v020.csv    1079.857143                   -2.322276
# sabre_look_8_v020.csv    1082.224490                   -2.108139
# sabre_look_9_v020.csv    1079.142857                   -2.386886
# sabre_v020.csv           1105.530612                    0.000000
# sabre_v025.csv           1061.367347                   -3.994757
#                               time  % Difference from Baseline
# file
# sabre_depth_v020.csv      3.039106                  204.506675
# sabre_extended_v020.csv   1.115992                   11.818103
# sabre_look_0_v020.csv     1.168674                   17.096659
# sabre_look_1_v020.csv     1.743569                   74.698861
# sabre_look_2_v020.csv     4.931216                  394.088808
# sabre_look_3_v020.csv     6.227185                  523.939892
# sabre_look_4_v020.csv     7.883565                  689.902745
# sabre_look_5_v020.csv     9.362137                  838.049983
# sabre_look_6_v020.csv    10.707901                  972.890330
# sabre_look_7_v020.csv    12.562316                 1158.695565
# sabre_look_8_v020.csv    13.865069                 1289.226405
# sabre_look_9_v020.csv    14.507454                 1353.590909
# sabre_v020.csv            0.998042                    0.000000
# sabre_v025.csv            0.858619                  -13.969732
#                            cx_gates  % Difference from Baseline
# file
# sabre_depth_v020.csv     975.367347                    4.144604
# sabre_extended_v020.csv  848.938776                   -9.354775
# sabre_look_0_v020.csv    869.816327                   -7.125580
# sabre_look_1_v020.csv    793.163265                  -15.310192
# sabre_look_2_v020.csv    830.755102                  -11.296333
# sabre_look_3_v020.csv    827.020408                  -11.695104
# sabre_look_4_v020.csv    861.061224                   -8.060404
# sabre_look_5_v020.csv    839.816327                  -10.328823
# sabre_look_6_v020.csv    848.204082                   -9.433222
# sabre_look_7_v020.csv    847.469388                   -9.511669
# sabre_look_8_v020.csv    840.551020                  -10.250376
# sabre_look_9_v020.csv    817.959184                  -12.662614
# sabre_v020.csv           936.551020                    0.000000
# sabre_v025.csv           790.653061                  -15.578218
