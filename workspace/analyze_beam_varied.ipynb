# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import ast
from ulti.graphs import plot_data

# %% [markdown]
# GHZ 25

# %%
filename = 'data/ghz_25/sabre_v020_look.csv'
plot_data(filename, 'depth', 'Sabre Look: GHZ 25 Qubits (Depth vs Beam Width), lookahead = 10', 'beam width', 'depth')
plot_data(filename, 'cx_gates', 'Sabre Look: GHZ 25 Qubits (Depth vs Beam Width), lookahead = 10', 'beam width', 'cx gates')
# Out:
# /Users/henryzou/Documents/GitHub/qiskit/workspace/ulti/graphs.py:150: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   scatter = sns.scatterplot(data=df, x='RowNumber', y=y_key, palette="viridis", s=100, edgecolor="w", alpha=0.7)
# /Users/henryzou/Documents/GitHub/qiskit/workspace/ulti/graphs.py:150: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   scatter = sns.scatterplot(data=df, x='RowNumber', y=y_key, palette="viridis", s=100, edgecolor="w", alpha=0.7)

# %% [markdown]
# GHZ 100

# %%
filename = 'data/ghz_100/sabre_v020_look.csv'
plot_data(filename, 'depth', 'Sabre Look: GHZ 100 Qubits (Depth vs Beam Width), lookahead = 10', 'beam width', 'depth')
plot_data(filename, 'cx_gates', 'Sabre Look: GHZ 100 Qubits (Depth vs Beam Width), lookahead = 10', 'beam width', 'cx gates')
# Out:
# /Users/henryzou/Documents/GitHub/qiskit/workspace/ulti/graphs.py:150: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   scatter = sns.scatterplot(data=df, x='RowNumber', y=y_key, palette="viridis", s=100, edgecolor="w", alpha=0.7)
# /Users/henryzou/Documents/GitHub/qiskit/workspace/ulti/graphs.py:150: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   scatter = sns.scatterplot(data=df, x='RowNumber', y=y_key, palette="viridis", s=100, edgecolor="w", alpha=0.7)

# %% [markdown]
# QVOL Circuit

# %%
filename = 'data/qvol_10_depth_100/sabre_v020_look.csv'
plot_data(filename, 'depth', 'Sabre Look: QVOL 10 Qubits 100 Depth (Depth vs Beam Width), Lookahead = 10', 'beam width', 'depth')
plot_data(filename, 'cx_gates', 'Sabre Look: QVOL 10 Qubits 100 Depth (Depth vs Beam Width), Lookahead = 10', 'beam width', 'cx gates')
# Out:
# /Users/henryzou/Documents/GitHub/qiskit/workspace/ulti/graphs.py:150: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   scatter = sns.scatterplot(data=df, x='RowNumber', y=y_key, palette="viridis", s=100, edgecolor="w", alpha=0.7)
# /Users/henryzou/Documents/GitHub/qiskit/workspace/ulti/graphs.py:150: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   scatter = sns.scatterplot(data=df, x='RowNumber', y=y_key, palette="viridis", s=100, edgecolor="w", alpha=0.7)
