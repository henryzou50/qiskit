# %% [markdown]
# This code runs the experiment for SabreSwap v0.25 and SabreLayout v0.25

# %%
from qiskit.transpiler.passes.routing.sabre_swap_v020_dive   import SabreSwap   as SabreSwap_v020
from qiskit.transpiler.passes.layout.sabre_layout                 import SabreLayout as SabreLayout_v045
from qiskit.transpiler.passes.layout.sabre_layout_v020            import SabreLayout as SabreLayout_v020
from ulti.circuits import get_circuit_list, sort_circuits_by_depth
from ulti.coupling_maps import file_to_coupling_map
from ulti.pass_managers import generate_pass_managers, transpiled_data
import pandas as pd
import random
random.seed(42)
import os

# %%
# Option to keep the layout inital layout the same for faster transpilation
fast_layout = True
num_shots = 5
qc_name = "ghz_25"
cp_name = "hex_27"
print(f"Running experiment for the circuits: {qc_name}")
qc_list = get_circuit_list([f'circuits/{qc_name}/'])
qc_list = sort_circuits_by_depth(qc_list)

csv_file_path = f'data/{qc_name}/sabre_v020_dive_data_fast.csv'
directory = f'data/{qc_name}'
if not os.path.exists(directory):
        os.makedirs(directory)
# Out:
# Running experiment for the circuits: ghz_25

# %%
# Test beam_width from 1
beam_width = [1000, 2000, 4000, 8000]
all_data_df = pd.DataFrame()
for beam in beam_width:
    print(f"Running experiment for dive {beam}")
    # Experiment for Sabre v0.20 with lookahead heuristic
    # set beam to max integer
    lp_name = "sabre_v020"
    if beam < 10:
        rp_name = f"sabre_v020_dive_00{beam}"
    elif beam < 100:
        rp_name = f"sabre_v020_dive_0{beam}"
    else:
        rp_name = f"sabre_v020_dive_{beam}"

    rp = SabreSwap_v020
    lp = SabreLayout_v020
    cm = file_to_coupling_map(f'coupling_maps/{cp_name}.txt')
    pm = generate_pass_managers(num_shots, rp, lp, cm, beam_width = beam, 
                                fast_layout=fast_layout)

    for qc_idx, qc in enumerate(qc_list):
        data = transpiled_data(qc, pm)
        data['routing pass'] = rp_name
        data['layout pass'] = lp_name
        data['coupling map'] = cp_name
        data['circuit label'] = qc_idx
        data['beam width'] = beam
        data['look ahead'] = 0
        
        # Create a DataFrame from the current data and append it to the all_data_df
        current_data_df = pd.DataFrame([data])
        all_data_df = pd.concat([all_data_df, current_data_df])

        # Append the current data to the CSV file
        with open(csv_file_path, 'a') as f:
            current_data_df.to_csv(f, header=f.tell()==0, index=False)

        print(f"    Finished {qc_idx} for experiment {rp_name} and circuit {qc_name}")

    print(f"Finished all for experiment {rp_name} and circuit {qc_name}")
    print(f"Saved to {csv_file_path}")
    print("*" * 50)
# Out:
# Running experiment for dive 1000
# current level:  0
#      Number of candidate states:  6
#      Update (after sabre) depth to  69
#      Update (after sabre) depth to  66
# current level:  1
#      Number of candidate states:  31
# current level:  2
#      Number of candidate states:  148
# current level:  3
#      Number of candidate states:  728
# current level:  4
#      Number of candidate states:  3405
# current level:  5
#      Number of candidate states:  4878
#      Update (after sabre) depth to  64
# current level:  6
#      Number of candidate states:  4772
#      Update (after sabre) depth to  63
# current level:  7
#      Number of candidate states:  4731
# current level:  8
#      Number of candidate states:  4656
#      Update (after sabre) depth to  62
# current level:  9
#      Number of candidate states:  4725
# current level:  10
#      Number of candidate states:  4757
# current level:  11
#      Number of candidate states:  5051
# current level:  12
#      Number of candidate states:  4996
# current level:  13
#      Number of candidate states:  5017
# current level:  14
#      Number of candidate states:  4981
# current level:  15
#      Number of candidate states:  5326
# current level:  16
#      Number of candidate states:  4901
# current level:  17
#      Number of candidate states:  5625
# current level:  18
#      Number of candidate states:  4786
# current level:  19
#      Number of candidate states:  5546
# current level:  20
#      Number of candidate states:  4940
# current level:  21
#      Number of candidate states:  5296
# current level:  22
#      Number of candidate states:  5488
# current level:  23
#      Number of candidate states:  4891
# current level:  24
#      Number of candidate states:  5619
# current level:  25
#      Number of candidate states:  4914
# current level:  26
#      Number of candidate states:  5892
# current level:  27
#      Number of candidate states:  4710
# current level:  28
#      Number of candidate states:  5724
# current level:  29
#      Number of candidate states:  4947
# current level:  30
#      Number of candidate states:  5539
# current level:  31
#      Number of candidate states:  4997
# current level:  32
#      Number of candidate states:  5551
# current level:  33
#      Number of candidate states:  5157
# current level:  34
#      Number of candidate states:  5493
# current level:  35
#      Number of candidate states:  5278
# current level:  36
#      Number of candidate states:  5287
# current level:  37
#      Number of candidate states:  5269
# current level:  38
#      Number of candidate states:  5123
# current level:  39
#      Number of candidate states:  4844
# current level:  40
#      Number of candidate states:  4911
# current level:  41
#      Number of candidate states:  4568
# current level:  42
#      Number of candidate states:  4770
# current level:  43
#      Number of candidate states:  4557
# current level:  44
#      Number of candidate states:  4838
# current level:  45
#      Number of candidate states:  4553
# current level:  46
#      Number of candidate states:  4816
# current level:  47
#      Number of candidate states:  4555
# current level:  48
#      Number of candidate states:  4782
# current level:  49
#      Number of candidate states:  4629
# current level:  50
#      Number of candidate states:  4814
# current level:  51
#      Number of candidate states:  4803
# current level:  52
#      Number of candidate states:  4912
# current level:  53
#      Number of candidate states:  4981
# current level:  54
#      Number of candidate states:  5057
# current level:  55
#      Number of candidate states:  5114
# current level:  56
#      Number of candidate states:  5065
# current level:  57
#      Number of candidate states:  5211
# current level:  58
#      Number of candidate states:  4996
# current level:  59
#      Number of candidate states:  5276
# current level:  60
#      Number of candidate states:  5026
# current level:  61
#      Number of candidate states:  5374
# current level:  62
#      Number of candidate states:  4788
# current level:  63
#      Number of candidate states:  5679
# current level:  64
#      Number of candidate states:  4802
# current level:  65
#      Number of candidate states:  5757
# current level:  66
#      Number of candidate states:  4947
# current level:  67
#      Number of candidate states:  5677
# current level:  68
#      Number of candidate states:  4846
# current level:  69
#      Number of candidate states:  5547
# current level:  70
#      Number of candidate states:  4718
# current level:  71
#      Number of candidate states:  5946
# current level:  72
#      Number of candidate states:  4686
# current level:  73
#      Number of candidate states:  5884
# current level:  74
#      Number of candidate states:  4778
# current level:  75
#      Number of candidate states:  5880
# current level:  76
#      Number of candidate states:  4783
# current level:  77
#      Number of candidate states:  5734
# current level:  78
#      Number of candidate states:  4828
# current level:  79
#      Number of candidate states:  5295
#      Update (after sabre) depth to  61
# current level:  80
#      Number of candidate states:  4778
# current level:  81
#      Number of candidate states:  5150
# current level:  82
#      Number of candidate states:  4679
# current level:  83
#      Number of candidate states:  4716
# current level:  84
#      Number of candidate states:  4617
# current level:  85
#      Number of candidate states:  4518
# current level:  86
#      Number of candidate states:  4629
# current level:  87
#      Number of candidate states:  4491
# current level:  88
#      Number of candidate states:  4746
# current level:  89
#      Number of candidate states:  4551
# current level:  90
#      Number of candidate states:  5134
# current level:  91
#      Number of candidate states:  4610
# current level:  92
#      Number of candidate states:  5269
# current level:  93
#      Number of candidate states:  3928
# current level:  94
#      Number of candidate states:  4616
# current level:  95
#      Number of candidate states:  2768
# current level:  96
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Number of candidate states:  3522
# current level:  97
#      Number of candidate states:  2529
# current level:  98
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Number of candidate states:  3015
# current level:  99
#      Number of candidate states:  1854
# current level:  0
#      Number of candidate states:  4
#      Update (after sabre) depth to  79
#      Update (after sabre) depth to  76
# current level:  1
#      Number of candidate states:  19
#      Update (after sabre) depth to  75
# current level:  2
#      Number of candidate states:  87
# current level:  3
#      Number of candidate states:  407
#      Update (after sabre) depth to  72
# current level:  4
#      Number of candidate states:  1838
# current level:  5
#      Number of candidate states:  4696
# current level:  6
#      Number of candidate states:  4714
#      Update (after sabre) depth to  67
# current level:  7
#      Number of candidate states:  4771
# current level:  8
#      Number of candidate states:  4793
# current level:  9
#      Number of candidate states:  4972
# current level:  10
#      Number of candidate states:  4628
# current level:  11
#      Number of candidate states:  4729
# current level:  12
#      Number of candidate states:  4406
# current level:  13
#      Number of candidate states:  4311
# current level:  14
#      Number of candidate states:  4083
# current level:  15
#      Number of candidate states:  4147
# current level:  16
#      Number of candidate states:  3750
# current level:  17
#      Number of candidate states:  4475
# current level:  18
#      Number of candidate states:  4041
# current level:  19
#      Number of candidate states:  4617
# current level:  20
#      Number of candidate states:  4361
# current level:  21
#      Number of candidate states:  4664
# current level:  22
#      Number of candidate states:  4763
# current level:  23
#      Number of candidate states:  4963
# current level:  24
#      Number of candidate states:  5284
# current level:  25
#      Number of candidate states:  5412
# current level:  26
#      Number of candidate states:  4944
#      Update (after sabre) depth to  62
# current level:  27
#      Number of candidate states:  4996
# current level:  28
#      Number of candidate states:  4617
# current level:  29
#      Number of candidate states:  4626
# current level:  30
#      Number of candidate states:  4632
# current level:  31
#      Number of candidate states:  4333
# current level:  32
#      Number of candidate states:  4623
# current level:  33
#      Number of candidate states:  4167
# current level:  34
#      Number of candidate states:  3865
# current level:  35
#      Number of candidate states:  4728
# current level:  36
#      Number of candidate states:  3773
# current level:  37
#      Number of candidate states:  4546
# current level:  38
#      Number of candidate states:  4029
# current level:  39
#      Number of candidate states:  4179
# current level:  40
#      Number of candidate states:  4419
# current level:  41
#      Number of candidate states:  3810
# current level:  42
#      Number of candidate states:  4718
#      Update (after sabre) depth to  61
# current level:  43
#      Number of candidate states:  4012
# current level:  44
#      Number of candidate states:  4798
# current level:  45
#      Number of candidate states:  4411
# current level:  46
#      Number of candidate states:  4953
# current level:  47
#      Number of candidate states:  4593
# current level:  48
#      Number of candidate states:  5243
# current level:  49
#      Number of candidate states:  4758
# current level:  50
#      Number of candidate states:  5685
# current level:  51
#      Number of candidate states:  4878
# current level:  52
#      Number of candidate states:  5712
# current level:  53
#      Number of candidate states:  4843
# current level:  54
#      Number of candidate states:  5586
# current level:  55
#      Number of candidate states:  4926
# current level:  56
#      Number of candidate states:  5791
# current level:  57
#      Number of candidate states:  4895
# current level:  58
#      Number of candidate states:  5536
# current level:  59
#      Number of candidate states:  5166
# current level:  60
#      Number of candidate states:  5273
# current level:  61
#      Number of candidate states:  5362
# current level:  62
#      Number of candidate states:  5162
# current level:  63
#      Number of candidate states:  5526
# current level:  64
#      Number of candidate states:  5049
# current level:  65
#      Number of candidate states:  5754
# current level:  66
#      Number of candidate states:  4839
# current level:  67
#      Number of candidate states:  5904
# current level:  68
#      Number of candidate states:  4786
# current level:  69
#      Number of candidate states:  5821
# current level:  70
#      Number of candidate states:  4826
# current level:  71
#      Number of candidate states:  5828
# current level:  72
#      Number of candidate states:  4934
# current level:  73
#      Number of candidate states:  5515
# current level:  74
#      Number of candidate states:  4822
# current level:  75
#      Number of candidate states:  5110
# current level:  76
#      Number of candidate states:  4641
# current level:  77
#      Number of candidate states:  4870
# current level:  78
#      Number of candidate states:  4444
# current level:  79
#      Number of candidate states:  4788
# current level:  80
#      Number of candidate states:  4368
# current level:  81
#      Number of candidate states:  4629
# current level:  82
#      Number of candidate states:  4384
# current level:  83
#      Number of candidate states:  4408
# current level:  84
#      Number of candidate states:  4522
# current level:  85
#      Number of candidate states:  4204
# current level:  86
#      Number of candidate states:  4705
# current level:  87
#      Update depth to  61
#      Update depth to  61
#      Number of candidate states:  4100
# current level:  88
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Number of candidate states:  4806
# current level:  89
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Number of candidate states:  3986
# current level:  90
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Number of candidate states:  4435
# current level:  91
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Number of candidate states:  3587
# current level:  92
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Number of candidate states:  3184
# current level:  93
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Number of candidate states:  2822
# current level:  94
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Number of candidate states:  2017
# current level:  95
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Number of candidate states:  1501
# current level:  96
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Number of candidate states:  1282
# current level:  97
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Number of candidate states:  577
# current level:  98
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Update depth to  61
#      Number of candidate states:  696
# current level:  99
#      Number of candidate states:  0
# current level:  0
#      Number of candidate states:  4
#      Update (after sabre) depth to  71
# current level:  1
#      Number of candidate states:  19
# current level:  2
#      Number of candidate states:  89
# current level:  3
#      Number of candidate states:  424
# current level:  4
#      Number of candidate states:  1932
# current level:  5
#      Number of candidate states:  4761
# current level:  6
#      Number of candidate states:  4781
#      Update (after sabre) depth to  70
# current level:  7
#      Number of candidate states:  4757
# current level:  8
#      Number of candidate states:  4647
# current level:  9
#      Number of candidate states:  4752
# current level:  10
#      Number of candidate states:  4943
# current level:  11
#      Number of candidate states:  5167
# current level:  12
#      Number of candidate states:  5128
#      Update (after sabre) depth to  68
# current level:  13
#      Number of candidate states:  5375
# current level:  14
#      Number of candidate states:  4980
# current level:  15
#      Number of candidate states:  5241
# current level:  16
#      Number of candidate states:  4965
# current level:  17
#      Number of candidate states:  5107
# current level:  18
#      Number of candidate states:  5133
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 23
#      19 pm = generate_pass_managers(num_shots, rp, lp, cm, beam_width = beam,
#      20                             fast_layout=fast_layout)
#      22 for qc_idx, qc in enumerate(qc_list):
# ---> 23     data = transpiled_data(qc, pm)
#      24     data['routing pass'] = rp_name
#      25     data['layout pass'] = lp_name
#
# File ~/Documents/GitHub/qiskit/workspace/ulti/pass_managers.py:131, in transpiled_data(qc, pass_managers)
#     129 for pm in pass_managers:
#     130     time_start = time.time()
# --> 131     qc_tr = pm.run(qc_decomposed)
#     132     time_end = time.time()
#     133     time_elapsed = time_end - time_start
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:551, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     548 @wraps(meth)
#     549 def wrapper(*meth_args, **meth_kwargs):
#     550     try:
# --> 551         return meth(*meth_args, **meth_kwargs)
#     552     except PassManagerError as ex:
#     553         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:291, in PassManager.run(self, circuits, output_name, callback)
#     288 if callback is not None:
#     289     callback = _legacy_style_callback(callback)
# --> 291 return super().run(
#     292     in_programs=circuits,
#     293     callback=callback,
#     294     output_name=output_name,
#     295 )
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:222, in BasePassManager.run(self, in_programs, callback, **kwargs)
#     219     is_list = False
#     221 if len(in_programs) == 1:
# --> 222     out_program = _run_workflow(
#     223         program=in_programs[0],
#     224         pass_manager=self,
#     225         callback=callback,
#     226         **kwargs,
#     227     )
#     228     if is_list:
#     229         return [out_program]
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:284, in _run_workflow(program, pass_manager, **kwargs)
#     278 initial_status = WorkflowStatus()
#     280 passmanager_ir = pass_manager._passmanager_frontend(
#     281     input_program=program,
#     282     **kwargs,
#     283 )
# --> 284 passmanager_ir, _ = flow_controller.execute(
#     285     passmanager_ir=passmanager_ir,
#     286     state=PassManagerState(
#     287         workflow_status=initial_status,
#     288         property_set=pass_manager.property_set,
#     289     ),
#     290     callback=kwargs.get("callback", None),
#     291 )
#     292 out_program = pass_manager._passmanager_backend(
#     293     passmanager_ir=passmanager_ir,
#     294     in_program=program,
#     295     **kwargs,
#     296 )
#     298 return out_program
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/runningpassmanager.py:161, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     158 @wraps(meth)
#     159 def wrapper(*meth_args, **meth_kwargs):
#     160     try:
# --> 161         return meth(*meth_args, **meth_kwargs)
#     162     except PassManagerError as ex:
#     163         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:218, in BaseController.execute(self, passmanager_ir, state, callback)
#     216     return passmanager_ir, state
#     217 while True:
# --> 218     passmanager_ir, state = next_task.execute(
#     219         passmanager_ir=passmanager_ir,
#     220         state=state,
#     221         callback=callback,
#     222     )
#     223     try:
#     224         # Sending the object through the generator implies the custom controllers
#     225         # can always rely on the latest data to choose the next task to run.
#     226         next_task = task_generator.send(state)
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/basepasses.py:195, in TransformationPass.execute(self, passmanager_ir, state, callback)
#     189 def execute(
#     190     self,
#     191     passmanager_ir: PassManagerIR,
#     192     state: PassManagerState,
#     193     callback: Callable = None,
#     194 ) -> tuple[PassManagerIR, PassManagerState]:
# --> 195     new_dag, state = super().execute(
#     196         passmanager_ir=passmanager_ir,
#     197         state=state,
#     198         callback=callback,
#     199     )
#     201     if state.workflow_status.previous_run == RunState.SUCCESS:
#     202         if isinstance(new_dag, DAGCircuit):
#     203             # Copy calibration data from the original program
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:98, in GenericPass.execute(self, passmanager_ir, state, callback)
#      96 try:
#      97     if self not in state.workflow_status.completed_passes:
# ---> 98         ret = self.run(passmanager_ir)
#      99         run_state = RunState.SUCCESS
#     100     else:
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v020_dive.py:166, in SabreSwap.run(self, dag)
#     164 for state in candidate_states:
#     165     while state.front_layer:
# --> 166         self._apply_swap(state)
#     167         self._update_state(state)
#     169 # Phase 4a: Get list of depths of each candidate state and store the lowest depth
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v020_dive.py:455, in SabreSwap._apply_swap(self, state)
#     453 state.layout.swap(*best_swap)
#     454 # Update gate sequence (note that gate count is not updated)
# --> 455 best_swap_node = DAGOpNode(op=SwapGate(), qargs=best_swap)
#     456 state.gates_seq.append(best_swap_node)
#     457 # Update qubit depth
#
# File ~/Documents/GitHub/qiskit/qiskit/dagcircuit/dagnode.py:272, in DAGOpNode.__init__(self, op, qargs, cargs, dag)
#     270         dag._key_cache[cache_key] = self.sort_key
#     271 else:
# --> 272     self.sort_key = str(self.qargs)
#
# KeyboardInterrupt:
