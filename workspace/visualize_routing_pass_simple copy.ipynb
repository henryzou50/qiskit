# %% [markdown]
# # Testing routing pass with simple visualization
# This notebook tests the routing pass with the features:
# - Small coupling map
# - Small circuit (GHZ without the H gate)
# - No layout pass applied
#     - This makes sure that the routing pass is only runnning one time each

# %%
from qiskit.transpiler.passes.routing.sabre_swap_v020          import SabreSwap as SabreSwap_v020
from qiskit.transpiler.passes.routing.sabre_swap_v020_dive     import SabreSwap as SabreSwap_v020_lookahead
from ulti.circuits import get_circuit_list, sort_circuits_by_depth
from ulti.coupling_maps import file_to_coupling_map
from qiskit.transpiler import PassManager
import random
import time
random.seed(42)

# %%
seed=42
cp_name = 'hex_27'
cm = file_to_coupling_map(f'coupling_maps/{cp_name}.txt')

# pass manager for Sabre v0.20
rp_v020 = SabreSwap_v020(cm, seed=seed)
pm_v020 = PassManager(rp_v020)

# pass manager for Sabre v0.20 with lookahead
rp_v020_lookahead = SabreSwap_v020_lookahead(cm, seed=seed)
pm_v020_lookahead = PassManager(rp_v020_lookahead)

# creating the small circuit 
qc_name = 'ghz_2-127'
qc_list = get_circuit_list([f'circuits/{qc_name}/'])
qc_list = sort_circuits_by_depth(qc_list)
qc = qc_list[25]

# %%
# Start timing the transpilation for v0.20
start_time = time.time()
qc_tr_20 = pm_v020.run(qc)
#qc_tr_20 = qc_tr_20.decompose(["swap"])
duration_20 = time.time() - start_time

# Start timing the transpilation for v0.20 with lookahead
start_time = time.time()
qc_tr_20_lookahead = pm_v020_lookahead.run(qc)

#qc_tr_20_lookahead = qc_tr_20_lookahead.decompose(["swap"])
duration_20_lookahead = time.time() - start_time

# decompose swaps in the transpiled circuits
qc_tr_20 = qc_tr_20.decompose(["swap"])
qc_tr_20_lookahead = qc_tr_20_lookahead.decompose(["swap"])

# Print the depth and duration for each transpilation
print(f"{'Depth of the circuit after transpiled v0.20:':<60}{qc_tr_20.depth():<10}{'Time taken:':<20}{duration_20:.5f} seconds")
print(f"{'Depth of the circuit after transpiled v0.20 with lookahead:':<60}{qc_tr_20_lookahead.depth():<10}{'Time taken:':<20}{duration_20_lookahead:.5f} seconds")
# Out:
# current level:  0
#      Number of candidate states:  3
#      Update (after sabre) depth to  86
# current level:  1
#      Number of candidate states:  3
# current level:  2
#      Number of candidate states:  5
# current level:  3
#      Number of candidate states:  5
# current level:  4
#      Number of candidate states:  5
#      Update (after sabre) depth to  84
# current level:  5
#      Number of candidate states:  4
# current level:  6
#      Number of candidate states:  6
# current level:  7
#      Number of candidate states:  4
# current level:  8
#      Number of candidate states:  3
# current level:  9
#      Number of candidate states:  5
# current level:  10
#      Number of candidate states:  3
# current level:  11
#      Number of candidate states:  4
# current level:  12
#      Number of candidate states:  6
# current level:  13
#      Number of candidate states:  5
# current level:  14
#      Number of candidate states:  5
# current level:  15
#      Number of candidate states:  4
# current level:  16
#      Number of candidate states:  2
# current level:  17
#      Number of candidate states:  4
# current level:  18
#      Number of candidate states:  6
# current level:  19
#      Number of candidate states:  5
# current level:  20
#      Number of candidate states:  5
# current level:  21
#      Number of candidate states:  5
# current level:  22
#      Number of candidate states:  6
# current level:  23
#      Number of candidate states:  5
# current level:  24
#      Number of candidate states:  6
# current level:  25
#      Number of candidate states:  5
# current level:  26
#      Number of candidate states:  6
# current level:  27
#      Number of candidate states:  5
# current level:  28
#      Number of candidate states:  6
# current level:  29
#      Number of candidate states:  5
# current level:  30
#      Number of candidate states:  6
# current level:  31
#      Number of candidate states:  5
# current level:  32
#      Number of candidate states:  5
# current level:  33
#      Number of candidate states:  6
# current level:  34
#      Number of candidate states:  5
# current level:  35
#      Number of candidate states:  6
# current level:  36
#      Number of candidate states:  5
# current level:  37
#      Number of candidate states:  6
# current level:  38
#      Number of candidate states:  5
# current level:  39
#      Number of candidate states:  6
# current level:  40
#      Number of candidate states:  5
# current level:  41
#      Number of candidate states:  6
# current level:  42
#      Number of candidate states:  5
# current level:  43
#      Number of candidate states:  3
# current level:  44
#      Number of candidate states:  5
# current level:  45
#      Number of candidate states:  6
# current level:  46
#      Number of candidate states:  5
# current level:  47
#      Number of candidate states:  6
# current level:  48
#      Number of candidate states:  6
# current level:  49
#      Number of candidate states:  5
# current level:  50
#      Number of candidate states:  6
# current level:  51
#      Number of candidate states:  5
# current level:  52
#      Number of candidate states:  5
# current level:  53
#      Number of candidate states:  5
# current level:  54
#      Number of candidate states:  6
# current level:  55
#      Number of candidate states:  5
# current level:  56
#      Number of candidate states:  4
# current level:  57
#      Number of candidate states:  4
# current level:  58
#      Number of candidate states:  5
# current level:  59
#      Number of candidate states:  4
# current level:  60
#      Number of candidate states:  5
# current level:  61
#      Number of candidate states:  4
# current level:  62
#      Number of candidate states:  5
# current level:  63
#      Number of candidate states:  6
# current level:  64
#      Number of candidate states:  4
# current level:  65
#      Number of candidate states:  3
# current level:  66
#      Number of candidate states:  5
# current level:  67
#      Number of candidate states:  4
# current level:  68
#      Number of candidate states:  5
# current level:  69
#      Number of candidate states:  4
# current level:  70
#      Number of candidate states:  5
# current level:  71
#      Number of candidate states:  4
# current level:  72
#      Number of candidate states:  3
# current level:  73
#      Number of candidate states:  5
# current level:  74
#      Number of candidate states:  6
# current level:  75
#      Number of candidate states:  6
# current level:  76
#      Number of candidate states:  4
# current level:  77
#      Number of candidate states:  6
# current level:  78
#      Number of candidate states:  4
# current level:  79
#      Number of candidate states:  6
# current level:  80
#      Number of candidate states:  4
# current level:  81
#      Number of candidate states:  6
# current level:  82
#      Number of candidate states:  4
# current level:  83
#      Number of candidate states:  6
# current level:  84
#      Number of candidate states:  4
# current level:  85
#      Number of candidate states:  6
# current level:  86
#      Number of candidate states:  4
# current level:  87
#      Number of candidate states:  6
# current level:  88
#      Number of candidate states:  4
# current level:  89
#      Number of candidate states:  6
# current level:  90
#      Number of candidate states:  4
# current level:  91
#      Number of candidate states:  6
# current level:  92
#      Number of candidate states:  5
# current level:  93
#      Number of candidate states:  6
# current level:  94
#      Number of candidate states:  4
# current level:  95
#      Number of candidate states:  6
# current level:  96
#      Number of candidate states:  5
# current level:  97
#      Number of candidate states:  4
# current level:  98
#      Number of candidate states:  5
# current level:  99
#      Number of candidate states:  6
# Depth of the circuit after transpiled v0.20:                120       Time taken:         0.00524 seconds
# Depth of the circuit after transpiled v0.20 with lookahead: 85        Time taken:         0.85740 seconds

# %%
qc_tr_20_lookahead.draw(output='mpl', idle_wires=False)
# Out:
# /Users/henryzou/Documents/GitHub/qiskit/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
qc_tr_20.draw(output='mpl', idle_wires=False)
