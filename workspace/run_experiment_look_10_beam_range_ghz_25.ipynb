# %% [markdown]
# This code runs the experiment for SabreSwap v0.25 and SabreLayout v0.25

# %%
from qiskit.transpiler.passes.routing.sabre_swap_v020_lookahead   import SabreSwap   as SabreSwap_v020
from qiskit.transpiler.passes.layout.sabre_layout                 import SabreLayout as SabreLayout_v045
from qiskit.transpiler.passes.layout.sabre_layout_v020            import SabreLayout as SabreLayout_v020
from ulti.circuits import get_circuit_list, sort_circuits_by_depth
from ulti.coupling_maps import file_to_coupling_map
from ulti.pass_managers import generate_pass_managers, transpiled_data
import pandas as pd
import random
random.seed(42)
import os

# %%
# Option to keep the layout inital layout the same for faster transpilation
fast_layout = False
num_shots = 5
qc_name = "ghz_25"
cp_name = "hex_27"
print(f"Running experiment for the circuits: {qc_name}")
qc_list = get_circuit_list([f'circuits/{qc_name}/'])
qc_list = sort_circuits_by_depth(qc_list)

csv_file_path = f'data/{qc_name}/sabre_v020_look.csv'
directory = f'data/{qc_name}'
if not os.path.exists(directory):
        os.makedirs(directory)
# Out:
# Running experiment for the circuits: ghz_25

# %%
# Test beam_width from 1
beam_width = list(range(1, 1000))
look = 10
all_data_df = pd.DataFrame()
for beam in beam_width:
    print(f"Running experiment for beam {beam}")
    # Experiment for Sabre v0.20 with lookahead heuristic
    # set beam to max integer
    lp_name = "sabre_v020"
    if beam < 10:
        rp_name = f"sabre_v020_look_010_beam_00{beam}"
    elif beam < 100:
        rp_name = f"sabre_v020_look_010_beam_0{beam}"
    else:
        rp_name = f"sabre_v020_look_010_beam_{beam}"

    rp = SabreSwap_v020
    lp = SabreLayout_v020
    cm = file_to_coupling_map(f'coupling_maps/{cp_name}.txt')
    pm = generate_pass_managers(num_shots, rp, lp, cm, beam_width = beam, lookahead = look,
                                fast_layout=fast_layout)

    for qc_idx, qc in enumerate(qc_list):
        data = transpiled_data(qc, pm)
        data['routing pass'] = rp_name
        data['layout pass'] = lp_name
        data['coupling map'] = cp_name
        data['circuit label'] = qc_idx
        data['beam width'] = beam
        data['look ahead'] = look
        
        # Create a DataFrame from the current data and append it to the all_data_df
        current_data_df = pd.DataFrame([data])
        all_data_df = pd.concat([all_data_df, current_data_df])

        # Append the current data to the CSV file
        with open(csv_file_path, 'a') as f:
            current_data_df.to_csv(f, header=f.tell()==0, index=False)

        print(f"    Finished {qc_idx} for experiment {rp_name} and circuit {qc_name}")

    print(f"Finished all for experiment {rp_name} and circuit {qc_name}")
    print(f"Saved to {csv_file_path}")
    print("*" * 50)
# Out:
# Running experiment for beam 1
#     Finished 0 for experiment sabre_v020_look_010_beam_001 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_001 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 2
#     Finished 0 for experiment sabre_v020_look_010_beam_002 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_002 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 3
#     Finished 0 for experiment sabre_v020_look_010_beam_003 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_003 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 4
#     Finished 0 for experiment sabre_v020_look_010_beam_004 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_004 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 5
#     Finished 0 for experiment sabre_v020_look_010_beam_005 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_005 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 6
#     Finished 0 for experiment sabre_v020_look_010_beam_006 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_006 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 7
#     Finished 0 for experiment sabre_v020_look_010_beam_007 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_007 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 8
#     Finished 0 for experiment sabre_v020_look_010_beam_008 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_008 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 9
#     Finished 0 for experiment sabre_v020_look_010_beam_009 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_009 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 10
#     Finished 0 for experiment sabre_v020_look_010_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 11
#     Finished 0 for experiment sabre_v020_look_010_beam_011 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_011 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 12
#     Finished 0 for experiment sabre_v020_look_010_beam_012 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_012 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 13
#     Finished 0 for experiment sabre_v020_look_010_beam_013 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_013 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 14
#     Finished 0 for experiment sabre_v020_look_010_beam_014 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_014 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 15
#     Finished 0 for experiment sabre_v020_look_010_beam_015 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_015 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 16
#     Finished 0 for experiment sabre_v020_look_010_beam_016 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_016 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 17
#     Finished 0 for experiment sabre_v020_look_010_beam_017 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_017 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 18
#     Finished 0 for experiment sabre_v020_look_010_beam_018 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_018 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 19
#     Finished 0 for experiment sabre_v020_look_010_beam_019 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_019 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 20
#     Finished 0 for experiment sabre_v020_look_010_beam_020 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_020 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 21
#     Finished 0 for experiment sabre_v020_look_010_beam_021 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_021 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 22
#     Finished 0 for experiment sabre_v020_look_010_beam_022 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_022 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 23
#     Finished 0 for experiment sabre_v020_look_010_beam_023 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_023 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 24
#     Finished 0 for experiment sabre_v020_look_010_beam_024 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_024 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 25
#     Finished 0 for experiment sabre_v020_look_010_beam_025 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_025 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 26
#     Finished 0 for experiment sabre_v020_look_010_beam_026 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_026 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 27
#     Finished 0 for experiment sabre_v020_look_010_beam_027 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_027 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 28
#     Finished 0 for experiment sabre_v020_look_010_beam_028 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_028 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 29
#     Finished 0 for experiment sabre_v020_look_010_beam_029 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_029 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 30
#     Finished 0 for experiment sabre_v020_look_010_beam_030 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_030 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 31
#     Finished 0 for experiment sabre_v020_look_010_beam_031 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_031 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 32
#     Finished 0 for experiment sabre_v020_look_010_beam_032 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_032 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 33
#     Finished 0 for experiment sabre_v020_look_010_beam_033 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_033 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 34
#     Finished 0 for experiment sabre_v020_look_010_beam_034 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_034 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 35
#     Finished 0 for experiment sabre_v020_look_010_beam_035 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_035 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 36
#     Finished 0 for experiment sabre_v020_look_010_beam_036 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_036 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 37
#     Finished 0 for experiment sabre_v020_look_010_beam_037 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_037 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 38
#     Finished 0 for experiment sabre_v020_look_010_beam_038 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_038 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 39
#     Finished 0 for experiment sabre_v020_look_010_beam_039 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_039 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 40
#     Finished 0 for experiment sabre_v020_look_010_beam_040 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_040 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 41
#     Finished 0 for experiment sabre_v020_look_010_beam_041 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_041 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 42
#     Finished 0 for experiment sabre_v020_look_010_beam_042 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_042 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 43
#     Finished 0 for experiment sabre_v020_look_010_beam_043 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_043 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 44
#     Finished 0 for experiment sabre_v020_look_010_beam_044 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_044 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 45
#     Finished 0 for experiment sabre_v020_look_010_beam_045 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_045 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 46
#     Finished 0 for experiment sabre_v020_look_010_beam_046 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_046 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 47
#     Finished 0 for experiment sabre_v020_look_010_beam_047 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_047 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 48
#     Finished 0 for experiment sabre_v020_look_010_beam_048 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_048 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 49
#     Finished 0 for experiment sabre_v020_look_010_beam_049 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_049 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 50
#     Finished 0 for experiment sabre_v020_look_010_beam_050 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_050 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 51
#     Finished 0 for experiment sabre_v020_look_010_beam_051 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_051 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 52
#     Finished 0 for experiment sabre_v020_look_010_beam_052 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_052 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 53
#     Finished 0 for experiment sabre_v020_look_010_beam_053 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_053 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 54
#     Finished 0 for experiment sabre_v020_look_010_beam_054 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_054 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 55
#     Finished 0 for experiment sabre_v020_look_010_beam_055 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_055 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 56
#     Finished 0 for experiment sabre_v020_look_010_beam_056 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_056 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 57
#     Finished 0 for experiment sabre_v020_look_010_beam_057 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_057 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 58
#     Finished 0 for experiment sabre_v020_look_010_beam_058 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_058 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 59
#     Finished 0 for experiment sabre_v020_look_010_beam_059 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_059 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 60
#     Finished 0 for experiment sabre_v020_look_010_beam_060 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_060 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 61
#     Finished 0 for experiment sabre_v020_look_010_beam_061 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_061 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 62
#     Finished 0 for experiment sabre_v020_look_010_beam_062 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_062 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 63
#     Finished 0 for experiment sabre_v020_look_010_beam_063 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_063 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 64
#     Finished 0 for experiment sabre_v020_look_010_beam_064 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_064 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 65
#     Finished 0 for experiment sabre_v020_look_010_beam_065 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_065 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 66
#     Finished 0 for experiment sabre_v020_look_010_beam_066 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_066 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 67
#     Finished 0 for experiment sabre_v020_look_010_beam_067 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_067 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 68
#     Finished 0 for experiment sabre_v020_look_010_beam_068 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_068 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 69
#     Finished 0 for experiment sabre_v020_look_010_beam_069 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_069 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 70
#     Finished 0 for experiment sabre_v020_look_010_beam_070 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_070 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 71
#     Finished 0 for experiment sabre_v020_look_010_beam_071 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_071 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 72
#     Finished 0 for experiment sabre_v020_look_010_beam_072 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_072 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 73
#     Finished 0 for experiment sabre_v020_look_010_beam_073 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_073 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 74
#     Finished 0 for experiment sabre_v020_look_010_beam_074 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_074 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 75
#     Finished 0 for experiment sabre_v020_look_010_beam_075 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_075 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 76
#     Finished 0 for experiment sabre_v020_look_010_beam_076 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_076 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 77
#     Finished 0 for experiment sabre_v020_look_010_beam_077 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_077 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 78
#     Finished 0 for experiment sabre_v020_look_010_beam_078 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_078 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 79
#     Finished 0 for experiment sabre_v020_look_010_beam_079 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_079 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 80
#     Finished 0 for experiment sabre_v020_look_010_beam_080 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_080 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 81
#     Finished 0 for experiment sabre_v020_look_010_beam_081 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_081 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 82
#     Finished 0 for experiment sabre_v020_look_010_beam_082 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_082 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 83
#     Finished 0 for experiment sabre_v020_look_010_beam_083 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_083 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 84
#     Finished 0 for experiment sabre_v020_look_010_beam_084 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_084 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 85
#     Finished 0 for experiment sabre_v020_look_010_beam_085 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_085 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 86
#     Finished 0 for experiment sabre_v020_look_010_beam_086 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_086 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 87
#     Finished 0 for experiment sabre_v020_look_010_beam_087 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_087 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 88
#     Finished 0 for experiment sabre_v020_look_010_beam_088 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_088 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 89
#     Finished 0 for experiment sabre_v020_look_010_beam_089 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_089 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 90
#     Finished 0 for experiment sabre_v020_look_010_beam_090 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_090 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 91
#     Finished 0 for experiment sabre_v020_look_010_beam_091 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_091 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 92
#     Finished 0 for experiment sabre_v020_look_010_beam_092 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_092 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 93
#     Finished 0 for experiment sabre_v020_look_010_beam_093 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_093 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 94
#     Finished 0 for experiment sabre_v020_look_010_beam_094 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_094 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 95
#     Finished 0 for experiment sabre_v020_look_010_beam_095 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_095 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 96
#     Finished 0 for experiment sabre_v020_look_010_beam_096 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_096 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 97
#     Finished 0 for experiment sabre_v020_look_010_beam_097 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_097 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 98
#     Finished 0 for experiment sabre_v020_look_010_beam_098 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_098 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 99
#     Finished 0 for experiment sabre_v020_look_010_beam_099 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_099 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 100
#     Finished 0 for experiment sabre_v020_look_010_beam_100 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_100 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 101
#     Finished 0 for experiment sabre_v020_look_010_beam_101 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_101 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 102
#     Finished 0 for experiment sabre_v020_look_010_beam_102 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_102 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 103
#     Finished 0 for experiment sabre_v020_look_010_beam_103 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_103 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 104
#     Finished 0 for experiment sabre_v020_look_010_beam_104 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_104 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 105
#     Finished 0 for experiment sabre_v020_look_010_beam_105 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_105 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 106
#     Finished 0 for experiment sabre_v020_look_010_beam_106 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_106 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 107
#     Finished 0 for experiment sabre_v020_look_010_beam_107 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_107 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 108
#     Finished 0 for experiment sabre_v020_look_010_beam_108 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_108 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 109
#     Finished 0 for experiment sabre_v020_look_010_beam_109 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_109 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 110
#     Finished 0 for experiment sabre_v020_look_010_beam_110 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_110 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 111
#     Finished 0 for experiment sabre_v020_look_010_beam_111 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_111 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 112
#     Finished 0 for experiment sabre_v020_look_010_beam_112 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_112 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 113
#     Finished 0 for experiment sabre_v020_look_010_beam_113 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_113 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 114
#     Finished 0 for experiment sabre_v020_look_010_beam_114 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_114 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 115
#     Finished 0 for experiment sabre_v020_look_010_beam_115 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_115 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 116
#     Finished 0 for experiment sabre_v020_look_010_beam_116 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_116 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 117
#     Finished 0 for experiment sabre_v020_look_010_beam_117 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_117 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 118
#     Finished 0 for experiment sabre_v020_look_010_beam_118 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_118 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 119
#     Finished 0 for experiment sabre_v020_look_010_beam_119 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_119 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 120
#     Finished 0 for experiment sabre_v020_look_010_beam_120 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_120 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 121
#     Finished 0 for experiment sabre_v020_look_010_beam_121 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_121 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 122
#     Finished 0 for experiment sabre_v020_look_010_beam_122 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_122 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 123
#     Finished 0 for experiment sabre_v020_look_010_beam_123 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_123 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 124
#     Finished 0 for experiment sabre_v020_look_010_beam_124 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_124 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 125
#     Finished 0 for experiment sabre_v020_look_010_beam_125 and circuit ghz_25
# Finished all for experiment sabre_v020_look_010_beam_125 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_look.csv
# **************************************************
# Running experiment for beam 126
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 24
#      20 pm = generate_pass_managers(num_shots, rp, lp, cm, beam_width = beam, lookahead = look,
#      21                             fast_layout=fast_layout)
#      23 for qc_idx, qc in enumerate(qc_list):
# ---> 24     data = transpiled_data(qc, pm)
#      25     data['routing pass'] = rp_name
#      26     data['layout pass'] = lp_name
#
# File ~/Documents/GitHub/qiskit/workspace/ulti/pass_managers.py:131, in transpiled_data(qc, pass_managers)
#     129 for pm in pass_managers:
#     130     time_start = time.time()
# --> 131     qc_tr = pm.run(qc_decomposed)
#     132     time_end = time.time()
#     133     time_elapsed = time_end - time_start
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:551, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     548 @wraps(meth)
#     549 def wrapper(*meth_args, **meth_kwargs):
#     550     try:
# --> 551         return meth(*meth_args, **meth_kwargs)
#     552     except PassManagerError as ex:
#     553         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:291, in PassManager.run(self, circuits, output_name, callback)
#     288 if callback is not None:
#     289     callback = _legacy_style_callback(callback)
# --> 291 return super().run(
#     292     in_programs=circuits,
#     293     callback=callback,
#     294     output_name=output_name,
#     295 )
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:222, in BasePassManager.run(self, in_programs, callback, **kwargs)
#     219     is_list = False
#     221 if len(in_programs) == 1:
# --> 222     out_program = _run_workflow(
#     223         program=in_programs[0],
#     224         pass_manager=self,
#     225         callback=callback,
#     226         **kwargs,
#     227     )
#     228     if is_list:
#     229         return [out_program]
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:284, in _run_workflow(program, pass_manager, **kwargs)
#     278 initial_status = WorkflowStatus()
#     280 passmanager_ir = pass_manager._passmanager_frontend(
#     281     input_program=program,
#     282     **kwargs,
#     283 )
# --> 284 passmanager_ir, _ = flow_controller.execute(
#     285     passmanager_ir=passmanager_ir,
#     286     state=PassManagerState(
#     287         workflow_status=initial_status,
#     288         property_set=pass_manager.property_set,
#     289     ),
#     290     callback=kwargs.get("callback", None),
#     291 )
#     292 out_program = pass_manager._passmanager_backend(
#     293     passmanager_ir=passmanager_ir,
#     294     in_program=program,
#     295     **kwargs,
#     296 )
#     298 return out_program
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/runningpassmanager.py:161, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     158 @wraps(meth)
#     159 def wrapper(*meth_args, **meth_kwargs):
#     160     try:
# --> 161         return meth(*meth_args, **meth_kwargs)
#     162     except PassManagerError as ex:
#     163         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:218, in BaseController.execute(self, passmanager_ir, state, callback)
#     216     return passmanager_ir, state
#     217 while True:
# --> 218     passmanager_ir, state = next_task.execute(
#     219         passmanager_ir=passmanager_ir,
#     220         state=state,
#     221         callback=callback,
#     222     )
#     223     try:
#     224         # Sending the object through the generator implies the custom controllers
#     225         # can always rely on the latest data to choose the next task to run.
#     226         next_task = task_generator.send(state)
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:98, in GenericPass.execute(self, passmanager_ir, state, callback)
#      96 try:
#      97     if self not in state.workflow_status.completed_passes:
# ---> 98         ret = self.run(passmanager_ir)
#      99         run_state = RunState.SUCCESS
#     100     else:
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/layout/sabre_layout_v020.py:123, in SabreLayout.run(self, dag)
#     121 for _ in ("forward", "backward"):
#     122     pm = self._layout_and_route_passmanager(initial_layout)
# --> 123     new_circ = pm.run(circ)
#     125     # Update initial layout and reverse the unmapped circuit.
#     126     pass_final_layout = pm.property_set["final_layout"]
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:551, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     548 @wraps(meth)
#     549 def wrapper(*meth_args, **meth_kwargs):
#     550     try:
# --> 551         return meth(*meth_args, **meth_kwargs)
#     552     except PassManagerError as ex:
#     553         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:291, in PassManager.run(self, circuits, output_name, callback)
#     288 if callback is not None:
#     289     callback = _legacy_style_callback(callback)
# --> 291 return super().run(
#     292     in_programs=circuits,
#     293     callback=callback,
#     294     output_name=output_name,
#     295 )
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:222, in BasePassManager.run(self, in_programs, callback, **kwargs)
#     219     is_list = False
#     221 if len(in_programs) == 1:
# --> 222     out_program = _run_workflow(
#     223         program=in_programs[0],
#     224         pass_manager=self,
#     225         callback=callback,
#     226         **kwargs,
#     227     )
#     228     if is_list:
#     229         return [out_program]
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:284, in _run_workflow(program, pass_manager, **kwargs)
#     278 initial_status = WorkflowStatus()
#     280 passmanager_ir = pass_manager._passmanager_frontend(
#     281     input_program=program,
#     282     **kwargs,
#     283 )
# --> 284 passmanager_ir, _ = flow_controller.execute(
#     285     passmanager_ir=passmanager_ir,
#     286     state=PassManagerState(
#     287         workflow_status=initial_status,
#     288         property_set=pass_manager.property_set,
#     289     ),
#     290     callback=kwargs.get("callback", None),
#     291 )
#     292 out_program = pass_manager._passmanager_backend(
#     293     passmanager_ir=passmanager_ir,
#     294     in_program=program,
#     295     **kwargs,
#     296 )
#     298 return out_program
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/runningpassmanager.py:161, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     158 @wraps(meth)
#     159 def wrapper(*meth_args, **meth_kwargs):
#     160     try:
# --> 161         return meth(*meth_args, **meth_kwargs)
#     162     except PassManagerError as ex:
#     163         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:218, in BaseController.execute(self, passmanager_ir, state, callback)
#     216     return passmanager_ir, state
#     217 while True:
# --> 218     passmanager_ir, state = next_task.execute(
#     219         passmanager_ir=passmanager_ir,
#     220         state=state,
#     221         callback=callback,
#     222     )
#     223     try:
#     224         # Sending the object through the generator implies the custom controllers
#     225         # can always rely on the latest data to choose the next task to run.
#     226         next_task = task_generator.send(state)
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/basepasses.py:195, in TransformationPass.execute(self, passmanager_ir, state, callback)
#     189 def execute(
#     190     self,
#     191     passmanager_ir: PassManagerIR,
#     192     state: PassManagerState,
#     193     callback: Callable = None,
#     194 ) -> tuple[PassManagerIR, PassManagerState]:
# --> 195     new_dag, state = super().execute(
#     196         passmanager_ir=passmanager_ir,
#     197         state=state,
#     198         callback=callback,
#     199     )
#     201     if state.workflow_status.previous_run == RunState.SUCCESS:
#     202         if isinstance(new_dag, DAGCircuit):
#     203             # Copy calibration data from the original program
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:98, in GenericPass.execute(self, passmanager_ir, state, callback)
#      96 try:
#      97     if self not in state.workflow_status.completed_passes:
# ---> 98         ret = self.run(passmanager_ir)
#      99         run_state = RunState.SUCCESS
#     100     else:
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v020_lookahead.py:191, in SabreSwap.run(self, dag)
#     187 initial_node = Node(current_layout, front_layer, self.required_predecessors,
#     188                     self.qubits_depth, [])
#     190 # get the first node in the lookahead search
# --> 191 gate_seq  = self.lookahead_search(initial_node, dag).gate_seq
#     193 # if end solution is found, loop to apply all of the gates to the mapped_dag
#     194 if self.end_solution_found:
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v020_lookahead.py:316, in SabreSwap.lookahead_search(self, initial_node, dag)
#     314     if gate not in node.gate_seq:
#     315         gates_remaining.append(gate)
# --> 316 node.score_looka = self._compute_cost(gates_remaining, node.layout)
#     317 node.score_total_1 = node.score_front + node.score_looka
#     318 node.score_total_2 = node.score_depth + node.score_gates
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v020_lookahead.py:457, in SabreSwap._compute_cost(self, layer, layout)
#     455 layout_map = layout._v2p
#     456 for node in layer:
# --> 457     cost += self.dist_matrix[layout_map[node.qargs[0]], layout_map[node.qargs[1]]]
#     459 # normalize by the number of gates
#     460 if len(layer) == 0:
#
# File ~/Documents/GitHub/qiskit/qiskit/circuit/bit.py:115, in Bit.__hash__(self)
#     112         return object.__repr__(self)
#     113     return self._repr
# --> 115 def __hash__(self):
#     116     return self._hash
#     118 def __eq__(self, other):
#
# KeyboardInterrupt:
