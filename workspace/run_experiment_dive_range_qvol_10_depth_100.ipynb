# %% [markdown]
# This code runs the experiment for SabreSwap v0.25 and SabreLayout v0.25

# %%
from qiskit.transpiler.passes.routing.sabre_swap_v020_dive   import SabreSwap   as SabreSwap_v020
from qiskit.transpiler.passes.layout.sabre_layout                 import SabreLayout as SabreLayout_v045
from qiskit.transpiler.passes.layout.sabre_layout_v020            import SabreLayout as SabreLayout_v020
from ulti.circuits import get_circuit_list, sort_circuits_by_depth
from ulti.coupling_maps import file_to_coupling_map
from ulti.pass_managers import generate_pass_managers, transpiled_data
import pandas as pd
import random
random.seed(42)
import os

# %%
# Option to keep the layout inital layout the same for faster transpilation
fast_layout = False
num_shots = 5
qc_name = "qvol_10_depth_100"
cp_name = "hex_27"
print(f"Running experiment for the circuits: {qc_name}")
qc_list = get_circuit_list([f'circuits/{qc_name}/'])
qc_list = sort_circuits_by_depth(qc_list)

csv_file_path = f'data/{qc_name}/sabre_v020_dive.csv'
directory = f'data/{qc_name}'
if not os.path.exists(directory):
        os.makedirs(directory)
# Out:
# Running experiment for the circuits: qvol_10_depth_100

# %%
# Test beam_width from 1
beam_width = list(range(1, 1000))
all_data_df = pd.DataFrame()
for beam in beam_width:
    print(f"Running experiment for dive {beam}")
    # Experiment for Sabre v0.20 with lookahead heuristic
    # set beam to max integer
    lp_name = "sabre_v020"
    if beam < 10:
        rp_name = f"sabre_v020_dive_00{beam}"
    elif beam < 100:
        rp_name = f"sabre_v020_dive_0{beam}"
    else:
        rp_name = f"sabre_v020_dive_{beam}"

    rp = SabreSwap_v020
    lp = SabreLayout_v020
    cm = file_to_coupling_map(f'coupling_maps/{cp_name}.txt')
    pm = generate_pass_managers(num_shots, rp, lp, cm, beam_width = beam, 
                                fast_layout=fast_layout)

    for qc_idx, qc in enumerate(qc_list):
        data = transpiled_data(qc, pm)
        data['routing pass'] = rp_name
        data['layout pass'] = lp_name
        data['coupling map'] = cp_name
        data['circuit label'] = qc_idx
        data['beam width'] = beam
        data['look ahead'] = 0
        
        # Create a DataFrame from the current data and append it to the all_data_df
        current_data_df = pd.DataFrame([data])
        all_data_df = pd.concat([all_data_df, current_data_df])

        # Append the current data to the CSV file
        with open(csv_file_path, 'a') as f:
            current_data_df.to_csv(f, header=f.tell()==0, index=False)

        print(f"    Finished {qc_idx} for experiment {rp_name} and circuit {qc_name}")

    print(f"Finished all for experiment {rp_name} and circuit {qc_name}")
    print(f"Saved to {csv_file_path}")
    print("*" * 50)
# Out:
# Running experiment for dive 1
#     Finished 0 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_001 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 2
#     Finished 0 for experiment sabre_v020_dive_002 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_002 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_002 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 3
#     Finished 0 for experiment sabre_v020_dive_003 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_003 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_003 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 4
#     Finished 0 for experiment sabre_v020_dive_004 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_004 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_004 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 5
#     Finished 0 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_005 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 6
#     Finished 0 for experiment sabre_v020_dive_006 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_006 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_006 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 7
#     Finished 0 for experiment sabre_v020_dive_007 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_007 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_007 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 8
#     Finished 0 for experiment sabre_v020_dive_008 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_008 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_008 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 9
#     Finished 0 for experiment sabre_v020_dive_009 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_009 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_009 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 10
#     Finished 0 for experiment sabre_v020_dive_010 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_010 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_010 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 11
#     Finished 0 for experiment sabre_v020_dive_011 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_011 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_011 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 12
#     Finished 0 for experiment sabre_v020_dive_012 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_012 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_012 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 13
#     Finished 0 for experiment sabre_v020_dive_013 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_013 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_013 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 14
#     Finished 0 for experiment sabre_v020_dive_014 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_014 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_014 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 15
#     Finished 0 for experiment sabre_v020_dive_015 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_015 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_015 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 16
#     Finished 0 for experiment sabre_v020_dive_016 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_016 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_016 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 17
#     Finished 0 for experiment sabre_v020_dive_017 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_017 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_017 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 18
#     Finished 0 for experiment sabre_v020_dive_018 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_018 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_018 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 19
#     Finished 0 for experiment sabre_v020_dive_019 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_019 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_019 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 20
#     Finished 0 for experiment sabre_v020_dive_020 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_020 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_020 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 21
#     Finished 0 for experiment sabre_v020_dive_021 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_021 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_021 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 22
#     Finished 0 for experiment sabre_v020_dive_022 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_022 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_022 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 23
#     Finished 0 for experiment sabre_v020_dive_023 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_023 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_023 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 24
#     Finished 0 for experiment sabre_v020_dive_024 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_024 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_024 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 25
#     Finished 0 for experiment sabre_v020_dive_025 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_025 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_025 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 26
#     Finished 0 for experiment sabre_v020_dive_026 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_026 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_026 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 27
#     Finished 0 for experiment sabre_v020_dive_027 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_027 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_027 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 28
#     Finished 0 for experiment sabre_v020_dive_028 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_028 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_028 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 29
#     Finished 0 for experiment sabre_v020_dive_029 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_029 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_029 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 30
#     Finished 0 for experiment sabre_v020_dive_030 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_030 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_030 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 31
#     Finished 0 for experiment sabre_v020_dive_031 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_031 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_031 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 32
#     Finished 0 for experiment sabre_v020_dive_032 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_032 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_032 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 33
#     Finished 0 for experiment sabre_v020_dive_033 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_033 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_033 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 34
#     Finished 0 for experiment sabre_v020_dive_034 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_034 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_034 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 35
#     Finished 0 for experiment sabre_v020_dive_035 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_035 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_035 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 36
#     Finished 0 for experiment sabre_v020_dive_036 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_036 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_036 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 37
#     Finished 0 for experiment sabre_v020_dive_037 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_037 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_037 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 38
#     Finished 0 for experiment sabre_v020_dive_038 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_038 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_038 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 39
#     Finished 0 for experiment sabre_v020_dive_039 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_039 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_039 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 40
#     Finished 0 for experiment sabre_v020_dive_040 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_040 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_040 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 41
#     Finished 0 for experiment sabre_v020_dive_041 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_041 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_041 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 42
#     Finished 0 for experiment sabre_v020_dive_042 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_042 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_042 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 43
#     Finished 0 for experiment sabre_v020_dive_043 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_043 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_043 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 44
#     Finished 0 for experiment sabre_v020_dive_044 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_044 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_044 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 45
#     Finished 0 for experiment sabre_v020_dive_045 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_045 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_045 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 46
#     Finished 0 for experiment sabre_v020_dive_046 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_046 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_046 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 47
#     Finished 0 for experiment sabre_v020_dive_047 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_047 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_047 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 48
#     Finished 0 for experiment sabre_v020_dive_048 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_048 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_048 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 49
#     Finished 0 for experiment sabre_v020_dive_049 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_049 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_049 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 50
#     Finished 0 for experiment sabre_v020_dive_050 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_050 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_050 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 51
#     Finished 0 for experiment sabre_v020_dive_051 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_051 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_051 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 52
#     Finished 0 for experiment sabre_v020_dive_052 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_052 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_052 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 53
#     Finished 0 for experiment sabre_v020_dive_053 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_053 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_053 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 54
#     Finished 0 for experiment sabre_v020_dive_054 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_054 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_054 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 55
#     Finished 0 for experiment sabre_v020_dive_055 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_055 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_055 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 56
#     Finished 0 for experiment sabre_v020_dive_056 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_056 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_056 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 57
#     Finished 0 for experiment sabre_v020_dive_057 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_057 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_057 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 58
#     Finished 0 for experiment sabre_v020_dive_058 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_058 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_058 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 59
#     Finished 0 for experiment sabre_v020_dive_059 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_059 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_059 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 60
#     Finished 0 for experiment sabre_v020_dive_060 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_060 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_060 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 61
#     Finished 0 for experiment sabre_v020_dive_061 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_061 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_061 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 62
#     Finished 0 for experiment sabre_v020_dive_062 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_062 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_062 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 63
#     Finished 0 for experiment sabre_v020_dive_063 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_063 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_063 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 64
#     Finished 0 for experiment sabre_v020_dive_064 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_064 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_064 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 65
#     Finished 0 for experiment sabre_v020_dive_065 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_065 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_065 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 66
#     Finished 0 for experiment sabre_v020_dive_066 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_066 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_066 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 67
#     Finished 0 for experiment sabre_v020_dive_067 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_067 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_067 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 68
#     Finished 0 for experiment sabre_v020_dive_068 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_068 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_068 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 69
#     Finished 0 for experiment sabre_v020_dive_069 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_069 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_069 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 70
#     Finished 0 for experiment sabre_v020_dive_070 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_070 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_070 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 71
#     Finished 0 for experiment sabre_v020_dive_071 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_071 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_071 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 72
#     Finished 0 for experiment sabre_v020_dive_072 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_072 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_072 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 73
#     Finished 0 for experiment sabre_v020_dive_073 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_073 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_073 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 74
#     Finished 0 for experiment sabre_v020_dive_074 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_074 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_074 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 75
#     Finished 0 for experiment sabre_v020_dive_075 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_075 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_075 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 76
#     Finished 0 for experiment sabre_v020_dive_076 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_076 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_076 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 77
#     Finished 0 for experiment sabre_v020_dive_077 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_077 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_077 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 78
#     Finished 0 for experiment sabre_v020_dive_078 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_078 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_078 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 79
#     Finished 0 for experiment sabre_v020_dive_079 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_079 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_079 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 80
#     Finished 0 for experiment sabre_v020_dive_080 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_080 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_080 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 81
#     Finished 0 for experiment sabre_v020_dive_081 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_081 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_081 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 82
#     Finished 0 for experiment sabre_v020_dive_082 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_082 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_082 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 83
#     Finished 0 for experiment sabre_v020_dive_083 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_083 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_083 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 84
#     Finished 0 for experiment sabre_v020_dive_084 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_084 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_084 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 85
#     Finished 0 for experiment sabre_v020_dive_085 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_085 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_085 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 86
#     Finished 0 for experiment sabre_v020_dive_086 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_086 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_086 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 87
#     Finished 0 for experiment sabre_v020_dive_087 and circuit qvol_10_depth_100
#     Finished 1 for experiment sabre_v020_dive_087 and circuit qvol_10_depth_100
# Finished all for experiment sabre_v020_dive_087 and circuit qvol_10_depth_100
# Saved to data/qvol_10_depth_100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 88
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/jt/44gl1rhd26v6ykt0frqzl87r0000gn/T/ipykernel_37141/3135895391.py", line 23, in <module>
#     data = transpiled_data(qc, pm)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/workspace/ulti/pass_managers.py", line 131, in transpiled_data
#     qc_tr = pm.run(qc_decomposed)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py", line 551, in wrapper
#     return meth(*meth_args, **meth_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py", line 291, in run
#     return super().run(
#            ^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py", line 222, in run
#     out_program = _run_workflow(
#                   ^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py", line 284, in _run_workflow
#     passmanager_ir, _ = flow_controller.execute(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/runningpassmanager.py", line 161, in wrapper
#     return meth(*meth_args, **meth_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py", line 218, in execute
#     passmanager_ir, state = next_task.execute(
#                             ^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py", line 98, in execute
#     ret = self.run(passmanager_ir)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/passes/layout/sabre_layout_v020.py", line 123, in run
#     new_circ = pm.run(circ)
#                ^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py", line 551, in wrapper
#     return meth(*meth_args, **meth_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py", line 291, in run
#     return super().run(
#            ^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py", line 222, in run
#     out_program = _run_workflow(
#                   ^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py", line 284, in _run_workflow
#     passmanager_ir, _ = flow_controller.execute(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/runningpassmanager.py", line 161, in wrapper
#     return meth(*meth_args, **meth_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py", line 218, in execute
#     passmanager_ir, state = next_task.execute(
#                             ^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/basepasses.py", line 195, in execute
#     new_dag, state = super().execute(
#                      ^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py", line 98, in execute
#     ret = self.run(passmanager_ir)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v020_dive.py", line 149, in run
#     self._apply_swap(state)
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v020_dive.py", line 360, in _apply_swap
#     self._update_state(trial_state, trial=True)
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v020_dive.py", line -1, in _update_state
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2144, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/IPython/core/ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#            ^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/executing/executing.py", line 116, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
