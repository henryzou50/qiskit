# %%
from qiskit.transpiler.passes import SabreSwap, SabreLayout
from ulti.circuits import get_circuit_list, sort_circuits_by_depth
from ulti.coupling_maps import file_to_coupling_map
from ulti.pass_managers import generate_pass_managers, transpiled_data
import random
import pandas as pd
from ast import literal_eval
import matplotlib.pyplot as plt
import random
random.seed(42)

# %% [markdown]
# # This notebook tests the pass managers and returns the result to the test.csv file

# %%
# Variables to change
experiment_name = "sabre"
qc_name = "size10_depth_10-30"
lp_name = "sabre_0.25"
cp_name = "heavy_hex_27"
version = "25" # version for the routing pass after _v0.

# %%
num_shots = 2
rp = SabreSwap
lp = SabreLayout
cm = file_to_coupling_map(f'coupling_maps/{cp_name}.txt')
pm = generate_pass_managers(num_shots, rp, lp, cm)


rp_name = experiment_name + "_v0." + version
qc_list = get_circuit_list([f'circuits/{qc_name}/'])
qc_list = sort_circuits_by_depth(qc_list)

#csv_file_path = f'data/{qc_name}/{experiment_name}_v0{version}.csv'
csv_file_path = f'test.csv'

# %%
data_list = []
for qc_idx, qc in enumerate(qc_list):
    data = transpiled_data(qc, pm)
    data['routing pass'] = rp_name
    data['layout pass'] = lp_name
    data['coupling map'] = cp_name
    data['circuit label'] = qc_idx
    data_list.append(data)

    print(f"Finished {qc_idx}")
print("Finished all")
# Out:
# Finished 0
# Finished 1
# Finished 2
# Finished 3
# Finished 4
# Finished 5
# Finished 6
# Finished 7
# Finished 8
# Finished 9
# Finished 10
# Finished 11
# Finished 12
# Finished 13
# Finished 14
# Finished 15
# Finished 16
# Finished 17
# Finished 18
# Finished 19
# Finished all

# %%
df = pd.DataFrame(data_list)
df.to_csv(csv_file_path, index=False)
df
# Out:
#                                             best_data  \
# 0   {'depth': 194, 'depth_ratio': 19.4, 'time': 0....
# 1   {'depth': 268, 'depth_ratio': 24.36, 'time': 0...
# 2   {'depth': 257, 'depth_ratio': 21.42, 'time': 0...
# 3   {'depth': 310, 'depth_ratio': 23.85, 'time': 0...
# 4   {'depth': 192, 'depth_ratio': 13.71, 'time': 0...
# 5   {'depth': 353, 'depth_ratio': 23.53, 'time': 0...
# 6   {'depth': 384, 'depth_ratio': 24.0, 'time': 0....
# 7   {'depth': 413, 'depth_ratio': 24.29, 'time': 0...
# 8   {'depth': 404, 'depth_ratio': 22.44, 'time': 0...
# 9   {'depth': 317, 'depth_ratio': 16.68, 'time': 0...
# 10  {'depth': 349, 'depth_ratio': 17.45, 'time': 0...
# 11  {'depth': 544, 'depth_ratio': 25.9, 'time': 0....
# 12  {'depth': 589, 'depth_ratio': 26.77, 'time': 0...
# 13  {'depth': 416, 'depth_ratio': 18.09, 'time': 0...
# 14  {'depth': 618, 'depth_ratio': 25.75, 'time': 0...
# 15  {'depth': 609, 'depth_ratio': 24.36, 'time': 0...
# 16  {'depth': 639, 'depth_ratio': 24.58, 'time': 0...
# 17  {'depth': 718, 'depth_ratio': 26.59, 'time': 0...
# 18  {'depth': 767, 'depth_ratio': 27.39, 'time': 0...
# 19  {'depth': 548, 'depth_ratio': 18.9, 'time': 0....
#
#                                               std_dev routing pass  \
# 0   {'depth': 32.0, 'depth_ratio': 3.2, 'time': 0....  sabre_v0.25
# 1   {'depth': 10.0, 'depth_ratio': 0.91, 'time': 0...  sabre_v0.25
# 2   {'depth': 4.5, 'depth_ratio': 0.375, 'time': 0...  sabre_v0.25
# 3   {'depth': 8.0, 'depth_ratio': 0.615, 'time': 0...  sabre_v0.25
# 4   {'depth': 102.0, 'depth_ratio': 7.29, 'time': ...  sabre_v0.25
# 5   {'depth': 3.0, 'depth_ratio': 0.2, 'time': 0.0...  sabre_v0.25
# 6   {'depth': 13.5, 'depth_ratio': 0.845, 'time': ...  sabre_v0.25
# 7   {'depth': 34.0, 'depth_ratio': 2.0, 'time': 0....  sabre_v0.25
# 8   {'depth': 20.5, 'depth_ratio': 1.14, 'time': 0...  sabre_v0.25
# 9   {'depth': 51.0, 'depth_ratio': 2.685, 'time': ...  sabre_v0.25
# 10  {'depth': 88.5, 'depth_ratio': 4.425, 'time': ...  sabre_v0.25
# 11  {'depth': 17.0, 'depth_ratio': 0.81, 'time': 0...  sabre_v0.25
# 12  {'depth': 2.5, 'depth_ratio': 0.115, 'time': 0...  sabre_v0.25
# 13  {'depth': 117.5, 'depth_ratio': 5.105, 'time':...  sabre_v0.25
# 14  {'depth': 12.5, 'depth_ratio': 0.52, 'time': 0...  sabre_v0.25
# 15  {'depth': 17.5, 'depth_ratio': 0.7, 'time': 0....  sabre_v0.25
# 16  {'depth': 22.0, 'depth_ratio': 0.845, 'time': ...  sabre_v0.25
# 17  {'depth': 2.0, 'depth_ratio': 0.075, 'time': 0...  sabre_v0.25
# 18  {'depth': 2.5, 'depth_ratio': 0.09, 'time': 0....  sabre_v0.25
# 19  {'depth': 81.0, 'depth_ratio': 2.79, 'time': 0...  sabre_v0.25
#
#    layout pass  coupling map  circuit label
# 0   sabre_0.25  heavy_hex_27              0
# 1   sabre_0.25  heavy_hex_27              1
# 2   sabre_0.25  heavy_hex_27              2
# 3   sabre_0.25  heavy_hex_27              3
# 4   sabre_0.25  heavy_hex_27              4
# 5   sabre_0.25  heavy_hex_27              5
# 6   sabre_0.25  heavy_hex_27              6
# 7   sabre_0.25  heavy_hex_27              7
# 8   sabre_0.25  heavy_hex_27              8
# 9   sabre_0.25  heavy_hex_27              9
# 10  sabre_0.25  heavy_hex_27             10
# 11  sabre_0.25  heavy_hex_27             11
# 12  sabre_0.25  heavy_hex_27             12
# 13  sabre_0.25  heavy_hex_27             13
# 14  sabre_0.25  heavy_hex_27             14
# 15  sabre_0.25  heavy_hex_27             15
# 16  sabre_0.25  heavy_hex_27             16
# 17  sabre_0.25  heavy_hex_27             17
# 18  sabre_0.25  heavy_hex_27             18
# 19  sabre_0.25  heavy_hex_27             19

# %%
data = pd.read_csv(csv_file_path)

# Convert the string representation of dictionaries into actual dictionaries
data['best_data'] = data['best_data'].apply(literal_eval)
data['std_dev'] = data['std_dev'].apply(literal_eval)

# Extract the data from the 'best_data' and 'std_dev' columns and add them to the DataFrame
for col in ['depth', 'depth_ratio', 'time', 'cx_gates', 'num_gates']:
    data[f"best_{col}"] = data['best_data'].apply(lambda x: x[col])
    data[f"std_dev_{col}"] = data['std_dev'].apply(lambda x: x[col])

metrics = [
    ("depth", "Depth"),
    ("cx_gates", "CX Gates"),
    ("num_gates", "Number of Gates"),
    ("time", "Time"),
    ("depth_ratio", "Depth Ratio")
]

unique_routing_layout_combinations = data[['routing pass', 'layout pass']].drop_duplicates().values

for metric, label in metrics:
    plt.figure(figsize=(10, 6))
    for routing_pass, layout_pass in unique_routing_layout_combinations:
        subset = data[(data['routing pass'] == routing_pass) & (data['layout pass'] == layout_pass)]
        plt.errorbar(subset['circuit label'], subset[f"best_{metric}"], yerr=subset[f"std_dev_{metric}"], fmt='o-', label=f'Routing: {routing_pass}, Layout: {layout_pass}')
    plt.xlabel('Circuit Label')
    plt.ylabel('Value')
    plt.title(f'Comparison of Circuit {label} for Coupling Map: {data["coupling map"].iloc[0]}')
    plt.legend()
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.tight_layout()
    #plt.savefig(f"data/graphs/{qc_name}/{experiment_name}_v0{version}/{label.replace(' ', '_').lower()}.png")
    plt.show()
    plt.close()
