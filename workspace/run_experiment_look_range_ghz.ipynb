# %%
from qiskit.transpiler.passes.routing.sabre_swap_v020_lookahead import SabreSwap
from qiskit.transpiler.passes.layout.sabre_layout_v020 import SabreLayout
from ulti.circuits import get_circuit_list, sort_circuits_by_depth
from ulti.coupling_maps import file_to_coupling_map
from ulti.pass_managers import generate_pass_managers, transpiled_data
import pandas as pd
from ast import literal_eval
import matplotlib.pyplot as plt
import random
random.seed(42)
import os

# %%
qc_name = "ghz_2-27"
version = "20" # version for the routing pass after _v0.
lp_name = "sabre_0.20"
cp_name = "hex_27"
num_shots = 5
rp = SabreSwap
lp = SabreLayout
cm = file_to_coupling_map(f'coupling_maps/{cp_name}.txt')
qc_list = get_circuit_list([f'circuits/{qc_name}/'])
qc_list = sort_circuits_by_depth(qc_list)

# %%
for lookahead in range(0, 5):
    experiment_name = f"sabre_look_{lookahead}"

    pm = generate_pass_managers(num_shots, rp, lp, cm, lookahead=lookahead)
    rp_name = experiment_name + "_v0." + version

    csv_file_path = f'data/{qc_name}/{experiment_name}_v0{version}_{cp_name}.csv'
    directory = f'data/{qc_name}'
    if not os.path.exists(directory):
            os.makedirs(directory)

    data_list = []
    for qc_idx, qc in enumerate(qc_list):
        data = transpiled_data(qc, pm)
        data['routing pass'] = rp_name
        data['layout pass'] = lp_name
        data['coupling map'] = cp_name
        data['circuit label'] = qc_idx
        data_list.append(data)

        print(f"Finished {qc_idx}")
    print("Finished all")

    df = pd.DataFrame(data_list)
    df.to_csv(csv_file_path, index=False)
# Out:
# Finished 0
# Finished 1
# Finished 2
# Finished 3
# Finished 4
# Finished 5
# Finished 6
# Finished 7
# Finished 8
# Finished 9
# Finished 10
# Finished 11
# Finished 12
# Finished 13
# Finished 14
# Finished 15
# Finished 16
# Finished 17
# Finished 18
# Finished 19
# Finished all
# Finished 0
# Finished 1
# Finished 2
# Finished 3
# Finished 4
# Finished 5
# Finished 6
# Finished 7
# Finished 8
# Finished 9
# Finished 10
# Finished 11
# Finished 12
# Finished 13
# Finished 14
# Finished 15
# Finished 16
# Finished 17
# Finished 18
# Finished 19
# Finished all
# Finished 0
# Finished 1
# Finished 2
# Finished 3
# Finished 4
# Finished 5
# Finished 6
# Finished 7
# Finished 8
# Finished 9
# Finished 10
# Finished 11
# Finished 12
# Finished 13
# Finished 14
# Finished 15
# Finished 16
# Finished 17
# Finished 18
# Finished 19
# Finished all
# Finished 0
# Finished 1
# Finished 2
# Finished 3
# Finished 4
# Finished 5
# Finished 6
# Finished 7
# Finished 8
# Finished 9
# Finished 10
# Finished 11
# Finished 12
# Finished 13
# Finished 14
# Finished 15
# Finished 16
# Finished 17
# Finished 18
# Finished 19
# Finished all
# Finished 0
# Finished 1
# Finished 2
# Finished 3
# Finished 4
# Finished 5
# Finished 6
# Finished 7
# Finished 8
# Finished 9
# Finished 10
# Finished 11
# Finished 12
# Finished 13
# Finished 14
# Finished 15
# Finished 16
# Finished 17
# Finished 18
# Finished 19
# Finished all
# Finished 0
# Finished 1
# Finished 2
# Finished 3
# Finished 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/henryzou/Documents/GitHub/qiskit/workspace/run_experiment_look_range_ghz.ipynb Cell 3 line 1
#      <a href='vscode-notebook-cell:/Users/henryzou/Documents/GitHub/qiskit/workspace/run_experiment_look_range_ghz.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a> data_list = []
#      <a href='vscode-notebook-cell:/Users/henryzou/Documents/GitHub/qiskit/workspace/run_experiment_look_range_ghz.ipynb#W5sZmlsZQ%3D%3D?line=12'>13</a> for qc_idx, qc in enumerate(qc_list):
# ---> <a href='vscode-notebook-cell:/Users/henryzou/Documents/GitHub/qiskit/workspace/run_experiment_look_range_ghz.ipynb#W5sZmlsZQ%3D%3D?line=13'>14</a>     data = transpiled_data(qc, pm)
#      <a href='vscode-notebook-cell:/Users/henryzou/Documents/GitHub/qiskit/workspace/run_experiment_look_range_ghz.ipynb#W5sZmlsZQ%3D%3D?line=14'>15</a>     data['routing pass'] = rp_name
#      <a href='vscode-notebook-cell:/Users/henryzou/Documents/GitHub/qiskit/workspace/run_experiment_look_range_ghz.ipynb#W5sZmlsZQ%3D%3D?line=15'>16</a>     data['layout pass'] = lp_name
#
# File ~/Documents/GitHub/qiskit/workspace/ulti/pass_managers.py:95, in transpiled_data(qc, pass_managers)
#      93 for pm in pass_managers:
#      94     time_start = time.time()
# ---> 95     qc_tr = pm.run(qc)
#      96     time_end = time.time()
#      97     time_elapsed = time_end - time_start
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:551, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     548 @wraps(meth)
#     549 def wrapper(*meth_args, **meth_kwargs):
#     550     try:
# --> 551         return meth(*meth_args, **meth_kwargs)
#     552     except PassManagerError as ex:
#     553         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:291, in PassManager.run(self, circuits, output_name, callback)
#     288 if callback is not None:
#     289     callback = _legacy_style_callback(callback)
# --> 291 return super().run(
#     292     in_programs=circuits,
#     293     callback=callback,
#     294     output_name=output_name,
#     295 )
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:222, in BasePassManager.run(self, in_programs, callback, **kwargs)
#     219     is_list = False
#     221 if len(in_programs) == 1:
# --> 222     out_program = _run_workflow(
#     223         program=in_programs[0],
#     224         pass_manager=self,
#     225         callback=callback,
#     226         **kwargs,
#     227     )
#     228     if is_list:
#     229         return [out_program]
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:284, in _run_workflow(program, pass_manager, **kwargs)
#     278 initial_status = WorkflowStatus()
#     280 passmanager_ir = pass_manager._passmanager_frontend(
#     281     input_program=program,
#     282     **kwargs,
#     283 )
# --> 284 passmanager_ir, _ = flow_controller.execute(
#     285     passmanager_ir=passmanager_ir,
#     286     state=PassManagerState(
#     287         workflow_status=initial_status,
#     288         property_set=pass_manager.property_set,
#     289     ),
#     290     callback=kwargs.get("callback", None),
#     291 )
#     292 out_program = pass_manager._passmanager_backend(
#     293     passmanager_ir=passmanager_ir,
#     294     in_program=program,
#     295     **kwargs,
#     296 )
#     298 return out_program
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/runningpassmanager.py:161, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     158 @wraps(meth)
#     159 def wrapper(*meth_args, **meth_kwargs):
#     160     try:
# --> 161         return meth(*meth_args, **meth_kwargs)
#     162     except PassManagerError as ex:
#     163         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:218, in BaseController.execute(self, passmanager_ir, state, callback)
#     216     return passmanager_ir, state
#     217 while True:
# --> 218     passmanager_ir, state = next_task.execute(
#     219         passmanager_ir=passmanager_ir,
#     220         state=state,
#     221         callback=callback,
#     222     )
#     223     try:
#     224         # Sending the object through the generator implies the custom controllers
#     225         # can always rely on the latest data to choose the next task to run.
#     226         next_task = task_generator.send(state)
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/basepasses.py:195, in TransformationPass.execute(self, passmanager_ir, state, callback)
#     189 def execute(
#     190     self,
#     191     passmanager_ir: PassManagerIR,
#     192     state: PassManagerState,
#     193     callback: Callable = None,
#     194 ) -> tuple[PassManagerIR, PassManagerState]:
# --> 195     new_dag, state = super().execute(
#     196         passmanager_ir=passmanager_ir,
#     197         state=state,
#     198         callback=callback,
#     199     )
#     201     if state.workflow_status.previous_run == RunState.SUCCESS:
#     202         if isinstance(new_dag, DAGCircuit):
#     203             # Copy calibration data from the original program
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:98, in GenericPass.execute(self, passmanager_ir, state, callback)
#      96 try:
#      97     if self not in state.workflow_status.completed_passes:
# ---> 98         ret = self.run(passmanager_ir)
#      99         run_state = RunState.SUCCESS
#     100     else:
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v020_lookahead.py:234, in run(self, dag)
#     223     qubit_indices.append(tuple(qubit.index for qubit in node.qargs))
#     224 #index_order = []
#     225 #for index in queue_layout.get_virtual_bits().keys():
#     226 #    index_order.append(index.index)
#    (...)
#     230 #print("Current queue depth: ", depth)
#     231 #print("Current queue explored gates: ", explored_gates)
#     233 if depth <= self.lookahead_depth:
# --> 234     # obtaining the swaps for the current lookahead layer
#     235     swap_candidates = list(self._obtain_swaps(queue_front_layer, queue_layout))
#     236     swap_candidates.sort(key=lambda x: (self._bit_indices[x[0]], self._bit_indices[x[1]]))
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/layout.py:231, in Layout.swap(self, left, right)
#     229     raise LayoutError("The method swap only works with elements of the same type.")
#     230 temp = self[left]
# --> 231 self[left] = self[right]
#     232 self[right] = temp
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/layout.py:118, in Layout.__setitem__(self, key, value)
#     116 def __setitem__(self, key, value):
#     117     virtual, physical = Layout.order_based_on_type(key, value)
# --> 118     self._set_type_checked_item(virtual, physical)
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/layout.py:128, in Layout._set_type_checked_item(self, virtual, physical)
#     126 self._p2v[physical] = virtual
#     127 if virtual is not None:
# --> 128     self._v2p[virtual] = physical
#
# File ~/Documents/GitHub/qiskit/qiskit/circuit/bit.py:115, in Bit.__hash__(self)
#     112         return object.__repr__(self)
#     113     return self._repr
# --> 115 def __hash__(self):
#     116     return self._hash
#     118 def __eq__(self, other):
#
# KeyboardInterrupt:
