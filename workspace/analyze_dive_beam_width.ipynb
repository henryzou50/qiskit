# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import ast
from ulti.graphs import plot_data

# %% [markdown]
# GHZ 25

# %%
filename = 'data/ghz_25/sabre_v020_dive.csv'
plot_data(filename, 'depth', 'Sabre Dive: GHZ 25 Qubits (Depth vs Beam Width)', 'beam width', 'depth', baseline=102)
plot_data(filename, 'cx_gates', 'Sabre Dive: GHZ 25 Qubits (Depth vs Beam Width)', 'beam width', 'cx gates', baseline=159, point_color='tab:blue')
# Out:
# /Users/henryzou/Documents/GitHub/qiskit/workspace/ulti/graphs.py:150: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   scatter = sns.scatterplot(data=df, x='RowNumber', y=y_key, color=point_color, palette="viridis", s=100, edgecolor="w", alpha=0.7)
# /Users/henryzou/Documents/GitHub/qiskit/workspace/ulti/graphs.py:150: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   scatter = sns.scatterplot(data=df, x='RowNumber', y=y_key, color=point_color, palette="viridis", s=100, edgecolor="w", alpha=0.7)

# %% [markdown]
# GHZ 100

# %%
filename = 'data/ghz_100/sabre_v020_dive.csv'
plot_data(filename, 'depth', 'Sabre Dive: GHZ 100 Qubits (Depth vs Beam Width)', 'beam width', 'depth', baseline=648)
plot_data(filename, 'cx_gates', 'Sabre Dive: GHZ 100 Qubits (Depth vs Beam Width)', 'beam width', 'cx gates', baseline=1068, point_color='tab:blue')
# Out:
# /Users/henryzou/Documents/GitHub/qiskit/workspace/ulti/graphs.py:150: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   scatter = sns.scatterplot(data=df, x='RowNumber', y=y_key, color=point_color, palette="viridis", s=100, edgecolor="w", alpha=0.7)
# /Users/henryzou/Documents/GitHub/qiskit/workspace/ulti/graphs.py:150: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   scatter = sns.scatterplot(data=df, x='RowNumber', y=y_key, color=point_color, palette="viridis", s=100, edgecolor="w", alpha=0.7)

# %% [markdown]
# QVOL 10

# %%
filename = 'data/qvol_10_depth_100/sabre_v020_dive.csv'
plot_data(filename, 'depth', 'Sabre Dive: QVOL 10 Qubits 100 Depth (Depth vs Beam Width)', 'beam width', 'depth', baseline=915)
plot_data(filename, 'cx_gates', 'Sabre Dive: QVOL 10 Qubits 100 Depth (Depth vs Beam Width)', 'beam width', 'cx gates', baseline=2226, point_color='tab:blue')
# Out:
# /Users/henryzou/Documents/GitHub/qiskit/workspace/ulti/graphs.py:150: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   scatter = sns.scatterplot(data=df, x='RowNumber', y=y_key, color=point_color, palette="viridis", s=100, edgecolor="w", alpha=0.7)
# /Users/henryzou/Documents/GitHub/qiskit/workspace/ulti/graphs.py:150: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   scatter = sns.scatterplot(data=df, x='RowNumber', y=y_key, color=point_color, palette="viridis", s=100, edgecolor="w", alpha=0.7)
