# %% [markdown]
# This code runs the experiment for SabreSwap v0.25 and SabreLayout v0.25

# %%
from qiskit.transpiler.passes.routing.sabre_swap_v020_dive   import SabreSwap   as SabreSwap_v020
from qiskit.transpiler.passes.layout.sabre_layout                 import SabreLayout as SabreLayout_v045
from qiskit.transpiler.passes.layout.sabre_layout_v020            import SabreLayout as SabreLayout_v020
from ulti.circuits import get_circuit_list, sort_circuits_by_depth
from ulti.coupling_maps import file_to_coupling_map
from ulti.pass_managers import generate_pass_managers, transpiled_data
import pandas as pd
import random
random.seed(42)
import os

# %%
# Option to keep the layout inital layout the same for faster transpilation
fast_layout = False
num_shots = 5
qc_name = "qvol_10_depth_5-100"
cp_name = "hex_27"
print(f"Running experiment for the circuits: {qc_name}")
qc_list = get_circuit_list([f'circuits/{qc_name}/'])
qc_list = sort_circuits_by_depth(qc_list)

csv_file_path = f'data/{qc_name}/sabre_v020_dive.csv'
directory = f'data/{qc_name}'
if not os.path.exists(directory):
        os.makedirs(directory)
# Out:
# Running experiment for the circuits: qvol_10_depth_5-100

# %%
# Test beam_width from 1
beam_width = [1, 5, 10, 50, 100]
all_data_df = pd.DataFrame()
for beam in beam_width:
    print(f"Running experiment for dive {beam}")
    # Experiment for Sabre v0.20 with lookahead heuristic
    # set beam to max integer
    lp_name = "sabre_v020"
    if beam < 10:
        rp_name = f"sabre_v020_dive_00{beam}"
    elif beam < 100:
        rp_name = f"sabre_v020_dive_0{beam}"
    else:
        rp_name = f"sabre_v020_dive_{beam}"

    rp = SabreSwap_v020
    lp = SabreLayout_v020
    cm = file_to_coupling_map(f'coupling_maps/{cp_name}.txt')
    pm = generate_pass_managers(num_shots, rp, lp, cm, beam_width = beam, 
                                fast_layout=fast_layout)

    for qc_idx, qc in enumerate(qc_list):
        data = transpiled_data(qc, pm)
        data['routing pass'] = rp_name
        data['layout pass'] = lp_name
        data['coupling map'] = cp_name
        data['circuit label'] = qc_idx
        data['beam width'] = beam
        data['look ahead'] = 0
        
        # Create a DataFrame from the current data and append it to the all_data_df
        current_data_df = pd.DataFrame([data])
        all_data_df = pd.concat([all_data_df, current_data_df])

        # Append the current data to the CSV file
        with open(csv_file_path, 'a') as f:
            current_data_df.to_csv(f, header=f.tell()==0, index=False)

        print(f"    Finished {qc_idx} for experiment {rp_name} and circuit {qc_name}")

    print(f"Finished all for experiment {rp_name} and circuit {qc_name}")
    print(f"Saved to {csv_file_path}")
    print("*" * 50)
# Out:
# Running experiment for dive 1
#     Finished 0 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 1 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 2 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 3 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 4 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 5 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 6 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 7 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 8 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 9 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 10 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 11 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 12 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 13 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 14 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 15 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 16 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 17 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 18 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 19 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 20 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 21 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 22 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 23 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 24 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 25 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 26 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 27 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 28 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 29 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 30 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 31 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 32 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 33 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 34 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 35 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 36 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 37 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 38 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 39 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 40 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 41 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 42 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 43 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 44 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 45 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 46 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 47 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 48 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 49 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 50 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 51 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 52 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 53 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 54 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 55 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 56 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 57 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 58 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 59 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 60 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 61 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 62 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 63 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 64 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 65 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 66 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 67 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 68 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 69 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 70 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 71 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 72 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 73 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 74 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 75 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 76 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 77 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 78 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 79 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 80 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 81 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 82 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 83 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 84 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 85 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 86 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 87 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 88 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 89 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 90 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 91 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 92 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 93 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
#     Finished 94 for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
# Finished all for experiment sabre_v020_dive_001 and circuit qvol_10_depth_5-100
# Saved to data/qvol_10_depth_5-100/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 5
#     Finished 0 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 1 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 2 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 3 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 4 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 5 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 6 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 7 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 8 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 9 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 10 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 11 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 12 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 13 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 14 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 15 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 16 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 17 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 18 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 19 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 20 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished 21 for experiment sabre_v020_dive_005 and circuit qvol_10_depth_5-100
#     Finished