# %% [markdown]
# This code runs the experiment for SabreSwap v0.25 and SabreLayout v0.25

# %%
from qiskit.transpiler.passes.routing.sabre_swap_v020_lookahead   import SabreSwap   as SabreSwap_v020
from qiskit.transpiler.passes.layout.sabre_layout                 import SabreLayout as SabreLayout_v045
from qiskit.transpiler.passes.layout.sabre_layout_v020            import SabreLayout as SabreLayout_v020
from ulti.circuits import get_circuit_list, sort_circuits_by_depth
from ulti.coupling_maps import file_to_coupling_map
from ulti.pass_managers import generate_pass_managers, transpiled_data
import pandas as pd
import random
random.seed(42)
import os

# %%
# Option to keep the layout inital layout the same for faster transpilation
fast_layout = False
num_shots = 5
qc_name = "ghz_25"
cp_name = "hex_27"
print(f"Running experiment for the circuits: {qc_name}")
qc_list = get_circuit_list([f'circuits/{qc_name}/'])
qc_list = sort_circuits_by_depth(qc_list)

csv_file_path = f'data/{qc_name}/sabre_v020_beam.csv'
directory = f'data/{qc_name}'
if not os.path.exists(directory):
        os.makedirs(directory)
# Out:
# Running experiment for the circuits: ghz_25

# %%
# Test beam_width from 1
lookaheads = list(range(100, 1000))
beam = 10
all_data_df = pd.DataFrame()
for look in lookaheads:
    print(f"Running experiment for look {beam}")
    # Experiment for Sabre v0.20 with lookahead heuristic
    # set beam to max integer
    lp_name = "sabre_v020"
    if beam < 10:
        rp_name = f"sabre_v020_look_00{look}_beam_010"
    elif beam < 100:
        rp_name = f"sabre_v020_look_0{look}_beam_010"
    else:
        rp_name = f"sabre_v020_look_{look}_beam_010"

    rp = SabreSwap_v020
    lp = SabreLayout_v020
    cm = file_to_coupling_map(f'coupling_maps/{cp_name}.txt')
    pm = generate_pass_managers(num_shots, rp, lp, cm, beam_width = beam, lookahead = look,
                                fast_layout=fast_layout)

    for qc_idx, qc in enumerate(qc_list):
        data = transpiled_data(qc, pm)
        data['routing pass'] = rp_name
        data['layout pass'] = lp_name
        data['coupling map'] = cp_name
        data['circuit label'] = qc_idx
        data['beam width'] = beam
        data['look ahead'] = look
        
        # Create a DataFrame from the current data and append it to the all_data_df
        current_data_df = pd.DataFrame([data])
        all_data_df = pd.concat([all_data_df, current_data_df])

        # Append the current data to the CSV file
        with open(csv_file_path, 'a') as f:
            current_data_df.to_csv(f, header=f.tell()==0, index=False)

        print(f"    Finished {qc_idx} for experiment {rp_name} and circuit {qc_name}")

    print(f"Finished all for experiment {rp_name} and circuit {qc_name}")
    print(f"Saved to {csv_file_path}")
    print("*" * 50)
# Out:
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0100_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0100_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0101_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0101_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0102_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0102_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0103_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0103_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0104_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0104_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0105_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0105_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0106_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0106_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0107_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0107_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0108_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0108_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0109_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0109_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0110_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0110_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0111_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0111_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0112_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0112_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0113_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0113_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0114_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0114_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0115_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0115_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0116_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0116_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0117_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0117_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0118_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0118_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0119_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0119_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0120_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0120_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0121_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0121_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0122_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0122_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0123_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0123_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0124_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0124_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0125_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0125_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0126_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0126_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0127_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0127_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0128_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0128_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0129_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0129_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0130_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0130_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0131_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0131_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0132_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0132_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0133_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0133_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0134_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0134_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0135_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0135_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0136_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0136_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0137_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0137_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0138_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0138_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0139_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0139_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0140_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0140_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0141_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0141_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0142_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0142_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0143_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0143_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0144_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0144_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0145_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0145_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0146_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0146_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0147_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0147_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0148_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0148_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0149_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0149_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0150_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0150_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0151_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0151_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0152_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0152_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0153_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0153_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0154_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0154_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0155_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0155_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0156_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0156_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0157_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0157_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0158_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0158_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0159_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0159_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0160_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0160_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0161_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0161_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0162_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0162_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0163_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0163_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0164_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0164_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0165_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0165_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0166_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0166_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0167_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0167_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0168_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0168_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0169_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0169_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0170_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0170_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0171_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0171_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0172_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0172_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0173_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0173_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0174_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0174_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0175_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0175_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0176_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0176_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0177_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0177_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0178_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0178_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0179_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0179_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0180_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0180_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0181_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0181_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0182_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0182_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0183_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0183_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0184_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0184_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0185_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0185_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0186_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0186_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0187_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0187_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0188_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0188_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0189_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0189_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0190_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0190_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0191_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0191_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0192_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0192_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0193_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0193_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0194_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0194_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0195_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0195_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0196_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0196_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0197_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0197_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0198_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0198_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0199_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0199_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0200_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0200_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0201_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0201_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0202_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0202_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0203_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0203_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0204_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0204_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0205_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0205_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
#     Finished 0 for experiment sabre_v020_look_0206_beam_010 and circuit ghz_25
# Finished all for experiment sabre_v020_look_0206_beam_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_beam.csv
# **************************************************
# Running experiment for look 10
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/jt/44gl1rhd26v6ykt0frqzl87r0000gn/T/ipykernel_37157/2903558769.py", line 24, in <module>
#     data = transpiled_data(qc, pm)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/workspace/ulti/pass_managers.py", line 131, in transpiled_data
#     qc_tr = pm.run(qc_decomposed)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py", line 551, in wrapper
#     return meth(*meth_args, **meth_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py", line 291, in run
#     return super().run(
#            ^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py", line 222, in run
#     out_program = _run_workflow(
#                   ^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py", line 284, in _run_workflow
#     passmanager_ir, _ = flow_controller.execute(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/runningpassmanager.py", line 161, in wrapper
#     return meth(*meth_args, **meth_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py", line 218, in execute
#     passmanager_ir, state = next_task.execute(
#                             ^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py", line 98, in execute
#     ret = self.run(passmanager_ir)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/passes/layout/sabre_layout_v020.py", line 123, in run
#     new_circ = pm.run(circ)
#                ^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py", line 551, in wrapper
#     return meth(*meth_args, **meth_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py", line 291, in run
#     return super().run(
#            ^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py", line 222, in run
#     out_program = _run_workflow(
#                   ^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py", line 284, in _run_workflow
#     passmanager_ir, _ = flow_controller.execute(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/runningpassmanager.py", line 161, in wrapper
#     return meth(*meth_args, **meth_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py", line 218, in execute
#     passmanager_ir, state = next_task.execute(
#                             ^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/basepasses.py", line 195, in execute
#     new_dag, state = super().execute(
#                      ^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py", line 98, in execute
#     ret = self.run(passmanager_ir)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v020_lookahead.py", line 191, in run
#     gate_seq  = self.lookahead_search(initial_node, dag).gate_seq
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v020_lookahead.py", line -1, in lookahead_search
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2144, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/IPython/core/ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#            ^^^^^
#   File "/Users/henryzou/.venvs/qiskit-dev/lib/python3.11/site-packages/executing/executing.py", line 116, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
