# %% [markdown]
# This code runs the experiment for SabreSwap v0.25 and SabreLayout v0.25

# %%
from qiskit.transpiler.passes.routing.sabre_swap_v020_lookahead   import SabreSwap   as SabreSwap_v020
from qiskit.transpiler.passes.layout.sabre_layout                 import SabreLayout as SabreLayout_v045
from qiskit.transpiler.passes.layout.sabre_layout_v020            import SabreLayout as SabreLayout_v020
from ulti.circuits import get_circuit_list, sort_circuits_by_depth
from ulti.coupling_maps import file_to_coupling_map
from ulti.pass_managers import generate_pass_managers, transpiled_data
import pandas as pd
import random
random.seed(42)
import os

# %%
# Option to keep the layout inital layout the same for faster transpilation
fast_layout = False
num_shots = 5

# %%
# Variables for type of circuit to test
qc_names = ["ghz_2-127", "ghz_100", 
            "size5_depth_1-10", "size5_depth_10-500",
            "size25_depth_10"]
cp_names = ["hex_127", "hex_127", 
            "hex_7", "hex_7",
            "hex_27"]

for idx in range(len(qc_names)):
    qc_name = qc_names[idx]
    cp_name = cp_names[idx]

    print(f"Running experiment for the circuits: {qc_name}")
    qc_list = get_circuit_list([f'circuits/{qc_name}/'])
    qc_list = sort_circuits_by_depth(qc_list)
    
    # Experiment for Sabre v0.20 with depth heuristic
    lp_name = "sabre_v020"
    rp_name = "sabre_v020_depth"

    rp = SabreSwap_v020
    lp = SabreLayout_v020
    cm = file_to_coupling_map(f'coupling_maps/{cp_name}.txt')
    pm = generate_pass_managers(num_shots, rp, lp, cm, fast_layout=fast_layout)


    csv_file_path = f'data/{qc_name}/{rp_name}.csv'
    directory = f'data/{qc_name}'
    if not os.path.exists(directory):
            os.makedirs(directory)

       # Run the experiment and store the data
    data_list = []
    for qc_idx, qc in enumerate(qc_list):
        data = transpiled_data(qc, pm)
        data['routing pass'] = rp_name
        data['layout pass'] = lp_name
        data['coupling map'] = cp_name
        data['circuit label'] = qc_idx
        data_list.append(data)

        print(f"    Finished {qc_idx} for experiment {rp_name} and circuit {qc_name}")
    print(f"Finished all for experiment {rp_name} and circuit {qc_name}")
    df = pd.DataFrame(data_list)
    df.to_csv(csv_file_path, index=False)
    print(f"Saved to {csv_file_path}")
    print("*"*50)
    print("Finished all")
# Out:
# Running experiment for the circuits: ghz_2-127
#     Finished 0 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 1 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 2 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 3 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 4 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 5 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 6 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 7 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 8 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 9 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 10 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 11 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 12 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 13 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 14 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 15 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 16 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 17 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 18 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 19 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 20 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 21 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 22 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 23 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 24 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 25 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 26 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 27 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 28 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 29 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 30 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 31 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 32 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 33 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 34 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 35 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 36 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 37 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 38 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 39 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 40 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 41 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 42 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 43 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 44 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 45 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 46 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 47 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 48 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 49 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 50 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 51 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 52 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 53 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 54 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 55 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 56 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 57 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 58 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 59 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 60 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 61 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 62 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 63 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 64 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 65 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 66 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 67 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 68 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 69 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 70 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 71 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 72 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 73 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 74 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 75 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 76 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 77 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 78 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 79 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 80 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 81 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 82 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 83 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 84 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 85 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 86 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 87 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 88 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 89 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 90 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 91 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 92 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 93 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 94 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 95 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 96 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 97 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 98 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 99 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 100 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 101 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 102 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 103 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 104 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 105 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 106 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 107 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 108 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 109 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 110 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 111 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 112 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 113 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 114 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 115 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 116 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 117 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 118 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 119 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 120 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 121 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 122 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 123 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 124 for experiment sabre_v020_depth and circuit ghz_2-127
#     Finished 125 for experiment sabre_v020_depth and circuit ghz_2-127
# Finished all for experiment sabre_v020_depth and circuit ghz_2-127
# Saved to data/ghz_2-127/sabre_v020_depth.csv
# **************************************************
# Finished all
# Running experiment for the circuits: ghz_100
#     Finished 0 for experiment sabre_v020_depth and circuit ghz_100
# Finished all for experiment sabre_v020_depth and circuit ghz_100
# Saved to data/ghz_100/sabre_v020_depth.csv
# **************************************************
# Finished all
# Running experiment for the circuits: size5_depth_1-10
#     Finished 0 for experiment sabre_v020_depth and circuit size5_depth_1-10
#     Finished 1 for experiment sabre_v020_depth and circuit size5_depth_1-10
#     Finished 2 for experiment sabre_v020_depth and circuit size5_depth_1-10
#     Finished 3 for experiment sabre_v020_depth and circuit size5_depth_1-10
#     Finished 4 for experiment sabre_v020_depth and circuit size5_depth_1-10
#     Finished 5 for experiment sabre_v020_depth and circuit size5_depth_1-10
#     Finished 6 for experiment sabre_v020_depth and circuit size5_depth_1-10
#     Finished 7 for experiment sabre_v020_depth and circuit size5_depth_1-10
#     Finished 8 for experiment sabre_v020_depth and circuit size5_depth_1-10
# Finished all for experiment sabre_v020_depth and circuit size5_depth_1-10
# Saved to data/size5_depth_1-10/sabre_v020_depth.csv
# **************************************************
# Finished all
# Running experiment for the circuits: size5_depth_10-500
#     Finished 0 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 1 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 2 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 3 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 4 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 5 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 6 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 7 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 8 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 9 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 10 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 11 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 12 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 13 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 14 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 15 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 16 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 17 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 18 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 19 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 20 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 21 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 22 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 23 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 24 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 25 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 26 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 27 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 28 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 29 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 30 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 31 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 32 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 33 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 34 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 35 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 36 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 37 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 38 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 39 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 40 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 41 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 42 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 43 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 44 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 45 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 46 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 47 for experiment sabre_v020_depth and circuit size5_depth_10-500
#     Finished 48 for experiment sabre_v020_depth and circuit size5_depth_10-500
# Finished all for experiment sabre_v020_depth and circuit size5_depth_10-500
# Saved to data/size5_depth_10-500/sabre_v020_depth.csv
# **************************************************
# Finished all
# Running experiment for the circuits: size25_depth_10
#     Finished 0 for experiment sabre_v020_depth and circuit size25_depth_10
# Finished all for experiment sabre_v020_depth and circuit size25_depth_10
# Saved to data/size25_depth_10/sabre_v020_depth.csv
# **************************************************
# Finished all
