# %% [markdown]
# This code runs the experiment for SabreSwap v0.25 and SabreLayout v0.25

# %%
from qiskit.transpiler.passes.routing.sabre_swap_v020_dive   import SabreSwap   as SabreSwap_v020
from qiskit.transpiler.passes.layout.sabre_layout                 import SabreLayout as SabreLayout_v045
from qiskit.transpiler.passes.layout.sabre_layout_v020            import SabreLayout as SabreLayout_v020
from ulti.circuits import get_circuit_list, sort_circuits_by_depth
from ulti.coupling_maps import file_to_coupling_map
from ulti.pass_managers import generate_pass_managers, transpiled_data
import pandas as pd
import random
random.seed(42)
import os

# %%
# Option to keep the layout inital layout the same for faster transpilation
fast_layout = False
num_shots = 5
qc_name = "ghz_25"
cp_name = "hex_27"
print(f"Running experiment for the circuits: {qc_name}")
qc_list = get_circuit_list([f'circuits/{qc_name}/'])
qc_list = sort_circuits_by_depth(qc_list)

csv_file_path = f'data/{qc_name}/sabre_v020_dive_test.csv'
directory = f'data/{qc_name}'
if not os.path.exists(directory):
        os.makedirs(directory)
# Out:
# Running experiment for the circuits: ghz_25

# %%
# Test beam_width from 1
beam_width = list(range(1, 10))
all_data_df = pd.DataFrame()
for beam in beam_width:
    print(f"Running experiment for dive {beam}")
    # Experiment for Sabre v0.20 with lookahead heuristic
    # set beam to max integer
    lp_name = "sabre_v020"
    if beam < 10:
        rp_name = f"sabre_v020_dive_00{beam}"
    elif beam < 100:
        rp_name = f"sabre_v020_dive_0{beam}"
    else:
        rp_name = f"sabre_v020_dive_{beam}"

    rp = SabreSwap_v020
    lp = SabreLayout_v020
    cm = file_to_coupling_map(f'coupling_maps/{cp_name}.txt')
    pm = generate_pass_managers(num_shots, rp, lp, cm, beam_width = beam, 
                                fast_layout=fast_layout)

    for qc_idx, qc in enumerate(qc_list):
        data = transpiled_data(qc, pm)
        data['routing pass'] = rp_name
        data['layout pass'] = lp_name
        data['coupling map'] = cp_name
        data['circuit label'] = qc_idx
        data['beam width'] = beam
        data['look ahead'] = 0
        
        # Create a DataFrame from the current data and append it to the all_data_df
        current_data_df = pd.DataFrame([data])
        all_data_df = pd.concat([all_data_df, current_data_df])

        # Append the current data to the CSV file
        with open(csv_file_path, 'a') as f:
            current_data_df.to_csv(f, header=f.tell()==0, index=False)

        print(f"    Finished {qc_idx} for experiment {rp_name} and circuit {qc_name}")

    print(f"Finished all for experiment {rp_name} and circuit {qc_name}")
    print(f"Saved to {csv_file_path}")
    print("*" * 50)
# Out:
# Running experiment for dive 1
# current level:  0
#      Number of candidate states:  3
#      Update (after sabre) depth to  76
# current level:  1
#      Number of candidate states:  10
# current level:  2
#      Number of candidate states:  10
# current level:  3
#      Number of candidate states:  10
# current level:  4
#      Number of candidate states:  10
# current level:  5
#      Number of candidate states:  10
# current level:  6
#      Number of candidate states:  10
# current level:  7
#      Number of candidate states:  10
# current level:  8
#      Number of candidate states:  10
# current level:  9
#      Number of candidate states:  10
# current level:  10
#      Number of candidate states:  10
# current level:  11
#      Number of candidate states:  10
# current level:  12
#      Number of candidate states:  10
# current level:  13
#      Number of candidate states:  10
# current level:  14
#      Number of candidate states:  10
# current level:  15
#      Number of candidate states:  10
# current level:  16
#      Number of candidate states:  10
# current level:  17
#      Number of candidate states:  10
# current level:  18
#      Number of candidate states:  10
# current level:  19
#      Number of candidate states:  10
# current level:  20
#      Number of candidate states:  10
# current level:  21
#      Number of candidate states:  10
# current level:  22
#      Number of candidate states:  10
# current level:  23
#      Number of candidate states:  10
# current level:  24
#      Number of candidate states:  10
# current level:  25
#      Number of candidate states:  10
# current level:  26
#      Number of candidate states:  10
# current level:  27
#      Number of candidate states:  10
# current level:  28
#      Number of candidate states:  10
# current level:  29
#      Number of candidate states:  10
# current level:  30
#      Number of candidate states:  10
# current level:  31
#      Number of candidate states:  10
# current level:  32
#      Number of candidate states:  10
# current level:  33
#      Number of candidate states:  10
# current level:  34
#      Number of candidate states:  10
# current level:  35
#      Number of candidate states:  10
# current level:  36
#      Number of candidate states:  10
# current level:  37
#      Number of candidate states:  10
# current level:  38
#      Number of candidate states:  10
# current level:  39
#      Number of candidate states:  10
# current level:  40
#      Number of candidate states:  10
# current level:  41
#      Number of candidate states:  10
# current level:  42
#      Number of candidate states:  10
# current level:  43
#      Number of candidate states:  10
# current level:  44
#      Number of candidate states:  10
# current level:  45
#      Number of candidate states:  10
# current level:  46
#      Number of candidate states:  10
# current level:  47
#      Number of candidate states:  10
# current level:  48
#      Number of candidate states:  10
# current level:  49
#      Number of candidate states:  10
# current level:  50
#      Number of candidate states:  10
# current level:  51
#      Number of candidate states:  10
# current level:  52
#      Number of candidate states:  10
# current level:  53
#      Number of candidate states:  10
# current level:  54
#      Number of candidate states:  10
# current level:  55
#      Number of candidate states:  10
# current level:  56
#      Number of candidate states:  10
# current level:  57
#      Number of candidate states:  10
# current level:  58
#      Number of candidate states:  10
# current level:  59
#      Number of candidate states:  10
# current level:  60
#      Number of candidate states:  10
# current level:  61
#      Number of candidate states:  10
# current level:  62
#      Number of candidate states:  10
# current level:  63
#      Number of candidate states:  10
# current level:  64
#      Number of candidate states:  10
# current level:  65
#      Number of candidate states:  10
# current level:  66
#      Number of candidate states:  10
# current level:  67
#      Number of candidate states:  10
# current level:  68
#      Number of candidate states:  10
# current level:  69
#      Number of candidate states:  10
# current level:  70
#      Number of candidate states:  10
# current level:  71
#      Number of candidate states:  10
# current level:  72
#      Number of candidate states:  10
# current level:  73
#      Number of candidate states:  10
# current level:  74
#      Number of candidate states:  10
# current level:  75
#      Number of candidate states:  10
# current level:  76
#      Number of candidate states:  10
# current level:  77
#      Number of candidate states:  10
# current level:  78
#      Number of candidate states:  10
# current level:  79
#      Number of candidate states:  0
# current level:  80
#      Number of candidate states:  0
# current level:  81
#      Number of candidate states:  0
# current level:  82
#      Number of candidate states:  0
# current level:  83
#      Number of candidate states:  0
# current level:  84
#      Number of candidate states:  0
# current level:  85
#      Number of candidate states:  0
# current level:  86
#      Number of candidate states:  0
# current level:  87
#      Number of candidate states:  0
# current level:  88
#      Number of candidate states:  0
# current level:  89
#      Number of candidate states:  0
# current level:  90
#      Number of candidate states:  0
# current level:  91
#      Number of candidate states:  0
# current level:  92
#      Number of candidate states:  0
# current level:  93
#      Number of candidate states:  0
# current level:  94
#      Number of candidate states:  0
# current level:  95
#      Number of candidate states:  0
# current level:  96
#      Number of candidate states:  0
# current level:  97
#      Number of candidate states:  0
# current level:  98
#      Number of candidate states:  0
# current level:  99
#      Number of candidate states:  0
# current level:  0
#      Number of candidate states:  5
#      Update (after sabre) depth to  68
# current level:  1
#      Number of candidate states:  10
#      Update (after sabre) depth to  67
# current level:  2
#      Number of candidate states:  10
# current level:  3
#      Number of candidate states:  10
# current level:  4
#      Number of candidate states:  10
# current level:  5
#      Number of candidate states:  10
# current level:  6
#      Number of candidate states:  10
# current level:  7
#      Number of candidate states:  10
#      Update (after sabre) depth to  66
# current level:  8
#      Number of candidate states:  10
# current level:  9
#      Number of candidate states:  10
# current level:  10
#      Number of candidate states:  10
# current level:  11
#      Number of candidate states:  10
# current level:  12
#      Number of candidate states:  10
# current level:  13
#      Number of candidate states:  10
# current level:  14
#      Number of candidate states:  10
# current level:  15
#      Number of candidate states:  10
# current level:  16
#      Number of candidate states:  10
# current level:  17
#      Number of candidate states:  10
# current level:  18
#      Number of candidate states:  10
# current level:  19
#      Number of candidate states:  10
# current level:  20
#      Number of candidate states:  10
# current level:  21
#      Number of candidate states:  10
# current level:  22
#      Number of candidate states:  10
# current level:  23
#      Number of candidate states:  10
# current level:  24
#      Number of candidate states:  10
# current level:  25
#      Number of candidate states:  10
# current level:  26
#      Number of candidate states:  10
# current level:  27
#      Number of candidate states:  10
# current level:  28
#      Number of candidate states:  10
# current level:  29
#      Number of candidate states:  10
# current level:  30
#      Number of candidate states:  10
# current level:  31
#      Number of candidate states:  10
# current level:  32
#      Number of candidate states:  10
# current level:  33
#      Number of candidate states:  10
# current level:  34
#      Number of candidate states:  10
# current level:  35
#      Number of candidate states:  10
# current level:  36
#      Number of candidate states:  10
# current level:  37
#      Number of candidate states:  10
# current level:  38
#      Number of candidate states:  10
# current level:  39
#      Number of candidate states:  10
# current level:  40
#      Number of candidate states:  10
# current level:  41
#      Number of candidate states:  10
# current level:  42
#      Number of candidate states:  10
# current level:  43
#      Number of candidate states:  10
# current level:  44
#      Number of candidate states:  10
# current level:  45
#      Number of candidate states:  10
# current level:  46
#      Number of candidate states:  10
# current level:  47
#      Number of candidate states:  10
# current level:  48
#      Number of candidate states:  10
# current level:  49
#      Number of candidate states:  10
# current level:  50
#      Number of candidate states:  10
# current level:  51
#      Number of candidate states:  10
# current level:  52
#      Number of candidate states:  10
# current level:  53
#      Number of candidate states:  10
# current level:  54
#      Number of candidate states:  10
# current level:  55
#      Number of candidate states:  10
# current level:  56
#      Number of candidate states:  10
# current level:  57
#      Number of candidate states:  10
# current level:  58
#      Number of candidate states:  10
# current level:  59
#      Number of candidate states:  10
# current level:  60
#      Number of candidate states:  10
# current level:  61
#      Number of candidate states:  10
# current level:  62
#      Number of candidate states:  10
# current level:  63
#      Number of candidate states:  10
# current level:  64
#      Number of candidate states:  10
# current level:  65
#      Number of candidate states:  0
# current level:  66
#      Number of candidate states:  0
# current level:  67
#      Number of candidate states:  0
# current level:  68
#      Number of candidate states:  0
# current level:  69
#      Number of candidate states:  0
# current level:  70
#      Number of candidate states:  0
# current level:  71
#      Number of candidate states:  0
# current level:  72
#      Number of candidate states:  0
# current level:  73
#      Number of candidate states:  0
# current level:  74
#      Number of candidate states:  0
# current level:  75
#      Number of candidate states:  0
# current level:  76
#      Number of candidate states:  0
# current level:  77
#      Number of candidate states:  0
# current level:  78
#      Number of candidate states:  0
# current level:  79
#      Number of candidate states:  0
# current level:  80
#      Number of candidate states:  0
# current level:  81
#      Number of candidate states:  0
# current level:  82
#      Number of candidate states:  0
# current level:  83
#      Number of candidate states:  0
# current level:  84
#      Number of candidate states:  0
# current level:  85
#      Number of candidate states:  0
# current level:  86
#      Number of candidate states:  0
# current level:  87
#      Number of candidate states:  0
# current level:  88
#      Number of candidate states:  0
# current level:  89
#      Number of candidate states:  0
# current level:  90
#      Number of candidate states:  0
# current level:  91
#      Number of candidate states:  0
# current level:  92
#      Number of candidate states:  0
# current level:  93
#      Number of candidate states:  0
# current level:  94
#      Number of candidate states:  0
# current level:  95
#      Number of candidate states:  0
# current level:  96
#      Number of candidate states:  0
# current level:  97
#      Number of candidate states:  0
# current level:  98
#      Number of candidate states:  0
# current level:  99
#      Number of candidate states:  0
# current level:  0
#      Number of candidate states:  4
#      Update (after sabre) depth to  63
# current level:  1
#      Number of candidate states:  10
# current level:  2
#      Number of candidate states:  10
# current level:  3
#      Number of candidate states:  10
# current level:  4
#      Number of candidate states:  10
# current level:  5
#      Number of candidate states:  10
# current level:  6
#      Number of candidate states:  10
# current level:  7
#      Number of candidate states:  10
#      Update (after sabre) depth to  61
# current level:  8
#      Number of candidate states:  10
# current level:  9
#      Number of candidate states:  10
# current level:  10
#      Number of candidate states:  10
# current level:  11
#      Number of candidate states:  10
# current level:  12
#      Number of candidate states:  10
# current level:  13
#      Number of candidate states:  10
# current level:  14
#      Number of candidate states:  10
# current level:  15
#      Number of candidate states:  10
# current level:  16
#      Number of candidate states:  10
# current level:  17
#      Number of candidate states:  10
# current level:  18
#      Number of candidate states:  10
# current level:  19
#      Number of candidate states:  10
# current level:  20
#      Number of candidate states:  10
# current level:  21
#      Number of candidate states:  10
# current level:  22
#      Number of candidate states:  10
# current level:  23
#      Number of candidate states:  10
# current level:  24
#      Number of candidate states:  10
# current level:  25
#      Number of candidate states:  10
# current level:  26
#      Number of candidate states:  10
# current level:  27
#      Number of candidate states:  10
# current level:  28
#      Number of candidate states:  10
# current level:  29
#      Number of candidate states:  10
# current level:  30
#      Number of candidate states:  10
# current level:  31
#      Number of candidate states:  10
# current level:  32
#      Number of candidate states:  10
# current level:  33
#      Number of candidate states:  10
# current level:  34
#      Number of candidate states:  10
# current level:  35
#      Number of candidate states:  10
# current level:  36
#      Number of candidate states:  10
# current level:  37
#      Number of candidate states:  10
# current level:  38
#      Number of candidate states:  10
# current level:  39
#      Number of candidate states:  10
# current level:  40
#      Number of candidate states:  10
# current level:  41
#      Number of candidate states:  10
# current level:  42
#      Number of candidate states:  10
# current level:  43
#      Number of candidate states:  10
# current level:  44
#      Number of candidate states:  10
# current level:  45
#      Number of candidate states:  10
# current level:  46
#      Number of candidate states:  10
# current level:  47
#      Number of candidate states:  10
# current level:  48
#      Number of candidate states:  10
# current level:  49
#      Number of candidate states:  10
# current level:  50
#      Number of candidate states:  10
# current level:  51
#      Number of candidate states:  10
# current level:  52
#      Number of candidate states:  10
# current level:  53
#      Number of candidate states:  10
# current level:  54
#      Number of candidate states:  10
# current level:  55
#      Number of candidate states:  10
# current level:  56
#      Number of candidate states:  10
# current level:  57
#      Number of candidate states:  10
# current level:  58
#      Number of candidate states:  0
# current level:  59
#      Number of candidate states:  0
# current level:  60
#      Number of candidate states:  0
# current level:  61
#      Number of candidate states:  0
# current level:  62
#      Number of candidate states:  0
# current level:  63
#      Number of candidate states:  0
# current level:  64
#      Number of candidate states:  0
# current level:  65
#      Number of candidate states:  0
# current level:  66
#      Number of candidate states:  0
# current level:  67
#      Number of candidate states:  0
# current level:  68
#      Number of candidate states:  0
# current level:  69
#      Number of candidate states:  0
# current level:  70
#      Number of candidate states:  0
# current level:  71
#      Number of candidate states:  0
# current level:  72
#      Number of candidate states:  0
# current level:  73
#      Number of candidate states:  0
# current level:  74
#      Number of candidate states:  0
# current level:  75
#      Number of candidate states:  0
# current level:  76
#      Number of candidate states:  0
# current level:  77
#      Number of candidate states:  0
# current level:  78
#      Number of candidate states:  0
# current level:  79
#      Number of candidate states:  0
# current level:  80
#      Number of candidate states:  0
# current level:  81
#      Number of candidate states:  0
# current level:  82
#      Number of candidate states:  0
# current level:  83
#      Number of candidate states:  0
# current level:  84
#      Number of candidate states:  0
# current level:  85
#      Number of candidate states:  0
# current level:  86
#      Number of candidate states:  0
# current level:  87
#      Number of candidate states:  0
# current level:  88
#      Number of candidate states:  0
# current level:  89
#      Number of candidate states:  0
# current level:  90
#      Number of candidate states:  0
# current level:  91
#      Number of candidate states:  0
# current level:  92
#      Number of candidate states:  0
# current level:  93
#      Number of candidate states:  0
# current level:  94
#      Number of candidate states:  0
# current level:  95
#      Number of candidate states:  0
# current level:  96
#      Number of candidate states:  0
# current level:  97
#      Number of candidate states:  0
# current level:  98
#      Number of candidate states:  0
# current level:  99
#      Number of candidate states:  0
# current level:  0
#      Number of candidate states:  4
#      Update (after sabre) depth to  73
# current level:  1
#      Number of candidate states:  10
#      Update (after sabre) depth to  70
# current level:  2
#      Number of candidate states:  10
# current level:  3
#      Number of candidate states:  10
#      Update (after sabre) depth to  69
# current level:  4
#      Number of candidate states:  10
# current level:  5
#      Number of candidate states:  10
# current level:  6
#      Number of candidate states:  10
#      Update (after sabre) depth to  68
# current level:  7
#      Number of candidate states:  10
# current level:  8
#      Number of candidate states:  10
# current level:  9
#      Number of candidate states:  10
# current level:  10
#      Number of candidate states:  10
#      Update (after sabre) depth to  66
# current level:  11
#      Number of candidate states:  10
# current level:  12
#      Number of candidate states:  10
# current level:  13
#      Number of candidate states:  10
# current level:  14
#      Number of candidate states:  10
# current level:  15
#      Number of candidate states:  10
#      Update (after sabre) depth to  60
# current level:  16
#      Number of candidate states:  10
# current level:  17
#      Number of candidate states:  10
# current level:  18
#      Number of candidate states:  10
# current level:  19
#      Number of candidate states:  10
# current level:  20
#      Number of candidate states:  10
# current level:  21
#      Number of candidate states:  10
# current level:  22
#      Number of candidate states:  10
# current level:  23
#      Number of candidate states:  10
# current level:  24
#      Number of candidate states:  10
# current level:  25
#      Number of candidate states:  10
# current level:  26
#      Number of candidate states:  10
# current level:  27
#      Number of candidate states:  10
# current level:  28
#      Number of candidate states:  10
# current level:  29
#      Number of candidate states:  10
# current level:  30
#      Number of candidate states:  10
# current level:  31
#      Number of candidate states:  10
# current level:  32
#      Number of candidate states:  10
# current level:  33
#      Number of candidate states:  10
# current level:  34
#      Number of candidate states:  10
# current level:  35
#      Number of candidate states:  10
# current level:  36
#      Number of candidate states:  10
# current level:  37
#      Number of candidate states:  10
# current level:  38
#      Number of candidate states:  10
# current level:  39
#      Number of candidate states:  10
# current level:  40
#      Number of candidate states:  10
# current level:  41
#      Number of candidate states:  10
# current level:  42
#      Number of candidate states:  10
# current level:  43
#      Number of candidate states:  10
# current level:  44
#      Number of candidate states:  10
# current level:  45
#      Number of candidate states:  10
# current level:  46
#      Number of candidate states:  10
# current level:  47
#      Number of candidate states:  10
# current level:  48
#      Number of candidate states:  10
# current level:  49
#      Number of candidate states:  10
# current level:  50
#      Number of candidate states:  10
# current level:  51
#      Number of candidate states:  10
# current level:  52
#      Number of candidate states:  0
# current level:  53
#      Number of candidate states:  0
# current level:  54
#      Number of candidate states:  0
# current level:  55
#      Number of candidate states:  0
# current level:  56
#      Number of candidate states:  0
# current level:  57
#      Number of candidate states:  0
# current level:  58
#      Number of candidate states:  0
# current level:  59
#      Number of candidate states:  0
# current level:  60
#      Number of candidate states:  0
# current level:  61
#      Number of candidate states:  0
# current level:  62
#      Number of candidate states:  0
# current level:  63
#      Number of candidate states:  0
# current level:  64
#      Number of candidate states:  0
# current level:  65
#      Number of candidate states:  0
# current level:  66
#      Number of candidate states:  0
# current level:  67
#      Number of candidate states:  0
# current level:  68
#      Number of candidate states:  0
# current level:  69
#      Number of candidate states:  0
# current level:  70
#      Number of candidate states:  0
# current level:  71
#      Number of candidate states:  0
# current level:  72
#      Number of candidate states:  0
# current level:  73
#      Number of candidate states:  0
# current level:  74
#      Number of candidate states:  0
# current level:  75
#      Number of candidate states:  0
# current level:  76
#      Number of candidate states:  0
# current level:  77
#      Number of candidate states:  0
# current level:  78
#      Number of candidate states:  0
# current level:  79
#      Number of candidate states:  0
# current level:  80
#      Number of candidate states:  0
# current level:  81
#      Number of candidate states:  0
# current level:  82
#      Number of candidate states:  0
# current level:  83
#      Number of candidate states:  0
# current level:  84
#      Number of candidate states:  0
# current level:  85
#      Number of candidate states:  0
# current level:  86
#      Number of candidate states:  0
# current level:  87
#      Number of candidate states:  0
# current level:  88
#      Number of candidate states:  0
# current level:  89
#      Number of candidate states:  0
# current level:  90
#      Number of candidate states:  0
# current level:  91
#      Number of candidate states:  0
# current level:  92
#      Number of candidate states:  0
# current level:  93
#      Number of candidate states:  0
# current level:  94
#      Number of candidate states:  0
# current level:  95
#      Number of candidate states:  0
# current level:  96
#      Number of candidate states:  0
# current level:  97
#      Number of candidate states:  0
# current level:  98
#      Number of candidate states:  0
# current level:  99
#      Number of candidate states:  0
# current level:  0
#      Number of candidate states:  4
#      Update (after sabre) depth to  70
#      Update (after sabre) depth to  66
# current level:  1
#      Number of candidate states:  10
# current level:  2
#      Number of candidate states:  10
# current level:  3
#      Number of candidate states:  10
# current level:  4
#      Number of candidate states:  10
# current level:  5
#      Number of candidate states:  10
# current level:  6
#      Number of candidate states:  10
#      Update (after sabre) depth to  64
# current level:  7
#      Number of candidate states:  10
# current level:  8
#      Number of candidate states:  10
# current level:  9
#      Number of candidate states:  10
# current level:  10
#      Number of candidate states:  10
# current level:  11
#      Number of candidate states:  10
# current level:  12
#      Number of candidate states:  10
# current level:  13
#      Number of candidate states:  10
# current level:  14
#      Number of candidate states:  10
# current level:  15
#      Number of candidate states:  10
# current level:  16
#      Number of candidate states:  10
# current level:  17
#      Number of candidate states:  10
# current level:  18
#      Number of candidate states:  10
# current level:  19
#      Number of candidate states:  10
# current level:  20
#      Number of candidate states:  10
# current level:  21
#      Number of candidate states:  10
# current level:  22
#      Number of candidate states:  10
# current level:  23
#      Number of candidate states:  10
# current level:  24
#      Number of candidate states:  10
#      Update (after sabre) depth to  63
# current level:  25
#      Number of candidate states:  10
# current level:  26
#      Number of candidate states:  10
# current level:  27
#      Number of candidate states:  10
# current level:  28
#      Number of candidate states:  10
# current level:  29
#      Number of candidate states:  10
# current level:  30
#      Number of candidate states:  10
# current level:  31
#      Number of candidate states:  10
# current level:  32
#      Number of candidate states:  10
# current level:  33
#      Number of candidate states:  10
# current level:  34
#      Number of candidate states:  10
# current level:  35
#      Number of candidate states:  10
#      Update (after sabre) depth to  61
# current level:  36
#      Number of candidate states:  10
# current level:  37
#      Number of candidate states:  10
# current level:  38
#      Number of candidate states:  10
# current level:  39
#      Number of candidate states:  10
# current level:  40
#      Number of candidate states:  10
# current level:  41
#      Number of candidate states:  10
# current level:  42
#      Number of candidate states:  10
# current level:  43
#      Number of candidate states:  10
# current level:  44
#      Number of candidate states:  10
# current level:  45
#      Number of candidate states:  10
# current level:  46
#      Number of candidate states:  10
# current level:  47
#      Number of candidate states:  10
# current level:  48
#      Number of candidate states:  10
# current level:  49
#      Number of candidate states:  10
# current level:  50
#      Number of candidate states:  10
# current level:  51
#      Number of candidate states:  10
# current level:  52
#      Number of candidate states:  10
# current level:  53
#      Number of candidate states:  10
# current level:  54
#      Number of candidate states:  10
# current level:  55
#      Number of candidate states:  10
# current level:  56
#      Number of candidate states:  10
# current level:  57
#      Number of candidate states:  10
# current level:  58
#      Number of candidate states:  10
# current level:  59
#      Number of candidate states:  10
# current level:  60
#      Number of candidate states:  10
# current level:  61
#      Number of candidate states:  10
# current level:  62
#      Number of candidate states:  10
# current level:  63
#      Number of candidate states:  10
# current level:  64
#      Number of candidate states:  10
# current level:  65
#      Number of candidate states:  10
# current level:  66
#      Number of candidate states:  10
# current level:  67
#      Number of candidate states:  10
# current level:  68
#      Number of candidate states:  10
# current level:  69
#      Number of candidate states:  10
# current level:  70
#      Number of candidate states:  0
# current level:  71
#      Number of candidate states:  0
# current level:  72
#      Number of candidate states:  0
# current level:  73
#      Number of candidate states:  0
# current level:  74
#      Number of candidate states:  0
# current level:  75
#      Number of candidate states:  0
# current level:  76
#      Number of candidate states:  0
# current level:  77
#      Number of candidate states:  0
# current level:  78
#      Number of candidate states:  0
# current level:  79
#      Number of candidate states:  0
# current level:  80
#      Number of candidate states:  0
# current level:  81
#      Number of candidate states:  0
# current level:  82
#      Number of candidate states:  0
# current level:  83
#      Number of candidate states:  0
# current level:  84
#      Number of candidate states:  0
# current level:  85
#      Number of candidate states:  0
# current level:  86
#      Number of candidate states:  0
# current level:  87
#      Number of candidate states:  0
# current level:  88
#      Number of candidate states:  0
# current level:  89
#      Number of candidate states:  0
# current level:  90
#      Number of candidate states:  0
# current level:  91
#      Number of candidate states:  0
# current level:  92
#      Number of candidate states:  0
# current level:  93
#      Number of candidate states:  0
# current level:  94
#      Number of candidate states:  0
# current level:  95
#      Number of candidate states:  0
# current level:  96
#      Number of candidate states:  0
# current level:  97
#      Number of candidate states:  0
# current level:  98
#      Number of candidate states:  0
# current level:  99
#      Number of candidate states:  0
# current level:  0
#      Number of candidate states:  6
#      Update (after sabre) depth to  66
# current level:  1
#      Number of candidate states:  10
# current level:  2
#      Number of candidate states:  10
# current level:  3
#      Number of candidate states:  10
# current level:  4
#      Number of candidate states:  10
# current level:  5
#      Number of candidate states:  10
# current level:  6
#      Number of candidate states:  10
# current level:  7
#      Number of candidate states:  10
# current level:  8
#      Number of candidate states:  10
# current level:  9
#      Number of candidate states:  10
# current level:  10
#      Number of candidate states:  10
# current level:  11
#      Number of candidate states:  10
# current level:  12
#      Number of candidate states:  10
# current level:  13
#      Number of candidate states:  10
# current level:  14
#      Number of candidate states:  10
# current level:  15
#      Number of candidate states:  10
# current level:  16
#      Number of candidate states:  10
# current level:  17
#      Number of candidate states:  10
# current level:  18
#      Number of candidate states:  10
# current level:  19
#      Number of candidate states:  10
# current level:  20
#      Number of candidate states:  10
# current level:  21
#      Number of candidate states:  10
# current level:  22
#      Number of candidate states:  10
# current level:  23
#      Number of candidate states:  10
# current level:  24
#      Number of candidate states:  10
# current level:  25
#      Number of candidate states:  10
# current level:  26
#      Number of candidate states:  10
# current level:  27
#      Number of candidate states:  10
# current level:  28
#      Number of candidate states:  10
# current level:  29
#      Number of candidate states:  10
# current level:  30
#      Number of candidate states:  10
# current level:  31
#      Number of candidate states:  10
# current level:  32
#      Number of candidate states:  10
# current level:  33
#      Number of candidate states:  10
# current level:  34
#      Number of candidate states:  10
# current level:  35
#      Number of candidate states:  10
# current level:  36
#      Number of candidate states:  10
# current level:  37
#      Number of candidate states:  10
# current level:  38
#      Number of candidate states:  10
# current level:  39
#      Number of candidate states:  10
# current level:  40
#      Number of candidate states:  10
# current level:  41
#      Number of candidate states:  10
# current level:  42
#      Number of candidate states:  10
# current level:  43
#      Number of candidate states:  10
# current level:  44
#      Number of candidate states:  10
# current level:  45
#      Number of candidate states:  10
# current level:  46
#      Number of candidate states:  10
# current level:  47
#      Number of candidate states:  0
# current level:  48
#      Number of candidate states:  0
# current level:  49
#      Number of candidate states:  0
# current level:  50
#      Number of candidate states:  0
# current level:  51
#      Number of candidate states:  0
# current level:  52
#      Number of candidate states:  0
# current level:  53
#      Number of candidate states:  0
# current level:  54
#      Number of candidate states:  0
# current level:  55
#      Number of candidate states:  0
# current level:  56
#      Number of candidate states:  0
# current level:  57
#      Number of candidate states:  0
# current level:  58
#      Number of candidate states:  0
# current level:  59
#      Number of candidate states:  0
# current level:  60
#      Number of candidate states:  0
# current level:  61
#      Number of candidate states:  0
# current level:  62
#      Number of candidate states:  0
# current level:  63
#      Number of candidate states:  0
# current level:  64
#      Number of candidate states:  0
# current level:  65
#      Number of candidate states:  0
# current level:  66
#      Number of candidate states:  0
# current level:  67
#      Number of candidate states:  0
# current level:  68
#      Number of candidate states:  0
# current level:  69
#      Number of candidate states:  0
# current level:  70
#      Number of candidate states:  0
# current level:  71
#      Number of candidate states:  0
# current level:  72
#      Number of candidate states:  0
# current level:  73
#      Number of candidate states:  0
# current level:  74
#      Number of candidate states:  0
# current level:  75
#      Number of candidate states:  0
# current level:  76
#      Number of candidate states:  0
# current level:  77
#      Number of candidate states:  0
# current level:  78
#      Number of candidate states:  0
# current level:  79
#      Number of candidate states:  0
# current level:  80
#      Number of candidate states:  0
# current level:  81
#      Number of candidate states:  0
# current level:  82
#      Number of candidate states:  0
# current level:  83
#      Number of candidate states:  0
# current level:  84
#      Number of candidate states:  0
# current level:  85
#      Number of candidate states:  0
# current level:  86
#      Number of candidate states:  0
# current level:  87
#      Number of candidate states:  0
# current level:  88
#      Number of candidate states:  0
# current level:  89
#      Number of candidate states:  0
# current level:  90
#      Number of candidate states:  0
# current level:  91
#      Number of candidate states:  0
# current level:  92
#      Number of candidate states:  0
# current level:  93
#      Number of candidate states:  0
# current level:  94
#      Number of candidate states:  0
# current level:  95
#      Number of candidate states:  0
# current level:  96
#      Number of candidate states:  0
# current level:  97
#      Number of candidate states:  0
# current level:  98
#      Number of candidate states:  0
# current level:  99
#      Number of candidate states:  0
# current level:  0
#      Number of candidate states:  6
#      Update (after sabre) depth to  65
# current level:  1
#      Number of candidate states:  10
# current level:  2
#      Number of candidate states:  10
# current level:  3
#      Number of candidate states:  10
# current level:  4
#      Number of candidate states:  10
# current level:  5
#      Number of candidate states:  10
# current level:  6
#      Number of candidate states:  10
# current level:  7
#      Number of candidate states:  10
# current level:  8
#      Number of candidate states:  10
# current level:  9
#      Number of candidate states:  10
# current level:  10
#      Number of candidate states:  10
# current level:  11
#      Number of candidate states:  10
# current level:  12
#      Number of candidate states:  10
# current level:  13
#      Number of candidate states:  10
# current level:  14
#      Number of candidate states:  10
# current level:  15
#      Number of candidate states:  10
# current level:  16
#      Number of candidate states:  10
# current level:  17
#      Number of candidate states:  10
# current level:  18
#      Number of candidate states:  10
# current level:  19
#      Number of candidate states:  10
# current level:  20
#      Number of candidate states:  10
# current level:  21
#      Number of candidate states:  10
# current level:  22
#      Number of candidate states:  10
# current level:  23
#      Number of candidate states:  10
# current level:  24
#      Number of candidate states:  10
# current level:  25
#      Number of candidate states:  10
# current level:  26
#      Number of candidate states:  10
# current level:  27
#      Number of candidate states:  10
# current level:  28
#      Number of candidate states:  10
# current level:  29
#      Number of candidate states:  10
# current level:  30
#      Number of candidate states:  10
# current level:  31
#      Number of candidate states:  10
# current level:  32
#      Number of candidate states:  10
# current level:  33
#      Number of candidate states:  10
# current level:  34
#      Number of candidate states:  10
# current level:  35
#      Number of candidate states:  10
# current level:  36
#      Number of candidate states:  10
# current level:  37
#      Number of candidate states:  10
# current level:  38
#      Number of candidate states:  10
# current level:  39
#      Number of candidate states:  10
# current level:  40
#      Number of candidate states:  10
# current level:  41
#      Number of candidate states:  10
# current level:  42
#      Number of candidate states:  10
# current level:  43
#      Number of candidate states:  0
# current level:  44
#      Number of candidate states:  0
# current level:  45
#      Number of candidate states:  0
# current level:  46
#      Number of candidate states:  0
# current level:  47
#      Number of candidate states:  0
# current level:  48
#      Number of candidate states:  0
# current level:  49
#      Number of candidate states:  0
# current level:  50
#      Number of candidate states:  0
# current level:  51
#      Number of candidate states:  0
# current level:  52
#      Number of candidate states:  0
# current level:  53
#      Number of candidate states:  0
# current level:  54
#      Number of candidate states:  0
# current level:  55
#      Number of candidate states:  0
# current level:  56
#      Number of candidate states:  0
# current level:  57
#      Number of candidate states:  0
# current level:  58
#      Number of candidate states:  0
# current level:  59
#      Number of candidate states:  0
# current level:  60
#      Number of candidate states:  0
# current level:  61
#      Number of candidate states:  0
# current level:  62
#      Number of candidate states:  0
# current level:  63
#      Number of candidate states:  0
# current level:  64
#      Number of candidate states:  0
# current level:  65
#      Number of candidate states:  0
# current level:  66
#      Number of candidate states:  0
# current level:  67
#      Number of candidate states:  0
# current level:  68
#      Number of candidate states:  0
# current level:  69
#      Number of candidate states:  0
# current level:  70
#      Number of candidate states:  0
# current level:  71
#      Number of candidate states:  0
# current level:  72
#      Number of candidate states:  0
# current level:  73
#      Number of candidate states:  0
# current level:  74
#      Number of candidate states:  0
# current level:  75
#      Number of candidate states:  0
# current level:  76
#      Number of candidate states:  0
# current level:  77
#      Number of candidate states:  0
# current level:  78
#      Number of candidate states:  0
# current level:  79
#      Number of candidate states:  0
# current level:  80
#      Number of candidate states:  0
# current level:  81
#      Number of candidate states:  0
# current level:  82
#      Number of candidate states:  0
# current level:  83
#      Number of candidate states:  0
# current level:  84
#      Number of candidate states:  0
# current level:  85
#      Number of candidate states:  0
# current level:  86
#      Number of candidate states:  0
# current level:  87
#      Number of candidate states:  0
# current level:  88
#      Number of candidate states:  0
# current level:  89
#      Number of candidate states:  0
# current level:  90
#      Number of candidate states:  0
# current level:  91
#      Number of candidate states:  0
# current level:  92
#      Number of candidate states:  0
# current level:  93
#      Number of candidate states:  0
# current level:  94
#      Number of candidate states:  0
# current level:  95
#      Number of candidate states:  0
# current level:  96
#      Number of candidate states:  0
# current level:  97
#      Number of candidate states:  0
# current level:  98
#      Number of candidate states:  0
# current level:  99
#      Number of candidate states:  0
# current level:  0
#      Number of candidate states:  3
#      Update (after sabre) depth to  81
# current level:  1
#      Number of candidate states:  10
#      Update (after sabre) depth to  76
# current level:  2
#      Number of candidate states:  10
# current level:  3
#      Number of candidate states:  10
# current level:  4
#      Number of candidate states:  10
# current level:  5
#      Number of candidate states:  10
#      Update (after sabre) depth to  73
# current level:  6
#      Number of candidate states:  10
# current level:  7
#      Number of candidate states:  10
# current level:  8
#      Number of candidate states:  10
# current level:  9
#      Number of candidate states:  10
# current level:  10
#      Number of candidate states:  10
# current level:  11
#      Number of candidate states:  10
# current level:  12
#      Number of candidate states:  10
# current level:  13
#      Number of candidate states:  10
# current level:  14
#      Number of candidate states:  10
# current level:  15
#      Number of candidate states:  10
# current level:  16
#      Number of candidate states:  10
# current level:  17
#      Number of candidate states:  10
# current level:  18
#      Number of candidate states:  10
# current level:  19
#      Number of candidate states:  10
# current level:  20
#      Number of candidate states:  10
# current level:  21
#      Number of candidate states:  10
# current level:  22
#      Number of candidate states:  10
# current level:  23
#      Number of candidate states:  10
# current level:  24
#      Number of candidate states:  10
# current level:  25
#      Number of candidate states:  10
# current level:  26
#      Number of candidate states:  10
# current level:  27
#      Number of candidate states:  10
# current level:  28
#      Number of candidate states:  10
# current level:  29
#      Number of candidate states:  10
# current level:  30
#      Number of candidate states:  10
# current level:  31
#      Number of candidate states:  10
# current level:  32
#      Number of candidate states:  10
# current level:  33
#      Number of candidate states:  10
# current level:  34
#      Number of candidate states:  10
# current level:  35
#      Number of candidate states:  10
# current level:  36
#      Number of candidate states:  10
# current level:  37
#      Number of candidate states:  10
# current level:  38
#      Number of candidate states:  10
# current level:  39
#      Number of candidate states:  10
# current level:  40
#      Number of candidate states:  10
# current level:  41
#      Number of candidate states:  10
# current level:  42
#      Number of candidate states:  10
# current level:  43
#      Number of candidate states:  10
# current level:  44
#      Number of candidate states:  10
# current level:  45
#      Number of candidate states:  10
# current level:  46
#      Number of candidate states:  10
# current level:  47
#      Number of candidate states:  10
# current level:  48
#      Number of candidate states:  10
# current level:  49
#      Number of candidate states:  0
# current level:  50
#      Number of candidate states:  0
# current level:  51
#      Number of candidate states:  0
# current level:  52
#      Number of candidate states:  0
# current level:  53
#      Number of candidate states:  0
# current level:  54
#      Number of candidate states:  0
# current level:  55
#      Number of candidate states:  0
# current level:  56
#      Number of candidate states:  0
# current level:  57
#      Number of candidate states:  0
# current level:  58
#      Number of candidate states:  0
# current level:  59
#      Number of candidate states:  0
# current level:  60
#      Number of candidate states:  0
# current level:  61
#      Number of candidate states:  0
# current level:  62
#      Number of candidate states:  0
# current level:  63
#      Number of candidate states:  0
# current level:  64
#      Number of candidate states:  0
# current level:  65
#      Number of candidate states:  0
# current level:  66
#      Number of candidate states:  0
# current level:  67
#      Number of candidate states:  0
# current level:  68
#      Number of candidate states:  0
# current level:  69
#      Number of candidate states:  0
# current level:  70
#      Number of candidate states:  0
# current level:  71
#      Number of candidate states:  0
# current level:  72
#      Number of candidate states:  0
# current level:  73
#      Number of candidate states:  0
# current level:  74
#      Number of candidate states:  0
# current level:  75
#      Number of candidate states:  0
# current level:  76
#      Number of candidate states:  0
# current level:  77
#      Number of candidate states:  0
# current level:  78
#      Number of candidate states:  0
# current level:  79
#      Number of candidate states:  0
# current level:  80
#      Number of candidate states:  0
# current level:  81
#      Number of candidate states:  0
# current level:  82
#      Number of candidate states:  0
# current level:  83
#      Number of candidate states:  0
# current level:  84
#      Number of candidate states:  0
# current level:  85
#      Number of candidate states:  0
# current level:  86
#      Number of candidate states:  0
# current level:  87
#      Number of candidate states:  0
# current level:  88
#      Number of candidate states:  0
# current level:  89
#      Number of candidate states:  0
# current level:  90
#      Number of candidate states:  0
# current level:  91
#      Number of candidate states:  0
# current level:  92
#      Number of candidate states:  0
# current level:  93
#      Number of candidate states:  0
# current level:  94
#      Number of candidate states:  0
# current level:  95
#      Number of candidate states:  0
# current level:  96
#      Number of candidate states:  0
# current level:  97
#      Number of candidate states:  0
# current level:  98
#      Number of candidate states:  0
# current level:  99
#      Number of candidate states:  0
# current level:  0
#      Number of candidate states:  4
#      Update (after sabre) depth to  66
#      Update (after sabre) depth to  65
# current level:  1
#      Number of candidate states:  10
#      Update (after sabre) depth to  64
# current level:  2
#      Number of candidate states:  10
#      Update (after sabre) depth to  61
# current level:  3
#      Number of candidate states:  10
# current level:  4
#      Number of candidate states:  10
# current level:  5
#      Number of candidate states:  10
#      Update (after sabre) depth to  60
# current level:  6
#      Number of candidate states:  10
# current level:  7
#      Number of candidate states:  10
#      Update (after sabre) depth to  58
# current level:  8
#      Number of candidate states:  10
# current level:  9
#      Number of candidate states:  10
# current level:  10
#      Number of candidate states:  10
# current level:  11
#      Number of candidate states:  10
#      Update (after sabre) depth to  57
# current level:  12
#      Number of candidate states:  10
#      Update (after sabre) depth to  56
# current level:  13
#      Number of candidate states:  10
# current level:  14
#      Number of candidate states:  10
# current level:  15
#      Number of candidate states:  10
# current level:  16
#      Number of candidate states:  10
# current level:  17
#      Number of candidate states:  10
#      Update (after sabre) depth to  55
# current level:  18
#      Number of candidate states:  10
# current level:  19
#      Number of candidate states:  10
# current level:  20
#      Number of candidate states:  10
# current level:  21
#      Number of candidate states:  10
# current level:  22
#      Number of candidate states:  10
# current level:  23
#      Number of candidate states:  10
# current level:  24
#      Number of candidate states:  10
# current level:  25
#      Number of candidate states:  10
# current level:  26
#      Number of candidate states:  10
# current level:  27
#      Number of candidate states:  10
# current level:  28
#      Number of candidate states:  10
# current level:  29
#      Number of candidate states:  10
# current level:  30
#      Number of candidate states:  10
# current level:  31
#      Number of candidate states:  10
# current level:  32
#      Number of candidate states:  10
# current level:  33
#      Number of candidate states:  10
# current level:  34
#      Number of candidate states:  10
# current level:  35
#      Number of candidate states:  10
# current level:  36
#      Number of candidate states:  10
# current level:  37
#      Number of candidate states:  10
# current level:  38
#      Number of candidate states:  10
# current level:  39
#      Number of candidate states:  10
# current level:  40
#      Number of candidate states:  10
# current level:  41
#      Number of candidate states:  10
# current level:  42
# ...
# current level:  21
#      Number of candidate states:  9
# current level:  22
#      Number of candidate states:  9
# current level:  23
#      Number of candidate states:  9
# current level:  24
#      Number of candidate states:  9
# current level:  25
#      Number of candidate states:  9
# current level:  26
#      Number of candidate states:  9
# current level:  27
#      Number of candidate states:  9
# current level:  28
#      Number of candidate states:  9
# current level:  29
#      Number of candidate states:  9
# current level:  30
#      Number of candidate states:  9
# current level:  31
#      Number of candidate states:  9
# current level:  32
#      Number of candidate states:  9
# current level:  33
#      Number of candidate states:  9
# current level:  34
#      Number of candidate states:  9
# current level:  35
#      Number of candidate states:  9
# current level:  36
#      Number of candidate states:  9
# current level:  37
#      Number of candidate states:  9
# current level:  38
#      Number of candidate states:  9
# current level:  39
#      Number of candidate states:  9
# current level:  40
#      Number of candidate states:  9
# current level:  41
#      Number of candidate states:  9
# current level:  42
#      Number of candidate states:  9
# current level:  43
#      Number of candidate states:  9
# current level:  44
#      Number of candidate states:  9
# current level:  45
#      Number of candidate states:  9
# current level:  46
#      Number of candidate states:  9
# current level:  47
#      Number of candidate states:  9
# current level:  48
#      Number of candidate states:  9
# current level:  49
#      Number of candidate states:  9
# current level:  50
#      Number of candidate states:  9
# current level:  51
#      Number of candidate states:  9
# current level:  52
#      Number of candidate states:  0
# current level:  53
#      Number of candidate states:  0
# current level:  54
#      Number of candidate states:  0
# current level:  55
#      Number of candidate states:  0
# current level:  56
#      Number of candidate states:  0
# current level:  57
#      Number of candidate states:  0
# current level:  58
#      Number of candidate states:  0
# current level:  59
#      Number of candidate states:  0
# current level:  60
#      Number of candidate states:  0
# current level:  61
#      Number of candidate states:  0
# current level:  62
#      Number of candidate states:  0
# current level:  63
#      Number of candidate states:  0
# current level:  64
#      Number of candidate states:  0
# current level:  65
#      Number of candidate states:  0
# current level:  66
#      Number of candidate states:  0
# current level:  67
#      Number of candidate states:  0
# current level:  68
#      Number of candidate states:  0
# current level:  69
#      Number of candidate states:  0
# current level:  70
#      Number of candidate states:  0
# current level:  71
#      Number of candidate states:  0
# current level:  72
#      Number of candidate states:  0
# current level:  73
#      Number of candidate states:  0
# current level:  74
#      Number of candidate states:  0
# current level:  75
#      Number of candidate states:  0
# current level:  76
#      Number of candidate states:  0
# current level:  77
#      Number of candidate states:  0
# current level:  78
#      Number of candidate states:  0
# current level:  79
#      Number of candidate states:  0
# current level:  80
#      Number of candidate states:  0
# current level:  81
#      Number of candidate states:  0
# current level:  82
#      Number of candidate states:  0
# current level:  83
#      Number of candidate states:  0
# current level:  84
#      Number of candidate states:  0
# current level:  85
#      Number of candidate states:  0
# current level:  86
#      Number of candidate states:  0
# current level:  87
#      Number of candidate states:  0
# current level:  88
#      Number of candidate states:  0
# current level:  89
#      Number of candidate states:  0
# current level:  90
#      Number of candidate states:  0
# current level:  91
#      Number of candidate states:  0
# current level:  92
#      Number of candidate states:  0
# current level:  93
#      Number of candidate states:  0
# current level:  94
#      Number of candidate states:  0
# current level:  95
#      Number of candidate states:  0
# current level:  96
#      Number of candidate states:  0
# current level:  97
#      Number of candidate states:  0
# current level:  98
#      Number of candidate states:  0
# current level:  99
#      Number of candidate states:  0
# current level:  0
#      Number of candidate states:  6
#      Update (after sabre) depth to  67
#      Update (after sabre) depth to  57
# current level:  1
#      Number of candidate states:  9
# current level:  2
#      Number of candidate states:  9
# current level:  3
#      Number of candidate states:  9
#      Update (after sabre) depth to  55
# current level:  4
#      Number of candidate states:  9
# current level:  5
#      Number of candidate states:  9
# current level:  6
#      Number of candidate states:  9
# current level:  7
#      Number of candidate states:  9
# current level:  8
#      Number of candidate states:  9
# current level:  9
#      Number of candidate states:  9
# current level:  10
#      Number of candidate states:  9
# current level:  11
#      Number of candidate states:  9
# current level:  12
#      Number of candidate states:  9
# current level:  13
#      Number of candidate states:  9
# current level:  14
#      Number of candidate states:  9
# current level:  15
#      Number of candidate states:  9
# current level:  16
#      Number of candidate states:  9
# current level:  17
#      Number of candidate states:  9
# current level:  18
#      Number of candidate states:  9
# current level:  19
#      Number of candidate states:  9
# current level:  20
#      Number of candidate states:  9
# current level:  21
#      Number of candidate states:  9
# current level:  22
#      Number of candidate states:  9
# current level:  23
#      Number of candidate states:  9
# current level:  24
#      Number of candidate states:  9
# current level:  25
#      Number of candidate states:  9
# current level:  26
#      Number of candidate states:  9
# current level:  27
#      Number of candidate states:  9
# current level:  28
#      Number of candidate states:  9
# current level:  29
#      Number of candidate states:  9
# current level:  30
#      Number of candidate states:  9
# current level:  31
#      Number of candidate states:  9
# current level:  32
#      Number of candidate states:  9
# current level:  33
#      Number of candidate states:  9
# current level:  34
#      Number of candidate states:  9
# current level:  35
#      Number of candidate states:  9
# current level:  36
#      Number of candidate states:  9
# current level:  37
#      Number of candidate states:  9
# current level:  38
#      Number of candidate states:  9
# current level:  39
#      Number of candidate states:  9
# current level:  40
#      Number of candidate states:  9
# current level:  41
#      Number of candidate states:  9
# current level:  42
#      Number of candidate states:  9
# current level:  43
#      Number of candidate states:  9
# current level:  44
#      Number of candidate states:  9
# current level:  45
#      Number of candidate states:  9
# current level:  46
#      Number of candidate states:  9
# current level:  47
#      Number of candidate states:  9
# current level:  48
#      Number of candidate states:  7
# current level:  49
#      Number of candidate states:  9
# current level:  50
#      Number of candidate states:  9
# current level:  51
#      Number of candidate states:  9
# current level:  52
#      Number of candidate states:  0
# current level:  53
#      Number of candidate states:  0
# current level:  54
#      Number of candidate states:  0
# current level:  55
#      Number of candidate states:  0
# current level:  56
#      Number of candidate states:  0
# current level:  57
#      Number of candidate states:  0
# current level:  58
#      Number of candidate states:  0
# current level:  59
#      Number of candidate states:  0
# current level:  60
#      Number of candidate states:  0
# current level:  61
#      Number of candidate states:  0
# current level:  62
#      Number of candidate states:  0
# current level:  63
#      Number of candidate states:  0
# current level:  64
#      Number of candidate states:  0
# current level:  65
#      Number of candidate states:  0
# current level:  66
#      Number of candidate states:  0
# current level:  67
#      Number of candidate states:  0
# current level:  68
#      Number of candidate states:  0
# current level:  69
#      Number of candidate states:  0
# current level:  70
#      Number of candidate states:  0
# current level:  71
#      Number of candidate states:  0
# current level:  72
#      Number of candidate states:  0
# current level:  73
#      Number of candidate states:  0
# current level:  74
#      Number of candidate states:  0
# current level:  75
#      Number of candidate states:  0
# current level:  76
#      Number of candidate states:  0
# current level:  77
#      Number of candidate states:  0
# current level:  78
#      Number of candidate states:  0
# current level:  79
#      Number of candidate states:  0
# current level:  80
#      Number of candidate states:  0
# current level:  81
#      Number of candidate states:  0
# current level:  82
#      Number of candidate states:  0
# current level:  83
#      Number of candidate states:  0
# current level:  84
#      Number of candidate states:  0
# current level:  85
#      Number of candidate states:  0
# current level:  86
#      Number of candidate states:  0
# current level:  87
#      Number of candidate states:  0
# current level:  88
#      Number of candidate states:  0
# current level:  89
#      Number of candidate states:  0
# current level:  90
#      Number of candidate states:  0
# current level:  91
#      Number of candidate states:  0
# current level:  92
#      Number of candidate states:  0
# current level:  93
#      Number of candidate states:  0
# current level:  94
#      Number of candidate states:  0
# current level:  95
#      Number of candidate states:  0
# current level:  96
#      Number of candidate states:  0
# current level:  97
#      Number of candidate states:  0
# current level:  98
#      Number of candidate states:  0
# current level:  99
#      Number of candidate states:  0
# current level:  0
#      Number of candidate states:  6
#      Update (after sabre) depth to  69
#      Update (after sabre) depth to  68
# current level:  1
#      Number of candidate states:  9
# current level:  2
#      Number of candidate states:  9
# current level:  3
#      Number of candidate states:  9
# current level:  4
#      Number of candidate states:  9
# current level:  5
#      Number of candidate states:  9
#      Update (after sabre) depth to  67
# current level:  6
#      Number of candidate states:  9
# current level:  7
#      Number of candidate states:  9
# current level:  8
#      Number of candidate states:  9
#      Update (after sabre) depth to  66
# current level:  9
#      Number of candidate states:  9
# current level:  10
#      Number of candidate states:  9
#      Update (after sabre) depth to  62
#      Update (after sabre) depth to  61
# current level:  11
#      Number of candidate states:  9
# current level:  12
#      Number of candidate states:  9
# current level:  13
#      Number of candidate states:  9
# current level:  14
#      Number of candidate states:  9
# current level:  15
#      Number of candidate states:  9
# current level:  16
#      Number of candidate states:  9
#      Update (after sabre) depth to  60
# current level:  17
#      Number of candidate states:  9
# current level:  18
#      Number of candidate states:  9
# current level:  19
#      Number of candidate states:  9
# current level:  20
#      Number of candidate states:  9
# current level:  21
#      Number of candidate states:  9
# current level:  22
#      Number of candidate states:  9
# current level:  23
#      Number of candidate states:  9
# current level:  24
#      Number of candidate states:  9
# current level:  25
#      Number of candidate states:  9
# current level:  26
#      Number of candidate states:  9
# current level:  27
#      Number of candidate states:  9
# current level:  28
#      Number of candidate states:  9
# current level:  29
#      Number of candidate states:  9
# current level:  30
#      Number of candidate states:  9
# current level:  31
#      Number of candidate states:  9
# current level:  32
#      Number of candidate states:  9
# current level:  33
#      Number of candidate states:  9
# current level:  34
#      Number of candidate states:  9
# current level:  35
#      Number of candidate states:  9
# current level:  36
#      Number of candidate states:  9
# current level:  37
#      Number of candidate states:  9
#      Update (after sabre) depth to  59
# current level:  38
#      Number of candidate states:  9
# current level:  39
#      Number of candidate states:  9
# current level:  40
#      Number of candidate states:  9
# current level:  41
#      Number of candidate states:  9
# current level:  42
#      Number of candidate states:  9
# current level:  43
#      Number of candidate states:  9
# current level:  44
#      Number of candidate states:  9
# current level:  45
#      Number of candidate states:  9
# current level:  46
#      Number of candidate states:  9
# current level:  47
#      Number of candidate states:  9
# current level:  48
#      Number of candidate states:  9
# current level:  49
#      Number of candidate states:  9
# current level:  50
#      Number of candidate states:  9
# current level:  51
#      Number of candidate states:  9
# current level:  52
#      Number of candidate states:  9
# current level:  53
#      Number of candidate states:  9
# current level:  54
#      Number of candidate states:  9
# current level:  55
#      Number of candidate states:  9
# current level:  56
#      Number of candidate states:  9
# current level:  57
#      Number of candidate states:  9
# current level:  58
#      Number of candidate states:  9
# current level:  59
#      Number of candidate states:  6
# current level:  60
#      Number of candidate states:  0
# current level:  61
#      Number of candidate states:  0
# current level:  62
#      Number of candidate states:  0
# current level:  63
#      Number of candidate states:  0
# current level:  64
#      Number of candidate states:  0
# current level:  65
#      Number of candidate states:  0
# current level:  66
#      Number of candidate states:  0
# current level:  67
#      Number of candidate states:  0
# current level:  68
#      Number of candidate states:  0
# current level:  69
#      Number of candidate states:  0
# current level:  70
#      Number of candidate states:  0
# current level:  71
#      Number of candidate states:  0
# current level:  72
#      Number of candidate states:  0
# current level:  73
#      Number of candidate states:  0
# current level:  74
#      Number of candidate states:  0
# current level:  75
#      Number of candidate states:  0
# current level:  76
#      Number of candidate states:  0
# current level:  77
#      Number of candidate states:  0
# current level:  78
#      Number of candidate states:  0
# current level:  79
#      Number of candidate states:  0
# current level:  80
#      Number of candidate states:  0
# current level:  81
#      Number of candidate states:  0
# current level:  82
#      Number of candidate states:  0
# current level:  83
#      Number of candidate states:  0
# current level:  84
#      Number of candidate states:  0
# current level:  85
#      Number of candidate states:  0
# current level:  86
#      Number of candidate states:  0
# current level:  87
#      Number of candidate states:  0
# current level:  88
#      Number of candidate states:  0
# current level:  89
#      Number of candidate states:  0
# current level:  90
#      Number of candidate states:  0
# current level:  91
#      Number of candidate states:  0
# current level:  92
#      Number of candidate states:  0
# current level:  93
#      Number of candidate states:  0
# current level:  94
#      Number of candidate states:  0
# current level:  95
#      Number of candidate states:  0
# current level:  96
#      Number of candidate states:  0
# current level:  97
#      Number of candidate states:  0
# current level:  98
#      Number of candidate states:  0
# current level:  99
#      Number of candidate states:  0
#     Finished 0 for experiment sabre_v020_dive_009 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_009 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive_test.csv
# **************************************************
