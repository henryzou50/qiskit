# %% [markdown]
# # Rename gates
# This notebook is used to rename gates in the qasm files so that it is more readible.

# %%
from ulti.circuits import get_circuit_list, sort_circuits_by_depth, update_qasm_file

# %% [markdown]
# Update file

# %%
path = "circuits/size5_depth_1-10/qv_size5_depth9.qasm"
update_qasm_file(path)
# Out:
# Updated .qasm file: circuits/size5_depth_1-10/qv_size5_depth9.qasm

# %% [markdown]
# Visualize update

# %%
qc_name = "size5_depth_1-10"
circuits = get_circuit_list([f'circuits/{qc_name}/'])
circuits = sort_circuits_by_depth(circuits)

# draw circuit
qc = circuits[2].decompose()
qc.draw(output='mpl')
# Out:
# /Users/henryzou/Documents/GitHub/qiskit/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)
