# %% [markdown]
# This notebook runs a single experiment for `SabreSwap` with lookahead. Note that you will need to change the file of `sabre_swap_v020_lookahead.py` to adjust the parameters for lookahead.

# %%
from qiskit.transpiler.passes.routing.sabre_swap_v020_lookahead import SabreSwap
from qiskit.transpiler.passes.layout.sabre_layout_v020 import SabreLayout
from ulti.circuits import get_circuit_list, sort_circuits_by_depth
from ulti.coupling_maps import file_to_coupling_map
from ulti.pass_managers import generate_pass_managers, transpiled_data
import pandas as pd
from ast import literal_eval
import matplotlib.pyplot as plt
import random
random.seed(42)
import os

# %%
# Variables to change
qc_name = "size5_depth_100-500"

experiment_name = "sabre_look_test"
version = "20" # version for the routing pass after _v0.
lp_name = "sabre_0.20"
cp_name = "hex_7"

fast_layout = True

# %%
num_shots = 3
rp = SabreSwap
lp = SabreLayout
cm = file_to_coupling_map(f'coupling_maps/{cp_name}.txt')
pm = generate_pass_managers(num_shots, rp, lp, cm, fast_layout=fast_layout, lookahead=20)


rp_name = experiment_name + "_v0." + version
qc_list = get_circuit_list([f'circuits/{qc_name}/'])
qc_list = sort_circuits_by_depth(qc_list)

csv_file_path = f'data/test_20_0.csv'

# %%
qc = qc_list[0]
label = qc.decompose().depth()
print(label)
# Out:
# 100

# %%
data_list = []
data = transpiled_data(qc, pm)
data['routing pass'] = rp_name
data['layout pass'] = lp_name
data['coupling map'] = cp_name
data['circuit label'] = label
data_list.append(data)
print("Finished all")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/henryzou/Documents/GitHub/qiskit/workspace/run_experiment_single_qvol_500.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/Users/henryzou/Documents/GitHub/qiskit/workspace/run_experiment_single_qvol_500.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> data_list = []
# ----> <a href='vscode-notebook-cell:/Users/henryzou/Documents/GitHub/qiskit/workspace/run_experiment_single_qvol_500.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> data = transpiled_data(qc, pm)
#       <a href='vscode-notebook-cell:/Users/henryzou/Documents/GitHub/qiskit/workspace/run_experiment_single_qvol_500.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> data['routing pass'] = rp_name
#       <a href='vscode-notebook-cell:/Users/henryzou/Documents/GitHub/qiskit/workspace/run_experiment_single_qvol_500.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> data['layout pass'] = lp_name
#
# File ~/Documents/GitHub/qiskit/workspace/ulti/pass_managers.py:119, in transpiled_data(qc, pass_managers)
#     117 for pm in pass_managers:
#     118     time_start = time.time()
# --> 119     qc_tr = pm.run(qc)
#     120     time_end = time.time()
#     121     time_elapsed = time_end - time_start
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:551, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     548 @wraps(meth)
#     549 def wrapper(*meth_args, **meth_kwargs):
#     550     try:
# --> 551         return meth(*meth_args, **meth_kwargs)
#     552     except PassManagerError as ex:
#     553         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:291, in PassManager.run(self, circuits, output_name, callback)
#     288 if callback is not None:
#     289     callback = _legacy_style_callback(callback)
# --> 291 return super().run(
#     292     in_programs=circuits,
#     293     callback=callback,
#     294     output_name=output_name,
#     295 )
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:222, in BasePassManager.run(self, in_programs, callback, **kwargs)
#     219     is_list = False
#     221 if len(in_programs) == 1:
# --> 222     out_program = _run_workflow(
#     223         program=in_programs[0],
#     224         pass_manager=self,
#     225         callback=callback,
#     226         **kwargs,
#     227     )
#     228     if is_list:
#     229         return [out_program]
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:284, in _run_workflow(program, pass_manager, **kwargs)
#     278 initial_status = WorkflowStatus()
#     280 passmanager_ir = pass_manager._passmanager_frontend(
#     281     input_program=program,
#     282     **kwargs,
#     283 )
# --> 284 passmanager_ir, _ = flow_controller.execute(
#     285     passmanager_ir=passmanager_ir,
#     286     state=PassManagerState(
#     287         workflow_status=initial_status,
#     288         property_set=pass_manager.property_set,
#     289     ),
#     290     callback=kwargs.get("callback", None),
#     291 )
#     292 out_program = pass_manager._passmanager_backend(
#     293     passmanager_ir=passmanager_ir,
#     294     in_program=program,
#     295     **kwargs,
#     296 )
#     298 return out_program
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/runningpassmanager.py:161, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     158 @wraps(meth)
#     159 def wrapper(*meth_args, **meth_kwargs):
#     160     try:
# --> 161         return meth(*meth_args, **meth_kwargs)
#     162     except PassManagerError as ex:
#     163         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:218, in BaseController.execute(self, passmanager_ir, state, callback)
#     216     return passmanager_ir, state
#     217 while True:
# --> 218     passmanager_ir, state = next_task.execute(
#     219         passmanager_ir=passmanager_ir,
#     220         state=state,
#     221         callback=callback,
#     222     )
#     223     try:
#     224         # Sending the object through the generator implies the custom controllers
#     225         # can always rely on the latest data to choose the next task to run.
#     226         next_task = task_generator.send(state)
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/basepasses.py:195, in TransformationPass.execute(self, passmanager_ir, state, callback)
#     189 def execute(
#     190     self,
#     191     passmanager_ir: PassManagerIR,
#     192     state: PassManagerState,
#     193     callback: Callable = None,
#     194 ) -> tuple[PassManagerIR, PassManagerState]:
# --> 195     new_dag, state = super().execute(
#     196         passmanager_ir=passmanager_ir,
#     197         state=state,
#     198         callback=callback,
#     199     )
#     201     if state.workflow_status.previous_run == RunState.SUCCESS:
#     202         if isinstance(new_dag, DAGCircuit):
#     203             # Copy calibration data from the original program
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:98, in GenericPass.execute(self, passmanager_ir, state, callback)
#      96 try:
#      97     if self not in state.workflow_status.completed_passes:
# ---> 98         ret = self.run(passmanager_ir)
#      99         run_state = RunState.SUCCESS
#     100     else:
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v020_lookahead.py:220, in SabreSwap.run(self, dag)
#     215 max_score_gates = 0
#     216 while queue:
#     217     # length of gates_to_execute is the gate score (does not contain swaps)
#     218     # all_gate contains all of the gates in DAGOpNode form
#     219     q_front_layer, q_current_layout, q_swap_sequence, predecessors, gates_order, \
# --> 220         score_front, gates_to_execute, all_gates, step = queue.pop(0)
#     222     # exploring all swap candidates at this depth and then adding the next layer to the queue
#     223     if step <= self.lookahead_steps:
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(data_list)
df.to_csv(csv_file_path, index=False)
df
# Out:
#                                            best_data  \
# 0  {'depth': 406, 'depth_ratio': 4.06, 'time': 72...
#
#                                              std_dev           routing pass  \
# 0  {'depth': 10.78, 'depth_ratio': 0.1078, 'time'...  sabre_look_test_v0.20
#
#   layout pass coupling map  circuit label
# 0  sabre_0.20        hex_7            100

# %%
data = pd.read_csv(csv_file_path)

# Convert the string representation of dictionaries into actual dictionaries
data['best_data'] = data['best_data'].apply(literal_eval)
data['std_dev'] = data['std_dev'].apply(literal_eval)

# Extract the data from the 'best_data' and 'std_dev' columns and add them to the DataFrame
for col in ['depth', 'depth_ratio', 'time', 'cx_gates', 'num_gates']:
    data[f"best_{col}"] = data['best_data'].apply(lambda x: x[col])
    data[f"std_dev_{col}"] = data['std_dev'].apply(lambda x: x[col])

metrics = [
    ("depth", "Depth"),
    ("cx_gates", "CX Gates"),
    ("num_gates", "Number of Gates"),
    ("time", "Time"),
    ("depth_ratio", "Depth Ratio")
]

unique_routing_layout_combinations = data[['routing pass', 'layout pass']].drop_duplicates().values

for metric, label in metrics:
    plt.figure(figsize=(10, 6))
    for routing_pass, layout_pass in unique_routing_layout_combinations:
        subset = data[(data['routing pass'] == routing_pass) & (data['layout pass'] == layout_pass)]
        plt.errorbar(subset['circuit label'], subset[f"best_{metric}"], yerr=subset[f"std_dev_{metric}"], fmt='o-', label=f'Routing: {routing_pass}, Layout: {layout_pass}')
    plt.xlabel('Circuit Label')
    plt.ylabel('Value')
    plt.title(f'Comparison of Circuit {label} for Coupling Map: {data["coupling map"].iloc[0]}')
    plt.legend()
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.tight_layout()
    #plt.savefig(f"data/graphs/{qc_name}/{experiment_name}_v0{version}/{label.replace(' ', '_').lower()}.png")
    plt.show()
    plt.close()
