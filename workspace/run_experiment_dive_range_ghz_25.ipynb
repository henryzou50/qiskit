# %% [markdown]
# This code runs the experiment for SabreSwap v0.25 and SabreLayout v0.25

# %%
from qiskit.transpiler.passes.routing.sabre_swap_v020_dive   import SabreSwap   as SabreSwap_v020
from qiskit.transpiler.passes.layout.sabre_layout                 import SabreLayout as SabreLayout_v045
from qiskit.transpiler.passes.layout.sabre_layout_v020            import SabreLayout as SabreLayout_v020
from ulti.circuits import get_circuit_list, sort_circuits_by_depth
from ulti.coupling_maps import file_to_coupling_map
from ulti.pass_managers import generate_pass_managers, transpiled_data
import pandas as pd
import random
random.seed(42)
import os

# %%
# Option to keep the layout inital layout the same for faster transpilation
fast_layout = False
num_shots = 5
qc_name = "ghz_25"
cp_name = "hex_27"
print(f"Running experiment for the circuits: {qc_name}")
qc_list = get_circuit_list([f'circuits/{qc_name}/'])
qc_list = sort_circuits_by_depth(qc_list)

csv_file_path = f'data/{qc_name}/sabre_v020_dive.csv'
directory = f'data/{qc_name}'
if not os.path.exists(directory):
        os.makedirs(directory)
# Out:
# Running experiment for the circuits: ghz_25

# %%
# Test beam_width from 1
beam_width = list(range(1, 1000))
all_data_df = pd.DataFrame()
for beam in beam_width:
    print(f"Running experiment for dive {beam}")
    # Experiment for Sabre v0.20 with lookahead heuristic
    # set beam to max integer
    lp_name = "sabre_v020"
    if beam < 10:
        rp_name = f"sabre_v020_dive_00{beam}"
    elif beam < 100:
        rp_name = f"sabre_v020_dive_0{beam}"
    else:
        rp_name = f"sabre_v020_dive_{beam}"

    rp = SabreSwap_v020
    lp = SabreLayout_v020
    cm = file_to_coupling_map(f'coupling_maps/{cp_name}.txt')
    pm = generate_pass_managers(num_shots, rp, lp, cm, beam_width = beam, 
                                fast_layout=fast_layout)

    for qc_idx, qc in enumerate(qc_list):
        data = transpiled_data(qc, pm)
        data['routing pass'] = rp_name
        data['layout pass'] = lp_name
        data['coupling map'] = cp_name
        data['circuit label'] = qc_idx
        data['beam width'] = beam
        data['look ahead'] = 0
        
        # Create a DataFrame from the current data and append it to the all_data_df
        current_data_df = pd.DataFrame([data])
        all_data_df = pd.concat([all_data_df, current_data_df])

        # Append the current data to the CSV file
        with open(csv_file_path, 'a') as f:
            current_data_df.to_csv(f, header=f.tell()==0, index=False)

        print(f"    Finished {qc_idx} for experiment {rp_name} and circuit {qc_name}")

    print(f"Finished all for experiment {rp_name} and circuit {qc_name}")
    print(f"Saved to {csv_file_path}")
    print("*" * 50)
# Out:
# Running experiment for dive 1
#     Finished 0 for experiment sabre_v020_dive_001 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_001 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 2
#     Finished 0 for experiment sabre_v020_dive_002 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_002 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 3
#     Finished 0 for experiment sabre_v020_dive_003 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_003 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 4
#     Finished 0 for experiment sabre_v020_dive_004 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_004 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 5
#     Finished 0 for experiment sabre_v020_dive_005 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_005 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 6
#     Finished 0 for experiment sabre_v020_dive_006 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_006 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 7
#     Finished 0 for experiment sabre_v020_dive_007 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_007 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 8
#     Finished 0 for experiment sabre_v020_dive_008 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_008 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 9
#     Finished 0 for experiment sabre_v020_dive_009 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_009 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 10
#     Finished 0 for experiment sabre_v020_dive_010 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_010 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 11
#     Finished 0 for experiment sabre_v020_dive_011 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_011 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 12
#     Finished 0 for experiment sabre_v020_dive_012 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_012 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 13
#     Finished 0 for experiment sabre_v020_dive_013 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_013 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 14
#     Finished 0 for experiment sabre_v020_dive_014 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_014 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 15
#     Finished 0 for experiment sabre_v020_dive_015 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_015 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 16
#     Finished 0 for experiment sabre_v020_dive_016 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_016 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 17
#     Finished 0 for experiment sabre_v020_dive_017 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_017 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 18
#     Finished 0 for experiment sabre_v020_dive_018 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_018 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 19
#     Finished 0 for experiment sabre_v020_dive_019 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_019 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 20
#     Finished 0 for experiment sabre_v020_dive_020 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_020 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 21
#     Finished 0 for experiment sabre_v020_dive_021 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_021 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 22
#     Finished 0 for experiment sabre_v020_dive_022 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_022 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 23
#     Finished 0 for experiment sabre_v020_dive_023 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_023 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 24
#     Finished 0 for experiment sabre_v020_dive_024 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_024 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 25
#     Finished 0 for experiment sabre_v020_dive_025 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_025 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 26
#     Finished 0 for experiment sabre_v020_dive_026 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_026 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 27
#     Finished 0 for experiment sabre_v020_dive_027 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_027 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 28
#     Finished 0 for experiment sabre_v020_dive_028 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_028 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 29
#     Finished 0 for experiment sabre_v020_dive_029 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_029 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 30
#     Finished 0 for experiment sabre_v020_dive_030 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_030 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 31
#     Finished 0 for experiment sabre_v020_dive_031 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_031 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 32
#     Finished 0 for experiment sabre_v020_dive_032 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_032 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 33
#     Finished 0 for experiment sabre_v020_dive_033 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_033 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 34
#     Finished 0 for experiment sabre_v020_dive_034 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_034 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 35
#     Finished 0 for experiment sabre_v020_dive_035 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_035 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 36
#     Finished 0 for experiment sabre_v020_dive_036 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_036 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 37
#     Finished 0 for experiment sabre_v020_dive_037 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_037 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 38
#     Finished 0 for experiment sabre_v020_dive_038 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_038 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 39
#     Finished 0 for experiment sabre_v020_dive_039 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_039 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 40
#     Finished 0 for experiment sabre_v020_dive_040 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_040 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 41
#     Finished 0 for experiment sabre_v020_dive_041 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_041 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 42
#     Finished 0 for experiment sabre_v020_dive_042 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_042 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 43
#     Finished 0 for experiment sabre_v020_dive_043 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_043 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 44
#     Finished 0 for experiment sabre_v020_dive_044 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_044 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 45
#     Finished 0 for experiment sabre_v020_dive_045 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_045 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 46
#     Finished 0 for experiment sabre_v020_dive_046 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_046 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 47
#     Finished 0 for experiment sabre_v020_dive_047 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_047 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 48
#     Finished 0 for experiment sabre_v020_dive_048 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_048 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 49
#     Finished 0 for experiment sabre_v020_dive_049 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_049 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 50
#     Finished 0 for experiment sabre_v020_dive_050 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_050 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 51
#     Finished 0 for experiment sabre_v020_dive_051 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_051 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 52
#     Finished 0 for experiment sabre_v020_dive_052 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_052 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 53
#     Finished 0 for experiment sabre_v020_dive_053 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_053 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 54
#     Finished 0 for experiment sabre_v020_dive_054 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_054 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 55
#     Finished 0 for experiment sabre_v020_dive_055 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_055 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 56
#     Finished 0 for experiment sabre_v020_dive_056 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_056 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 57
#     Finished 0 for experiment sabre_v020_dive_057 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_057 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 58
#     Finished 0 for experiment sabre_v020_dive_058 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_058 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 59
#     Finished 0 for experiment sabre_v020_dive_059 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_059 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 60
#     Finished 0 for experiment sabre_v020_dive_060 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_060 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 61
#     Finished 0 for experiment sabre_v020_dive_061 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_061 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 62
#     Finished 0 for experiment sabre_v020_dive_062 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_062 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 63
#     Finished 0 for experiment sabre_v020_dive_063 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_063 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 64
#     Finished 0 for experiment sabre_v020_dive_064 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_064 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 65
#     Finished 0 for experiment sabre_v020_dive_065 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_065 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 66
#     Finished 0 for experiment sabre_v020_dive_066 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_066 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 67
#     Finished 0 for experiment sabre_v020_dive_067 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_067 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 68
#     Finished 0 for experiment sabre_v020_dive_068 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_068 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 69
#     Finished 0 for experiment sabre_v020_dive_069 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_069 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 70
#     Finished 0 for experiment sabre_v020_dive_070 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_070 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 71
#     Finished 0 for experiment sabre_v020_dive_071 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_071 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 72
#     Finished 0 for experiment sabre_v020_dive_072 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_072 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 73
#     Finished 0 for experiment sabre_v020_dive_073 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_073 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 74
#     Finished 0 for experiment sabre_v020_dive_074 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_074 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 75
#     Finished 0 for experiment sabre_v020_dive_075 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_075 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 76
#     Finished 0 for experiment sabre_v020_dive_076 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_076 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 77
#     Finished 0 for experiment sabre_v020_dive_077 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_077 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 78
#     Finished 0 for experiment sabre_v020_dive_078 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_078 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 79
#     Finished 0 for experiment sabre_v020_dive_079 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_079 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 80
#     Finished 0 for experiment sabre_v020_dive_080 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_080 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 81
#     Finished 0 for experiment sabre_v020_dive_081 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_081 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 82
#     Finished 0 for experiment sabre_v020_dive_082 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_082 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 83
#     Finished 0 for experiment sabre_v020_dive_083 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_083 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 84
#     Finished 0 for experiment sabre_v020_dive_084 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_084 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 85
#     Finished 0 for experiment sabre_v020_dive_085 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_085 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 86
#     Finished 0 for experiment sabre_v020_dive_086 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_086 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 87
#     Finished 0 for experiment sabre_v020_dive_087 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_087 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 88
#     Finished 0 for experiment sabre_v020_dive_088 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_088 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 89
#     Finished 0 for experiment sabre_v020_dive_089 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_089 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 90
#     Finished 0 for experiment sabre_v020_dive_090 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_090 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 91
#     Finished 0 for experiment sabre_v020_dive_091 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_091 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 92
#     Finished 0 for experiment sabre_v020_dive_092 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_092 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 93
#     Finished 0 for experiment sabre_v020_dive_093 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_093 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 94
#     Finished 0 for experiment sabre_v020_dive_094 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_094 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 95
#     Finished 0 for experiment sabre_v020_dive_095 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_095 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 96
#     Finished 0 for experiment sabre_v020_dive_096 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_096 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 97
#     Finished 0 for experiment sabre_v020_dive_097 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_097 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 98
#     Finished 0 for experiment sabre_v020_dive_098 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_098 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 99
#     Finished 0 for experiment sabre_v020_dive_099 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_099 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 100
#     Finished 0 for experiment sabre_v020_dive_100 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_100 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 101
#     Finished 0 for experiment sabre_v020_dive_101 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_101 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 102
#     Finished 0 for experiment sabre_v020_dive_102 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_102 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 103
#     Finished 0 for experiment sabre_v020_dive_103 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_103 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 104
#     Finished 0 for experiment sabre_v020_dive_104 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_104 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 105
#     Finished 0 for experiment sabre_v020_dive_105 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_105 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 106
#     Finished 0 for experiment sabre_v020_dive_106 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_106 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 107
#     Finished 0 for experiment sabre_v020_dive_107 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_107 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 108
#     Finished 0 for experiment sabre_v020_dive_108 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_108 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 109
#     Finished 0 for experiment sabre_v020_dive_109 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_109 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 110
#     Finished 0 for experiment sabre_v020_dive_110 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_110 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 111
#     Finished 0 for experiment sabre_v020_dive_111 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_111 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 112
#     Finished 0 for experiment sabre_v020_dive_112 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_112 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 113
#     Finished 0 for experiment sabre_v020_dive_113 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_113 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 114
#     Finished 0 for experiment sabre_v020_dive_114 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_114 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 115
#     Finished 0 for experiment sabre_v020_dive_115 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_115 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 116
#     Finished 0 for experiment sabre_v020_dive_116 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_116 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 117
#     Finished 0 for experiment sabre_v020_dive_117 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_117 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 118
#     Finished 0 for experiment sabre_v020_dive_118 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_118 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 119
#     Finished 0 for experiment sabre_v020_dive_119 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_119 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 120
#     Finished 0 for experiment sabre_v020_dive_120 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_120 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 121
#     Finished 0 for experiment sabre_v020_dive_121 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_121 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 122
#     Finished 0 for experiment sabre_v020_dive_122 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_122 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 123
#     Finished 0 for experiment sabre_v020_dive_123 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_123 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 124
#     Finished 0 for experiment sabre_v020_dive_124 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_124 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 125
#     Finished 0 for experiment sabre_v020_dive_125 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_125 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 126
#     Finished 0 for experiment sabre_v020_dive_126 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_126 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 127
#     Finished 0 for experiment sabre_v020_dive_127 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_127 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 128
#     Finished 0 for experiment sabre_v020_dive_128 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_128 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 129
#     Finished 0 for experiment sabre_v020_dive_129 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_129 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 130
#     Finished 0 for experiment sabre_v020_dive_130 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_130 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 131
#     Finished 0 for experiment sabre_v020_dive_131 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_131 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 132
#     Finished 0 for experiment sabre_v020_dive_132 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_132 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 133
#     Finished 0 for experiment sabre_v020_dive_133 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_133 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 134
#     Finished 0 for experiment sabre_v020_dive_134 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_134 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 135
#     Finished 0 for experiment sabre_v020_dive_135 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_135 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 136
#     Finished 0 for experiment sabre_v020_dive_136 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_136 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 137
#     Finished 0 for experiment sabre_v020_dive_137 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_137 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 138
#     Finished 0 for experiment sabre_v020_dive_138 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_138 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 139
#     Finished 0 for experiment sabre_v020_dive_139 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_139 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 140
#     Finished 0 for experiment sabre_v020_dive_140 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_140 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 141
#     Finished 0 for experiment sabre_v020_dive_141 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_141 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 142
#     Finished 0 for experiment sabre_v020_dive_142 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_142 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 143
#     Finished 0 for experiment sabre_v020_dive_143 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_143 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 144
#     Finished 0 for experiment sabre_v020_dive_144 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_144 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 145
#     Finished 0 for experiment sabre_v020_dive_145 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_145 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 146
#     Finished 0 for experiment sabre_v020_dive_146 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_146 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 147
#     Finished 0 for experiment sabre_v020_dive_147 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_147 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 148
#     Finished 0 for experiment sabre_v020_dive_148 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_148 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 149
#     Finished 0 for experiment sabre_v020_dive_149 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_149 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 150
#     Finished 0 for experiment sabre_v020_dive_150 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_150 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 151
#     Finished 0 for experiment sabre_v020_dive_151 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_151 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 152
#     Finished 0 for experiment sabre_v020_dive_152 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_152 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 153
#     Finished 0 for experiment sabre_v020_dive_153 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_153 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 154
#     Finished 0 for experiment sabre_v020_dive_154 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_154 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 155
#     Finished 0 for experiment sabre_v020_dive_155 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_155 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 156
#     Finished 0 for experiment sabre_v020_dive_156 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_156 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 157
#     Finished 0 for experiment sabre_v020_dive_157 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_157 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 158
#     Finished 0 for experiment sabre_v020_dive_158 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_158 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 159
#     Finished 0 for experiment sabre_v020_dive_159 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_159 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 160
#     Finished 0 for experiment sabre_v020_dive_160 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_160 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 161
#     Finished 0 for experiment sabre_v020_dive_161 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_161 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 162
#     Finished 0 for experiment sabre_v020_dive_162 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_162 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 163
#     Finished 0 for experiment sabre_v020_dive_163 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_163 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 164
#     Finished 0 for experiment sabre_v020_dive_164 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_164 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 165
#     Finished 0 for experiment sabre_v020_dive_165 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_165 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 166
#     Finished 0 for experiment sabre_v020_dive_166 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_166 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 167
#     Finished 0 for experiment sabre_v020_dive_167 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_167 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 168
#     Finished 0 for experiment sabre_v020_dive_168 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_168 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 169
#     Finished 0 for experiment sabre_v020_dive_169 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_169 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 170
#     Finished 0 for experiment sabre_v020_dive_170 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_170 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 171
#     Finished 0 for experiment sabre_v020_dive_171 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_171 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 172
#     Finished 0 for experiment sabre_v020_dive_172 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_172 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 173
#     Finished 0 for experiment sabre_v020_dive_173 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_173 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 174
#     Finished 0 for experiment sabre_v020_dive_174 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_174 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 175
#     Finished 0 for experiment sabre_v020_dive_175 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_175 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 176
#     Finished 0 for experiment sabre_v020_dive_176 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_176 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 177
#     Finished 0 for experiment sabre_v020_dive_177 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_177 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 178
#     Finished 0 for experiment sabre_v020_dive_178 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_178 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 179
#     Finished 0 for experiment sabre_v020_dive_179 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_179 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 180
#     Finished 0 for experiment sabre_v020_dive_180 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_180 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 181
#     Finished 0 for experiment sabre_v020_dive_181 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_181 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 182
#     Finished 0 for experiment sabre_v020_dive_182 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_182 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 183
#     Finished 0 for experiment sabre_v020_dive_183 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_183 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 184
#     Finished 0 for experiment sabre_v020_dive_184 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_184 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 185
#     Finished 0 for experiment sabre_v020_dive_185 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_185 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# ...
#     Finished 0 for experiment sabre_v020_dive_711 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_711 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 712
#     Finished 0 for experiment sabre_v020_dive_712 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_712 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 713
#     Finished 0 for experiment sabre_v020_dive_713 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_713 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 714
#     Finished 0 for experiment sabre_v020_dive_714 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_714 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 715
#     Finished 0 for experiment sabre_v020_dive_715 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_715 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 716
#     Finished 0 for experiment sabre_v020_dive_716 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_716 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 717
#     Finished 0 for experiment sabre_v020_dive_717 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_717 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 718
#     Finished 0 for experiment sabre_v020_dive_718 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_718 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 719
#     Finished 0 for experiment sabre_v020_dive_719 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_719 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 720
#     Finished 0 for experiment sabre_v020_dive_720 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_720 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 721
#     Finished 0 for experiment sabre_v020_dive_721 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_721 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 722
#     Finished 0 for experiment sabre_v020_dive_722 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_722 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 723
#     Finished 0 for experiment sabre_v020_dive_723 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_723 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 724
#     Finished 0 for experiment sabre_v020_dive_724 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_724 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 725
#     Finished 0 for experiment sabre_v020_dive_725 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_725 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 726
#     Finished 0 for experiment sabre_v020_dive_726 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_726 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 727
#     Finished 0 for experiment sabre_v020_dive_727 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_727 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 728
#     Finished 0 for experiment sabre_v020_dive_728 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_728 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 729
#     Finished 0 for experiment sabre_v020_dive_729 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_729 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 730
#     Finished 0 for experiment sabre_v020_dive_730 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_730 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 731
#     Finished 0 for experiment sabre_v020_dive_731 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_731 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 732
#     Finished 0 for experiment sabre_v020_dive_732 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_732 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 733
#     Finished 0 for experiment sabre_v020_dive_733 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_733 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 734
#     Finished 0 for experiment sabre_v020_dive_734 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_734 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 735
#     Finished 0 for experiment sabre_v020_dive_735 and circuit ghz_25
# Finished all for experiment sabre_v020_dive_735 and circuit ghz_25
# Saved to data/ghz_25/sabre_v020_dive.csv
# **************************************************
# Running experiment for dive 736
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 23
#      19 pm = generate_pass_managers(num_shots, rp, lp, cm, beam_width = beam,
#      20                             fast_layout=fast_layout)
#      22 for qc_idx, qc in enumerate(qc_list):
# ---> 23     data = transpiled_data(qc, pm)
#      24     data['routing pass'] = rp_name
#      25     data['layout pass'] = lp_name
#
# File ~/Documents/GitHub/qiskit/workspace/ulti/pass_managers.py:131, in transpiled_data(qc, pass_managers)
#     129 for pm in pass_managers:
#     130     time_start = time.time()
# --> 131     qc_tr = pm.run(qc_decomposed)
#     132     time_end = time.time()
#     133     time_elapsed = time_end - time_start
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:551, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     548 @wraps(meth)
#     549 def wrapper(*meth_args, **meth_kwargs):
#     550     try:
# --> 551         return meth(*meth_args, **meth_kwargs)
#     552     except PassManagerError as ex:
#     553         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:291, in PassManager.run(self, circuits, output_name, callback)
#     288 if callback is not None:
#     289     callback = _legacy_style_callback(callback)
# --> 291 return super().run(
#     292     in_programs=circuits,
#     293     callback=callback,
#     294     output_name=output_name,
#     295 )
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:222, in BasePassManager.run(self, in_programs, callback, **kwargs)
#     219     is_list = False
#     221 if len(in_programs) == 1:
# --> 222     out_program = _run_workflow(
#     223         program=in_programs[0],
#     224         pass_manager=self,
#     225         callback=callback,
#     226         **kwargs,
#     227     )
#     228     if is_list:
#     229         return [out_program]
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:284, in _run_workflow(program, pass_manager, **kwargs)
#     278 initial_status = WorkflowStatus()
#     280 passmanager_ir = pass_manager._passmanager_frontend(
#     281     input_program=program,
#     282     **kwargs,
#     283 )
# --> 284 passmanager_ir, _ = flow_controller.execute(
#     285     passmanager_ir=passmanager_ir,
#     286     state=PassManagerState(
#     287         workflow_status=initial_status,
#     288         property_set=pass_manager.property_set,
#     289     ),
#     290     callback=kwargs.get("callback", None),
#     291 )
#     292 out_program = pass_manager._passmanager_backend(
#     293     passmanager_ir=passmanager_ir,
#     294     in_program=program,
#     295     **kwargs,
#     296 )
#     298 return out_program
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/runningpassmanager.py:161, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     158 @wraps(meth)
#     159 def wrapper(*meth_args, **meth_kwargs):
#     160     try:
# --> 161         return meth(*meth_args, **meth_kwargs)
#     162     except PassManagerError as ex:
#     163         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:218, in BaseController.execute(self, passmanager_ir, state, callback)
#     216     return passmanager_ir, state
#     217 while True:
# --> 218     passmanager_ir, state = next_task.execute(
#     219         passmanager_ir=passmanager_ir,
#     220         state=state,
#     221         callback=callback,
#     222     )
#     223     try:
#     224         # Sending the object through the generator implies the custom controllers
#     225         # can always rely on the latest data to choose the next task to run.
#     226         next_task = task_generator.send(state)
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:98, in GenericPass.execute(self, passmanager_ir, state, callback)
#      96 try:
#      97     if self not in state.workflow_status.completed_passes:
# ---> 98         ret = self.run(passmanager_ir)
#      99         run_state = RunState.SUCCESS
#     100     else:
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/layout/sabre_layout_v020.py:123, in SabreLayout.run(self, dag)
#     121 for _ in ("forward", "backward"):
#     122     pm = self._layout_and_route_passmanager(initial_layout)
# --> 123     new_circ = pm.run(circ)
#     125     # Update initial layout and reverse the unmapped circuit.
#     126     pass_final_layout = pm.property_set["final_layout"]
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:551, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     548 @wraps(meth)
#     549 def wrapper(*meth_args, **meth_kwargs):
#     550     try:
# --> 551         return meth(*meth_args, **meth_kwargs)
#     552     except PassManagerError as ex:
#     553         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:291, in PassManager.run(self, circuits, output_name, callback)
#     288 if callback is not None:
#     289     callback = _legacy_style_callback(callback)
# --> 291 return super().run(
#     292     in_programs=circuits,
#     293     callback=callback,
#     294     output_name=output_name,
#     295 )
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:222, in BasePassManager.run(self, in_programs, callback, **kwargs)
#     219     is_list = False
#     221 if len(in_programs) == 1:
# --> 222     out_program = _run_workflow(
#     223         program=in_programs[0],
#     224         pass_manager=self,
#     225         callback=callback,
#     226         **kwargs,
#     227     )
#     228     if is_list:
#     229         return [out_program]
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:284, in _run_workflow(program, pass_manager, **kwargs)
#     278 initial_status = WorkflowStatus()
#     280 passmanager_ir = pass_manager._passmanager_frontend(
#     281     input_program=program,
#     282     **kwargs,
#     283 )
# --> 284 passmanager_ir, _ = flow_controller.execute(
#     285     passmanager_ir=passmanager_ir,
#     286     state=PassManagerState(
#     287         workflow_status=initial_status,
#     288         property_set=pass_manager.property_set,
#     289     ),
#     290     callback=kwargs.get("callback", None),
#     291 )
#     292 out_program = pass_manager._passmanager_backend(
#     293     passmanager_ir=passmanager_ir,
#     294     in_program=program,
#     295     **kwargs,
#     296 )
#     298 return out_program
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/runningpassmanager.py:161, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     158 @wraps(meth)
#     159 def wrapper(*meth_args, **meth_kwargs):
#     160     try:
# --> 161         return meth(*meth_args, **meth_kwargs)
#     162     except PassManagerError as ex:
#     163         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:218, in BaseController.execute(self, passmanager_ir, state, callback)
#     216     return passmanager_ir, state
#     217 while True:
# --> 218     passmanager_ir, state = next_task.execute(
#     219         passmanager_ir=passmanager_ir,
#     220         state=state,
#     221         callback=callback,
#     222     )
#     223     try:
#     224         # Sending the object through the generator implies the custom controllers
#     225         # can always rely on the latest data to choose the next task to run.
#     226         next_task = task_generator.send(state)
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/basepasses.py:195, in TransformationPass.execute(self, passmanager_ir, state, callback)
#     189 def execute(
#     190     self,
#     191     passmanager_ir: PassManagerIR,
#     192     state: PassManagerState,
#     193     callback: Callable = None,
#     194 ) -> tuple[PassManagerIR, PassManagerState]:
# --> 195     new_dag, state = super().execute(
#     196         passmanager_ir=passmanager_ir,
#     197         state=state,
#     198         callback=callback,
#     199     )
#     201     if state.workflow_status.previous_run == RunState.SUCCESS:
#     202         if isinstance(new_dag, DAGCircuit):
#     203             # Copy calibration data from the original program
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:98, in GenericPass.execute(self, passmanager_ir, state, callback)
#      96 try:
#      97     if self not in state.workflow_status.completed_passes:
# ---> 98         ret = self.run(passmanager_ir)
#      99         run_state = RunState.SUCCESS
#     100     else:
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v020_dive.py:149, in SabreSwap.run(self, dag)
#     147 for state in candidate_states:
#     148     while state.front_layer:
# --> 149         self._apply_swap(state)
#     150         self._update_state(state)
#     152 # Phase 5) Set the final dag to be the one with lowest depth
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v020_dive.py:348, in SabreSwap._apply_swap(self, state)
#     345 best_depth = float('inf')
#     347 for swap in swap_candidates:
# --> 348     trial_layout = state.layout.copy()
#     349     trial_layout.swap(*swap)
#     350     score = self._score_heuristic(state.front_layer, trial_layout)
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/layout.py:157, in Layout.copy(self)
#     155 layout_copy._regs = self._regs.copy()
#     156 layout_copy._p2v = self._p2v.copy()
# --> 157 layout_copy._v2p = self._v2p.copy()
#     159 return layout_copy
#
# KeyboardInterrupt:
