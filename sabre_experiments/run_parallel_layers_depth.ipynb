# %%
from ulti.pass_manager import run_experiment
from ulti.process_files import file_to_circuit_list, file_to_coupling_map
from qiskit.transpiler.passes.routing.sabre_depth import SabreSwap
from qiskit.transpiler.passes.layout.sabre_layout import SabreLayout
from qiskit.transpiler import CouplingMap

# %%
# Set up
circuit = "parallel_vary_layers"
path = f"results/{circuit}/sabre_025_depth.csv"

qc_list_filename = f"circuits/{circuit}/"
qc_list = file_to_circuit_list(qc_list_filename)
cm = CouplingMap.from_ring(12)

# %% [markdown]
# Testing experiment for SabreSwap 0.45

# %%
data = run_experiment(path, qc_list, SabreSwap, SabreLayout, cm)
# Out:
# Finished:  0  out of  100
# Finished:  1  out of  100
# Finished:  2  out of  100
# Finished:  3  out of  100
# Finished:  4  out of  100
# Finished:  5  out of  100
# Finished:  6  out of  100
# Finished:  7  out of  100
# Finished:  8  out of  100
# Finished:  9  out of  100
# Finished:  10  out of  100
# Finished:  11  out of  100
# Finished:  12  out of  100
# Finished:  13  out of  100
# Finished:  14  out of  100
# Finished:  15  out of  100
# Finished:  16  out of  100
# Finished:  17  out of  100
# Finished:  18  out of  100
# Finished:  19  out of  100
# Finished:  20  out of  100
# Finished:  21  out of  100
# Finished:  22  out of  100
# Finished:  23  out of  100
# Finished:  24  out of  100
# Finished:  25  out of  100
# Finished:  26  out of  100
# Finished:  27  out of  100
# Finished:  28  out of  100
# Finished:  29  out of  100
# Finished:  30  out of  100
# Finished:  31  out of  100
# Finished:  32  out of  100
# Finished:  33  out of  100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = run_experiment(path, qc_list, SabreSwap, SabreLayout, cm)
#
# File ~/Documents/GitHub/qiskit/sabre_experiments/ulti/pass_manager.py:174, in run_experiment(filename, qc_list, routing_pass, layout_pass, coupling_map, num_pm, heuristic, seed, look, beam, triv_layout)
#     172 counter = 0
#     173 for qc in qc_list:
# --> 174     data = run_one_circuit(qc, pm_list)
#     175     data['look'] = look
#     176     data['beam'] = beam
#
# File ~/Documents/GitHub/qiskit/sabre_experiments/ulti/pass_manager.py:105, in run_one_circuit(qc, pm_list)
#     102 for pm in pm_list:
#     103     # Timing the transpilation
#     104     start = time.time()
# --> 105     qc_tr = pm.run(qc_decomposed)
#     106     end = time.time()
#     108     # Decompose the swaps gate in the circuit
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:413, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     410 @wraps(meth)
#     411 def wrapper(*meth_args, **meth_kwargs):
#     412     try:
# --> 413         return meth(*meth_args, **meth_kwargs)
#     414     except PassManagerError as ex:
#     415         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:177, in PassManager.run(self, circuits, output_name, callback)
#     174 if callback is not None:
#     175     callback = _legacy_style_callback(callback)
# --> 177 return super().run(
#     178     in_programs=circuits,
#     179     callback=callback,
#     180     output_name=output_name,
#     181 )
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:222, in BasePassManager.run(self, in_programs, callback, **kwargs)
#     219     is_list = False
#     221 if len(in_programs) == 1:
# --> 222     out_program = _run_workflow(
#     223         program=in_programs[0],
#     224         pass_manager=self,
#     225         callback=callback,
#     226         **kwargs,
#     227     )
#     228     if is_list:
#     229         return [out_program]
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:284, in _run_workflow(program, pass_manager, **kwargs)
#     278 initial_status = WorkflowStatus()
#     280 passmanager_ir = pass_manager._passmanager_frontend(
#     281     input_program=program,
#     282     **kwargs,
#     283 )
# --> 284 passmanager_ir, _ = flow_controller.execute(
#     285     passmanager_ir=passmanager_ir,
#     286     state=PassManagerState(
#     287         workflow_status=initial_status,
#     288         property_set=pass_manager.property_set,
#     289     ),
#     290     callback=kwargs.get("callback", None),
#     291 )
#     292 out_program = pass_manager._passmanager_backend(
#     293     passmanager_ir=passmanager_ir,
#     294     in_program=program,
#     295     **kwargs,
#     296 )
#     298 return out_program
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:218, in BaseController.execute(self, passmanager_ir, state, callback)
#     216     return passmanager_ir, state
#     217 while True:
# --> 218     passmanager_ir, state = next_task.execute(
#     219         passmanager_ir=passmanager_ir,
#     220         state=state,
#     221         callback=callback,
#     222     )
#     223     try:
#     224         # Sending the object through the generator implies the custom controllers
#     225         # can always rely on the latest data to choose the next task to run.
#     226         next_task = task_generator.send(state)
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/basepasses.py:195, in TransformationPass.execute(self, passmanager_ir, state, callback)
#     189 def execute(
#     190     self,
#     191     passmanager_ir: PassManagerIR,
#     192     state: PassManagerState,
#     193     callback: Callable = None,
#     194 ) -> tuple[PassManagerIR, PassManagerState]:
# --> 195     new_dag, state = super().execute(
#     196         passmanager_ir=passmanager_ir,
#     197         state=state,
#     198         callback=callback,
#     199     )
#     201     if state.workflow_status.previous_run == RunState.SUCCESS:
#     202         if isinstance(new_dag, DAGCircuit):
#     203             # Copy calibration data from the original program
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:98, in GenericPass.execute(self, passmanager_ir, state, callback)
#      96 try:
#      97     if self not in state.workflow_status.completed_passes:
# ---> 98         ret = self.run(passmanager_ir)
#      99         run_state = RunState.SUCCESS
#     100     else:
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/layout/sabre_layout.py:236, in SabreLayout.run(self, dag)
#     234 for _ in ("forward", "backward"):
#     235     pm = self._layout_and_route_passmanager(initial_layout)
# --> 236     new_circ = pm.run(circ)
#     238     # Update initial layout and reverse the unmapped circuit.
#     239     pass_final_layout = pm.property_set["final_layout"]
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:413, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     410 @wraps(meth)
#     411 def wrapper(*meth_args, **meth_kwargs):
#     412     try:
# --> 413         return meth(*meth_args, **meth_kwargs)
#     414     except PassManagerError as ex:
#     415         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:177, in PassManager.run(self, circuits, output_name, callback)
#     174 if callback is not None:
#     175     callback = _legacy_style_callback(callback)
# --> 177 return super().run(
#     178     in_programs=circuits,
#     179     callback=callback,
#     180     output_name=output_name,
#     181 )
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:222, in BasePassManager.run(self, in_programs, callback, **kwargs)
#     219     is_list = False
#     221 if len(in_programs) == 1:
# --> 222     out_program = _run_workflow(
#     223         program=in_programs[0],
#     224         pass_manager=self,
#     225         callback=callback,
#     226         **kwargs,
#     227     )
#     228     if is_list:
#     229         return [out_program]
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:284, in _run_workflow(program, pass_manager, **kwargs)
#     278 initial_status = WorkflowStatus()
#     280 passmanager_ir = pass_manager._passmanager_frontend(
#     281     input_program=program,
#     282     **kwargs,
#     283 )
# --> 284 passmanager_ir, _ = flow_controller.execute(
#     285     passmanager_ir=passmanager_ir,
#     286     state=PassManagerState(
#     287         workflow_status=initial_status,
#     288         property_set=pass_manager.property_set,
#     289     ),
#     290     callback=kwargs.get("callback", None),
#     291 )
#     292 out_program = pass_manager._passmanager_backend(
#     293     passmanager_ir=passmanager_ir,
#     294     in_program=program,
#     295     **kwargs,
#     296 )
#     298 return out_program
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:218, in BaseController.execute(self, passmanager_ir, state, callback)
#     216     return passmanager_ir, state
#     217 while True:
# --> 218     passmanager_ir, state = next_task.execute(
#     219         passmanager_ir=passmanager_ir,
#     220         state=state,
#     221         callback=callback,
#     222     )
#     223     try:
#     224         # Sending the object through the generator implies the custom controllers
#     225         # can always rely on the latest data to choose the next task to run.
#     226         next_task = task_generator.send(state)
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/basepasses.py:195, in TransformationPass.execute(self, passmanager_ir, state, callback)
#     189 def execute(
#     190     self,
#     191     passmanager_ir: PassManagerIR,
#     192     state: PassManagerState,
#     193     callback: Callable = None,
#     194 ) -> tuple[PassManagerIR, PassManagerState]:
# --> 195     new_dag, state = super().execute(
#     196         passmanager_ir=passmanager_ir,
#     197         state=state,
#     198         callback=callback,
#     199     )
#     201     if state.workflow_status.previous_run == RunState.SUCCESS:
#     202         if isinstance(new_dag, DAGCircuit):
#     203             # Copy calibration data from the original program
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:98, in GenericPass.execute(self, passmanager_ir, state, callback)
#      96 try:
#      97     if self not in state.workflow_status.completed_passes:
# ---> 98         ret = self.run(passmanager_ir)
#      99         run_state = RunState.SUCCESS
#     100     else:
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_025.py:264, in SabreSwap.run(self, dag)
#     262 for swap_qubits in self._obtain_swaps(front_layer, current_layout):
#     263     trial_layout = current_layout.copy()
# --> 264     trial_layout.swap(*swap_qubits)
#     265     score = self._score_heuristic(
#     266         self.heuristic, front_layer, extended_set, trial_layout, swap_qubits
#     267     )
#     268     swap_scores[swap_qubits] = score
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/layout.py:231, in Layout.swap(self, left, right)
#     229     raise LayoutError("The method swap only works with elements of the same type.")
#     230 temp = self[left]
# --> 231 self[left] = self[right]
#     232 self[right] = temp
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/layout.py:117, in Layout.__setitem__(self, key, value)
#     116 def __setitem__(self, key, value):
# --> 117     virtual, physical = Layout.order_based_on_type(key, value)
#     118     self._set_type_checked_item(virtual, physical)
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/layout.py:96, in Layout.order_based_on_type(value1, value2)
#      94     physical = int(value1)
#      95     virtual = value2
# ---> 96 elif isinstanceint(value2) and isinstance(value1, (Qubit, type(None))):
#      97     physical = int(value2)
#      98     virtual = value1
#
# File ~/Documents/GitHub/qiskit/qiskit/converters/__init__.py:40, in isinstanceint(obj)
#      36 from .dag_to_dagdependency import dag_to_dagdependency
#      37 from .dagdependency_to_dag import dagdependency_to_dag
# ---> 40 def isinstanceint(obj):
#      41     """Like isinstance(obj,int), but with casting. Except for strings."""
#      42     if isinstance(obj, str):
#
# KeyboardInterrupt:
