# %%
from ulti.pass_manager import run_experiment
from ulti.process_files import file_to_circuit_list, file_to_coupling_map
from qiskit.transpiler.passes.routing.sabre_swap_025 import SabreSwap
from qiskit.transpiler.passes.layout.sabre_layout import SabreLayout

# %%
# Set up
circuit = "misc"
qc_list_filename = f"circuits/{circuit}/"
cm_filename = "coupling_maps/heavy_hex_027.txt"
qc_list = file_to_circuit_list(qc_list_filename)
cm = file_to_coupling_map(cm_filename)

# %% [markdown]
# Testing experiment for SabreSwap 0.45

# %%
path = f"results/{circuit}/sabre_extended.csv"

# %%
data = run_experiment(path, qc_list, SabreSwap, SabreLayout, cm, heuristic="lookahead")
# Out:
# Finished:  0  out of  158
# Finished:  1  out of  158
# Finished:  2  out of  158
# Finished:  3  out of  158
# Finished:  4  out of  158
# Finished:  5  out of  158
# Finished:  6  out of  158
# Finished:  7  out of  158
# Finished:  8  out of  158
# Finished:  9  out of  158
# Finished:  10  out of  158
# Finished:  11  out of  158
# Finished:  12  out of  158
# Finished:  13  out of  158
# Finished:  14  out of  158
# Finished:  15  out of  158
# Finished:  16  out of  158
# Finished:  17  out of  158
# Finished:  18  out of  158
# Finished:  19  out of  158
# Finished:  20  out of  158
# Finished:  21  out of  158
# Finished:  22  out of  158
# Finished:  23  out of  158
# Finished:  24  out of  158
# Finished:  25  out of  158
# Finished:  26  out of  158
# Finished:  27  out of  158
# Finished:  28  out of  158
# Finished:  29  out of  158
# Finished:  30  out of  158
# Finished:  31  out of  158
# Finished:  32  out of  158
# Finished:  33  out of  158
# Finished:  34  out of  158
# Finished:  35  out of  158
# Finished:  36  out of  158
# Finished:  37  out of  158
# Finished:  38  out of  158
# Finished:  39  out of  158
# Finished:  40  out of  158
# Finished:  41  out of  158
# Finished:  42  out of  158
# Finished:  43  out of  158
# Finished:  44  out of  158
# Finished:  45  out of  158
# Finished:  46  out of  158
# Finished:  47  out of  158
# Finished:  48  out of  158
# Finished:  49  out of  158
# Finished:  50  out of  158
# Finished:  51  out of  158
# Finished:  52  out of  158
# Finished:  53  out of  158
# Finished:  54  out of  158
# Finished:  55  out of  158
# Finished:  56  out of  158
# Finished:  57  out of  158
# Finished:  58  out of  158
# Finished:  59  out of  158
# Finished:  60  out of  158
# Finished:  61  out of  158
# Finished:  62  out of  158
# Finished:  63  out of  158
# Finished:  64  out of  158
# Finished:  65  out of  158
# Finished:  66  out of  158
# Finished:  67  out of  158
# Finished:  68  out of  158
# Finished:  69  out of  158
# Finished:  70  out of  158
# Finished:  71  out of  158
# Finished:  72  out of  158
# Finished:  73  out of  158
# Finished:  74  out of  158
# Finished:  75  out of  158
# Finished:  76  out of  158
# Finished:  77  out of  158
# Finished:  78  out of  158
# Finished:  79  out of  158
# Finished:  80  out of  158
# Finished:  81  out of  158
# Finished:  82  out of  158
# Finished:  83  out of  158
# Finished:  84  out of  158
# Finished:  85  out of  158
# Finished:  86  out of  158
# Finished:  87  out of  158
# Finished:  88  out of  158
# Finished:  89  out of  158
# Finished:  90  out of  158
# Finished:  91  out of  158
# Finished:  92  out of  158
# Finished:  93  out of  158
# Finished:  94  out of  158
# Finished:  95  out of  158
# Finished:  96  out of  158
# Finished:  97  out of  158
# Finished:  98  out of  158
# Finished:  99  out of  158
# Finished:  100  out of  158
# Finished:  101  out of  158
# Finished:  102  out of  158
# Finished:  103  out of  158
# Finished:  104  out of  158
# Finished:  105  out of  158
# Finished:  106  out of  158
# Finished:  107  out of  158
# Finished:  108  out of  158
# Finished:  109  out of  158
# Finished:  110  out of  158
# Finished:  111  out of  158
# Finished:  112  out of  158
# Finished:  113  out of  158
# Finished:  114  out of  158
# Finished:  115  out of  158
# Finished:  116  out of  158
# Finished:  117  out of  158
# Finished:  118  out of  158
# Finished:  119  out of  158
# Finished:  120  out of  158
# Finished:  121  out of  158
# Finished:  122  out of  158
# Finished:  123  out of  158
# Finished:  124  out of  158
# Finished:  125  out of  158
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data = run_experiment(path, qc_list, SabreSwap, SabreLayout, cm, heuristic="lookahead")
#
# File ~/Documents/GitHub/qiskit/sabre_experiments/ulti/pass_manager.py:169, in run_experiment(filename, qc_list, routing_pass, layout_pass, coupling_map, num_pm, heuristic, seed, look, beam)
#     167 counter = 0
#     168 for qc in qc_list:
# --> 169     data = run_one_circuit(qc, pm_list)
#     170     data['look'] = look
#     171     data['beam'] = beam
#
# File ~/Documents/GitHub/qiskit/sabre_experiments/ulti/pass_manager.py:104, in run_one_circuit(qc, pm_list)
#     101 end = time.time()
#     103 # Decompose the swaps gate in the circuit
# --> 104 qc_tr = qc_tr.decompose()
#     106 # Obtaining data
#     107 depth = qc_tr.depth()
#
# File ~/Documents/GitHub/qiskit/qiskit/circuit/quantumcircuit.py:2078, in QuantumCircuit.decompose(self, gates_to_decompose, reps)
#    2076     dag = pass_.run(dag)
#    2077 # do not copy operations, this is done in the conversion with circuit_to_dag
# -> 2078 return dag_to_circuit(dag, copy_operations=False)
#
# File ~/Documents/GitHub/qiskit/qiskit/converters/dag_to_circuit.py:73, in dag_to_circuit(dag, copy_operations)
#      71     if copy_operations:
#      72         op = copy.deepcopy(op)
# ---> 73     circuit._append(CircuitInstruction(op, node.qargs, node.cargs))
#      75 circuit.duration = dag.duration
#      76 circuit.unit = dag.unit
#
# File ~/Documents/GitHub/qiskit/qiskit/circuit/quantumcircuit.py:1462, in QuantumCircuit._append(self, instruction, qargs, cargs)
#    1460 if old_style:
#    1461     instruction = CircuitInstruction(instruction, qargs, cargs)
# -> 1462 self._data.append(instruction)
#    1463 self._track_operation(instruction.operation)
#    1464 return instruction.operation if old_style else instruction
#
# KeyboardInterrupt:
