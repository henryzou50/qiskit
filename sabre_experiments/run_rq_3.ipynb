# %%
from ulti.pass_manager import run_experiment
from ulti.process_files import file_to_circuit_list, file_to_coupling_map

# %%
# Set up
circuit = "rq"
rp_str = "sabre_025_dive"
lp_str = "fast_layout"


cm_filename = "coupling_maps/heavy_hex_127.txt"

qc_list_filename = f"circuits/{circuit}/"
qc_list = file_to_circuit_list(qc_list_filename)
cm = file_to_coupling_map(cm_filename)

# %% [markdown]
# Testing experiment for SabreSwap 0.45

# %%
num_iter_list = [28, 33, 38, 43, 48]

for num_iter in num_iter_list:
    path = f"results/{circuit}/{rp_str}_iter_{num_iter}.csv"
    data = run_experiment(path, qc_list, rp_str, lp_str, cm, num_iter=num_iter, num_pm=1)
# Out:
# Successfully built Sabre_Dive. Seed:  42  Beam:  5  Iter:  28
# Successfully built Fast_Layout
# Running SabreSwap
# Beam Search Iteration 0
# Number of Candidate States: 92
# New Lowest Depth: 1098
# New Lowest Depth: 1058
# New Lowest Depth: 1033
# New Lowest Depth: 1031
# New Lowest Depth: 1027
# New Lowest Depth: 980
# New Lowest Depth: 951
# Beam Search Iteration 1
# Number of Candidate States: 460
# New Lowest Depth: 936
# New Lowest Depth: 919
# Beam Search Iteration 2
# Number of Candidate States: 452
# New Lowest Depth: 901
# Beam Search Iteration 3
# Number of Candidate States: 450
# New Lowest Depth: 893
# Beam Search Iteration 4
# Number of Candidate States: 452
# New Lowest Depth: 886
# New Lowest Depth: 883
# Beam Search Iteration 5
# Number of Candidate States: 444
# New Lowest Depth: 880
# Beam Search Iteration 6
# Number of Candidate States: 440
# Beam Search Iteration 7
# Number of Candidate States: 441
# Beam Search Iteration 8
# Number of Candidate States: 444
# Beam Search Iteration 9
# Number of Candidate States: 441
# Beam Search Iteration 10
# Number of Candidate States: 444
# Beam Search Iteration 11
# Number of Candidate States: 441
# Beam Search Iteration 12
# Number of Candidate States: 444
# Beam Search Iteration 13
# Number of Candidate States: 441
# Beam Search Iteration 14
# Number of Candidate States: 430
# Beam Search Iteration 15
# Number of Candidate States: 431
# Beam Search Iteration 16
# Number of Candidate States: 428
# Beam Search Iteration 17
# Number of Candidate States: 428
# Beam Search Iteration 18
# Number of Candidate States: 428
# Beam Search Iteration 19
# Number of Candidate States: 428
# Beam Search Iteration 20
# Number of Candidate States: 428
# Beam Search Iteration 21
# Number of Candidate States: 428
# Beam Search Iteration 22
# Number of Candidate States: 428
# Beam Search Iteration 23
# Number of Candidate States: 428
# Beam Search Iteration 24
# Number of Candidate States: 418
# Beam Search Iteration 25
# Number of Candidate States: 418
# Beam Search Iteration 26
# Number of Candidate States: 418
# Beam Search Iteration 27
# Number of Candidate States: 420
# Finished:  0  out of  1
# Successfully built Sabre_Dive. Seed:  42  Beam:  5  Iter:  33
# Successfully built Fast_Layout
# Running SabreSwap
# Beam Search Iteration 0
# Number of Candidate States: 92
# New Lowest Depth: 1098
# New Lowest Depth: 1058
# New Lowest Depth: 1033
# New Lowest Depth: 1031
# New Lowest Depth: 1027
# New Lowest Depth: 980
# New Lowest Depth: 951
# Beam Search Iteration 1
# Number of Candidate States: 460
# New Lowest Depth: 936
# New Lowest Depth: 919
# Beam Search Iteration 2
# Number of Candidate States: 452
# New Lowest Depth: 901
# Beam Search Iteration 3
# Number of Candidate States: 450
# New Lowest Depth: 893
# Beam Search Iteration 4
# Number of Candidate States: 452
# New Lowest Depth: 886
# New Lowest Depth: 883
# Beam Search Iteration 5
# Number of Candidate States: 444
# New Lowest Depth: 880
# Beam Search Iteration 6
# Number of Candidate States: 440
# Beam Search Iteration 7
# Number of Candidate States: 441
# Beam Search Iteration 8
# Number of Candidate States: 444
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       3 for num_iter in num_iter_list:
#       4     path = f"results/{circuit}/{rp_str}_iter_{num_iter}.csv"
# ----> 5     data = run_experiment(path, qc_list, rp_str, lp_str, cm, num_iter=num_iter, num_pm=1)
#
# File ~/Documents/GitHub/qiskit/sabre_experiments/ulti/pass_manager.py:227, in run_experiment(filename, qc_list, rp_str, lp_str, coupling_map, num_pm, seed, look, beam, crit, num_iter)
#     225 counter = 0
#     226 for qc in qc_list:
# --> 227     data = run_one_circuit(qc, pm_list)
#     228     data['look'] = look
#     229     data['beam'] = beam
#
# File ~/Documents/GitHub/qiskit/sabre_experiments/ulti/pass_manager.py:168, in run_one_circuit(qc, pm_list)
#     165 for pm in pm_list:
#     166     # Timing the transpilation
#     167     start = time.time()
# --> 168     qc_tr = pm.run(qc_decomposed)
#     169     end = time.time()
#     171     # Decompose the swaps gate in the circuit
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:413, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     410 @wraps(meth)
#     411 def wrapper(*meth_args, **meth_kwargs):
#     412     try:
# --> 413         return meth(*meth_args, **meth_kwargs)
#     414     except PassManagerError as ex:
#     415         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:177, in PassManager.run(self, circuits, output_name, callback)
#     174 if callback is not None:
#     175     callback = _legacy_style_callback(callback)
# --> 177 return super().run(
#     178     in_programs=circuits,
#     179     callback=callback,
#     180     output_name=output_name,
#     181 )
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:222, in BasePassManager.run(self, in_programs, callback, **kwargs)
#     219     is_list = False
#     221 if len(in_programs) == 1:
# --> 222     out_program = _run_workflow(
#     223         program=in_programs[0],
#     224         pass_manager=self,
#     225         callback=callback,
#     226         **kwargs,
#     227     )
#     228     if is_list:
#     229         return [out_program]
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:284, in _run_workflow(program, pass_manager, **kwargs)
#     278 initial_status = WorkflowStatus()
#     280 passmanager_ir = pass_manager._passmanager_frontend(
#     281     input_program=program,
#     282     **kwargs,
#     283 )
# --> 284 passmanager_ir, _ = flow_controller.execute(
#     285     passmanager_ir=passmanager_ir,
#     286     state=PassManagerState(
#     287         workflow_status=initial_status,
#     288         property_set=pass_manager.property_set,
#     289     ),
#     290     callback=kwargs.get("callback", None),
#     291 )
#     292 out_program = pass_manager._passmanager_backend(
#     293     passmanager_ir=passmanager_ir,
#     294     in_program=program,
#     295     **kwargs,
#     296 )
#     298 return out_program
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:218, in BaseController.execute(self, passmanager_ir, state, callback)
#     216     return passmanager_ir, state
#     217 while True:
# --> 218     passmanager_ir, state = next_task.execute(
#     219         passmanager_ir=passmanager_ir,
#     220         state=state,
#     221         callback=callback,
#     222     )
#     223     try:
#     224         # Sending the object through the generator implies the custom controllers
#     225         # can always rely on the latest data to choose the next task to run.
#     226         next_task = task_generator.send(state)
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/basepasses.py:195, in TransformationPass.execute(self, passmanager_ir, state, callback)
#     189 def execute(
#     190     self,
#     191     passmanager_ir: PassManagerIR,
#     192     state: PassManagerState,
#     193     callback: Callable = None,
#     194 ) -> tuple[PassManagerIR, PassManagerState]:
# --> 195     new_dag, state = super().execute(
#     196         passmanager_ir=passmanager_ir,
#     197         state=state,
#     198         callback=callback,
#     199     )
#     201     if state.workflow_status.previous_run == RunState.SUCCESS:
#     202         if isinstance(new_dag, DAGCircuit):
#     203             # Copy calibration data from the original program
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:98, in GenericPass.execute(self, passmanager_ir, state, callback)
#      96 try:
#      97     if self not in state.workflow_status.completed_passes:
# ---> 98         ret = self.run(passmanager_ir)
#      99         run_state = RunState.SUCCESS
#     100     else:
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_dive.py:167, in SabreSwap.run(self, dag)
#     165 for state in candidate_states:
#     166     while state.front_layer:
# --> 167         self._apply_swap(state)
#     168         self._update_state(state)
#     170 # Phase 4a: Get list of depths of each candidate state and store the lowest depth
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_dive.py:434, in SabreSwap._apply_swap(self, state)
#     431 best_depth = float('inf')
#     433 for swap in swap_candidates:
# --> 434     trial_layout = state.layout.copy()
#     435     trial_layout.swap(*swap)
#     436     score = self._score_heuristic(state.front_layer, trial_layout)
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/layout.py:156, in Layout.copy(self)
#     153 layout_copy = type(self)()
#     155 layout_copy._regs = self._regs.copy()
# --> 156 layout_copy._p2v = self._p2v.copy()
#     157 layout_copy._v2p = self._v2p.copy()
#     159 return layout_copy
#
# KeyboardInterrupt:
