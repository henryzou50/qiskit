# %%
from ulti.pass_manager import run_experiment
from ulti.process_files import file_to_circuit_list, file_to_coupling_map
from qiskit.transpiler.passes.routing.sabre_depth_alt import SabreSwap
from qiskit.transpiler.passes.layout.sabre_layout import SabreLayout

# %%
# Set up
circuit = "misc"
qc_list_filename = f"circuits/{circuit}/"
cm_filename = "coupling_maps/heavy_hex_027.txt"
qc_list = file_to_circuit_list(qc_list_filename)
cm = file_to_coupling_map(cm_filename)

# %% [markdown]
# Testing experiment for SabreSwap 0.45

# %%
path = f"results/{circuit}/sabre_depth_alt.csv"

# %%
data = run_experiment(path, qc_list, SabreSwap, SabreLayout, cm)
# Out:
# Finished:  0  out of  134
# Finished:  1  out of  134
# Finished:  2  out of  134
# Finished:  3  out of  134
# Finished:  4  out of  134
# Finished:  5  out of  134
# Finished:  6  out of  134
# Finished:  7  out of  134
# Finished:  8  out of  134
# Finished:  9  out of  134
# Finished:  10  out of  134
# Finished:  11  out of  134
# Finished:  12  out of  134
# Finished:  13  out of  134
# Finished:  14  out of  134
# Finished:  15  out of  134
# Finished:  16  out of  134
# Finished:  17  out of  134
# Finished:  18  out of  134
# Finished:  19  out of  134
# Finished:  20  out of  134
# Finished:  21  out of  134
# Finished:  22  out of  134
# Finished:  23  out of  134
# Finished:  24  out of  134
# Finished:  25  out of  134
# Finished:  26  out of  134
# Finished:  27  out of  134
# Finished:  28  out of  134
# Finished:  29  out of  134
# Finished:  30  out of  134
# Finished:  31  out of  134
# Finished:  32  out of  134
# Finished:  33  out of  134
# Finished:  34  out of  134
# Finished:  35  out of  134
# Finished:  36  out of  134
# Finished:  37  out of  134
# Finished:  38  out of  134
# Finished:  39  out of  134
# Finished:  40  out of  134
# Finished:  41  out of  134
# Finished:  42  out of  134
# Finished:  43  out of  134
# Finished:  44  out of  134
# Finished:  45  out of  134
# Finished:  46  out of  134
# Finished:  47  out of  134
# Finished:  48  out of  134
# Finished:  49  out of  134
# Finished:  50  out of  134
# Finished:  51  out of  134
# Finished:  52  out of  134
# Finished:  53  out of  134
# Finished:  54  out of  134
# Finished:  55  out of  134
# Finished:  56  out of  134
# Finished:  57  out of  134
# Finished:  58  out of  134
# Finished:  59  out of  134
# Finished:  60  out of  134
# Finished:  61  out of  134
# Finished:  62  out of  134
# Finished:  63  out of  134
# Finished:  64  out of  134
# Finished:  65  out of  134
# Finished:  66  out of  134
# Finished:  67  out of  134
# Finished:  68  out of  134
# Finished:  69  out of  134
# Finished:  70  out of  134
# Finished:  71  out of  134
# Finished:  72  out of  134
# Finished:  73  out of  134
# Finished:  74  out of  134
# Finished:  75  out of  134
# Finished:  76  out of  134
# Finished:  77  out of  134
# Finished:  78  out of  134
# Finished:  79  out of  134
# Finished:  80  out of  134
# Finished:  81  out of  134
# Finished:  82  out of  134
# Finished:  83  out of  134
# Finished:  84  out of  134
# Finished:  85  out of  134
# Finished:  86  out of  134
# Finished:  87  out of  134
# Finished:  88  out of  134
# Finished:  89  out of  134
# Finished:  90  out of  134
# Finished:  91  out of  134
# Finished:  92  out of  134
# Finished:  93  out of  134
# Finished:  94  out of  134
# Finished:  95  out of  134
# Finished:  96  out of  134
# Finished:  97  out of  134
# Finished:  98  out of  134
# Finished:  99  out of  134
# Finished:  100  out of  134
# Finished:  101  out of  134
# Finished:  102  out of  134
# Finished:  103  out of  134
# Finished:  104  out of  134
# Finished:  105  out of  134
# Finished:  106  out of  134
# Finished:  107  out of  134
# Finished:  108  out of  134
# Finished:  109  out of  134
# Finished:  110  out of  134
# Finished:  111  out of  134
# Finished:  112  out of  134
# Finished:  113  out of  134
# Finished:  114  out of  134
# Finished:  115  out of  134
# Finished:  116  out of  134
# Finished:  117  out of  134
# Finished:  118  out of  134
# Finished:  119  out of  134
# Finished:  120  out of  134
# Finished:  121  out of  134
# Finished:  122  out of  134
# Finished:  123  out of  134
# Finished:  124  out of  134
# Finished:  125  out of  134
# Finished:  126  out of  134
# Finished:  127  out of  134
# Finished:  128  out of  134
# Finished:  129  out of  134
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = run_experiment(path, qc_list, SabreSwap, SabreLayout, cm)
#
# File ~/Documents/GitHub/qiskit/sabre_experiments/ulti/pass_manager.py:169, in run_experiment(filename, qc_list, routing_pass, layout_pass, coupling_map, num_pm, heuristic, seed, look, beam)
#     167 counter = 0
#     168 for qc in qc_list:
# --> 169     data = run_one_circuit(qc, pm_list)
#     170     data['look'] = look
#     171     data['beam'] = beam
#
# File ~/Documents/GitHub/qiskit/sabre_experiments/ulti/pass_manager.py:100, in run_one_circuit(qc, pm_list)
#      97 for pm in pm_list:
#      98     # Timing the transpilation
#      99     start = time.time()
# --> 100     qc_tr = pm.run(qc_decomposed)
#     101     end = time.time()
#     103     # Decompose the swaps gate in the circuit
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:413, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     410 @wraps(meth)
#     411 def wrapper(*meth_args, **meth_kwargs):
#     412     try:
# --> 413         return meth(*meth_args, **meth_kwargs)
#     414     except PassManagerError as ex:
#     415         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:177, in PassManager.run(self, circuits, output_name, callback)
#     174 if callback is not None:
#     175     callback = _legacy_style_callback(callback)
# --> 177 return super().run(
#     178     in_programs=circuits,
#     179     callback=callback,
#     180     output_name=output_name,
#     181 )
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:222, in BasePassManager.run(self, in_programs, callback, **kwargs)
#     219     is_list = False
#     221 if len(in_programs) == 1:
# --> 222     out_program = _run_workflow(
#     223         program=in_programs[0],
#     224         pass_manager=self,
#     225         callback=callback,
#     226         **kwargs,
#     227     )
#     228     if is_list:
#     229         return [out_program]
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:284, in _run_workflow(program, pass_manager, **kwargs)
#     278 initial_status = WorkflowStatus()
#     280 passmanager_ir = pass_manager._passmanager_frontend(
#     281     input_program=program,
#     282     **kwargs,
#     283 )
# --> 284 passmanager_ir, _ = flow_controller.execute(
#     285     passmanager_ir=passmanager_ir,
#     286     state=PassManagerState(
#     287         workflow_status=initial_status,
#     288         property_set=pass_manager.property_set,
#     289     ),
#     290     callback=kwargs.get("callback", None),
#     291 )
#     292 out_program = pass_manager._passmanager_backend(
#     293     passmanager_ir=passmanager_ir,
#     294     in_program=program,
#     295     **kwargs,
#     296 )
#     298 return out_program
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:218, in BaseController.execute(self, passmanager_ir, state, callback)
#     216     return passmanager_ir, state
#     217 while True:
# --> 218     passmanager_ir, state = next_task.execute(
#     219         passmanager_ir=passmanager_ir,
#     220         state=state,
#     221         callback=callback,
#     222     )
#     223     try:
#     224         # Sending the object through the generator implies the custom controllers
#     225         # can always rely on the latest data to choose the next task to run.
#     226         next_task = task_generator.send(state)
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/basepasses.py:195, in TransformationPass.execute(self, passmanager_ir, state, callback)
#     189 def execute(
#     190     self,
#     191     passmanager_ir: PassManagerIR,
#     192     state: PassManagerState,
#     193     callback: Callable = None,
#     194 ) -> tuple[PassManagerIR, PassManagerState]:
# --> 195     new_dag, state = super().execute(
#     196         passmanager_ir=passmanager_ir,
#     197         state=state,
#     198         callback=callback,
#     199     )
#     201     if state.workflow_status.previous_run == RunState.SUCCESS:
#     202         if isinstance(new_dag, DAGCircuit):
#     203             # Copy calibration data from the original program
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:98, in GenericPass.execute(self, passmanager_ir, state, callback)
#      96 try:
#      97     if self not in state.workflow_status.completed_passes:
# ---> 98         ret = self.run(passmanager_ir)
#      99         run_state = RunState.SUCCESS
#     100     else:
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/layout/sabre_layout.py:236, in SabreLayout.run(self, dag)
#     234 for _ in ("forward", "backward"):
#     235     pm = self._layout_and_route_passmanager(initial_layout)
# --> 236     new_circ = pm.run(circ)
#     238     # Update initial layout and reverse the unmapped circuit.
#     239     pass_final_layout = pm.property_set["final_layout"]
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:413, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     410 @wraps(meth)
#     411 def wrapper(*meth_args, **meth_kwargs):
#     412     try:
# --> 413         return meth(*meth_args, **meth_kwargs)
#     414     except PassManagerError as ex:
#     415         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:177, in PassManager.run(self, circuits, output_name, callback)
#     174 if callback is not None:
#     175     callback = _legacy_style_callback(callback)
# --> 177 return super().run(
#     178     in_programs=circuits,
#     179     callback=callback,
#     180     output_name=output_name,
#     181 )
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:222, in BasePassManager.run(self, in_programs, callback, **kwargs)
#     219     is_list = False
#     221 if len(in_programs) == 1:
# --> 222     out_program = _run_workflow(
#     223         program=in_programs[0],
#     224         pass_manager=self,
#     225         callback=callback,
#     226         **kwargs,
#     227     )
#     228     if is_list:
#     229         return [out_program]
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:284, in _run_workflow(program, pass_manager, **kwargs)
#     278 initial_status = WorkflowStatus()
#     280 passmanager_ir = pass_manager._passmanager_frontend(
#     281     input_program=program,
#     282     **kwargs,
#     283 )
# --> 284 passmanager_ir, _ = flow_controller.execute(
#     285     passmanager_ir=passmanager_ir,
#     286     state=PassManagerState(
#     287         workflow_status=initial_status,
#     288         property_set=pass_manager.property_set,
#     289     ),
#     290     callback=kwargs.get("callback", None),
#     291 )
#     292 out_program = pass_manager._passmanager_backend(
#     293     passmanager_ir=passmanager_ir,
#     294     in_program=program,
#     295     **kwargs,
#     296 )
#     298 return out_program
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:218, in BaseController.execute(self, passmanager_ir, state, callback)
#     216     return passmanager_ir, state
#     217 while True:
# --> 218     passmanager_ir, state = next_task.execute(
#     219         passmanager_ir=passmanager_ir,
#     220         state=state,
#     221         callback=callback,
#     222     )
#     223     try:
#     224         # Sending the object through the generator implies the custom controllers
#     225         # can always rely on the latest data to choose the next task to run.
#     226         next_task = task_generator.send(state)
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/basepasses.py:195, in TransformationPass.execute(self, passmanager_ir, state, callback)
#     189 def execute(
#     190     self,
#     191     passmanager_ir: PassManagerIR,
#     192     state: PassManagerState,
#     193     callback: Callable = None,
#     194 ) -> tuple[PassManagerIR, PassManagerState]:
# --> 195     new_dag, state = super().execute(
#     196         passmanager_ir=passmanager_ir,
#     197         state=state,
#     198         callback=callback,
#     199     )
#     201     if state.workflow_status.previous_run == RunState.SUCCESS:
#     202         if isinstance(new_dag, DAGCircuit):
#     203             # Copy calibration data from the original program
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:98, in GenericPass.execute(self, passmanager_ir, state, callback)
#      96 try:
#      97     if self not in state.workflow_status.completed_passes:
# ---> 98         ret = self.run(passmanager_ir)
#      99         run_state = RunState.SUCCESS
#     100     else:
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_depth_alt.py:147, in SabreSwap.run(self, dag)
#     145     # Phase 4: If there are still gates in the front layer, repeat phase 2 and 3
#     146     while initial_state.front_layer:
# --> 147         self._apply_swap(initial_state)
#     148         self._update_state(initial_state)
#     151 # Phase 5: Use gate sequence to apply the gates to the mapped dag
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_depth_alt.py:292, in SabreSwap._apply_swap(self, state)
#     289 self._update_qubit_depth(DAGOpNode(op=SwapGate(), qargs=swap), trial_qubit_depth)
#     290 trial_state = State(trial_layout, state.front_layer.copy(), state.predecessors.copy(),
#     291                     trial_qubit_depth, None, 0)
# --> 292 self._update_state(trial_state, trial=True)
#     293 depth = max(trial_state.qubit_depth.values())
#     294 depth_diff = depth - current_depth
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_depth_alt.py:214, in SabreSwap._update_state(self, state, trial)
#     211 v0, v1 = node.qargs
#     212 # Accessing layout._v2p directly to avoid overhead from __getitem__ and a
#     213 # single access isn't feasible because the layout is updated on each iteration
# --> 214 if self.coupling_map.graph.has_edge(
#     215     state.layout._v2p[v0], state.layout._v2p[v1]
#     216 ):
#     217     execute_gate_list.append(node)
#     218 else:
#
# KeyboardInterrupt:
