# %%
from experiment_setup.pass_managers import run_experiment
from experiment_setup.circuits.circuit_files import get_circuits_from_directory
from experiment_setup.coupling_maps.coupling_maps_files import file_to_coupling_map

# %%
# Parameters to change
circuit = "red_queen"
rp_str  = "sabre_v0_20_crit"
lp_str  = "sabre_layout"
cp_str  = "heavy_hex_127"

num_pm = 1
crit = 1.1

# %%
path = f"results/{circuit}/{rp_str}.csv"
cm_filename = f"experiment_setup/coupling_maps/{cp_str}.txt"

qc_list_directory = f"experiment_setup/circuits/{circuit}/"
qc_list = get_circuits_from_directory(qc_list_directory)
cm = file_to_coupling_map(cm_filename)

# decompose each circuit
qc_list_decomposed = []
for qc in qc_list:
    qc_decomposed = qc.decompose().decompose()
    qc_list_decomposed.append(qc_decomposed)
# Out:
# 2. qrng_n4.qasm
# 3. cat_state_n4.qasm
# 4. deutsch_n2.qasm
# 5. quantumwalks_n2.qasm
# 6. qft_n4.qasm
# 7. iswap_n2.qasm
# 8. qec_sm_n5.qasm
# 9. teleportation_n3.qasm
# 10. grover.qasm
# 11. qpe.qasm
# 12. quantum_teleportation.qasm
# 13. dj_constant.qasm
# 14. dj_balanced.qasm
# 15. inverseqft_n4.qasm
# 16. lpn_n5.qasm
# 17. fredkin_n3.qasm
# 18. toffoli_n3.qasm
# 19. shor_n5.qasm
# 20. grover_n2.qasm
# 21. wstate_n3.qasm
# 22. adder_n4.qasm
# 23. qaoa_n3.qasm
# 24. linearsolver_n3.qasm
# 25. bv.qasm
# 26. hs.qasm
# 27. multiply_n13.qasm
# 28. hs4_n4.qasm
# 29. adder_n10.qasm
# 30. simon_n6.qasm
# 31. qec_en_n5.qasm
# 32. knn_n25.qasm
# 33. swap_test_n25.qasm
# 34. ipe.qasm
# 35. basis_change_n3.qasm
# 36. cat_state_n22.qasm
# 37. bv_mcm.qasm
# 38. sat_n7.qasm
# 39. knn_n31.qasm
# 40. ghz_state_n23.qasm
# 41. pea_n5.qasm
# 42. bell_n4.qasm
# 43. qpe_n9.qasm
# 44. bigadder_n18.qasm
# 45. ipea_n2.qasm
# 46. bb84_n8.qasm
# 47. bv_n14.qasm
# 48. qec9xz_n17.qasm
# 49. swap_test_n41.qasm
# 50. knn_n41.qasm
# 51. ft_2.qasm
# 52. cc_n12.qasm
# 53. cat_n35.qasm
# 54. variational_n4.qasm
# 55. bv_n19.qasm
# 56. qram_n20.qasm
# 57. ghz_n40.qasm
# 58. multiplier_n15.qasm
# 59. vqe_n4.qasm
# 60. seca_n11.qasm
# 61. ft_1.qasm
# 62. qf21_n15.qasm
# 63. knn_n67.qasm
# 64. sat_n11.qasm
# 65. bv_n30.qasm
# 66. adder_n28.qasm
# 67. error_correctiond3_n5.qasm
# 68. basis_test_n4.qasm
# 69. swap_test_n83.qasm
# 70. cat_n65.qasm
# 71. wstate_n27.qasm
# 72. ghz_n78.qasm
# 73. cc_n32.qasm
# 74. swap_test_n115.qasm
# 75. wstate_n36.qasm
# 76. vqe_uccsd_n4.qasm
# 77. bv_n70.qasm
# 78. ghz_n127.qasm
# 79. dnn_n2.qasm
# 80. adder_n64.qasm
# 81. ising_n26.qasm
# 82. cc_n64.qasm
# 83. qaoa_n6.qasm
# 84. dnn_n33.qasm
# 85. wstate_n76.qasm
# 86. ising_n34.qasm
# 87. ising_n10.qasm
# 88. adder_n118.qasm
# 89. ising_n42.qasm
# 90. qugan_n39.qasm
# 91. dnn_n51.qasm
# 92. square_root_n18.qasm
# 93. wstate_n118.qasm
# 94. multiplier_n45.qasm
# 95. hhl_n7.qasm
# 96. ising_n66.qasm
# 97. qft_n18.qasm
# 98. qugan_n71.qasm
# 99. dnn_n8.qasm
# 100. ising_n98.qasm

# %%
data = run_experiment(path, qc_list_decomposed, rp_str, lp_str, cm, num_pm, crit = crit)
# Out:
# Using seed 42 for routing pass.
#     Building Sabre v0.20 crit routing pass with crit 1.1
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Sabre layout pass
# Finished: 0 out of 99 with depth 0 and time 0.011122941970825195
# Finished: 1 out of 99 with depth 15 and time 0.011934280395507812
# Finished: 2 out of 99 with depth 1 and time 0.009164094924926758
# Finished: 3 out of 99 with depth 3 and time 0.009872913360595703
# Finished: 4 out of 99 with depth 25 and time 0.014719963073730469
# Finished: 5 out of 99 with depth 2 and time 0.009998798370361328
# Finished: 6 out of 99 with depth 14 and time 0.011149883270263672
# Finished: 7 out of 99 with depth 5 and time 0.010628938674926758
# Finished: 8 out of 99 with depth 219 and time 0.0517888069152832
# Finished: 9 out of 99 with depth 31 and time 0.015034675598144531
# Finished: 10 out of 99 with depth 6 and time 0.010437726974487305
# Finished: 11 out of 99 with depth 0 and time 0.009155988693237305
# Finished: 12 out of 99 with depth 24 and time 0.013395071029663086
# Finished: 13 out of 99 with depth 3 and time 0.009283065795898438
# Finished: 14 out of 99 with depth 7 and time 0.010110855102539062
# Finished: 15 out of 99 with depth 17 and time 0.011542081832885742
# Finished: 16 out of 99 with depth 9 and time 0.011311054229736328
# Finished: 17 out of 99 with depth 69 and time 0.02117609977722168
# Finished: 18 out of 99 with depth 2 and time 0.010574102401733398
# Finished: 19 out of 99 with depth 15 and time 0.012727737426757812
# Finished: 20 out of 99 with depth 15 and time 0.014418840408325195
# Finished: 21 out of 99 with depth 9 and time 0.01164698600769043
# Finished: 22 out of 99 with depth 8 and time 0.012269973754882812
# Finished: 23 out of 99 with depth 16 and time 0.014254093170166016
# Finished: 24 out of 99 with depth 2 and time 0.01611185073852539
# Finished: 25 out of 99 with depth 100 and time 0.04137420654296875
# Finished: 26 out of 99 with depth 2 and time 0.013183832168579102
# Finished: 27 out of 99 with depth 165 and time 0.049957990646362305
# Finished: 28 out of 99 with depth 35 and time 0.01695394515991211
# Finished: 29 out of 99 with depth 19 and time 0.013869762420654297
# Finished: 30 out of 99 with depth 221 and time 0.12380313873291016
# Finished: 31 out of 99 with depth 221 and time 0.13188600540161133
# Finished: 32 out of 99 with depth 20 and time 0.01712322235107422
# Finished: 33 out of 99 with depth 10 and time 0.016571044921875
# Finished: 34 out of 99 with depth 125 and time 0.036924123764038086
# Finished: 35 out of 99 with depth 10 and time 0.01401209831237793
# Finished: 36 out of 99 with depth 124 and time 0.046483755111694336
# Finished: 37 out of 99 with depth 318 and time 0.2092599868774414
# Finished: 38 out of 99 with depth 142 and time 0.0365142822265625
# Finished: 39 out of 99 with depth 67 and time 0.02263498306274414
# Finished: 40 out of 99 with depth 7 and time 0.012916326522827148
# Finished: 41 out of 99 with depth 116 and time 0.03462100028991699
# Finished: 42 out of 99 with depth 232 and time 0.06181025505065918
# Finished: 43 out of 99 with depth 38 and time 0.016453981399536133
# Finished: 44 out of 99 with depth 0 and time 0.012625932693481445
