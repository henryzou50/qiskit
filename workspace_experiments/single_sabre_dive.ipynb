# %%
from experiment_setup.pass_managers import run_beam_experiment
from experiment_setup.circuits.circuit_files import get_circuits_from_directory
from experiment_setup.coupling_maps.coupling_maps_files import file_to_coupling_map

# %%
# Parameters to change
circuit = "red_queen_small"
rp_str  = "sabre_v0_20_dive"
lp_str  = "fast_layout"
cp_str  = "heavy_hex_027"

beam_list = [1, 2, 3, 4, 5, 7, 9, 10, 15, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000]

# %%
path = f"results/{circuit}/{rp_str}.csv"
cm_filename = f"experiment_setup/coupling_maps/{cp_str}.txt"

qc_list_directory = f"experiment_setup/circuits/{circuit}/"
qc_list = get_circuits_from_directory(qc_list_directory)
cm = file_to_coupling_map(cm_filename)

# decompose each circuit
qc_list_decomposed = []
for qc in qc_list:
    qc_decomposed = qc.decompose().decompose()
    qc_list_decomposed.append(qc_decomposed)

# %%
data = run_beam_experiment(path, qc_list_decomposed, rp_str, lp_str, cm, beam_list)
# Out:
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 1
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 4
#     New Lowest Depth: 114
#     New Lowest Depth: 113
#         Length of Candidate States: 1
# Beam Search Iteration 1
#     Number of Candidate States: 5
#     New Lowest Depth: 93
#         Length of Candidate States: 1
# Beam Search Iteration 2
#     Number of Candidate States: 4
#         Length of Candidate States: 1
# Beam Search Iteration 3
#     Number of Candidate States: 5
#         Length of Candidate States: 1
# Beam Search Iteration 4
#     Number of Candidate States: 4
#         Length of Candidate States: 1
# Beam Search Iteration 5
#     Number of Candidate States: 7
#         Length of Candidate States: 1
# Beam Search Iteration 6
#     Number of Candidate States: 7
#         Length of Candidate States: 1
# Beam Search Iteration 7
#     Number of Candidate States: 7
#         Length of Candidate States: 1
# Beam Search Iteration 8
#     Number of Candidate States: 7
#         Length of Candidate States: 1
# Beam Search Iteration 9
#     Number of Candidate States: 7
#         Length of Candidate States: 1
# Beam Search Iteration 10
#     Number of Candidate States: 7
#         Length of Candidate States: 1
# Beam Search Iteration 11
#     Number of Candidate States: 7
#         Length of Candidate States: 1
# Beam Search Iteration 12
#     Number of Candidate States: 7
#         Length of Candidate States: 1
# Beam Search Iteration 13
#     Number of Candidate States: 7
#         Length of Candidate States: 1
# Beam Search Iteration 14
#     Number of Candidate States: 7
#         Length of Candidate States: 1
# Beam Search Iteration 15
#     Number of Candidate States: 4
#         Length of Candidate States: 1
# Beam Search Iteration 16
#     Number of Candidate States: 6
#         Length of Candidate States: 1
# Beam Search Iteration 17
#     Number of Candidate States: 4
#         Length of Candidate States: 1
# Beam Search Iteration 18
#     Number of Candidate States: 6
#         Length of Candidate States: 1
# Beam Search Iteration 19
#     Number of Candidate States: 4
#         Length of Candidate States: 1
# Beam Search Iteration 20
#     Number of Candidate States: 6
#         Length of Candidate States: 1
# Beam Search Iteration 21
#     Number of Candidate States: 4
#         Length of Candidate States: 1
# Beam Search Iteration 22
#     Number of Candidate States: 4
#     New Lowest Depth: 88
#         Length of Candidate States: 1
# Beam Search Iteration 23
#     Number of Candidate States: 4
#         Length of Candidate States: 1
# Beam Search Iteration 24
#     Number of Candidate States: 4
#         Length of Candidate States: 1
# Beam Search Iteration 25
#     Number of Candidate States: 4
#         Length of Candidate States: 1
# Beam Search Iteration 26
#     Number of Candidate States: 5
#         Length of Candidate States: 1
# Beam Search Iteration 27
#     Number of Candidate States: 6
#         Length of Candidate States: 1
# Beam Search Iteration 28
#     Number of Candidate States: 8
#         Length of Candidate States: 1
# Beam Search Iteration 29
#     Number of Candidate States: 5
#         Length of Candidate States: 1
# Beam Search Iteration 30
#     Number of Candidate States: 9
#         Length of Candidate States: 1
# Beam Search Iteration 31
#     Number of Candidate States: 8
#         Length of Candidate States: 1
# Beam Search Iteration 32
#     Number of Candidate States: 9
#         Length of Candidate States: 1
# Beam Search Iteration 33
#     Number of Candidate States: 8
#         Length of Candidate States: 1
# Beam Search Iteration 34
#     Number of Candidate States: 9
#         Length of Candidate States: 1
# Beam Search Iteration 35
#     Number of Candidate States: 5
#         Length of Candidate States: 1
# Beam Search Iteration 36
#     Number of Candidate States: 4
#         Length of Candidate States: 1
# Beam Search Iteration 37
#     Number of Candidate States: 5
#         Length of Candidate States: 1
# Beam Search Iteration 38
#     Number of Candidate States: 4
#         Length of Candidate States: 1
# Beam Search Iteration 39
#     Number of Candidate States: 7
#         Length of Candidate States: 1
# Beam Search Iteration 40
#     Number of Candidate States: 9
#         Length of Candidate States: 1
# Beam Search Iteration 41
#     Number of Candidate States: 6
#         Length of Candidate States: 1
# Beam Search Iteration 42
#     Number of Candidate States: 5
#         Length of Candidate States: 1
# Beam Search Iteration 43
#     Number of Candidate States: 6
#         Length of Candidate States: 1
# Beam Search Iteration 44
#     Number of Candidate States: 9
#         Length of Candidate States: 1
# Beam Search Iteration 45
#     Number of Candidate States: 8
#         Length of Candidate States: 1
# Beam Search Iteration 46
#     Number of Candidate States: 9
#         Length of Candidate States: 1
# Beam Search Iteration 47
#     Number of Candidate States: 8
#         Length of Candidate States: 1
# Beam Search Iteration 48
#     Number of Candidate States: 9
#         Length of Candidate States: 1
# Beam Search Iteration 49
#     Number of Candidate States: 8
#         Length of Candidate States: 1
# Beam Search Iteration 50
#     Number of Candidate States: 9
#         Length of Candidate States: 1
# Beam Search Iteration 51
#     Number of Candidate States: 11
#         Length of Candidate States: 1
# Beam Search Iteration 52
#     Number of Candidate States: 10
#         Length of Candidate States: 1
# Beam Search Iteration 53
#     Number of Candidate States: 11
#         Length of Candidate States: 1
# Beam Search Iteration 54
#     Number of Candidate States: 8
#         Length of Candidate States: 1
# Beam Search Iteration 55
#     Number of Candidate States: 9
#         Length of Candidate States: 1
# Finished: 0 out of 7 with depth 88 and time 1.6590890884399414
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 10
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 4
#     New Lowest Depth: 114
#     New Lowest Depth: 113
#         Length of Candidate States: 4
# Beam Search Iteration 1
#     Number of Candidate States: 22
#     New Lowest Depth: 93
#         Length of Candidate States: 10
# Beam Search Iteration 2
#     Number of Candidate States: 57
#         Length of Candidate States: 10
# Beam Search Iteration 3
#     Number of Candidate States: 68
#         Length of Candidate States: 10
# Beam Search Iteration 4
#     Number of Candidate States: 60
#         Length of Candidate States: 10
# Beam Search Iteration 5
#     Number of Candidate States: 70
#     New Lowest Depth: 89
#     New Lowest Depth: 85
#     New Lowest Depth: 81
#         Length of Candidate States: 10
# Beam Search Iteration 6
#     Number of Candidate States: 77
#         Length of Candidate States: 10
# Beam Search Iteration 7
#     Number of Candidate States: 88
#         Length of Candidate States: 10
# Beam Search Iteration 8
#     Number of Candidate States: 72
#         Length of Candidate States: 10
# Beam Search Iteration 9
#     Number of Candidate States: 81
#         Length of Candidate States: 10
# Beam Search Iteration 10
#     Number of Candidate States: 100
#         Length of Candidate States: 10
# Beam Search Iteration 11
#     Number of Candidate States: 96
#         Length of Candidate States: 10
# Beam Search Iteration 12
#     Number of Candidate States: 77
#         Length of Candidate States: 10
# Beam Search Iteration 13
#     Number of Candidate States: 97
#         Length of Candidate States: 10
# Beam Search Iteration 14
#     Number of Candidate States: 86
#     New Lowest Depth: 80
#         Length of Candidate States: 10
# Beam Search Iteration 15
#     Number of Candidate States: 65
#     New Lowest Depth: 79
#         Length of Candidate States: 10
# Beam Search Iteration 16
#     Number of Candidate States: 72
#         Length of Candidate States: 10
# Beam Search Iteration 17
#     Number of Candidate States: 50
#         Length of Candidate States: 10
# Beam Search Iteration 18
#     Number of Candidate States: 48
#         Length of Candidate States: 10
# Beam Search Iteration 19
#     Number of Candidate States: 56
#         Length of Candidate States: 10
# Beam Search Iteration 20
#     Number of Candidate States: 56
#         Length of Candidate States: 10
# Beam Search Iteration 21
#     Number of Candidate States: 59
#         Length of Candidate States: 10
# Beam Search Iteration 22
#     Number of Candidate States: 73
#         Length of Candidate States: 10
# Beam Search Iteration 23
#     Number of Candidate States: 64
#         Length of Candidate States: 10
# Beam Search Iteration 24
#     Number of Candidate States: 74
#         Length of Candidate States: 10
# Beam Search Iteration 25
#     Number of Candidate States: 80
#         Length of Candidate States: 10
# Beam Search Iteration 26
#     Number of Candidate States: 72
#         Length of Candidate States: 10
# Beam Search Iteration 27
#     Number of Candidate States: 82
#         Length of Candidate States: 10
# Beam Search Iteration 28
#     Number of Candidate States: 83
#         Length of Candidate States: 10
# Beam Search Iteration 29
#     Number of Candidate States: 102
#         Length of Candidate States: 10
# Beam Search Iteration 30
#     Number of Candidate States: 95
#         Length of Candidate States: 10
# Beam Search Iteration 31
#     Number of Candidate States: 89
#         Length of Candidate States: 10
# Beam Search Iteration 32
#     Number of Candidate States: 92
#         Length of Candidate States: 10
# Beam Search Iteration 33
#     Number of Candidate States: 85
#         Length of Candidate States: 10
# Beam Search Iteration 34
#     Number of Candidate States: 88
#         Length of Candidate States: 10
# Beam Search Iteration 35
#     Number of Candidate States: 78
#         Length of Candidate States: 10
# Beam Search Iteration 36
#     Number of Candidate States: 89
#         Length of Candidate States: 10
# Beam Search Iteration 37
#     Number of Candidate States: 81
#         Length of Candidate States: 10
# Beam Search Iteration 38
#     Number of Candidate States: 83
#         Length of Candidate States: 10
# Beam Search Iteration 39
#     Number of Candidate States: 98
#         Length of Candidate States: 10
# Beam Search Iteration 40
#     Number of Candidate States: 91
#         Length of Candidate States: 10
# Beam Search Iteration 41
#     Number of Candidate States: 80
#         Length of Candidate States: 10
# Beam Search Iteration 42
#     Number of Candidate States: 89
#         Length of Candidate States: 10
# Beam Search Iteration 43
#     Number of Candidate States: 94
#         Length of Candidate States: 10
# Beam Search Iteration 44
#     Number of Candidate States: 98
#         Length of Candidate States: 10
# Beam Search Iteration 45
#     Number of Candidate States: 108
#         Length of Candidate States: 10
# Beam Search Iteration 46
#     Number of Candidate States: 100
#         Length of Candidate States: 10
# Beam Search Iteration 47
#     Number of Candidate States: 110
#         Length of Candidate States: 10
# Beam Search Iteration 48
#     Number of Candidate States: 96
#         Length of Candidate States: 10
# Beam Search Iteration 49
#     Number of Candidate States: 106
#         Length of Candidate States: 10
# Beam Search Iteration 50
#     Number of Candidate States: 79
#         Length of Candidate States: 10
# Beam Search Iteration 51
#     Number of Candidate States: 78
#         Length of Candidate States: 10
# Beam Search Iteration 52
#     Number of Candidate States: 77
#         Length of Candidate States: 10
# Beam Search Iteration 53
#     Number of Candidate States: 77
#         Length of Candidate States: 10
# Beam Search Iteration 54
#     Number of Candidate States: 76
#         Length of Candidate States: 10
# Beam Search Iteration 55
#     Number of Candidate States: 78
#         Length of Candidate States: 10
# Finished: 1 out of 7 with depth 79 and time 17.39634394645691
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 20
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 4
#     New Lowest Depth: 114
#     New Lowest Depth: 113
#         Length of Candidate States: 4
# Beam Search Iteration 1
#     Number of Candidate States: 22
#     New Lowest Depth: 93
#         Length of Candidate States: 20
# Beam Search Iteration 2
#     Number of Candidate States: 117
#         Length of Candidate States: 20
# Beam Search Iteration 3
#     Number of Candidate States: 134
#         Length of Candidate States: 20
# Beam Search Iteration 4
#     Number of Candidate States: 135
#     New Lowest Depth: 85
#         Length of Candidate States: 20
# Beam Search Iteration 5
#     Number of Candidate States: 141
#     New Lowest Depth: 81
#         Length of Candidate States: 20
# Beam Search Iteration 6
#     Number of Candidate States: 138
#         Length of Candidate States: 20
# Beam Search Iteration 7
#     Number of Candidate States: 167
#         Length of Candidate States: 20
# Beam Search Iteration 8
#     Number of Candidate States: 145
#         Length of Candidate States: 20
# Beam Search Iteration 9
#     Number of Candidate States: 164
#         Length of Candidate States: 20
# Beam Search Iteration 10
#     Number of Candidate States: 200
#         Length of Candidate States: 20
# Beam Search Iteration 11
#     Number of Candidate States: 183
#         Length of Candidate States: 20
# Beam Search Iteration 12
#     Number of Candidate States: 150
#         Length of Candidate States: 20
# Beam Search Iteration 13
#     Number of Candidate States: 190
#         Length of Candidate States: 20
# Beam Search Iteration 14
#     Number of Candidate States: 164
#     New Lowest Depth: 80
#         Length of Candidate States: 20
# Beam Search Iteration 15
#     Number of Candidate States: 147
#     New Lowest Depth: 79
#         Length of Candidate States: 20
# Beam Search Iteration 16
#     Number of Candidate States: 130
#         Length of Candidate States: 20
# Beam Search Iteration 17
#     Number of Candidate States: 102
#         Length of Candidate States: 20
# Beam Search Iteration 18
#     Number of Candidate States: 96
#         Length of Candidate States: 20
# Beam Search Iteration 19
#     Number of Candidate States: 110
#         Length of Candidate States: 20
# Beam Search Iteration 20
#     Number of Candidate States: 108
#         Length of Candidate States: 20
# Beam Search Iteration 21
#     Number of Candidate States: 119
#         Length of Candidate States: 20
# Beam Search Iteration 22
#     Number of Candidate States: 145
#         Length of Candidate States: 20
# Beam Search Iteration 23
#     Number of Candidate States: 130
#         Length of Candidate States: 20
# Beam Search Iteration 24
#     Number of Candidate States: 147
#         Length of Candidate States: 20
# Beam Search Iteration 25
#     Number of Candidate States: 159
#         Length of Candidate States: 20
# Beam Search Iteration 26
#     Number of Candidate States: 159
#         Length of Candidate States: 20
# Beam Search Iteration 27
#     Number of Candidate States: 154
#         Length of Candidate States: 20
# Beam Search Iteration 28
#     Number of Candidate States: 177
#         Length of Candidate States: 20
# Beam Search Iteration 29
#     Number of Candidate States: 203
#         Length of Candidate States: 20
# Beam Search Iteration 30
#     Number of Candidate States: 188
#         Length of Candidate States: 20
# Beam Search Iteration 31
#     Number of Candidate States: 179
#         Length of Candidate States: 20
# Beam Search Iteration 32
#     Number of Candidate States: 180
#         Length of Candidate States: 20
# Beam Search Iteration 33
#     Number of Candidate States: 171
#         Length of Candidate States: 20
# Beam Search Iteration 34
#     Number of Candidate States: 179
#         Length of Candidate States: 20
# Beam Search Iteration 35
#     Number of Candidate States: 158
#         Length of Candidate States: 20
# Beam Search Iteration 36
#     Number of Candidate States: 177
#         Length of Candidate States: 20
# Beam Search Iteration 37
#     Number of Candidate States: 165
#         Length of Candidate States: 20
# Beam Search Iteration 38
#     Number of Candidate States: 168
#         Length of Candidate States: 20
# Beam Search Iteration 39
#     Number of Candidate States: 192
#         Length of Candidate States: 20
# Beam Search Iteration 40
#     Number of Candidate States: 179
#         Length of Candidate States: 20
# Beam Search Iteration 41
#     Number of Candidate States: 163
#         Length of Candidate States: 20
# Beam Search Iteration 42
#     Number of Candidate States: 174
#         Length of Candidate States: 20
# Beam Search Iteration 43
#     Number of Candidate States: 185
#         Length of Candidate States: 20
# Beam Search Iteration 44
#     Number of Candidate States: 194
#         Length of Candidate States: 20
# Beam Search Iteration 45
#     Number of Candidate States: 208
#         Length of Candidate States: 20
# Beam Search Iteration 46
#     Number of Candidate States: 200
#         Length of Candidate States: 20
# Beam Search Iteration 47
#     Number of Candidate States: 220
#         Length of Candidate States: 20
# Beam Search Iteration 48
#     Number of Candidate States: 190
#         Length of Candidate States: 20
# Beam Search Iteration 49
#     Number of Candidate States: 210
#         Length of Candidate States: 20
# Beam Search Iteration 50
#     Number of Candidate States: 157
#         Length of Candidate States: 20
# Beam Search Iteration 51
#     Number of Candidate States: 162
#         Length of Candidate States: 20
# Beam Search Iteration 52
#     Number of Candidate States: 152
#         Length of Candidate States: 20
# Beam Search Iteration 53
#     Number of Candidate States: 155
#         Length of Candidate States: 20
# Beam Search Iteration 54
#     Number of Candidate States: 154
#         Length of Candidate States: 20
# Beam Search Iteration 55
#     Number of Candidate States: 154
#         Length of Candidate States: 20
# Finished: 2 out of 7 with depth 79 and time 35.114758014678955
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 50
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 4
#     New Lowest Depth: 114
#     New Lowest Depth: 113
#         Length of Candidate States: 4
# Beam Search Iteration 1
#     Number of Candidate States: 22
#     New Lowest Depth: 93
#         Length of Candidate States: 22
# Beam Search Iteration 2
#     Number of Candidate States: 124
#         Length of Candidate States: 50
# Beam Search Iteration 3
#     Number of Candidate States: 359
#     New Lowest Depth: 92
#     New Lowest Depth: 85
#         Length of Candidate States: 50
# Beam Search Iteration 4
#     Number of Candidate States: 378
#         Length of Candidate States: 50
# Beam Search Iteration 5
#     Number of Candidate States: 337
#     New Lowest Depth: 81
#         Length of Candidate States: 50
# Beam Search Iteration 6
#     Number of Candidate States: 360
#         Length of Candidate States: 50
# Beam Search Iteration 7
#     Number of Candidate States: 403
#         Length of Candidate States: 50
# Beam Search Iteration 8
#     Number of Candidate States: 384
#         Length of Candidate States: 50
# Beam Search Iteration 9
#     Number of Candidate States: 386
#         Length of Candidate States: 50
# Beam Search Iteration 10
#     Number of Candidate States: 476
#         Length of Candidate States: 50
# Beam Search Iteration 11
#     Number of Candidate States: 454
#         Length of Candidate States: 50
# Beam Search Iteration 12
#     Number of Candidate States: 404
#         Length of Candidate States: 50
# Beam Search Iteration 13
#     Number of Candidate States: 443
#         Length of Candidate States: 50
# Beam Search Iteration 14
#     Number of Candidate States: 430
#     New Lowest Depth: 80
#         Length of Candidate States: 50
# Beam Search Iteration 15
#     Number of Candidate States: 400
#     New Lowest Depth: 79
#     New Lowest Depth: 74
#         Length of Candidate States: 50
# Beam Search Iteration 16
#     Number of Candidate States: 353
#         Length of Candidate States: 50
# Beam Search Iteration 17
#     Number of Candidate States: 305
#         Length of Candidate States: 50
# Beam Search Iteration 18
#     Number of Candidate States: 266
#         Length of Candidate States: 50
# Beam Search Iteration 19
#     Number of Candidate States: 296
#         Length of Candidate States: 50
# Beam Search Iteration 20
#     Number of Candidate States: 258
#         Length of Candidate States: 50
# Beam Search Iteration 21
#     Number of Candidate States: 290
#         Length of Candidate States: 50
# Beam Search Iteration 22
#     Number of Candidate States: 164
#         Length of Candidate States: 50
# Beam Search Iteration 23
#     Number of Candidate States: 257
#         Length of Candidate States: 50
# Beam Search Iteration 24
#     Number of Candidate States: 209
#         Length of Candidate States: 50
# Beam Search Iteration 25
#     Number of Candidate States: 296
#         Length of Candidate States: 50
# Beam Search Iteration 26
#     Number of Candidate States: 232
#         Length of Candidate States: 50
# Beam Search Iteration 27
#     Number of Candidate States: 290
#         Length of Candidate States: 50
# Beam Search Iteration 28
#     Number of Candidate States: 227
#         Length of Candidate States: 50
# Beam Search Iteration 29
#     Number of Candidate States: 295
#         Length of Candidate States: 50
# Beam Search Iteration 30
#     Number of Candidate States: 210
#         Length of Candidate States: 50
# Beam Search Iteration 31
#     Number of Candidate States: 272
#         Length of Candidate States: 50
# Beam Search Iteration 32
#     Number of Candidate States: 180
#         Length of Candidate States: 50
# Beam Search Iteration 33
#     Number of Candidate States: 229
#         Length of Candidate States: 50
# Beam Search Iteration 34
#     Number of Candidate States: 230
#         Length of Candidate States: 50
# Beam Search Iteration 35
#     Number of Candidate States: 189
#         Length of Candidate States: 50
# Beam Search Iteration 36
#     Number of Candidate States: 266
#         Length of Candidate States: 50
# Beam Search Iteration 37
#     Number of Candidate States: 198
#     New Lowest Depth: 73
#         Length of Candidate States: 50
# Beam Search Iteration 38
#     Number of Candidate States: 234
#         Length of Candidate States: 50
# Beam Search Iteration 39
#     Number of Candidate States: 244
#         Length of Candidate States: 50
# Beam Search Iteration 40
#     Number of Candidate States: 250
#         Length of Candidate States: 50
# Beam Search Iteration 41
#     Number of Candidate States: 200
#         Length of Candidate States: 50
# Beam Search Iteration 42
#     Number of Candidate States: 268
#         Length of Candidate States: 50
# Beam Search Iteration 43
#     Number of Candidate States: 230
#         Length of Candidate States: 50
# Beam Search Iteration 44
#     Number of Candidate States: 283
#         Length of Candidate States: 50
# Beam Search Iteration 45
#     Number of Candidate States: 265
#         Length of Candidate States: 50
# Beam Search Iteration 46
#     Number of Candidate States: 263
#         Length of Candidate States: 50
# Beam Search Iteration 47
#     Number of Candidate States: 281
#         Length of Candidate States: 50
# Beam Search Iteration 48
#     Number of Candidate States: 249
#         Length of Candidate States: 50
# Beam Search Iteration 49
#     Number of Candidate States: 273
#         Length of Candidate States: 50
# Beam Search Iteration 50
#     Number of Candidate States: 241
#         Length of Candidate States: 50
# Beam Search Iteration 51
#     Number of Candidate States: 261
#     New Lowest Depth: 71
#         Length of Candidate States: 50
# Beam Search Iteration 52
#     Number of Candidate States: 232
#         Length of Candidate States: 50
# Beam Search Iteration 53
#     Number of Candidate States: 243
#         Length of Candidate States: 50
# Beam Search Iteration 54
#     Number of Candidate States: 238
#         Length of Candidate States: 50
# Beam Search Iteration 55
#     Number of Candidate States: 191
#         Length of Candidate States: 50
# Finished: 3 out of 7 with depth 71 and time 53.290761947631836
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 100
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 4
#     New Lowest Depth: 114
#     New Lowest Depth: 113
#         Length of Candidate States: 4
# Beam Search Iteration 1
#     Number of Candidate States: 22
#     New Lowest Depth: 93
#         Length of Candidate States: 22
# Beam Search Iteration 2
#     Number of Candidate States: 124
#         Length of Candidate States: 100
# Beam Search Iteration 3
#     Number of Candidate States: 689
#     New Lowest Depth: 92
#     New Lowest Depth: 85
#         Length of Candidate States: 100
# Beam Search Iteration 4
#     Number of Candidate States: 722
#         Length of Candidate States: 100
# Beam Search Iteration 5
#     Number of Candidate States: 731
#     New Lowest Depth: 81
#         Length of Candidate States: 100
# Beam Search Iteration 6
#     Number of Candidate States: 697
#         Length of Candidate States: 100
# Beam Search Iteration 7
#     Number of Candidate States: 816
#         Length of Candidate States: 100
# Beam Search Iteration 8
#     Number of Candidate States: 779
#         Length of Candidate States: 100
# Beam Search Iteration 9
#     Number of Candidate States: 813
#         Length of Candidate States: 100
# Beam Search Iteration 10
#     Number of Candidate States: 991
#         Length of Candidate States: 100
# Beam Search Iteration 11
#     Number of Candidate States: 912
#         Length of Candidate States: 100
# Beam Search Iteration 12
#     Number of Candidate States: 782
#         Length of Candidate States: 100
# Beam Search Iteration 13
#     Number of Candidate States: 874
#         Length of Candidate States: 100
# Beam Search Iteration 14
#     Number of Candidate States: 855
#     New Lowest Depth: 80
#         Length of Candidate States: 100
# Beam Search Iteration 15
#     Number of Candidate States: 783
#     New Lowest Depth: 79
#     New Lowest Depth: 74
#         Length of Candidate States: 100
# Beam Search Iteration 16
#     Number of Candidate States: 715
#         Length of Candidate States: 100
# Beam Search Iteration 17
#     Number of Candidate States: 597
#         Length of Candidate States: 100
# Beam Search Iteration 18
#     Number of Candidate States: 507
#         Length of Candidate States: 100
# Beam Search Iteration 19
#     Number of Candidate States: 572
#         Length of Candidate States: 100
# Beam Search Iteration 20
#     Number of Candidate States: 526
#         Length of Candidate States: 100
# Beam Search Iteration 21
#     Number of Candidate States: 590
#         Length of Candidate States: 100
# Beam Search Iteration 22
#     Number of Candidate States: 485
#         Length of Candidate States: 100
# Beam Search Iteration 23
#     Number of Candidate States: 590
#         Length of Candidate States: 100
# Beam Search Iteration 24
#     Number of Candidate States: 494
#         Length of Candidate States: 100
# Beam Search Iteration 25
#     Number of Candidate States: 609
#         Length of Candidate States: 100
# Beam Search Iteration 26
#     Number of Candidate States: 461
#         Length of Candidate States: 100
# Beam Search Iteration 27
#     Number of Candidate States: 583
#         Length of Candidate States: 100
# Beam Search Iteration 28
#     Number of Candidate States: 455
#         Length of Candidate States: 100
# Beam Search Iteration 29
#     Number of Candidate States: 592
#         Length of Candidate States: 100
# Beam Search Iteration 30
#     Number of Candidate States: 428
#         Length of Candidate States: 100
# Beam Search Iteration 31
#     Number of Candidate States: 547
#         Length of Candidate States: 100
# Beam Search Iteration 32
#     Number of Candidate States: 360
#         Length of Candidate States: 100
# Beam Search Iteration 33
#     Number of Candidate States: 460
#         Length of Candidate States: 100
# Beam Search Iteration 34
#     Number of Candidate States: 456
#         Length of Candidate States: 100
# Beam Search Iteration 35
#     Number of Candidate States: 378
#         Length of Candidate States: 100
# Beam Search Iteration 36
#     Number of Candidate States: 536
#         Length of Candidate States: 100
# Beam Search Iteration 37
#     Number of Candidate States: 399
#     New Lowest Depth: 73
#         Length of Candidate States: 100
# Beam Search Iteration 38
#     Number of Candidate States: 467
#         Length of Candidate States: 100
# Beam Search Iteration 39
#     Number of Candidate States: 490
#         Length of Candidate States: 100
# Beam Search Iteration 40
#     Number of Candidate States: 500
#         Length of Candidate States: 100
# Beam Search Iteration 41
#     Number of Candidate States: 400
#         Length of Candidate States: 100
# Beam Search Iteration 42
#     Number of Candidate States: 536
#         Length of Candidate States: 100
# Beam Search Iteration 43
#     Number of Candidate States: 460
#         Length of Candidate States: 100
# Beam Search Iteration 44
#     Number of Candidate States: 556
#         Length of Candidate States: 100
# Beam Search Iteration 45
#     Number of Candidate States: 529
#         Length of Candidate States: 100
# Beam Search Iteration 46
#     Number of Candidate States: 525
#         Length of Candidate States: 100
# Beam Search Iteration 47
#     Number of Candidate States: 541
#     New Lowest Depth: 71
#         Length of Candidate States: 100
# Beam Search Iteration 48
#     Number of Candidate States: 496
#         Length of Candidate States: 100
# Beam Search Iteration 49
#     Number of Candidate States: 520
#         Length of Candidate States: 100
# Beam Search Iteration 50
#     Number of Candidate States: 477
#         Length of Candidate States: 100
# Beam Search Iteration 51
#     Number of Candidate States: 456
#         Length of Candidate States: 100
# Beam Search Iteration 52
#     Number of Candidate States: 485
#         Length of Candidate States: 100
# Beam Search Iteration 53
#     Number of Candidate States: 405
#         Length of Candidate States: 100
# Beam Search Iteration 54
#     Number of Candidate States: 509
#         Length of Candidate States: 100
# Beam Search Iteration 55
#     Number of Candidate States: 428
#         Length of Candidate States: 100
# Finished: 4 out of 7 with depth 71 and time 107.5849061012268
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 1000
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 4
#     New Lowest Depth: 114
#     New Lowest Depth: 113
#         Length of Candidate States: 4
# Beam Search Iteration 1
#     Number of Candidate States: 22
#     New Lowest Depth: 93
#         Length of Candidate States: 22
# Beam Search Iteration 2
#     Number of Candidate States: 124
#         Length of Candidate States: 124
# Beam Search Iteration 3
#     Number of Candidate States: 817
#     New Lowest Depth: 92
#     New Lowest Depth: 85
#         Length of Candidate States: 817
# Beam Search Iteration 4
#     Number of Candidate States: 5649
#     New Lowest Depth: 83
#         Length of Candidate States: 1000
# Beam Search Iteration 5
#     Number of Candidate States: 7697
#     New Lowest Depth: 81
#         Length of Candidate States: 1000
# Beam Search Iteration 6
#     Number of Candidate States: 7654
#     New Lowest Depth: 78
#         Length of Candidate States: 1000
# Beam Search Iteration 7
#     Number of Candidate States: 7448
#         Length of Candidate States: 1000
# Beam Search Iteration 8
#     Number of Candidate States: 8083
#         Length of Candidate States: 1000
# Beam Search Iteration 9
#     Number of Candidate States: 7950
#         Length of Candidate States: 1000
# Beam Search Iteration 10
#     Number of Candidate States: 8168
#         Length of Candidate States: 1000
# Beam Search Iteration 11
#     Number of Candidate States: 8124
#         Length of Candidate States: 1000
# Beam Search Iteration 12
#     Number of Candidate States: 7759
#         Length of Candidate States: 1000
# Beam Search Iteration 13
#     Number of Candidate States: 7513
#         Length of Candidate States: 1000
# Beam Search Iteration 14
#     Number of Candidate States: 7520
#         Length of Candidate States: 1000
# Beam Search Iteration 15
#     Number of Candidate States: 8073
#         Length of Candidate States: 1000
# Beam Search Iteration 16
#     Number of Candidate States: 8885
#         Length of Candidate States: 1000
# Beam Search Iteration 17
#     Number of Candidate States: 8964
#         Length of Candidate States: 1000
# Beam Search Iteration 18
#     Number of Candidate States: 9606
#         Length of Candidate States: 1000
# Beam Search Iteration 19
#     Number of Candidate States: 9662
#         Length of Candidate States: 1000
# Beam Search Iteration 20
#     Number of Candidate States: 9926
#         Length of Candidate States: 1000
# Beam Search Iteration 21
#     Number of Candidate States: 9574
#         Length of Candidate States: 1000
# Beam Search Iteration 22
#     Number of Candidate States: 10263
#         Length of Candidate States: 1000
# Beam Search Iteration 23
#     Number of Candidate States: 9225
#         Length of Candidate States: 1000
# Beam Search Iteration 24
#     Number of Candidate States: 9783
#         Length of Candidate States: 1000
# Beam Search Iteration 25
#     Number of Candidate States: 8700
#         Length of Candidate States: 1000
# Beam Search Iteration 26
#     Number of Candidate States: 9155
#         Length of Candidate States: 1000
# Beam Search Iteration 27
#     Number of Candidate States: 8875
#         Length of Candidate States: 1000
# Beam Search Iteration 28
#     Number of Candidate States: 7846
#         Length of Candidate States: 1000
# Beam Search Iteration 29
#     Number of Candidate States: 7761
#         Length of Candidate States: 1000
# Beam Search Iteration 30
#     Number of Candidate States: 7713
#         Length of Candidate States: 1000
# Beam Search Iteration 31
#     Number of Candidate States: 7614
#         Length of Candidate States: 1000
# Beam Search Iteration 32
#     Number of Candidate States: 8254
#         Length of Candidate States: 1000
# Beam Search Iteration 33
#     Number of Candidate States: 8690
#         Length of Candidate States: 1000
# Beam Search Iteration 34
#     Number of Candidate States: 8538
#         Length of Candidate States: 1000
# Beam Search Iteration 35
#     Number of Candidate States: 8775
#         Length of Candidate States: 1000
# Beam Search Iteration 36
#     Number of Candidate States: 9322
#         Length of Candidate States: 1000
# Beam Search Iteration 37
#     Number of Candidate States: 9553
#         Length of Candidate States: 1000
# Beam Search Iteration 38
#     Number of Candidate States: 9354
#     New Lowest Depth: 76
#         Length of Candidate States: 1000
# Beam Search Iteration 39
#     Number of Candidate States: 9314
#         Length of Candidate States: 1000
# Beam Search Iteration 40
#     Number of Candidate States: 9298
#         Length of Candidate States: 1000
# Beam Search Iteration 41
#     Number of Candidate States: 9263
#         Length of Candidate States: 1000
# Beam Search Iteration 42
#     Number of Candidate States: 9371
#         Length of Candidate States: 1000
# Beam Search Iteration 43
#     Number of Candidate States: 9667
#         Length of Candidate States: 1000
# Beam Search Iteration 44
#     Number of Candidate States: 9702
#         Length of Candidate States: 1000
# Beam Search Iteration 45
#     Number of Candidate States: 9443
#         Length of Candidate States: 1000
# Beam Search Iteration 46
#     Number of Candidate States: 9134
#         Length of Candidate States: 1000
# Beam Search Iteration 47
#     Number of Candidate States: 8627
#         Length of Candidate States: 1000
# Beam Search Iteration 48
#     Number of Candidate States: 8710
#         Length of Candidate States: 1000
# Beam Search Iteration 49
#     Number of Candidate States: 8872
#         Length of Candidate States: 1000
# Beam Search Iteration 50
#     Number of Candidate States: 8144
#         Length of Candidate States: 1000
# Beam Search Iteration 51
#     Number of Candidate States: 8661
#         Length of Candidate States: 1000
# Beam Search Iteration 52
#     Number of Candidate States: 8650
#         Length of Candidate States: 1000
# Beam Search Iteration 53
#     Number of Candidate States: 8314
#         Length of Candidate States: 1000
# Beam Search Iteration 54
#     Number of Candidate States: 8404
#     New Lowest Depth: 75
#         Length of Candidate States: 1000
# Beam Search Iteration 55
#     Number of Candidate States: 8534
#         Length of Candidate States: 1000
# Finished: 5 out of 7 with depth 75 and time 7631.990806102753
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 10000
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 4
#     New Lowest Depth: 114
#     New Lowest Depth: 113
#         Length of Candidate States: 4
# Beam Search Iteration 1
#     Number of Candidate States: 22
#     New Lowest Depth: 93
#         Length of Candidate States: 22
# Beam Search Iteration 2
#     Number of Candidate States: 124
#         Length of Candidate States: 124
# Beam Search Iteration 3
#     Number of Candidate States: 817
#     New Lowest Depth: 92
#     New Lowest Depth: 85
#         Length of Candidate States: 817
# Beam Search Iteration 4
#     Number of Candidate States: 5649
#     New Lowest Depth: 83
#         Length of Candidate States: 5649
# Beam Search Iteration 5
#     Number of Candidate States: 42573
#     New Lowest Depth: 81
#         Length of Candidate States: 10000
# Beam Search Iteration 6
#     Number of Candidate States: 79494
#     New Lowest Depth: 78
#         Length of Candidate States: 10000
# Beam Search Iteration 7
#     Number of Candidate States: 79640
#         Length of Candidate States: 10000
# Beam Search Iteration 8
#     Number of Candidate States: 79190
#         Length of Candidate States: 10000
# Beam Search Iteration 9
#     Number of Candidate States: 82605
#         Length of Candidate States: 10000
# Beam Search Iteration 10
#     Number of Candidate States: 81448
#         Length of Candidate States: 10000
# Beam Search Iteration 11
#     Number of Candidate States: 78508
#         Length of Candidate States: 10000
# Beam Search Iteration 12
#     Number of Candidate States: 78595
#     New Lowest Depth: 74
#         Length of Candidate States: 10000
# Beam Search Iteration 13
#     Number of Candidate States: 79871
#         Length of Candidate States: 10000
# Beam Search Iteration 14
#     Number of Candidate States: 74140
#         Length of Candidate States: 10000
# Beam Search Iteration 15
#     Number of Candidate States: 77067
#         Length of Candidate States: 10000
# Beam Search Iteration 16
#     Number of Candidate States: 79943
#         Length of Candidate States: 10000
# Beam Search Iteration 17
#     Number of Candidate States: 75423
#         Length of Candidate States: 10000
# Beam Search Iteration 18
#     Number of Candidate States: 78694
#         Length of Candidate States: 10000
# Beam Search Iteration 19
#     Number of Candidate States: 56349
#         Length of Candidate States: 10000
# Beam Search Iteration 20
#     Number of Candidate States: 67172
#         Length of Candidate States: 10000
# Beam Search Iteration 21
#     Number of Candidate States: 51298
#         Length of Candidate States: 10000
# Beam Search Iteration 22
#     Number of Candidate States: 59126
#         Length of Candidate States: 10000
# Beam Search Iteration 23
#     Number of Candidate States: 46229
#         Length of Candidate States: 10000
# Beam Search Iteration 24
#     Number of Candidate States: 58352
#         Length of Candidate States: 10000
# Beam Search Iteration 25
#     Number of Candidate States: 45090
#         Length of Candidate States: 10000
# Beam Search Iteration 26
#     Number of Candidate States: 58406
#         Length of Candidate States: 10000
# Beam Search Iteration 27
#     Number of Candidate States: 41562
#         Length of Candidate States: 10000
# Beam Search Iteration 28
#     Number of Candidate States: 53113
#         Length of Candidate States: 10000
# Beam Search Iteration 29
#     Number of Candidate States: 36724
#         Length of Candidate States: 10000
# Beam Search Iteration 30
#     Number of Candidate States: 45576
#         Length of Candidate States: 10000
# Beam Search Iteration 31
#     Number of Candidate States: 46116
#         Length of Candidate States: 10000
# Beam Search Iteration 32
#     Number of Candidate States: 38059
#     New Lowest Depth: 73
#         Length of Candidate States: 10000
# Beam Search Iteration 33
#     Number of Candidate States: 52979
#         Length of Candidate States: 10000
# Beam Search Iteration 34
#     Number of Candidate States: 40446
#         Length of Candidate States: 10000
# Beam Search Iteration 35
#     Number of Candidate States: 47235
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = run_beam_experiment(path, qc, rp_str, lp_str, cm, beam_list)
#
# File ~/Documents/GitHub/qiskit/workspace_experiments/experiment_setup/pass_managers.py:271, in run_beam_experiment(filename, qc, rp_str, lp_str, coupling_map, beam_list, seed, num_pm, look, num_iter, crit, max_iter)
#     268 for beam in beam_list:
#     269     pm_list = build_pm_list(rp_str, lp_str, coupling_map, num_pm, seed, look, beam,
#     270                             num_iter, crit, max_iter)
# --> 271     data = run_one_circuit(qc, pm_list)
#     272     data['rp'] = rp_str
#     273     data['lp'] = lp_str
#
# File ~/Documents/GitHub/qiskit/workspace_experiments/experiment_setup/pass_managers.py:155, in run_one_circuit(qc, pm_list)
#     152 for pm in pm_list:
#     153     # Timing the transpilation
#     154     start = time.time()
# --> 155     qc_tr = pm.run(qc)
#     156     end = time.time()
#     158     # Decompose the swaps gate in the circuit
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:420, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     417 @wraps(meth)
#     418 def wrapper(*meth_args, **meth_kwargs):
#     419     try:
# --> 420         return meth(*meth_args, **meth_kwargs)
#     421     except PassManagerError as ex:
#     422         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:182, in PassManager.run(self, circuits, output_name, callback, num_processes)
#     179 if callback is not None:
#     180     callback = _legacy_style_callback(callback)
# --> 182 return super().run(
#     183     in_programs=circuits,
#     184     callback=callback,
#     185     output_name=output_name,
#     186     num_processes=num_processes,
#     187 )
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:229, in BasePassManager.run(self, in_programs, callback, num_processes, **kwargs)
#     226     is_list = False
#     228 if len(in_programs) == 1:
# --> 229     out_program = _run_workflow(
#     230         program=in_programs[0],
#     231         pass_manager=self,
#     232         callback=callback,
#     233         **kwargs,
#     234     )
#     235     if is_list:
#     236         return [out_program]
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:292, in _run_workflow(program, pass_manager, **kwargs)
#     286 initial_status = WorkflowStatus()
#     288 passmanager_ir = pass_manager._passmanager_frontend(
#     289     input_program=program,
#     290     **kwargs,
#     291 )
# --> 292 passmanager_ir, final_state = flow_controller.execute(
#     293     passmanager_ir=passmanager_ir,
#     294     state=PassManagerState(
#     295         workflow_status=initial_status,
#     296         property_set=PropertySet(),
#     297     ),
#     298     callback=kwargs.get("callback", None),
#     299 )
#     300 # The `property_set` has historically been returned as a mutable attribute on `PassManager`
#     301 # This makes us non-reentrant (though `PassManager` would be dependent on its internal tasks to
#     302 # be re-entrant if that was required), but is consistent with previous interfaces.  We're still
#     303 # safe to be called in a serial loop, again assuming internal tasks are re-runnable.  The
#     304 # conversion to the backend language is also allowed to use the property set, so it must be set
#     305 # before calling it.
#     306 pass_manager.property_set = final_state.property_set
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:218, in BaseController.execute(self, passmanager_ir, state, callback)
#     216     return passmanager_ir, state
#     217 while True:
# --> 218     passmanager_ir, state = next_task.execute(
#     219         passmanager_ir=passmanager_ir,
#     220         state=state,
#     221         callback=callback,
#     222     )
#     223     try:
#     224         # Sending the object through the generator implies the custom controllers
#     225         # can always rely on the latest data to choose the next task to run.
#     226         next_task = task_generator.send(state)
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/basepasses.py:195, in TransformationPass.execute(self, passmanager_ir, state, callback)
#     189 def execute(
#     190     self,
#     191     passmanager_ir: PassManagerIR,
#     192     state: PassManagerState,
#     193     callback: Callable = None,
#     194 ) -> tuple[PassManagerIR, PassManagerState]:
# --> 195     new_dag, state = super().execute(
#     196         passmanager_ir=passmanager_ir,
#     197         state=state,
#     198         callback=callback,
#     199     )
#     201     if state.workflow_status.previous_run == RunState.SUCCESS:
#     202         if isinstance(new_dag, DAGCircuit):
#     203             # Copy calibration data from the original program
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:98, in GenericPass.execute(self, passmanager_ir, state, callback)
#      96 try:
#      97     if self not in state.workflow_status.completed_passes:
# ---> 98         ret = self.run(passmanager_ir)
#      99         run_state = RunState.SUCCESS
#     100     else:
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v0_20_dive.py:183, in SabreSwap.run(self, dag)
#     181 for state in candidate_states:
#     182     while state.front_layer:
# --> 183         self._apply_swap(state)
#     184         self._update_state(state)
#     186 # Phase 4a: Get list of depths of each candidate state and store the lowest depth
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v0_20_dive.py:464, in SabreSwap._apply_swap(self, state)
#     461 trial_state = State(trial_layout, state.front_layer.copy(), state.predecessors.copy(),
#     462                     trial_qubit_depth, None, 0)
#     463 self._update_state(trial_state, trial=True)
# --> 464 depth = max(trial_state.qubit_depth.values())
#     466 if score < best_score or (score == best_score and depth < best_depth):
#     467     best_swap = swap
#
# KeyboardInterrupt:
