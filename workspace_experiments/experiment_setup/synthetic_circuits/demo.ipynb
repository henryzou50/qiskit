# %%
from synthetic_circuits import create_parallel_circuit

# %%
# Set num_layers and num_qubits
num_layers = 3
num_qubits = 12

# Set coupling_map
from qiskit.transpiler import CouplingMap
cm = CouplingMap.from_ring(num_qubits)

# set density
density = 1

# set seed
seed = 42

# %%
qc = create_parallel_circuit(cm, num_layers, density, barrier=True, seed=seed)
qc.draw(output='mpl')
