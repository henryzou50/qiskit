# %%
from experiment_setup.circuits.circuit_files import get_circuits_from_directory

# %%
# Parameters to change
circuit = "red_queen"
qc_list_directory = f"experiment_setup/circuits/{circuit}/"
qc_list = get_circuits_from_directory(qc_list_directory, print_files=True)
qc_list_decomposed = []
for qc in qc_list:
    qc_decomposed = qc.decompose().decompose()
    qc_list_decomposed.append(qc_decomposed)
# Out:
# Row 2: qrng_n4.qasm
# Row 3: cat_state_n4.qasm
# Row 4: deutsch_n2.qasm
# Row 5: quantumwalks_n2.qasm
# Row 6: qft_n4.qasm
# Row 7: iswap_n2.qasm
# Row 8: qec_sm_n5.qasm
# Row 9: teleportation_n3.qasm
# Row 10: grover.qasm
# Row 11: qpe.qasm
# Row 12: quantum_teleportation.qasm
# Row 13: dj_constant.qasm
# Row 14: dj_balanced.qasm
# Row 15: inverseqft_n4.qasm
# Row 16: lpn_n5.qasm
# Row 17: fredkin_n3.qasm
# Row 18: toffoli_n3.qasm
# Row 19: shor_n5.qasm
# Row 20: grover_n2.qasm
# Row 21: wstate_n3.qasm
# Row 22: adder_n4.qasm
# Row 23: qaoa_n3.qasm
# Row 24: linearsolver_n3.qasm
# Row 25: bv.qasm
# Row 26: hs.qasm
# Row 27: multiply_n13.qasm
# Row 28: hs4_n4.qasm
# Row 29: adder_n10.qasm
# Row 30: simon_n6.qasm
# Row 31: qec_en_n5.qasm
# Row 32: knn_n25.qasm
# Row 33: swap_test_n25.qasm
# Row 34: ipe.qasm
# Row 35: basis_change_n3.qasm
# Row 36: cat_state_n22.qasm
# Row 37: bv_mcm.qasm
# Row 38: sat_n7.qasm
# Row 39: knn_n31.qasm
# Row 40: ghz_state_n23.qasm
# Row 41: pea_n5.qasm
# Row 42: bell_n4.qasm
# Row 43: qpe_n9.qasm
# Row 44: bigadder_n18.qasm
# Row 45: ipea_n2.qasm
# Row 46: bb84_n8.qasm
# Row 47: bv_n14.qasm
# Row 48: qec9xz_n17.qasm
# Row 49: swap_test_n41.qasm
# Row 50: knn_n41.qasm
# Row 51: ft_2.qasm
# Row 52: cc_n12.qasm
# Row 53: cat_n35.qasm
# Row 54: variational_n4.qasm
# Row 55: bv_n19.qasm
# Row 56: qram_n20.qasm
# Row 57: ghz_n40.qasm
# Row 58: multiplier_n15.qasm
# Row 59: vqe_n4.qasm
# Row 60: seca_n11.qasm
# Row 61: ft_1.qasm
# Row 62: qf21_n15.qasm
# Row 63: knn_n67.qasm
# Row 64: sat_n11.qasm
# Row 65: bv_n30.qasm
# Row 66: adder_n28.qasm
# Row 67: error_correctiond3_n5.qasm
# Row 68: basis_test_n4.qasm
# Row 69: swap_test_n83.qasm
# Row 70: cat_n65.qasm
# Row 71: wstate_n27.qasm
# Row 72: ghz_n78.qasm
# Row 73: cc_n32.qasm
# Row 74: swap_test_n115.qasm
# Row 75: wstate_n36.qasm
# Row 76: vqe_uccsd_n4.qasm
# Row 77: bv_n70.qasm
# Row 78: ghz_n127.qasm
# Row 79: dnn_n2.qasm
# Row 80: adder_n64.qasm
# Row 81: ising_n26.qasm
# Row 82: cc_n64.qasm
# Row 83: qaoa_n6.qasm
# Row 84: dnn_n33.qasm
# Row 85: wstate_n76.qasm
# Row 86: ising_n34.qasm
# Row 87: ising_n10.qasm
# Row 88: adder_n118.qasm
# Row 89: ising_n42.qasm
# Row 90: qugan_n39.qasm
# Row 91: dnn_n51.qasm
# Row 92: square_root_n18.qasm
# Row 93: wstate_n118.qasm
# Row 94: multiplier_n45.qasm
# Row 95: hhl_n7.qasm
# Row 96: ising_n66.qasm
# Row 97: qft_n18.qasm
# Row 98: qugan_n71.qasm
# Row 99: dnn_n8.qasm
# Row 100: ising_n98.qasm

# %%
from qiskit.converters import circuit_to_dag
directory 

dag_list = []
for qc in qc_list_decomposed:
    dag = circuit_to_dag(qc)

    dag_list.append(dag)
