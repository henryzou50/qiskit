# %%
from experiment_setup.pass_managers import run_experiment
from experiment_setup.circuits.circuit_files import get_circuits_from_directory
from experiment_setup.coupling_maps.coupling_maps_files import file_to_coupling_map
from qiskit.transpiler import CouplingMap

# %%
circuits_path_list = ["zou_circuits/answers_ring_27_sample",
                 "zou_circuits/answers_heavy_hex_27_sample",
                 "zou_circuits/answers_square_25_sample",             
                 ]
cm_ring   = CouplingMap.from_ring(27)
cm_hex    = file_to_coupling_map("experiment_setup/coupling_maps/heavy_hex_027.txt")
cm_square = CouplingMap.from_grid(5, 5)

cm_list =  [cm_ring, cm_hex, cm_square]

rp_str_list =  ["None"]

lp_str = "trivial_layout"

# %%
for i in range(len(circuits_path_list)):
    for rp_str in rp_str_list:
        circuit_path = circuits_path_list[i]
        cm           = cm_list[i]

        save_path =  f"results/{circuit_path}/{rp_str}.csv"

        qc_list_directory = f"experiment_setup/circuits/{circuit_path}"
        qc_list = get_circuits_from_directory(qc_list_directory)

        data = run_experiment(save_path, qc_list, rp_str, lp_str, cm, max_iter=3)
# Out:
# Using seed 42 for routing pass.
#     Building None routing pass
#         Using seed 42 and max iterations 3 for layout pass.
#             Building Trivial layout pass
# Using seed 43 for routing pass.
#     Building None routing pass
#         Using seed 43 and max iterations 3 for layout pass.
#             Building Trivial layout pass
# Using seed 44 for routing pass.
#     Building None routing pass
#         Using seed 44 and max iterations 3 for layout pass.
#             Building Trivial layout pass
# Using seed 45 for routing pass.
#     Building None routing pass
#         Using seed 45 and max iterations 3 for layout pass.
#             Building Trivial layout pass
# Finished: 0 out of 10 with depth 17 and time 0.002892732620239258
# Finished: 1 out of 10 with depth 32 and time 0.003402233123779297
# Finished: 2 out of 10 with depth 45 and time 0.004587888717651367
# Finished: 3 out of 10 with depth 64 and time 0.005462169647216797
# Finished: 4 out of 10 with depth 82 and time 0.0068700313568115234
# Finished: 5 out of 10 with depth 96 and time 0.008326053619384766
# Finished: 6 out of 10 with depth 110 and time 0.009067058563232422
# Finished: 7 out of 10 with depth 126 and time 0.011450052261352539
# Finished: 8 out of 10 with depth 143 and time 0.01247406005859375
# Finished: 9 out of 10 with depth 152 and time 0.013495922088623047
# Using seed 42 for routing pass.
#     Building None routing pass
#         Using seed 42 and max iterations 3 for layout pass.
#             Building Trivial layout pass
# Using seed 43 for routing pass.
#     Building None routing pass
#         Using seed 43 and max iterations 3 for layout pass.
#             Building Trivial layout pass
# Using seed 44 for routing pass.
#     Building None routing pass
#         Using seed 44 and max iterations 3 for layout pass.
#             Building Trivial layout pass
# Using seed 45 for routing pass.
#     Building None routing pass
#         Using seed 45 and max iterations 3 for layout pass.
#             Building Trivial layout pass
# Finished: 0 out of 10 with depth 17 and time 0.0016660690307617188
# Finished: 1 out of 10 with depth 37 and time 0.0026521682739257812
# Finished: 2 out of 10 with depth 55 and time 0.0041048526763916016
# Finished: 3 out of 10 with depth 66 and time 0.0054209232330322266
# Finished: 4 out of 10 with depth 73 and time 0.006322145462036133
# Finished: 5 out of 10 with depth 95 and time 0.007673978805541992
# Finished: 6 out of 10 with depth 115 and time 0.008250951766967773
# Finished: 7 out of 10 with depth 124 and time 0.009573936462402344
# Finished: 8 out of 10 with depth 148 and time 0.010549068450927734
# Finished: 9 out of 10 with depth 155 and time 0.01145482063293457
# Using seed 42 for routing pass.
#     Building None routing pass
#         Using seed 42 and max iterations 3 for layout pass.
#             Building Trivial layout pass
# Using seed 43 for routing pass.
#     Building None routing pass
#         Using seed 43 and max iterations 3 for layout pass.
#             Building Trivial layout pass
# Using seed 44 for routing pass.
#     Building None routing pass
#         Using seed 44 and max iterations 3 for layout pass.
#             Building Trivial layout pass
# Using seed 45 for routing pass.
#     Building None routing pass
#         Using seed 45 and max iterations 3 for layout pass.
#             Building Trivial layout pass
# Finished: 0 out of 10 with depth 19 and time 0.001753091812133789
# Finished: 1 out of 10 with depth 39 and time 0.003245830535888672
# Finished: 2 out of 10 with depth 56 and time 0.00438690185546875
# Finished: 3 out of 10 with depth 76 and time 0.005609035491943359
# Finished: 4 out of 10 with depth 98 and time 0.007127046585083008
# Finished: 5 out of 10 with depth 108 and time 0.008109807968139648
# Finished: 6 out of 10 with depth 127 and time 0.009181022644042969
# Finished: 7 out of 10 with depth 146 and time 0.010617971420288086
# Finished: 8 out of 10 with depth 157 and time 0.011512041091918945
# Finished: 9 out of 10 with depth 197 and time 0.01324915885925293
