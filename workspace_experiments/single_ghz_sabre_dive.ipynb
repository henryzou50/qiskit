# %%
from experiment_setup.pass_managers import run_beam_experiment
from experiment_setup.circuits.circuit_files import get_circuits_from_directory
from experiment_setup.coupling_maps.coupling_maps_files import file_to_coupling_map

# %%
# Parameters to change
circuit = "ghz_25"
rp_str  = "sabre_v0_20_dive"
lp_str  = "fast_layout"
cp_str  = "heavy_hex_027"

beam_list = range(1, 1000)

# %%
path = f"results/{circuit}/{rp_str}.csv"
cm_filename = f"experiment_setup/coupling_maps/{cp_str}.txt"

qc_list_directory = f"experiment_setup/circuits/{circuit}/"
qc_list = get_circuits_from_directory(qc_list_directory)
cm = file_to_coupling_map(cm_filename)
qc = qc_list[0]

# %%
data = run_beam_experiment(path, qc, rp_str, lp_str, cm, beam_list)
# Out:
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 1
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 1
# Beam Search Iteration 1
#     Number of Candidate States: 5
#         Length of Candidate States: 1
# Beam Search Iteration 2
#     Number of Candidate States: 5
#         Length of Candidate States: 1
# Beam Search Iteration 3
#     Number of Candidate States: 4
#     New Lowest Depth: 87
#         Length of Candidate States: 1
# Beam Search Iteration 4
#     Number of Candidate States: 5
#         Length of Candidate States: 1
# Beam Search Iteration 5
#     Number of Candidate States: 4
#         Length of Candidate States: 1
# Beam Search Iteration 6
#     Number of Candidate States: 4
#         Length of Candidate States: 1
# Beam Search Iteration 7
#     Number of Candidate States: 5
#         Length of Candidate States: 1
# Beam Search Iteration 8
#     Number of Candidate States: 3
#         Length of Candidate States: 1
# Beam Search Iteration 9
#     Number of Candidate States: 5
#         Length of Candidate States: 1
# Beam Search Iteration 10
#     Number of Candidate States: 4
#         Length of Candidate States: 1
# Beam Search Iteration 11
#     Number of Candidate States: 4
#         Length of Candidate States: 1
# Beam Search Iteration 12
#     Number of Candidate States: 3
#         Length of Candidate States: 1
# Beam Search Iteration 13
#     Number of Candidate States: 5
#         Length of Candidate States: 1
# Beam Search Iteration 14
#     Number of Candidate States: 4
#         Length of Candidate States: 1
# Beam Search Iteration 15
#     Number of Candidate States: 5
#         Length of Candidate States: 1
# Beam Search Iteration 16
#     Number of Candidate States: 6
#         Length of Candidate States: 1
# Beam Search Iteration 17
#     Number of Candidate States: 4
#         Length of Candidate States: 1
# Beam Search Iteration 18
#     Number of Candidate States: 3
#         Length of Candidate States: 1
# Beam Search Iteration 19
#     Number of Candidate States: 6
#         Length of Candidate States: 1
# Beam Search Iteration 20
#     Number of Candidate States: 5
#         Length of Candidate States: 1
# Beam Search Iteration 21
#     Number of Candidate States: 6
#         Length of Candidate States: 1
# Beam Search Iteration 22
#     Number of Candidate States: 5
#         Length of Candidate States: 1
# Beam Search Iteration 23
#     Number of Candidate States: 6
#         Length of Candidate States: 1
# Beam Search Iteration 24
#     Number of Candidate States: 5
#         Length of Candidate States: 1
# Finished: 0 out of 999 with depth 87 and time 0.28327202796936035
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 2
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 2
# Beam Search Iteration 1
#     Number of Candidate States: 10
#         Length of Candidate States: 2
# Beam Search Iteration 2
#     Number of Candidate States: 9
#         Length of Candidate States: 2
# Beam Search Iteration 3
#     Number of Candidate States: 8
#     New Lowest Depth: 87
#         Length of Candidate States: 2
# Beam Search Iteration 4
#     Number of Candidate States: 10
#         Length of Candidate States: 2
# Beam Search Iteration 5
#     Number of Candidate States: 9
#         Length of Candidate States: 2
# Beam Search Iteration 6
#     Number of Candidate States: 9
#         Length of Candidate States: 2
# Beam Search Iteration 7
#     Number of Candidate States: 9
#         Length of Candidate States: 2
# Beam Search Iteration 8
#     Number of Candidate States: 6
#         Length of Candidate States: 2
# Beam Search Iteration 9
#     Number of Candidate States: 8
#         Length of Candidate States: 2
# Beam Search Iteration 10
#     Number of Candidate States: 9
#         Length of Candidate States: 2
# Beam Search Iteration 11
#     Number of Candidate States: 9
#         Length of Candidate States: 2
# Beam Search Iteration 12
#     Number of Candidate States: 6
#         Length of Candidate States: 2
# Beam Search Iteration 13
#     Number of Candidate States: 9
#         Length of Candidate States: 2
# Beam Search Iteration 14
#     Number of Candidate States: 10
#         Length of Candidate States: 2
# Beam Search Iteration 15
#     Number of Candidate States: 10
#         Length of Candidate States: 2
# Beam Search Iteration 16
#     Number of Candidate States: 12
#         Length of Candidate States: 2
# Beam Search Iteration 17
#     Number of Candidate States: 9
#         Length of Candidate States: 2
# Beam Search Iteration 18
#     Number of Candidate States: 7
#         Length of Candidate States: 2
# Beam Search Iteration 19
#     Number of Candidate States: 11
#         Length of Candidate States: 2
# Beam Search Iteration 20
#     Number of Candidate States: 10
#         Length of Candidate States: 2
# Beam Search Iteration 21
#     Number of Candidate States: 11
#         Length of Candidate States: 2
# Beam Search Iteration 22
#     Number of Candidate States: 10
#         Length of Candidate States: 2
# Beam Search Iteration 23
#     Number of Candidate States: 11
#         Length of Candidate States: 2
# Beam Search Iteration 24
#     Number of Candidate States: 10
#         Length of Candidate States: 2
# Finished: 1 out of 999 with depth 87 and time 0.4791858196258545
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 3
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 3
# Beam Search Iteration 1
#     Number of Candidate States: 15
#         Length of Candidate States: 3
# Beam Search Iteration 2
#     Number of Candidate States: 13
#         Length of Candidate States: 3
# Beam Search Iteration 3
#     Number of Candidate States: 12
#     New Lowest Depth: 87
#         Length of Candidate States: 3
# Beam Search Iteration 4
#     Number of Candidate States: 15
#         Length of Candidate States: 3
# Beam Search Iteration 5
#     Number of Candidate States: 13
#         Length of Candidate States: 3
# Beam Search Iteration 6
#     Number of Candidate States: 13
#         Length of Candidate States: 3
# Beam Search Iteration 7
#     Number of Candidate States: 14
#         Length of Candidate States: 3
# Beam Search Iteration 8
#     Number of Candidate States: 9
#         Length of Candidate States: 3
# Beam Search Iteration 9
#     Number of Candidate States: 13
#         Length of Candidate States: 3
# Beam Search Iteration 10
#     Number of Candidate States: 14
#         Length of Candidate States: 3
# Beam Search Iteration 11
#     Number of Candidate States: 13
#         Length of Candidate States: 3
# Beam Search Iteration 12
#     Number of Candidate States: 9
#         Length of Candidate States: 3
# Beam Search Iteration 13
#     Number of Candidate States: 14
#         Length of Candidate States: 3
# Beam Search Iteration 14
#     Number of Candidate States: 16
#         Length of Candidate States: 3
# Beam Search Iteration 15
#     Number of Candidate States: 15
#         Length of Candidate States: 3
# Beam Search Iteration 16
#     Number of Candidate States: 16
#         Length of Candidate States: 3
# Beam Search Iteration 17
#     Number of Candidate States: 14
#     New Lowest Depth: 85
#         Length of Candidate States: 3
# Beam Search Iteration 18
#     Number of Candidate States: 13
#         Length of Candidate States: 3
# Beam Search Iteration 19
#     Number of Candidate States: 15
#         Length of Candidate States: 3
# Beam Search Iteration 20
#     Number of Candidate States: 14
#         Length of Candidate States: 3
# Beam Search Iteration 21
#     Number of Candidate States: 15
#         Length of Candidate States: 3
# Beam Search Iteration 22
#     Number of Candidate States: 13
#         Length of Candidate States: 3
# Beam Search Iteration 23
#     Number of Candidate States: 15
#         Length of Candidate States: 3
# Beam Search Iteration 24
#     Number of Candidate States: 11
#         Length of Candidate States: 3
# Finished: 2 out of 999 with depth 85 and time 0.7424209117889404
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 4
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 4
# Beam Search Iteration 1
#     Number of Candidate States: 20
#         Length of Candidate States: 4
# Beam Search Iteration 2
#     Number of Candidate States: 18
#         Length of Candidate States: 4
# Beam Search Iteration 3
#     Number of Candidate States: 16
#     New Lowest Depth: 87
#         Length of Candidate States: 4
# Beam Search Iteration 4
#     Number of Candidate States: 19
#         Length of Candidate States: 4
# Beam Search Iteration 5
#     Number of Candidate States: 18
#         Length of Candidate States: 4
# Beam Search Iteration 6
#     Number of Candidate States: 17
#         Length of Candidate States: 4
# Beam Search Iteration 7
#     Number of Candidate States: 19
#         Length of Candidate States: 4
# Beam Search Iteration 8
#     Number of Candidate States: 12
#         Length of Candidate States: 4
# Beam Search Iteration 9
#     Number of Candidate States: 16
#         Length of Candidate States: 4
# Beam Search Iteration 10
#     Number of Candidate States: 18
#         Length of Candidate States: 4
# Beam Search Iteration 11
#     Number of Candidate States: 17
#         Length of Candidate States: 4
# Beam Search Iteration 12
#     Number of Candidate States: 12
#         Length of Candidate States: 4
# Beam Search Iteration 13
#     Number of Candidate States: 18
#         Length of Candidate States: 4
# Beam Search Iteration 14
#     Number of Candidate States: 20
#         Length of Candidate States: 4
# Beam Search Iteration 15
#     Number of Candidate States: 20
#         Length of Candidate States: 4
# Beam Search Iteration 16
#     Number of Candidate States: 22
#         Length of Candidate States: 4
# Beam Search Iteration 17
#     Number of Candidate States: 19
#     New Lowest Depth: 85
#         Length of Candidate States: 4
# Beam Search Iteration 18
#     Number of Candidate States: 17
#         Length of Candidate States: 4
# Beam Search Iteration 19
#     Number of Candidate States: 20
#         Length of Candidate States: 4
# Beam Search Iteration 20
#     Number of Candidate States: 20
#         Length of Candidate States: 4
# Beam Search Iteration 21
#     Number of Candidate States: 20
#         Length of Candidate States: 4
# Beam Search Iteration 22
#     Number of Candidate States: 17
#         Length of Candidate States: 4
# Beam Search Iteration 23
#     Number of Candidate States: 20
#         Length of Candidate States: 4
# Beam Search Iteration 24
#     Number of Candidate States: 15
#         Length of Candidate States: 4
# Finished: 3 out of 999 with depth 85 and time 0.9591171741485596
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 5
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 24
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 22
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 20
#     New Lowest Depth: 87
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 24
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 22
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 22
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 24
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 15
#         Length of Candidate States: 5
# Beam Search Iteration 9
#     Number of Candidate States: 21
#         Length of Candidate States: 5
# Beam Search Iteration 10
#     Number of Candidate States: 23
#         Length of Candidate States: 5
# Beam Search Iteration 11
#     Number of Candidate States: 21
#         Length of Candidate States: 5
# Beam Search Iteration 12
#     Number of Candidate States: 15
#         Length of Candidate States: 5
# Beam Search Iteration 13
#     Number of Candidate States: 23
#         Length of Candidate States: 5
# Beam Search Iteration 14
#     Number of Candidate States: 26
#         Length of Candidate States: 5
# Beam Search Iteration 15
#     Number of Candidate States: 25
#         Length of Candidate States: 5
# Beam Search Iteration 16
#     Number of Candidate States: 28
#         Length of Candidate States: 5
# Beam Search Iteration 17
#     Number of Candidate States: 24
#     New Lowest Depth: 85
#         Length of Candidate States: 5
# Beam Search Iteration 18
#     Number of Candidate States: 23
#         Length of Candidate States: 5
# Beam Search Iteration 19
#     Number of Candidate States: 26
#         Length of Candidate States: 5
# Beam Search Iteration 20
#     Number of Candidate States: 24
#         Length of Candidate States: 5
# Beam Search Iteration 21
#     Number of Candidate States: 25
#         Length of Candidate States: 5
# Beam Search Iteration 22
#     Number of Candidate States: 21
#         Length of Candidate States: 5
# Beam Search Iteration 23
#     Number of Candidate States: 25
#         Length of Candidate States: 5
# Beam Search Iteration 24
#     Number of Candidate States: 19
#         Length of Candidate States: 5
# Finished: 4 out of 999 with depth 85 and time 1.2120790481567383
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 6
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 6
# Beam Search Iteration 1
#     Number of Candidate States: 28
#         Length of Candidate States: 6
# Beam Search Iteration 2
#     Number of Candidate States: 28
#         Length of Candidate States: 6
# Beam Search Iteration 3
#     Number of Candidate States: 24
#     New Lowest Depth: 87
#         Length of Candidate States: 6
# Beam Search Iteration 4
#     Number of Candidate States: 28
#         Length of Candidate States: 6
# Beam Search Iteration 5
#     Number of Candidate States: 27
#         Length of Candidate States: 6
# Beam Search Iteration 6
#     Number of Candidate States: 26
#         Length of Candidate States: 6
# Beam Search Iteration 7
#     Number of Candidate States: 28
#         Length of Candidate States: 6
# Beam Search Iteration 8
#     Number of Candidate States: 18
#         Length of Candidate States: 6
# Beam Search Iteration 9
#     Number of Candidate States: 24
#         Length of Candidate States: 6
# Beam Search Iteration 10
#     Number of Candidate States: 28
#         Length of Candidate States: 6
# Beam Search Iteration 11
#     Number of Candidate States: 26
#         Length of Candidate States: 6
# Beam Search Iteration 12
#     Number of Candidate States: 18
#         Length of Candidate States: 6
# Beam Search Iteration 13
#     Number of Candidate States: 27
#         Length of Candidate States: 6
# Beam Search Iteration 14
#     Number of Candidate States: 32
#         Length of Candidate States: 6
# Beam Search Iteration 15
#     Number of Candidate States: 30
#         Length of Candidate States: 6
# Beam Search Iteration 16
#     Number of Candidate States: 32
#         Length of Candidate States: 6
# Beam Search Iteration 17
#     Number of Candidate States: 29
#     New Lowest Depth: 85
#         Length of Candidate States: 6
# Beam Search Iteration 18
#     Number of Candidate States: 26
#         Length of Candidate States: 6
# Beam Search Iteration 19
#     Number of Candidate States: 31
#         Length of Candidate States: 6
# Beam Search Iteration 20
#     Number of Candidate States: 28
#         Length of Candidate States: 6
# Beam Search Iteration 21
#     Number of Candidate States: 30
#         Length of Candidate States: 6
# Beam Search Iteration 22
#     Number of Candidate States: 27
#         Length of Candidate States: 6
# Beam Search Iteration 23
#     Number of Candidate States: 29
#         Length of Candidate States: 6
# Beam Search Iteration 24
#     Number of Candidate States: 22
#         Length of Candidate States: 6
# Finished: 5 out of 999 with depth 85 and time 1.417414903640747
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 7
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 6
# Beam Search Iteration 1
#     Number of Candidate States: 28
#         Length of Candidate States: 7
# Beam Search Iteration 2
#     Number of Candidate States: 31
#         Length of Candidate States: 7
# Beam Search Iteration 3
#     Number of Candidate States: 28
#     New Lowest Depth: 87
#         Length of Candidate States: 7
# Beam Search Iteration 4
#     Number of Candidate States: 33
#         Length of Candidate States: 7
# Beam Search Iteration 5
#     Number of Candidate States: 32
#         Length of Candidate States: 7
# Beam Search Iteration 6
#     Number of Candidate States: 30
#         Length of Candidate States: 7
# Beam Search Iteration 7
#     Number of Candidate States: 33
#         Length of Candidate States: 7
# Beam Search Iteration 8
#     Number of Candidate States: 21
#         Length of Candidate States: 7
# Beam Search Iteration 9
#     Number of Candidate States: 29
#         Length of Candidate States: 7
# Beam Search Iteration 10
#     Number of Candidate States: 32
#         Length of Candidate States: 7
# Beam Search Iteration 11
#     Number of Candidate States: 30
#         Length of Candidate States: 7
# Beam Search Iteration 12
#     Number of Candidate States: 21
#         Length of Candidate States: 7
# Beam Search Iteration 13
#     Number of Candidate States: 32
#         Length of Candidate States: 7
# Beam Search Iteration 14
#     Number of Candidate States: 36
#         Length of Candidate States: 7
# Beam Search Iteration 15
#     Number of Candidate States: 35
#         Length of Candidate States: 7
# Beam Search Iteration 16
#     Number of Candidate States: 38
#         Length of Candidate States: 7
# Beam Search Iteration 17
#     Number of Candidate States: 34
#     New Lowest Depth: 85
#         Length of Candidate States: 7
# Beam Search Iteration 18
#     Number of Candidate States: 32
#         Length of Candidate States: 7
# Beam Search Iteration 19
#     Number of Candidate States: 35
#         Length of Candidate States: 7
# Beam Search Iteration 20
#     Number of Candidate States: 33
#         Length of Candidate States: 7
# Beam Search Iteration 21
#     Number of Candidate States: 35
#         Length of Candidate States: 7
# Beam Search Iteration 22
#     Number of Candidate States: 31
#         Length of Candidate States: 7
# Beam Search Iteration 23
#     Number of Candidate States: 34
#         Length of Candidate States: 7
# Beam Search Iteration 24
#     Number of Candidate States: 26
#         Length of Candidate States: 7
# Finished: 6 out of 999 with depth 85 and time 1.6467630863189697
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 8
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 6
# Beam Search Iteration 1
#     Number of Candidate States: 28
#         Length of Candidate States: 8
# Beam Search Iteration 2
#     Number of Candidate States: 35
#         Length of Candidate States: 8
# Beam Search Iteration 3
#     Number of Candidate States: 33
#     New Lowest Depth: 87
#         Length of Candidate States: 8
# Beam Search Iteration 4
#     Number of Candidate States: 37
#         Length of Candidate States: 8
# Beam Search Iteration 5
#     Number of Candidate States: 37
#         Length of Candidate States: 8
# Beam Search Iteration 6
#     Number of Candidate States: 35
#         Length of Candidate States: 8
# Beam Search Iteration 7
#     Number of Candidate States: 38
#         Length of Candidate States: 8
# Beam Search Iteration 8
#     Number of Candidate States: 24
#         Length of Candidate States: 8
# Beam Search Iteration 9
#     Number of Candidate States: 32
#         Length of Candidate States: 8
# Beam Search Iteration 10
#     Number of Candidate States: 37
#         Length of Candidate States: 8
# Beam Search Iteration 11
#     Number of Candidate States: 34
#         Length of Candidate States: 8
# Beam Search Iteration 12
#     Number of Candidate States: 24
#         Length of Candidate States: 8
# Beam Search Iteration 13
#     Number of Candidate States: 36
#         Length of Candidate States: 8
# Beam Search Iteration 14
#     Number of Candidate States: 42
#         Length of Candidate States: 8
# Beam Search Iteration 15
#     Number of Candidate States: 40
#         Length of Candidate States: 8
# Beam Search Iteration 16
#     Number of Candidate States: 44
#         Length of Candidate States: 8
# Beam Search Iteration 17
#     Number of Candidate States: 39
#     New Lowest Depth: 85
#         Length of Candidate States: 8
# Beam Search Iteration 18
#     Number of Candidate States: 36
#         Length of Candidate States: 8
# Beam Search Iteration 19
#     Number of Candidate States: 40
#         Length of Candidate States: 8
# Beam Search Iteration 20
#     Number of Candidate States: 38
#         Length of Candidate States: 8
# Beam Search Iteration 21
#     Number of Candidate States: 40
#         Length of Candidate States: 8
# Beam Search Iteration 22
#     Number of Candidate States: 35
#         Length of Candidate States: 8
# Beam Search Iteration 23
#     Number of Candidate States: 39
#         Length of Candidate States: 8
# Beam Search Iteration 24
#     Number of Candidate States: 30
#         Length of Candidate States: 8
# Finished: 7 out of 999 with depth 85 and time 1.850466012954712
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 9
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 6
# Beam Search Iteration 1
#     Number of Candidate States: 28
#         Length of Candidate States: 9
# Beam Search Iteration 2
#     Number of Candidate States: 38
#         Length of Candidate States: 9
# Beam Search Iteration 3
#     Number of Candidate States: 36
#     New Lowest Depth: 87
#         Length of Candidate States: 9
# Beam Search Iteration 4
#     Number of Candidate States: 42
#         Length of Candidate States: 9
# Beam Search Iteration 5
#     Number of Candidate States: 42
#         Length of Candidate States: 9
# Beam Search Iteration 6
#     Number of Candidate States: 39
#         Length of Candidate States: 9
# Beam Search Iteration 7
#     Number of Candidate States: 43
#         Length of Candidate States: 9
# Beam Search Iteration 8
#     Number of Candidate States: 27
#         Length of Candidate States: 9
# Beam Search Iteration 9
#     Number of Candidate States: 37
#         Length of Candidate States: 9
# Beam Search Iteration 10
#     Number of Candidate States: 42
#         Length of Candidate States: 9
# Beam Search Iteration 11
#     Number of Candidate States: 38
#         Length of Candidate States: 9
# Beam Search Iteration 12
#     Number of Candidate States: 27
#         Length of Candidate States: 9
# Beam Search Iteration 13
#     Number of Candidate States: 41
#         Length of Candidate States: 9
# Beam Search Iteration 14
#     Number of Candidate States: 48
#         Length of Candidate States: 9
# Beam Search Iteration 15
#     Number of Candidate States: 45
#         Length of Candidate States: 9
# Beam Search Iteration 16
#     Number of Candidate States: 48
#         Length of Candidate States: 9
# Beam Search Iteration 17
#     Number of Candidate States: 43
#     New Lowest Depth: 85
#         Length of Candidate States: 9
# Beam Search Iteration 18
#     Number of Candidate States: 42
#         Length of Candidate States: 9
# Beam Search Iteration 19
#     Number of Candidate States: 45
#         Length of Candidate States: 9
# Beam Search Iteration 20
#     Number of Candidate States: 42
#         Length of Candidate States: 9
# Beam Search Iteration 21
#     Number of Candidate States: 46
#         Length of Candidate States: 9
# Beam Search Iteration 22
#     Number of Candidate States: 39
#         Length of Candidate States: 9
# Beam Search Iteration 23
#     Number of Candidate States: 44
#         Length of Candidate States: 9
# Beam Search Iteration 24
#     Number of Candidate States: 33
#         Length of Candidate States: 9
# Finished: 8 out of 999 with depth 85 and time 2.0532329082489014
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 10
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 6
# Beam Search Iteration 1
#     Number of Candidate States: 28
#         Length of Candidate States: 10
# Beam Search Iteration 2
#     Number of Candidate States: 44
#         Length of Candidate States: 10
# Beam Search Iteration 3
#     Number of Candidate States: 40
#     New Lowest Depth: 87
#         Length of Candidate States: 10
# Beam Search Iteration 4
#     Number of Candidate States: 47
#         Length of Candidate States: 10
# Beam Search Iteration 5
#     Number of Candidate States: 47
#         Length of Candidate States: 10
# Beam Search Iteration 6
#     Number of Candidate States: 43
#         Length of Candidate States: 10
# Beam Search Iteration 7
#     Number of Candidate States: 47
#         Length of Candidate States: 10
# Beam Search Iteration 8
#     Number of Candidate States: 30
#         Length of Candidate States: 10
# Beam Search Iteration 9
#     Number of Candidate States: 40
#         Length of Candidate States: 10
# Beam Search Iteration 10
#     Number of Candidate States: 46
#         Length of Candidate States: 10
# Beam Search Iteration 11
#     Number of Candidate States: 43
#         Length of Candidate States: 10
# Beam Search Iteration 12
#     Number of Candidate States: 30
#         Length of Candidate States: 10
# Beam Search Iteration 13
#     Number of Candidate States: 45
#         Length of Candidate States: 10
# Beam Search Iteration 14
#     Number of Candidate States: 52
#         Length of Candidate States: 10
# Beam Search Iteration 15
#     Number of Candidate States: 50
#         Length of Candidate States: 10
# Beam Search Iteration 16
#     Number of Candidate States: 54
#         Length of Candidate States: 10
# Beam Search Iteration 17
#     Number of Candidate States: 48
#     New Lowest Depth: 85
#         Length of Candidate States: 10
# Beam Search Iteration 18
#     Number of Candidate States: 48
#         Length of Candidate States: 10
# Beam Search Iteration 19
#     Number of Candidate States: 50
#         Length of Candidate States: 10
# Beam Search Iteration 20
#     Number of Candidate States: 46
#         Length of Candidate States: 10
# Beam Search Iteration 21
#     Number of Candidate States: 51
#         Length of Candidate States: 10
# Beam Search Iteration 22
#     Number of Candidate States: 43
#         Length of Candidate States: 10
# Beam Search Iteration 23
#     Number of Candidate States: 49
#         Length of Candidate States: 10
# Beam Search Iteration 24
#     Number of Candidate States: 37
#         Length of Candidate States: 10
# Finished: 9 out of 999 with depth 85 and time 2.266664981842041
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 11
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 6
# Beam Search Iteration 1
#     Number of Candidate States: 28
#         Length of Candidate States: 11
# Beam Search Iteration 2
#     Number of Candidate States: 48
#         Length of Candidate States: 11
# Beam Search Iteration 3
#     Number of Candidate States: 45
#     New Lowest Depth: 87
#         Length of Candidate States: 11
# Beam Search Iteration 4
#     Number of Candidate States: 51
#         Length of Candidate States: 11
# Beam Search Iteration 5
#     Number of Candidate States: 51
#         Length of Candidate States: 11
# Beam Search Iteration 6
#     Number of Candidate States: 47
#         Length of Candidate States: 11
# Beam Search Iteration 7
#     Number of Candidate States: 52
#         Length of Candidate States: 11
# Beam Search Iteration 8
#     Number of Candidate States: 33
#         Length of Candidate States: 11
# Beam Search Iteration 9
#     Number of Candidate States: 45
#         Length of Candidate States: 11
# Beam Search Iteration 10
#     Number of Candidate States: 51
#         Length of Candidate States: 11
# Beam Search Iteration 11
#     Number of Candidate States: 47
#         Length of Candidate States: 11
# Beam Search Iteration 12
#     Number of Candidate States: 33
#         Length of Candidate States: 11
# Beam Search Iteration 13
#     Number of Candidate States: 50
#         Length of Candidate States: 11
# Beam Search Iteration 14
#     Number of Candidate States: 58
#         Length of Candidate States: 11
# Beam Search Iteration 15
#     Number of Candidate States: 55
#         Length of Candidate States: 11
# Beam Search Iteration 16
#     Number of Candidate States: 60
#         Length of Candidate States: 11
# Beam Search Iteration 17
#     Number of Candidate States: 53
#     New Lowest Depth: 85
#         Length of Candidate States: 11
# Beam Search Iteration 18
#     Number of Candidate States: 54
#         Length of Candidate States: 11
# Beam Search Iteration 19
#     Number of Candidate States: 55
#         Length of Candidate States: 11
# Beam Search Iteration 20
#     Number of Candidate States: 52
#         Length of Candidate States: 11
# Beam Search Iteration 21
#     Number of Candidate States: 55
#         Length of Candidate States: 11
# Beam Search Iteration 22
#     Number of Candidate States: 48
#         Length of Candidate States: 11
# Beam Search Iteration 23
#     Number of Candidate States: 54
#         Length of Candidate States: 11
# Beam Search Iteration 24
#     Number of Candidate States: 41
#         Length of Candidate States: 11
# Finished: 10 out of 999 with depth 85 and time 2.5731892585754395
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 12
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 6
# Beam Search Iteration 1
#     Number of Candidate States: 28
#         Length of Candidate States: 12
# Beam Search Iteration 2
#     Number of Candidate States: 54
#         Length of Candidate States: 12
# Beam Search Iteration 3
#     Number of Candidate States: 50
#     New Lowest Depth: 87
#         Length of Candidate States: 12
# Beam Search Iteration 4
#     Number of Candidate States: 56
#         Length of Candidate States: 12
# Beam Search Iteration 5
#     Number of Candidate States: 56
#         Length of Candidate States: 12
# Beam Search Iteration 6
#     Number of Candidate States: 51
#         Length of Candidate States: 12
# Beam Search Iteration 7
#     Number of Candidate States: 57
#         Length of Candidate States: 12
# Beam Search Iteration 8
#     Number of Candidate States: 36
#         Length of Candidate States: 12
# Beam Search Iteration 9
#     Number of Candidate States: 48
#         Length of Candidate States: 12
# Beam Search Iteration 10
#     Number of Candidate States: 56
#         Length of Candidate States: 12
# Beam Search Iteration 11
#     Number of Candidate States: 51
#         Length of Candidate States: 12
# Beam Search Iteration 12
#     Number of Candidate States: 36
#         Length of Candidate States: 12
# Beam Search Iteration 13
#     Number of Candidate States: 54
#         Length of Candidate States: 12
# Beam Search Iteration 14
#     Number of Candidate States: 64
#         Length of Candidate States: 12
# Beam Search Iteration 15
#     Number of Candidate States: 60
#         Length of Candidate States: 12
# Beam Search Iteration 16
#     Number of Candidate States: 64
#         Length of Candidate States: 12
# Beam Search Iteration 17
#     Number of Candidate States: 58
#     New Lowest Depth: 85
#         Length of Candidate States: 12
# Beam Search Iteration 18
#     Number of Candidate States: 58
#         Length of Candidate States: 12
# Beam Search Iteration 19
#     Number of Candidate States: 60
#         Length of Candidate States: 12
# Beam Search Iteration 20
#     Number of Candidate States: 56
#         Length of Candidate States: 12
# Beam Search Iteration 21
#     Number of Candidate States: 60
#         Length of Candidate States: 12
# Beam Search Iteration 22
#     Number of Candidate States: 52
#         Length of Candidate States: 12
# Beam Search Iteration 23
#     Number of Candidate States: 59
#         Length of Candidate States: 12
# Beam Search Iteration 24
#     Number of Candidate States: 44
#         Length of Candidate States: 12
# Finished: 11 out of 999 with depth 85 and time 2.7728960514068604
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 13
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 6
# Beam Search Iteration 1
#     Number of Candidate States: 28
#         Length of Candidate States: 13
# Beam Search Iteration 2
#     Number of Candidate States: 58
#         Length of Candidate States: 13
# Beam Search Iteration 3
#     Number of Candidate States: 54
#     New Lowest Depth: 87
#         Length of Candidate States: 13
# Beam Search Iteration 4
#     Number of Candidate States: 61
#         Length of Candidate States: 13
# Beam Search Iteration 5
#     Number of Candidate States: 61
#         Length of Candidate States: 13
# Beam Search Iteration 6
#     Number of Candidate States: 54
#         Length of Candidate States: 13
# Beam Search Iteration 7
#     Number of Candidate States: 62
#         Length of Candidate States: 13
# Beam Search Iteration 8
#     Number of Candidate States: 39
#         Length of Candidate States: 13
# Beam Search Iteration 9
#     Number of Candidate States: 53
#         Length of Candidate States: 13
# Beam Search Iteration 10
#     Number of Candidate States: 60
#         Length of Candidate States: 13
# Beam Search Iteration 11
#     Number of Candidate States: 55
#         Length of Candidate States: 13
# Beam Search Iteration 12
#     Number of Candidate States: 39
#         Length of Candidate States: 13
# Beam Search Iteration 13
#     Number of Candidate States: 59
#         Length of Candidate States: 13
# Beam Search Iteration 14
#     Number of Candidate States: 68
#         Length of Candidate States: 13
# Beam Search Iteration 15
#     Number of Candidate States: 65
#         Length of Candidate States: 13
# Beam Search Iteration 16
#     Number of Candidate States: 70
#         Length of Candidate States: 13
# Beam Search Iteration 17
#     Number of Candidate States: 63
#     New Lowest Depth: 85
#         Length of Candidate States: 13
# Beam Search Iteration 18
#     Number of Candidate States: 64
#         Length of Candidate States: 13
# Beam Search Iteration 19
#     Number of Candidate States: 65
#         Length of Candidate States: 13
# Beam Search Iteration 20
#     Number of Candidate States: 61
#         Length of Candidate States: 13
# Beam Search Iteration 21
#     Number of Candidate States: 65
#         Length of Candidate States: 13
# Beam Search Iteration 22
#     Number of Candidate States: 56
#         Length of Candidate States: 13
# Beam Search Iteration 23
#     Number of Candidate States: 64
#         Length of Candidate States: 13
# Beam Search Iteration 24
#     Number of Candidate States: 48
#         Length of Candidate States: 13
# Finished: 12 out of 999 with depth 85 and time 2.9368367195129395
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 14
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 6
# Beam Search Iteration 1
#     Number of Candidate States: 28
#         Length of Candidate States: 14
# Beam Search Iteration 2
#     Number of Candidate States: 61
#         Length of Candidate States: 14
# Beam Search Iteration 3
#     Number of Candidate States: 57
#     New Lowest Depth: 87
#         Length of Candidate States: 14
# Beam Search Iteration 4
#     Number of Candidate States: 65
#         Length of Candidate States: 14
# Beam Search Iteration 5
#     Number of Candidate States: 65
#         Length of Candidate States: 14
# Beam Search Iteration 6
#     Number of Candidate States: 57
#         Length of Candidate States: 14
# Beam Search Iteration 7
#     Number of Candidate States: 67
#         Length of Candidate States: 14
# Beam Search Iteration 8
#     Number of Candidate States: 42
#         Length of Candidate States: 14
# Beam Search Iteration 9
#     Number of Candidate States: 56
#         Length of Candidate States: 14
# Beam Search Iteration 10
#     Number of Candidate States: 65
#         Length of Candidate States: 14
# Beam Search Iteration 11
#     Number of Candidate States: 60
#         Length of Candidate States: 14
# Beam Search Iteration 12
#     Number of Candidate States: 42
#         Length of Candidate States: 14
# Beam Search Iteration 13
#     Number of Candidate States: 63
#         Length of Candidate States: 14
# Beam Search Iteration 14
#     Number of Candidate States: 74
#         Length of Candidate States: 14
# Beam Search Iteration 15
#     Number of Candidate States: 70
#         Length of Candidate States: 14
# Beam Search Iteration 16
#     Number of Candidate States: 76
#         Length of Candidate States: 14
# Beam Search Iteration 17
#     Number of Candidate States: 68
#     New Lowest Depth: 85
#         Length of Candidate States: 14
# Beam Search Iteration 18
#     Number of Candidate States: 70
#         Length of Candidate States: 14
# Beam Search Iteration 19
#     Number of Candidate States: 70
#         Length of Candidate States: 14
# Beam Search Iteration 20
#     Number of Candidate States: 66
#         Length of Candidate States: 14
# Beam Search Iteration 21
#     Number of Candidate States: 70
#         Length of Candidate States: 14
# Beam Search Iteration 22
#     Number of Candidate States: 60
#         Length of Candidate States: 14
# Beam Search Iteration 23
#     Number of Candidate States: 69
#         Length of Candidate States: 14
# Beam Search Iteration 24
#     Number of Candidate States: 52
#         Length of Candidate States: 14
# Finished: 13 out of 999 with depth 85 and time 3.173011064529419
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 15
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 6
# Beam Search Iteration 1
#     Number of Candidate States: 28
#         Length of Candidate States: 15
# Beam Search Iteration 2
#     Number of Candidate States: 67
#         Length of Candidate States: 15
# Beam Search Iteration 3
#     Number of Candidate States: 61
#     New Lowest Depth: 87
#         Length of Candidate States: 15
# Beam Search Iteration 4
#     Number of Candidate States: 70
#         Length of Candidate States: 15
# Beam Search Iteration 5
#     Number of Candidate States: 70
#         Length of Candidate States: 15
# Beam Search Iteration 6
#     Number of Candidate States: 60
#         Length of Candidate States: 15
# Beam Search Iteration 7
#     Number of Candidate States: 72
#         Length of Candidate States: 15
# Beam Search Iteration 8
#     Number of Candidate States: 45
#         Length of Candidate States: 15
# Beam Search Iteration 9
#     Number of Candidate States: 61
#         Length of Candidate States: 15
# Beam Search Iteration 10
#     Number of Candidate States: 70
#         Length of Candidate States: 15
# Beam Search Iteration 11
#     Number of Candidate States: 64
#         Length of Candidate States: 15
# Beam Search Iteration 12
#     Number of Candidate States: 45
#         Length of Candidate States: 15
# Beam Search Iteration 13
#     Number of Candidate States: 68
#         Length of Candidate States: 15
# Beam Search Iteration 14
#     Number of Candidate States: 80
#         Length of Candidate States: 15
# Beam Search Iteration 15
#     Number of Candidate States: 75
#         Length of Candidate States: 15
# Beam Search Iteration 16
#     Number of Candidate States: 80
#         Length of Candidate States: 15
# Beam Search Iteration 17
#     Number of Candidate States: 73
#     New Lowest Depth: 85
#         Length of Candidate States: 15
# Beam Search Iteration 18
#     Number of Candidate States: 74
#         Length of Candidate States: 15
# Beam Search Iteration 19
#     Number of Candidate States: 75
#         Length of Candidate States: 15
# Beam Search Iteration 20
#     Number of Candidate States: 70
#         Length of Candidate States: 15
# Beam Search Iteration 21
#     Number of Candidate States: 75
#         Length of Candidate States: 15
# Beam Search Iteration 22
#     Number of Candidate States: 64
#         Length of Candidate States: 15
# Beam Search Iteration 23
#     Number of Candidate States: 74
#         Length of Candidate States: 15
# Beam Search Iteration 24
#     Number of Candidate States: 55
#         Length of Candidate States: 15
# Finished: 14 out of 999 with depth 85 and time 3.393231153488159
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 16
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 6
# Beam Search Iteration 1
#     Number of Candidate States: 28
#         Length of Candidate States: 16
# Beam Search Iteration 2
#     Number of Candidate States: 73
#         Length of Candidate States: 16
# Beam Search Iteration 3
#     Number of Candidate States: 65
#     New Lowest Depth: 87
#         Length of Candidate States: 16
# Beam Search Iteration 4
#     Number of Candidate States: 75
#         Length of Candidate States: 16
# Beam Search Iteration 5
#     Number of Candidate States: 75
#         Length of Candidate States: 16
# Beam Search Iteration 6
#     Number of Candidate States: 63
#         Length of Candidate States: 16
# Beam Search Iteration 7
#     Number of Candidate States: 77
#     New Lowest Depth: 86
#         Length of Candidate States: 16
# Beam Search Iteration 8
#     Number of Candidate States: 49
#         Length of Candidate States: 16
# Beam Search Iteration 9
#     Number of Candidate States: 65
#         Length of Candidate States: 16
# Beam Search Iteration 10
#     Number of Candidate States: 74
#         Length of Candidate States: 16
# Beam Search Iteration 11
#     Number of Candidate States: 68
#         Length of Candidate States: 16
# Beam Search Iteration 12
#     Number of Candidate States: 48
#         Length of Candidate States: 16
# Beam Search Iteration 13
#     Number of Candidate States: 72
#         Length of Candidate States: 16
# Beam Search Iteration 14
#     Number of Candidate States: 84
#         Length of Candidate States: 16
# Beam Search Iteration 15
#     Number of Candidate States: 80
#         Length of Candidate States: 16
# Beam Search Iteration 16
#     Number of Candidate States: 86
#         Length of Candidate States: 16
# Beam Search Iteration 17
#     Number of Candidate States: 80
#         Length of Candidate States: 16
# Beam Search Iteration 18
#     Number of Candidate States: 69
#         Length of Candidate States: 16
# Beam Search Iteration 19
#     Number of Candidate States: 76
#         Length of Candidate States: 16
# Beam Search Iteration 20
#     Number of Candidate States: 72
#         Length of Candidate States: 16
# Beam Search Iteration 21
#     Number of Candidate States: 75
#         Length of Candidate States: 16
# Beam Search Iteration 22
#     Number of Candidate States: 72
#         Length of Candidate States: 16
# Beam Search Iteration 23
#     Number of Candidate States: 77
#         Length of Candidate States: 16
# Beam Search Iteration 24
#     Number of Candidate States: 84
#         Length of Candidate States: 16
# Finished: 15 out of 999 with depth 86 and time 3.545097827911377
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 17
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 6
# Beam Search Iteration 1
#     Number of Candidate States: 28
#         Length of Candidate States: 17
# Beam Search Iteration 2
#     Number of Candidate States: 76
#         Length of Candidate States: 17
# Beam Search Iteration 3
#     Number of Candidate States: 70
#     New Lowest Depth: 87
#         Length of Candidate States: 17
# Beam Search Iteration 4
#     Number of Candidate States: 79
#         Length of Candidate States: 17
# Beam Search Iteration 5
#     Number of Candidate States: 79
#         Length of Candidate States: 17
# Beam Search Iteration 6
#     Number of Candidate States: 66
#         Length of Candidate States: 17
# Beam Search Iteration 7
#     Number of Candidate States: 80
#     New Lowest Depth: 86
#         Length of Candidate States: 17
# Beam Search Iteration 8
#     Number of Candidate States: 52
#         Length of Candidate States: 17
# Beam Search Iteration 9
#     Number of Candidate States: 70
#         Length of Candidate States: 17
# Beam Search Iteration 10
#     Number of Candidate States: 79
#         Length of Candidate States: 17
# Beam Search Iteration 11
#     Number of Candidate States: 72
#         Length of Candidate States: 17
# Beam Search Iteration 12
#     Number of Candidate States: 51
#         Length of Candidate States: 17
# Beam Search Iteration 13
#     Number of Candidate States: 77
#         Length of Candidate States: 17
# Beam Search Iteration 14
#     Number of Candidate States: 90
#         Length of Candidate States: 17
# Beam Search Iteration 15
#     Number of Candidate States: 85
#         Length of Candidate States: 17
# Beam Search Iteration 16
#     Number of Candidate States: 92
#         Length of Candidate States: 17
# Beam Search Iteration 17
#     Number of Candidate States: 85
#         Length of Candidate States: 17
# Beam Search Iteration 18
#     Number of Candidate States: 75
#         Length of Candidate States: 17
# Beam Search Iteration 19
#     Number of Candidate States: 81
#         Length of Candidate States: 17
# Beam Search Iteration 20
#     Number of Candidate States: 76
#         Length of Candidate States: 17
# Beam Search Iteration 21
#     Number of Candidate States: 80
#         Length of Candidate States: 17
# Beam Search Iteration 22
#     Number of Candidate States: 78
#         Length of Candidate States: 17
# Beam Search Iteration 23
#     Number of Candidate States: 82
#         Length of Candidate States: 17
# Beam Search Iteration 24
# ...
# Beam Search Iteration 17
#     Number of Candidate States: 875
#         Length of Candidate States: 178
# Beam Search Iteration 18
#     Number of Candidate States: 818
#         Length of Candidate States: 178
# Beam Search Iteration 19
#     Number of Candidate States: 878
#         Length of Candidate States: 178
# Beam Search Iteration 20
#     Number of Candidate States: 819
#         Length of Candidate States: 178
# Beam Search Iteration 21
#     Number of Candidate States: 890
#         Length of Candidate States: 178
# Beam Search Iteration 22
#     Number of Candidate States: 653
#         Length of Candidate States: 178
# Beam Search Iteration 23
#     Number of Candidate States: 890
#         Length of Candidate States: 178
# Beam Search Iteration 24
#     Number of Candidate States: 712
#         Length of Candidate States: 178
# Finished: 177 out of 999 with depth 83 and time 1049.8395681381226
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 179
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 6
# Beam Search Iteration 1
#     Number of Candidate States: 28
#         Length of Candidate States: 28
# Beam Search Iteration 2
#     Number of Candidate States: 118
#         Length of Candidate States: 118
# Beam Search Iteration 3
#     Number of Candidate States: 534
#     New Lowest Depth: 87
#         Length of Candidate States: 179
# Beam Search Iteration 4
#     Number of Candidate States: 804
#         Length of Candidate States: 179
# Beam Search Iteration 5
#     Number of Candidate States: 724
#         Length of Candidate States: 179
# Beam Search Iteration 6
#     Number of Candidate States: 716
#         Length of Candidate States: 179
# Beam Search Iteration 7
#     Number of Candidate States: 816
#     New Lowest Depth: 86
#         Length of Candidate States: 179
# Beam Search Iteration 8
#     Number of Candidate States: 753
#         Length of Candidate States: 179
# Beam Search Iteration 9
#     Number of Candidate States: 751
#         Length of Candidate States: 179
# Beam Search Iteration 10
#     Number of Candidate States: 804
#     New Lowest Depth: 85
#         Length of Candidate States: 179
# Beam Search Iteration 11
#     Number of Candidate States: 748
#         Length of Candidate States: 179
# Beam Search Iteration 12
#     Number of Candidate States: 579
#         Length of Candidate States: 179
# Beam Search Iteration 13
#     Number of Candidate States: 813
#         Length of Candidate States: 179
# Beam Search Iteration 14
#     Number of Candidate States: 954
#         Length of Candidate States: 179
# Beam Search Iteration 15
#     Number of Candidate States: 895
#     New Lowest Depth: 83
#         Length of Candidate States: 179
# Beam Search Iteration 16
#     Number of Candidate States: 839
#         Length of Candidate States: 179
# Beam Search Iteration 17
#     Number of Candidate States: 880
#         Length of Candidate States: 179
# Beam Search Iteration 18
#     Number of Candidate States: 825
#         Length of Candidate States: 179
# Beam Search Iteration 19
#     Number of Candidate States: 884
#         Length of Candidate States: 179
# Beam Search Iteration 20
#     Number of Candidate States: 810
#         Length of Candidate States: 179
# Beam Search Iteration 21
#     Number of Candidate States: 895
#         Length of Candidate States: 179
# Beam Search Iteration 22
#     Number of Candidate States: 657
#         Length of Candidate States: 179
# Beam Search Iteration 23
#     Number of Candidate States: 895
#         Length of Candidate States: 179
# Beam Search Iteration 24
#     Number of Candidate States: 716
#         Length of Candidate States: 179
# Finished: 178 out of 999 with depth 83 and time 1684.681254863739
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 180
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 6
# Beam Search Iteration 1
#     Number of Candidate States: 28
#         Length of Candidate States: 28
# Beam Search Iteration 2
#     Number of Candidate States: 118
#         Length of Candidate States: 118
# Beam Search Iteration 3
#     Number of Candidate States: 534
#     New Lowest Depth: 87
#         Length of Candidate States: 180
# Beam Search Iteration 4
#     Number of Candidate States: 807
#         Length of Candidate States: 180
# Beam Search Iteration 5
#     Number of Candidate States: 728
#         Length of Candidate States: 180
# Beam Search Iteration 6
#     Number of Candidate States: 719
#         Length of Candidate States: 180
# Beam Search Iteration 7
#     Number of Candidate States: 821
#     New Lowest Depth: 86
#         Length of Candidate States: 180
# Beam Search Iteration 8
#     Number of Candidate States: 758
#         Length of Candidate States: 180
# Beam Search Iteration 9
#     Number of Candidate States: 757
#         Length of Candidate States: 180
# Beam Search Iteration 10
#     Number of Candidate States: 807
#     New Lowest Depth: 85
#         Length of Candidate States: 180
# Beam Search Iteration 11
#     Number of Candidate States: 752
#         Length of Candidate States: 180
# Beam Search Iteration 12
#     Number of Candidate States: 585
#         Length of Candidate States: 180
# Beam Search Iteration 13
#     Number of Candidate States: 818
#         Length of Candidate States: 180
# Beam Search Iteration 14
#     Number of Candidate States: 960
#         Length of Candidate States: 180
# Beam Search Iteration 15
#     Number of Candidate States: 900
#     New Lowest Depth: 83
#         Length of Candidate States: 180
# Beam Search Iteration 16
#     Number of Candidate States: 845
#         Length of Candidate States: 180
# Beam Search Iteration 17
#     Number of Candidate States: 886
#         Length of Candidate States: 180
# Beam Search Iteration 18
#     Number of Candidate States: 832
#         Length of Candidate States: 180
# Beam Search Iteration 19
#     Number of Candidate States: 891
#         Length of Candidate States: 180
# Beam Search Iteration 20
#     Number of Candidate States: 807
#         Length of Candidate States: 180
# Beam Search Iteration 21
#     Number of Candidate States: 900
#         Length of Candidate States: 180
# Beam Search Iteration 22
#     Number of Candidate States: 660
#         Length of Candidate States: 180
# Beam Search Iteration 23
#     Number of Candidate States: 900
#         Length of Candidate States: 180
# Beam Search Iteration 24
#     Number of Candidate States: 720
#         Length of Candidate States: 180
# Finished: 179 out of 999 with depth 83 and time 131.58876514434814
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 181
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Fast layout pass
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 6
#     New Lowest Depth: 91
#     New Lowest Depth: 88
#         Length of Candidate States: 6
# Beam Search Iteration 1
#     Number of Candidate States: 28
#         Length of Candidate States: 28
# Beam Search Iteration 2
#     Number of Candidate States: 118
#         Length of Candidate States: 118
# Beam Search Iteration 3
#     Number of Candidate States: 534
#     New Lowest Depth: 87
#         Length of Candidate States: 181
# Beam Search Iteration 4
#     Number of Candidate States: 813
#         Length of Candidate States: 181
# Beam Search Iteration 5
#     Number of Candidate States: 732
#         Length of Candidate States: 181
# Beam Search Iteration 6
#     Number of Candidate States: 722
#         Length of Candidate States: 181
# Beam Search Iteration 7
#     Number of Candidate States: 825
#     New Lowest Depth: 86
#         Length of Candidate States: 181
# Beam Search Iteration 8
#     Number of Candidate States: 761
#         Length of Candidate States: 181
# Beam Search Iteration 9
#     Number of Candidate States: 762
#         Length of Candidate States: 181
# Beam Search Iteration 10
#     Number of Candidate States: 810
#     New Lowest Depth: 85
#         Length of Candidate States: 181
# Beam Search Iteration 11
#     Number of Candidate States: 756
#         Length of Candidate States: 181
# Beam Search Iteration 12
#     Number of Candidate States: 591
#         Length of Candidate States: 181
# Beam Search Iteration 13
#     Number of Candidate States: 823
#         Length of Candidate States: 181
# Beam Search Iteration 14
#     Number of Candidate States: 964
#         Length of Candidate States: 181
# Beam Search Iteration 15
#     Number of Candidate States: 905
#     New Lowest Depth: 83
#         Length of Candidate States: 181
# Beam Search Iteration 16
#     Number of Candidate States: 851
#         Length of Candidate States: 181
# Beam Search Iteration 17
#     Number of Candidate States: 892
#         Length of Candidate States: 181
# Beam Search Iteration 18
#     Number of Candidate States: 840
#         Length of Candidate States: 181
# Beam Search Iteration 19
#     Number of Candidate States: 897
#         Length of Candidate States: 181
# Beam Search Iteration 20
#     Number of Candidate States: 798
#         Length of Candidate States: 181
# Beam Search Iteration 21
#     Number of Candidate States: 905
#         Length of Candidate States: 181
# Beam Search Iteration 22
#     Number of Candidate States: 664
#         Length of Candidate States: 181
# Beam Search Iteration 23
#     Number of Candidate States: 905
#         Length of Candidate States: 181
# Beam Search Iteration 24
#     Number of Candidate States: 724
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = run_beam_experiment(path, qc, rp_str, lp_str, cm, beam_list)
#
# File ~/Documents/GitHub/qiskit/workspace_experiments/experiment_setup/pass_managers.py:271, in run_beam_experiment(filename, qc, rp_str, lp_str, coupling_map, beam_list, seed, num_pm, look, num_iter, crit, max_iter)
#     268 for beam in beam_list:
#     269     pm_list = build_pm_list(rp_str, lp_str, coupling_map, num_pm, seed, look, beam,
#     270                             num_iter, crit, max_iter)
# --> 271     data = run_one_circuit(qc, pm_list)
#     272     data['rp'] = rp_str
#     273     data['lp'] = lp_str
#
# File ~/Documents/GitHub/qiskit/workspace_experiments/experiment_setup/pass_managers.py:155, in run_one_circuit(qc, pm_list)
#     152 for pm in pm_list:
#     153     # Timing the transpilation
#     154     start = time.time()
# --> 155     qc_tr = pm.run(qc)
#     156     end = time.time()
#     158     # Decompose the swaps gate in the circuit
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:420, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     417 @wraps(meth)
#     418 def wrapper(*meth_args, **meth_kwargs):
#     419     try:
# --> 420         return meth(*meth_args, **meth_kwargs)
#     421     except PassManagerError as ex:
#     422         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:182, in PassManager.run(self, circuits, output_name, callback, num_processes)
#     179 if callback is not None:
#     180     callback = _legacy_style_callback(callback)
# --> 182 return super().run(
#     183     in_programs=circuits,
#     184     callback=callback,
#     185     output_name=output_name,
#     186     num_processes=num_processes,
#     187 )
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:229, in BasePassManager.run(self, in_programs, callback, num_processes, **kwargs)
#     226     is_list = False
#     228 if len(in_programs) == 1:
# --> 229     out_program = _run_workflow(
#     230         program=in_programs[0],
#     231         pass_manager=self,
#     232         callback=callback,
#     233         **kwargs,
#     234     )
#     235     if is_list:
#     236         return [out_program]
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:292, in _run_workflow(program, pass_manager, **kwargs)
#     286 initial_status = WorkflowStatus()
#     288 passmanager_ir = pass_manager._passmanager_frontend(
#     289     input_program=program,
#     290     **kwargs,
#     291 )
# --> 292 passmanager_ir, final_state = flow_controller.execute(
#     293     passmanager_ir=passmanager_ir,
#     294     state=PassManagerState(
#     295         workflow_status=initial_status,
#     296         property_set=PropertySet(),
#     297     ),
#     298     callback=kwargs.get("callback", None),
#     299 )
#     300 # The `property_set` has historically been returned as a mutable attribute on `PassManager`
#     301 # This makes us non-reentrant (though `PassManager` would be dependent on its internal tasks to
#     302 # be re-entrant if that was required), but is consistent with previous interfaces.  We're still
#     303 # safe to be called in a serial loop, again assuming internal tasks are re-runnable.  The
#     304 # conversion to the backend language is also allowed to use the property set, so it must be set
#     305 # before calling it.
#     306 pass_manager.property_set = final_state.property_set
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:218, in BaseController.execute(self, passmanager_ir, state, callback)
#     216     return passmanager_ir, state
#     217 while True:
# --> 218     passmanager_ir, state = next_task.execute(
#     219         passmanager_ir=passmanager_ir,
#     220         state=state,
#     221         callback=callback,
#     222     )
#     223     try:
#     224         # Sending the object through the generator implies the custom controllers
#     225         # can always rely on the latest data to choose the next task to run.
#     226         next_task = task_generator.send(state)
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/basepasses.py:195, in TransformationPass.execute(self, passmanager_ir, state, callback)
#     189 def execute(
#     190     self,
#     191     passmanager_ir: PassManagerIR,
#     192     state: PassManagerState,
#     193     callback: Callable = None,
#     194 ) -> tuple[PassManagerIR, PassManagerState]:
# --> 195     new_dag, state = super().execute(
#     196         passmanager_ir=passmanager_ir,
#     197         state=state,
#     198         callback=callback,
#     199     )
#     201     if state.workflow_status.previous_run == RunState.SUCCESS:
#     202         if isinstance(new_dag, DAGCircuit):
#     203             # Copy calibration data from the original program
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:98, in GenericPass.execute(self, passmanager_ir, state, callback)
#      96 try:
#      97     if self not in state.workflow_status.completed_passes:
# ---> 98         ret = self.run(passmanager_ir)
#      99         run_state = RunState.SUCCESS
#     100     else:
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v0_20_dive.py:183, in SabreSwap.run(self, dag)
#     181 for state in candidate_states:
#     182     while state.front_layer:
# --> 183         self._apply_swap(state)
#     184         self._update_state(state)
#     186 # Phase 4a: Get list of depths of each candidate state and store the lowest depth
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v0_20_dive.py:463, in SabreSwap._apply_swap(self, state)
#     460 self._update_qubit_depth(DAGOpNode(op=SwapGate(), qargs=swap), trial_qubit_depth)
#     461 trial_state = State(trial_layout, state.front_layer.copy(), state.predecessors.copy(),
#     462                     trial_qubit_depth, None, 0)
# --> 463 self._update_state(trial_state, trial=True)
#     464 depth = max(trial_state.qubit_depth.values())
#     466 if score < best_score or (score == best_score and depth < best_depth):
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v0_20_dive.py:-1, in SabreSwap._update_state(self, state, trial)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# KeyboardInterrupt:
