# %%
from experiment_setup.pass_managers import run_experiment
from experiment_setup.circuits.circuit_files import get_circuits_from_directory
from experiment_setup.coupling_maps.coupling_maps_files import file_to_coupling_map
from qiskit.transpiler import CouplingMap

# %%
circuits_path_list = ["zou_circuits/problems_ring_27_sample" ]
cm_ring   = CouplingMap.from_ring(27)
cm_hex    = file_to_coupling_map("experiment_setup/coupling_maps/heavy_hex_027.txt")
cm_square = CouplingMap.from_grid(5, 5)

cm_list =  [cm_ring]

rp_str_list =  ["sabre_v0_20_dive"]
beam_list = [5, 30, 40, 50, 100]

lp_str = "trivial_layout"

# %%
for i in range(len(circuits_path_list)):
    for rp_str in rp_str_list:
        for beam in beam_list:
            circuit_path = circuits_path_list[i]
            cm           = cm_list[i]

            save_path =  f"results/{circuit_path}/{rp_str}_beam_{beam}.csv"

            qc_list_directory = f"experiment_setup/circuits/{circuit_path}"
            qc_list = get_circuits_from_directory(qc_list_directory)

            data = run_experiment(save_path, qc_list, rp_str, lp_str, cm, max_iter=1, beam=beam)
# Out:
# Using seed 42 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 5
#         Using seed 42 and max iterations 1 for layout pass.
#             Building Trivial layout pass
# Using seed 43 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 5
#         Using seed 43 and max iterations 1 for layout pass.
#             Building Trivial layout pass
# Using seed 44 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 5
#         Using seed 44 and max iterations 1 for layout pass.
#             Building Trivial layout pass
# Using seed 45 for routing pass.
#     Building Sabre v0.20 dive routing pass with beam 5
#         Using seed 45 and max iterations 1 for layout pass.
#             Building Trivial layout pass
# Running SabreSwap
# Initial Depth: 6
# Beam Search Iteration 0
#     Number of Candidate States: 21
#     New Lowest Depth: 26
#     New Lowest Depth: 23
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 98
#     New Lowest Depth: 21
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 102
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 103
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 97
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 94
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 91
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 81
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 71
#         Length of Candidate States: 5
# Running SabreSwap
# Initial Depth: 6
# Beam Search Iteration 0
#     Number of Candidate States: 21
#     New Lowest Depth: 26
#     New Lowest Depth: 23
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 98
#     New Lowest Depth: 21
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 102
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 103
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 97
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 94
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 91
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 81
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 71
#         Length of Candidate States: 5
# Running SabreSwap
# Initial Depth: 6
# Beam Search Iteration 0
#     Number of Candidate States: 21
#     New Lowest Depth: 26
#     New Lowest Depth: 23
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 98
#     New Lowest Depth: 21
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 102
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 103
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 97
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 94
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 91
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 81
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 71
#         Length of Candidate States: 5
# Running SabreSwap
# Initial Depth: 6
# Beam Search Iteration 0
#     Number of Candidate States: 21
#     New Lowest Depth: 26
#     New Lowest Depth: 23
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 98
#     New Lowest Depth: 21
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 102
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 103
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 97
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 94
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 91
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 81
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 71
#         Length of Candidate States: 5
# Finished: 0 out of 5 with depth 21 and time 1.6613421440124512
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 27
#     New Lowest Depth: 85
#     New Lowest Depth: 67
#     New Lowest Depth: 62
#     New Lowest Depth: 61
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 132
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 131
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 132
#     New Lowest Depth: 51
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 9
#     Number of Candidate States: 125
#         Length of Candidate States: 5
# Beam Search Iteration 10
#     Number of Candidate States: 128
#         Length of Candidate States: 5
# Beam Search Iteration 11
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 12
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 13
#     Number of Candidate States: 113
#         Length of Candidate States: 5
# Beam Search Iteration 14
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 15
#     Number of Candidate States: 101
#         Length of Candidate States: 5
# Beam Search Iteration 16
#     Number of Candidate States: 100
#         Length of Candidate States: 5
# Beam Search Iteration 17
#     Number of Candidate States: 97
#         Length of Candidate States: 5
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 27
#     New Lowest Depth: 85
#     New Lowest Depth: 67
#     New Lowest Depth: 62
#     New Lowest Depth: 61
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 132
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 131
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 132
#     New Lowest Depth: 51
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 9
#     Number of Candidate States: 125
#         Length of Candidate States: 5
# Beam Search Iteration 10
#     Number of Candidate States: 128
#         Length of Candidate States: 5
# Beam Search Iteration 11
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 12
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 13
#     Number of Candidate States: 113
#         Length of Candidate States: 5
# Beam Search Iteration 14
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 15
#     Number of Candidate States: 101
#         Length of Candidate States: 5
# Beam Search Iteration 16
#     Number of Candidate States: 100
#         Length of Candidate States: 5
# Beam Search Iteration 17
#     Number of Candidate States: 97
#         Length of Candidate States: 5
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 27
#     New Lowest Depth: 85
#     New Lowest Depth: 67
#     New Lowest Depth: 62
#     New Lowest Depth: 61
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 132
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 131
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 132
#     New Lowest Depth: 51
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 9
#     Number of Candidate States: 125
#         Length of Candidate States: 5
# Beam Search Iteration 10
#     Number of Candidate States: 128
#         Length of Candidate States: 5
# Beam Search Iteration 11
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 12
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 13
#     Number of Candidate States: 113
#         Length of Candidate States: 5
# Beam Search Iteration 14
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 15
#     Number of Candidate States: 101
#         Length of Candidate States: 5
# Beam Search Iteration 16
#     Number of Candidate States: 100
#         Length of Candidate States: 5
# Beam Search Iteration 17
#     Number of Candidate States: 97
#         Length of Candidate States: 5
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 27
#     New Lowest Depth: 85
#     New Lowest Depth: 67
#     New Lowest Depth: 62
#     New Lowest Depth: 61
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 132
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 131
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 132
#     New Lowest Depth: 51
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 9
#     Number of Candidate States: 125
#         Length of Candidate States: 5
# Beam Search Iteration 10
#     Number of Candidate States: 128
#         Length of Candidate States: 5
# Beam Search Iteration 11
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 12
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 13
#     Number of Candidate States: 113
#         Length of Candidate States: 5
# Beam Search Iteration 14
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 15
#     Number of Candidate States: 101
#         Length of Candidate States: 5
# Beam Search Iteration 16
#     Number of Candidate States: 100
#         Length of Candidate States: 5
# Beam Search Iteration 17
#     Number of Candidate States: 97
#         Length of Candidate States: 5
# Finished: 1 out of 5 with depth 51 and time 17.168606996536255
# Running SabreSwap
# Initial Depth: 3
# Beam Search Iteration 0
#     Number of Candidate States: 26
#     New Lowest Depth: 90
#     New Lowest Depth: 83
#     New Lowest Depth: 74
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 127
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 128
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 133
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 128
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 134
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 134
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 134
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 134
#         Length of Candidate States: 5
# Beam Search Iteration 9
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 10
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 11
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 12
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 13
#     Number of Candidate States: 131
#         Length of Candidate States: 5
# Beam Search Iteration 14
#     Number of Candidate States: 131
#         Length of Candidate States: 5
# Beam Search Iteration 15
#     Number of Candidate States: 131
#         Length of Candidate States: 5
# Beam Search Iteration 16
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 17
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 18
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 19
#     Number of Candidate States: 115
#         Length of Candidate States: 5
# Beam Search Iteration 20
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 21
#     Number of Candidate States: 107
#         Length of Candidate States: 5
# Beam Search Iteration 22
#     Number of Candidate States: 104
#         Length of Candidate States: 5
# Beam Search Iteration 23
#     Number of Candidate States: 98
#         Length of Candidate States: 5
# Beam Search Iteration 24
#     Number of Candidate States: 94
#         Length of Candidate States: 5
# Beam Search Iteration 25
#     Number of Candidate States: 96
#     New Lowest Depth: 73
#     New Lowest Depth: 72
#         Length of Candidate States: 5
# Beam Search Iteration 26
#     Number of Candidate States: 96
#         Length of Candidate States: 5
# Beam Search Iteration 27
#     Number of Candidate States: 98
#         Length of Candidate States: 5
# Beam Search Iteration 28
#     Number of Candidate States: 100
#         Length of Candidate States: 5
# Beam Search Iteration 29
#     Number of Candidate States: 95
#         Length of Candidate States: 5
# Running SabreSwap
# Initial Depth: 3
# Beam Search Iteration 0
#     Number of Candidate States: 26
#     New Lowest Depth: 90
#     New Lowest Depth: 83
#     New Lowest Depth: 74
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 127
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 128
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 133
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 128
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 134
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 134
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 134
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 134
#         Length of Candidate States: 5
# Beam Search Iteration 9
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 10
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 11
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 12
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 13
#     Number of Candidate States: 131
#         Length of Candidate States: 5
# Beam Search Iteration 14
#     Number of Candidate States: 131
#         Length of Candidate States: 5
# Beam Search Iteration 15
#     Number of Candidate States: 131
#         Length of Candidate States: 5
# Beam Search Iteration 16
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 17
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 18
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 19
#     Number of Candidate States: 115
#         Length of Candidate States: 5
# Beam Search Iteration 20
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 21
#     Number of Candidate States: 107
#         Length of Candidate States: 5
# Beam Search Iteration 22
#     Number of Candidate States: 104
#         Length of Candidate States: 5
# Beam Search Iteration 23
#     Number of Candidate States: 98
#         Length of Candidate States: 5
# Beam Search Iteration 24
#     Number of Candidate States: 94
#         Length of Candidate States: 5
# Beam Search Iteration 25
#     Number of Candidate States: 96
#     New Lowest Depth: 73
#     New Lowest Depth: 72
#         Length of Candidate States: 5
# Beam Search Iteration 26
#     Number of Candidate States: 96
#         Length of Candidate States: 5
# Beam Search Iteration 27
#     Number of Candidate States: 98
#         Length of Candidate States: 5
# Beam Search Iteration 28
#     Number of Candidate States: 100
#         Length of Candidate States: 5
# Beam Search Iteration 29
#     Number of Candidate States: 95
#         Length of Candidate States: 5
# Running SabreSwap
# Initial Depth: 3
# Beam Search Iteration 0
#     Number of Candidate States: 26
#     New Lowest Depth: 90
#     New Lowest Depth: 83
#     New Lowest Depth: 74
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 127
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 128
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 133
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 128
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 134
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 134
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 134
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 134
#         Length of Candidate States: 5
# Beam Search Iteration 9
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 10
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 11
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 12
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 13
#     Number of Candidate States: 131
#         Length of Candidate States: 5
# Beam Search Iteration 14
#     Number of Candidate States: 131
#         Length of Candidate States: 5
# Beam Search Iteration 15
#     Number of Candidate States: 131
#         Length of Candidate States: 5
# Beam Search Iteration 16
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 17
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 18
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 19
#     Number of Candidate States: 115
#         Length of Candidate States: 5
# Beam Search Iteration 20
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 21
#     Number of Candidate States: 107
#         Length of Candidate States: 5
# Beam Search Iteration 22
#     Number of Candidate States: 104
#         Length of Candidate States: 5
# Beam Search Iteration 23
#     Number of Candidate States: 98
#         Length of Candidate States: 5
# Beam Search Iteration 24
#     Number of Candidate States: 94
#         Length of Candidate States: 5
# Beam Search Iteration 25
#     Number of Candidate States: 96
#     New Lowest Depth: 73
#     New Lowest Depth: 72
#         Length of Candidate States: 5
# Beam Search Iteration 26
#     Number of Candidate States: 96
#         Length of Candidate States: 5
# Beam Search Iteration 27
#     Number of Candidate States: 98
#         Length of Candidate States: 5
# Beam Search Iteration 28
#     Number of Candidate States: 100
#         Length of Candidate States: 5
# Beam Search Iteration 29
#     Number of Candidate States: 95
#         Length of Candidate States: 5
# Running SabreSwap
# Initial Depth: 3
# Beam Search Iteration 0
#     Number of Candidate States: 26
#     New Lowest Depth: 90
#     New Lowest Depth: 83
#     New Lowest Depth: 74
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 127
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 128
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 133
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 128
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 134
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 134
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 134
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 134
#         Length of Candidate States: 5
# Beam Search Iteration 9
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 10
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 11
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 12
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 13
#     Number of Candidate States: 131
#         Length of Candidate States: 5
# Beam Search Iteration 14
#     Number of Candidate States: 131
#         Length of Candidate States: 5
# Beam Search Iteration 15
#     Number of Candidate States: 131
#         Length of Candidate States: 5
# Beam Search Iteration 16
#     Number of Candidate States: 130
#         Length of Candidate States: 5
# Beam Search Iteration 17
#     Number of Candidate States: 129
#         Length of Candidate States: 5
# Beam Search Iteration 18
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 19
#     Number of Candidate States: 115
#         Length of Candidate States: 5
# Beam Search Iteration 20
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 21
#     Number of Candidate States: 107
#         Length of Candidate States: 5
# Beam Search Iteration 22
#     Number of Candidate States: 104
#         Length of Candidate States: 5
# Beam Search Iteration 23
#     Number of Candidate States: 98
#         Length of Candidate States: 5
# Beam Search Iteration 24
#     Number of Candidate States: 94
#         Length of Candidate States: 5
# Beam Search Iteration 25
#     Number of Candidate States: 96
#     New Lowest Depth: 73
#     New Lowest Depth: 72
#         Length of Candidate States: 5
# Beam Search Iteration 26
#     Number of Candidate States: 96
#         Length of Candidate States: 5
# Beam Search Iteration 27
#     Number of Candidate States: 98
#         Length of Candidate States: 5
# Beam Search Iteration 28
#     Number of Candidate States: 100
#         Length of Candidate States: 5
# Beam Search Iteration 29
#     Number of Candidate States: 95
#         Length of Candidate States: 5
# Finished: 2 out of 5 with depth 72 and time 44.52735900878906
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 26
#     New Lowest Depth: 110
#     New Lowest Depth: 101
#     New Lowest Depth: 93
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 127
#     New Lowest Depth: 92
#     New Lowest Depth: 87
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 125
#     New Lowest Depth: 85
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 134
#     New Lowest Depth: 80
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 128
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 123
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 123
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 122
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 123
#         Length of Candidate States: 5
# Beam Search Iteration 9
#     Number of Candidate States: 121
#         Length of Candidate States: 5
# Beam Search Iteration 10
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 11
#     Number of Candidate States: 123
#         Length of Candidate States: 5
# Beam Search Iteration 12
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 13
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 14
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 15
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 16
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 17
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 18
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 19
#     Number of Candidate States: 115
#         Length of Candidate States: 5
# Beam Search Iteration 20
#     Number of Candidate States: 118
#         Length of Candidate States: 5
# Beam Search Iteration 21
#     Number of Candidate States: 115
#         Length of Candidate States: 5
# Beam Search Iteration 22
#     Number of Candidate States: 118
#         Length of Candidate States: 5
# Beam Search Iteration 23
#     Number of Candidate States: 115
#         Length of Candidate States: 5
# Beam Search Iteration 24
#     Number of Candidate States: 107
#         Length of Candidate States: 5
# Beam Search Iteration 25
#     Number of Candidate States: 107
#         Length of Candidate States: 5
# Beam Search Iteration 26
#     Number of Candidate States: 107
#         Length of Candidate States: 5
# Beam Search Iteration 27
#     Number of Candidate States: 110
#         Length of Candidate States: 5
# Beam Search Iteration 28
#     Number of Candidate States: 94
#         Length of Candidate States: 5
# Beam Search Iteration 29
#     Number of Candidate States: 94
#         Length of Candidate States: 5
# Beam Search Iteration 30
#     Number of Candidate States: 99
#         Length of Candidate States: 5
# Beam Search Iteration 31
#     Number of Candidate States: 109
#         Length of Candidate States: 5
# Beam Search Iteration 32
#     Number of Candidate States: 103
#         Length of Candidate States: 5
# Beam Search Iteration 33
#     Number of Candidate States: 98
#         Length of Candidate States: 5
# Beam Search Iteration 34
#     Number of Candidate States: 97
#         Length of Candidate States: 5
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 26
#     New Lowest Depth: 110
#     New Lowest Depth: 101
#     New Lowest Depth: 93
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 127
#     New Lowest Depth: 92
#     New Lowest Depth: 87
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 125
#     New Lowest Depth: 85
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 134
#     New Lowest Depth: 80
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 128
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 123
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 123
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 122
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 123
#         Length of Candidate States: 5
# Beam Search Iteration 9
#     Number of Candidate States: 121
#         Length of Candidate States: 5
# Beam Search Iteration 10
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 11
#     Number of Candidate States: 123
#         Length of Candidate States: 5
# Beam Search Iteration 12
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 13
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 14
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 15
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 16
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 17
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 18
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 19
#     Number of Candidate States: 115
#         Length of Candidate States: 5
# Beam Search Iteration 20
#     Number of Candidate States: 118
#         Length of Candidate States: 5
# Beam Search Iteration 21
#     Number of Candidate States: 115
#         Length of Candidate States: 5
# Beam Search Iteration 22
#     Number of Candidate States: 118
#         Length of Candidate States: 5
# Beam Search Iteration 23
#     Number of Candidate States: 115
#         Length of Candidate States: 5
# Beam Search Iteration 24
#     Number of Candidate States: 107
#         Length of Candidate States: 5
# Beam Search Iteration 25
#     Number of Candidate States: 107
#         Length of Candidate States: 5
# Beam Search Iteration 26
#     Number of Candidate States: 107
#         Length of Candidate States: 5
# Beam Search Iteration 27
#     Number of Candidate States: 110
#         Length of Candidate States: 5
# Beam Search Iteration 28
#     Number of Candidate States: 94
#         Length of Candidate States: 5
# Beam Search Iteration 29
#     Number of Candidate States: 94
#         Length of Candidate States: 5
# Beam Search Iteration 30
#     Number of Candidate States: 99
#         Length of Candidate States: 5
# Beam Search Iteration 31
#     Number of Candidate States: 109
#         Length of Candidate States: 5
# Beam Search Iteration 32
#     Number of Candidate States: 103
#         Length of Candidate States: 5
# Beam Search Iteration 33
#     Number of Candidate States: 98
#         Length of Candidate States: 5
# Beam Search Iteration 34
#     Number of Candidate States: 97
#         Length of Candidate States: 5
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 26
#     New Lowest Depth: 110
#     New Lowest Depth: 101
#     New Lowest Depth: 93
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 127
#     New Lowest Depth: 92
#     New Lowest Depth: 87
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 125
#     New Lowest Depth: 85
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 134
#     New Lowest Depth: 80
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 128
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 123
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 123
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 122
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 123
#         Length of Candidate States: 5
# Beam Search Iteration 9
#     Number of Candidate States: 121
#         Length of Candidate States: 5
# Beam Search Iteration 10
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 11
#     Number of Candidate States: 123
#         Length of Candidate States: 5
# Beam Search Iteration 12
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 13
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 14
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 15
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 16
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 17
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 18
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 19
#     Number of Candidate States: 115
#         Length of Candidate States: 5
# Beam Search Iteration 20
#     Number of Candidate States: 118
#         Length of Candidate States: 5
# Beam Search Iteration 21
#     Number of Candidate States: 115
#         Length of Candidate States: 5
# Beam Search Iteration 22
#     Number of Candidate States: 118
#         Length of Candidate States: 5
# Beam Search Iteration 23
#     Number of Candidate States: 115
#         Length of Candidate States: 5
# Beam Search Iteration 24
#     Number of Candidate States: 107
#         Length of Candidate States: 5
# Beam Search Iteration 25
#     Number of Candidate States: 107
#         Length of Candidate States: 5
# Beam Search Iteration 26
#     Number of Candidate States: 107
#         Length of Candidate States: 5
# Beam Search Iteration 27
#     Number of Candidate States: 110
#         Length of Candidate States: 5
# Beam Search Iteration 28
#     Number of Candidate States: 94
#         Length of Candidate States: 5
# Beam Search Iteration 29
#     Number of Candidate States: 94
#         Length of Candidate States: 5
# Beam Search Iteration 30
#     Number of Candidate States: 99
#         Length of Candidate States: 5
# Beam Search Iteration 31
#     Number of Candidate States: 109
#         Length of Candidate States: 5
# Beam Search Iteration 32
#     Number of Candidate States: 103
#         Length of Candidate States: 5
# Beam Search Iteration 33
#     Number of Candidate States: 98
#         Length of Candidate States: 5
# Beam Search Iteration 34
#     Number of Candidate States: 97
#         Length of Candidate States: 5
# Running SabreSwap
# Initial Depth: 1
# Beam Search Iteration 0
#     Number of Candidate States: 26
#     New Lowest Depth: 110
#     New Lowest Depth: 101
#     New Lowest Depth: 93
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 127
#     New Lowest Depth: 92
#     New Lowest Depth: 87
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 125
#     New Lowest Depth: 85
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 134
#     New Lowest Depth: 80
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 128
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 123
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 123
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 122
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 123
#         Length of Candidate States: 5
# Beam Search Iteration 9
#     Number of Candidate States: 121
#         Length of Candidate States: 5
# Beam Search Iteration 10
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 11
#     Number of Candidate States: 123
#         Length of Candidate States: 5
# Beam Search Iteration 12
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 13
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 14
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 15
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 16
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 17
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 18
#     Number of Candidate States: 116
#         Length of Candidate States: 5
# Beam Search Iteration 19
#     Number of Candidate States: 115
#         Length of Candidate States: 5
# Beam Search Iteration 20
#     Number of Candidate States: 118
#         Length of Candidate States: 5
# Beam Search Iteration 21
#     Number of Candidate States: 115
#         Length of Candidate States: 5
# Beam Search Iteration 22
#     Number of Candidate States: 118
#         Length of Candidate States: 5
# Beam Search Iteration 23
#     Number of Candidate States: 115
#         Length of Candidate States: 5
# Beam Search Iteration 24
#     Number of Candidate States: 107
#         Length of Candidate States: 5
# Beam Search Iteration 25
#     Number of Candidate States: 107
#         Length of Candidate States: 5
# Beam Search Iteration 26
#     Number of Candidate States: 107
#         Length of Candidate States: 5
# Beam Search Iteration 27
#     Number of Candidate States: 110
#         Length of Candidate States: 5
# Beam Search Iteration 28
#     Number of Candidate States: 94
#         Length of Candidate States: 5
# Beam Search Iteration 29
#     Number of Candidate States: 94
#         Length of Candidate States: 5
# Beam Search Iteration 30
#     Number of Candidate States: 99
#         Length of Candidate States: 5
# Beam Search Iteration 31
#     Number of Candidate States: 109
#         Length of Candidate States: 5
# Beam Search Iteration 32
#     Number of Candidate States: 103
#         Length of Candidate States: 5
# Beam Search Iteration 33
#     Number of Candidate States: 98
#         Length of Candidate States: 5
# Beam Search Iteration 34
#     Number of Candidate States: 97
#         Length of Candidate States: 5
# Finished: 3 out of 5 with depth 80 and time 52.59293508529663
# Running SabreSwap
# Initial Depth: 2
# Beam Search Iteration 0
#     Number of Candidate States: 24
#     New Lowest Depth: 162
#     New Lowest Depth: 150
#     New Lowest Depth: 147
#     New Lowest Depth: 137
#     New Lowest Depth: 122
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 119
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 120
#     New Lowest Depth: 120
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 9
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 10
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 11
#     Number of Candidate States: 121
#         Length of Candidate States: 5
# Beam Search Iteration 12
#     Number of Candidate States: 124
#         Length of Candidate States: 5
# Beam Search Iteration 13
#     Number of Candidate States: 121
#         Length of Candidate States: 5
# Beam Search Iteration 14
#     Number of Candidate States: 123
#         Length of Candidate States: 5
# Beam Search Iteration 15
#     Number of Candidate States: 122
#         Length of Candidate States: 5
# Beam Search Iteration 16
#     Number of Candidate States: 118
#         Length of Candidate States: 5
# Beam Search Iteration 17
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 18
#     Number of Candidate States: 118
#         Length of Candidate States: 5
# Beam Search Iteration 19
#     Number of Candidate States: 118
#         Length of Candidate States: 5
# Beam Search Iteration 20
#     Number of Candidate States: 118
#     New Lowest Depth: 118
#         Length of Candidate States: 5
# Beam Search Iteration 21
#     Number of Candidate States: 119
#         Length of Candidate States: 5
# Beam Search Iteration 22
#     Number of Candidate States: 113
#         Length of Candidate States: 5
# Beam Search Iteration 23
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 24
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 25
#     Number of Candidate States: 114
#         Length of Candidate States: 5
# Beam Search Iteration 26
#     Number of Candidate States: 109
#         Length of Candidate States: 5
# Beam Search Iteration 27
#     Number of Candidate States: 110
#         Length of Candidate States: 5
# Beam Search Iteration 28
#     Number of Candidate States: 110
#         Length of Candidate States: 5
# Beam Search Iteration 29
#     Number of Candidate States: 112
#         Length of Candidate States: 5
# Beam Search Iteration 30
#     Number of Candidate States: 110
#         Length of Candidate States: 5
# Beam Search Iteration 31
#     Number of Candidate States: 112
#         Length of Candidate States: 5
# Beam Search Iteration 32
#     Number of Candidate States: 110
#         Length of Candidate States: 5
# Beam Search Iteration 33
#     Number of Candidate States: 112
#         Length of Candidate States: 5
# Beam Search Iteration 34
#     Number of Candidate States: 110
#         Length of Candidate States: 5
# Beam Search Iteration 35
#     Number of Candidate States: 113
#         Length of Candidate States: 5
# Beam Search Iteration 36
#     Number of Candidate States: 104
#         Length of Candidate States: 5
# Beam Search Iteration 37
#     Number of Candidate States: 105
#         Length of Candidate States: 5
# Beam Search Iteration 38
#     Number of Candidate States: 104
#         Length of Candidate States: 5
# Beam Search Iteration 39
#     Number of Candidate States: 104
#         Length of Candidate States: 5
# Beam Search Iteration 40
#     Number of Candidate States: 104
#         Length of Candidate States: 5
# Beam Search Iteration 41
#     Number of Candidate States: 104
#         Length of Candidate States: 5
# Beam Search Iteration 42
#     Number of Candidate States: 110
#         Length of Candidate States: 5
# Beam Search Iteration 43
#     Number of Candidate States: 109
#         Length of Candidate States: 5
# Beam Search Iteration 44
#     Number of Candidate States: 102
#         Length of Candidate States: 5
# Beam Search Iteration 45
#     Number of Candidate States: 93
#         Length of Candidate States: 5
# Beam Search Iteration 46
#     Number of Candidate States: 87
#         Length of Candidate States: 5
# Beam Search Iteration 47
#     Number of Candidate States: 84
#         Length of Candidate States: 5
# Running SabreSwap
# Initial Depth: 2
# Beam Search Iteration 0
#     Number of Candidate States: 24
#     New Lowest Depth: 162
#     New Lowest Depth: 150
#     New Lowest Depth: 147
#     New Lowest Depth: 137
#     New Lowest Depth: 122
#         Length of Candidate States: 5
# Beam Search Iteration 1
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 2
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 3
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 4
#     Number of Candidate States: 119
#         Length of Candidate States: 5
# Beam Search Iteration 5
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 6
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 7
#     Number of Candidate States: 120
#     New Lowest Depth: 120
#         Length of Candidate States: 5
# Beam Search Iteration 8
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 9
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 10
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 11
#     Number of Candidate States: 121
#         Length of Candidate States: 5
# Beam Search Iteration 12
#     Number of Candidate States: 124
#         Length of Candidate States: 5
# Beam Search Iteration 13
#     Number of Candidate States: 121
#         Length of Candidate States: 5
# Beam Search Iteration 14
#     Number of Candidate States: 123
#         Length of Candidate States: 5
# Beam Search Iteration 15
#     Number of Candidate States: 122
#         Length of Candidate States: 5
# Beam Search Iteration 16
#     Number of Candidate States: 118
#         Length of Candidate States: 5
# Beam Search Iteration 17
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 18
#     Number of Candidate States: 118
#         Length of Candidate States: 5
# Beam Search Iteration 19
#     Number of Candidate States: 118
#         Length of Candidate States: 5
# Beam Search Iteration 20
#     Number of Candidate States: 118
#     New Lowest Depth: 118
#         Length of Candidate States: 5
# Beam Search Iteration 21
#     Number of Candidate States: 119
#         Length of Candidate States: 5
# Beam Search Iteration 22
#     Number of Candidate States: 113
#         Length of Candidate States: 5
# Beam Search Iteration 23
#     Number of Candidate States: 120
#         Length of Candidate States: 5
# Beam Search Iteration 24
#     Number of Candidate States: 117
#         Length of Candidate States: 5
# Beam Search Iteration 25
#     Number of Candidate States: 114
#         Length of Candidate States: 5
# Beam Search Iteration 26
#     Number of Candidate States: 109
#         Length of Candidate States: 5
# Beam Search Iteration 27
#     Number of Candidate States: 110
#         Length of Candidate States: 5
# Beam Search Iteration 28
#     Number of Candidate States: 110
#         Length of Candidate States: 5
# Beam Search Iteration 29
#     Number of Candidate States: 112
#         Length of Candidate States: 5
# Beam Search Iteration 30
#     Number of Candidate States: 110
#         Length of Candidate States: 5
# ...
# Beam Search Iteration 7
#     Number of Candidate States: 1239
#         Length of Candidate States: 50
# Beam Search Iteration 8
#     Number of Candidate States: 1244
#         Length of Candidate States: 50
# Beam Search Iteration 9
#     Number of Candidate States: 1283
#         Length of Candidate States: 50
# Beam Search Iteration 10
#     Number of Candidate States: 1228
#         Length of Candidate States: 50
# Beam Search Iteration 11
#     Number of Candidate States: 1226
#         Length of Candidate States: 50
# Beam Search Iteration 12
#     Number of Candidate States: 1227
#         Length of Candidate States: 50
# Beam Search Iteration 13
#     Number of Candidate States: 1230
#         Length of Candidate States: 50
# Beam Search Iteration 14
#     Number of Candidate States: 1231
#         Length of Candidate States: 50
# Beam Search Iteration 15
#     Number of Candidate States: 1229
#         Length of Candidate States: 50
# Beam Search Iteration 16
#     Number of Candidate States: 1222
#         Length of Candidate States: 50
# Beam Search Iteration 17
#     Number of Candidate States: 1224
#         Length of Candidate States: 50
# Beam Search Iteration 18
#     Number of Candidate States: 1162
#         Length of Candidate States: 50
# Beam Search Iteration 19
#     Number of Candidate States: 1177
#         Length of Candidate States: 50
# Beam Search Iteration 20
#     Number of Candidate States: 1177
#         Length of Candidate States: 50
# Beam Search Iteration 21
#     Number of Candidate States: 1189
#         Length of Candidate States: 50
# Beam Search Iteration 22
#     Number of Candidate States: 1216
#         Length of Candidate States: 50
# Beam Search Iteration 23
#     Number of Candidate States: 1187
#         Length of Candidate States: 50
# Beam Search Iteration 24
#     Number of Candidate States: 1165
#         Length of Candidate States: 50
# Beam Search Iteration 25
#     Number of Candidate States: 1132
#         Length of Candidate States: 50
# Beam Search Iteration 26
#     Number of Candidate States: 1103
#         Length of Candidate States: 50
# Beam Search Iteration 27
#     Number of Candidate States: 1085
#         Length of Candidate States: 50
# Beam Search Iteration 28
#     Number of Candidate States: 1023
#         Length of Candidate States: 50
# Beam Search Iteration 29
#     Number of Candidate States: 1018
#         Length of Candidate States: 50
# Running SabreSwap
# Initial Depth: 3
# Beam Search Iteration 0
#     Number of Candidate States: 26
#     New Lowest Depth: 90
#     New Lowest Depth: 83
#     New Lowest Depth: 74
#         Length of Candidate States: 26
# Beam Search Iteration 1
#     Number of Candidate States: 669
#         Length of Candidate States: 50
# Beam Search Iteration 2
#     Number of Candidate States: 1281
#         Length of Candidate States: 50
# Beam Search Iteration 3
#     Number of Candidate States: 1291
#     New Lowest Depth: 71
#         Length of Candidate States: 50
# Beam Search Iteration 4
#     Number of Candidate States: 1309
#         Length of Candidate States: 50
# Beam Search Iteration 5
#     Number of Candidate States: 1294
#         Length of Candidate States: 50
# Beam Search Iteration 6
#     Number of Candidate States: 1230
#         Length of Candidate States: 50
# Beam Search Iteration 7
#     Number of Candidate States: 1239
#         Length of Candidate States: 50
# Beam Search Iteration 8
#     Number of Candidate States: 1244
#         Length of Candidate States: 50
# Beam Search Iteration 9
#     Number of Candidate States: 1283
#         Length of Candidate States: 50
# Beam Search Iteration 10
#     Number of Candidate States: 1228
#         Length of Candidate States: 50
# Beam Search Iteration 11
#     Number of Candidate States: 1226
#         Length of Candidate States: 50
# Beam Search Iteration 12
#     Number of Candidate States: 1227
#         Length of Candidate States: 50
# Beam Search Iteration 13
#     Number of Candidate States: 1230
#         Length of Candidate States: 50
# Beam Search Iteration 14
#     Number of Candidate States: 1231
#         Length of Candidate States: 50
# Beam Search Iteration 15
#     Number of Candidate States: 1229
#         Length of Candidate States: 50
# Beam Search Iteration 16
#     Number of Candidate States: 1222
#         Length of Candidate States: 50
# Beam Search Iteration 17
#     Number of Candidate States: 1224
#         Length of Candidate States: 50
# Beam Search Iteration 18
#     Number of Candidate States: 1162
#         Length of Candidate States: 50
# Beam Search Iteration 19
#     Number of Candidate States: 1177
#         Length of Candidate States: 50
# Beam Search Iteration 20
#     Number of Candidate States: 1177
#         Length of Candidate States: 50
# Beam Search Iteration 21
#     Number of Candidate States: 1189
#         Length of Candidate States: 50
# Beam Search Iteration 22
#     Number of Candidate States: 1216
#         Length of Candidate States: 50
# Beam Search Iteration 23
#     Number of Candidate States: 1187
#         Length of Candidate States: 50
# Beam Search Iteration 24
#     Number of Candidate States: 1165
#         Length of Candidate States: 50
# Beam Search Iteration 25
#     Number of Candidate States: 1132
#         Length of Candidate States: 50
# Beam Search Iteration 26
#     Number of Candidate States: 1103
#         Length of Candidate States: 50
# Beam Search Iteration 27
#     Number of Candidate States: 1085
#         Length of Candidate States: 50
# Beam Search Iteration 28
#     Number of Candidate States: 1023
#         Length of Candidate States: 50
# Beam Search Iteration 29
#     Number of Candidate States: 1018
#         Length of Candidate States: 50
# Running SabreSwap
# Initial Depth: 3
# Beam Search Iteration 0
#     Number of Candidate States: 26
#     New Lowest Depth: 90
#     New Lowest Depth: 83
#     New Lowest Depth: 74
#         Length of Candidate States: 26
# Beam Search Iteration 1
#     Number of Candidate States: 669
#         Length of Candidate States: 50
# Beam Search Iteration 2
#     Number of Candidate States: 1281
#         Length of Candidate States: 50
# Beam Search Iteration 3
#     Number of Candidate States: 1291
#     New Lowest Depth: 71
#         Length of Candidate States: 50
# Beam Search Iteration 4
#     Number of Candidate States: 1309
#         Length of Candidate States: 50
# Beam Search Iteration 5
#     Number of Candidate States: 1294
#         Length of Candidate States: 50
# Beam Search Iteration 6
#     Number of Candidate States: 1230
#         Length of Candidate States: 50
# Beam Search Iteration 7
#     Number of Candidate States: 1239
#         Length of Candidate States: 50
# Beam Search Iteration 8
#     Number of Candidate States: 1244
#         Length of Candidate States: 50
# Beam Search Iteration 9
#     Number of Candidate States: 1283
#         Length of Candidate States: 50
# Beam Search Iteration 10
#     Number of Candidate States: 1228
#         Length of Candidate States: 50
# Beam Search Iteration 11
#     Number of Candidate States: 1226
#         Length of Candidate States: 50
# Beam Search Iteration 12
#     Number of Candidate States: 1227
#         Length of Candidate States: 50
# Beam Search Iteration 13
#     Number of Candidate States: 1230
#         Length of Candidate States: 50
# Beam Search Iteration 14
#     Number of Candidate States: 1231
#         Length of Candidate States: 50
# Beam Search Iteration 15
#     Number of Candidate States: 1229
#         Length of Candidate States: 50
# Beam Search Iteration 16
#     Number of Candidate States: 1222
#         Length of Candidate States: 50
# Beam Search Iteration 17
#     Number of Candidate States: 1224
#         Length of Candidate States: 50
# Beam Search Iteration 18
#     Number of Candidate States: 1162
#         Length of Candidate States: 50
# Beam Search Iteration 19
#     Number of Candidate States: 1177
#         Length of Candidate States: 50
# Beam Search Iteration 20
#     Number of Candidate States: 1177
#         Length of Candidate States: 50
# Beam Search Iteration 21
#     Number of Candidate States: 1189
#         Length of Candidate States: 50
# Beam Search Iteration 22
#     Number of Candidate States: 1216
#         Length of Candidate States: 50
# Beam Search Iteration 23
#     Number of Candidate States: 1187
#         Length of Candidate States: 50
# Beam Search Iteration 24
#     Number of Candidate States: 1165
#         Length of Candidate States: 50
# Beam Search Iteration 25
#     Number of Candidate States: 1132
#         Length of Candidate States: 50
# Beam Search Iteration 26
#     Number of Candidate States: 1103
#         Length of Candidate States: 50
# Beam Search Iteration 27
#     Number of Candidate States: 1085
#         Length of Candidate States: 50
# Beam Search Iteration 28
#     Number of Candidate States: 1023
#         Length of Candidate States: 50
# Beam Search Iteration 29
#     Number of Candidate States: 1018
#         Length of Candidate States: 50
# Running SabreSwap
# Initial Depth: 3
# Beam Search Iteration 0
#     Number of Candidate States: 26
#     New Lowest Depth: 90
#     New Lowest Depth: 83
#     New Lowest Depth: 74
#         Length of Candidate States: 26
# Beam Search Iteration 1
#     Number of Candidate States: 669
#         Length of Candidate States: 50
# Beam Search Iteration 2
#     Number of Candidate States: 1281
#         Length of Candidate States: 50
# Beam Search Iteration 3
#     Number of Candidate States: 1291
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 12
#       9 qc_list_directory = f"experiment_setup/circuits/{circuit_path}"
#      10 qc_list = get_circuits_from_directory(qc_list_directory)
# ---> 12 data = run_experiment(save_path, qc_list, rp_str, lp_str, cm, max_iter=1, beam=beam)
#
# File ~/Documents/GitHub/qiskit/workspace_experiments/experiment_setup/pass_managers.py:248, in run_experiment(filename, qc_list, rp_str, lp_str, coupling_map, num_pm, seed, look, beam, num_iter, crit, max_iter)
#     246 counter = 0
#     247 for qc in qc_list:
# --> 248     data = run_one_circuit(qc, pm_list)
#     249     data['rp'] = rp_str
#     250     data['lp'] = lp_str
#
# File ~/Documents/GitHub/qiskit/workspace_experiments/experiment_setup/pass_managers.py:180, in run_one_circuit(qc, pm_list)
#     177 for pm in pm_list:
#     178     # Timing the transpilation
#     179     start = time.time()
# --> 180     qc_tr = pm.run(qc)
#     181     end = time.time()
#     183     # Decompose the swaps gate in the circuit
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:420, in _replace_error.<locals>.wrapper(*meth_args, **meth_kwargs)
#     417 @wraps(meth)
#     418 def wrapper(*meth_args, **meth_kwargs):
#     419     try:
# --> 420         return meth(*meth_args, **meth_kwargs)
#     421     except PassManagerError as ex:
#     422         raise TranspilerError(ex.message) from ex
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passmanager.py:182, in PassManager.run(self, circuits, output_name, callback, num_processes)
#     179 if callback is not None:
#     180     callback = _legacy_style_callback(callback)
# --> 182 return super().run(
#     183     in_programs=circuits,
#     184     callback=callback,
#     185     output_name=output_name,
#     186     num_processes=num_processes,
#     187 )
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:229, in BasePassManager.run(self, in_programs, callback, num_processes, **kwargs)
#     226     is_list = False
#     228 if len(in_programs) == 1:
# --> 229     out_program = _run_workflow(
#     230         program=in_programs[0],
#     231         pass_manager=self,
#     232         callback=callback,
#     233         **kwargs,
#     234     )
#     235     if is_list:
#     236         return [out_program]
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/passmanager.py:292, in _run_workflow(program, pass_manager, **kwargs)
#     286 initial_status = WorkflowStatus()
#     288 passmanager_ir = pass_manager._passmanager_frontend(
#     289     input_program=program,
#     290     **kwargs,
#     291 )
# --> 292 passmanager_ir, final_state = flow_controller.execute(
#     293     passmanager_ir=passmanager_ir,
#     294     state=PassManagerState(
#     295         workflow_status=initial_status,
#     296         property_set=PropertySet(),
#     297     ),
#     298     callback=kwargs.get("callback", None),
#     299 )
#     300 # The `property_set` has historically been returned as a mutable attribute on `PassManager`
#     301 # This makes us non-reentrant (though `PassManager` would be dependent on its internal tasks to
#     302 # be re-entrant if that was required), but is consistent with previous interfaces.  We're still
#     303 # safe to be called in a serial loop, again assuming internal tasks are re-runnable.  The
#     304 # conversion to the backend language is also allowed to use the property set, so it must be set
#     305 # before calling it.
#     306 pass_manager.property_set = final_state.property_set
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:218, in BaseController.execute(self, passmanager_ir, state, callback)
#     216     return passmanager_ir, state
#     217 while True:
# --> 218     passmanager_ir, state = next_task.execute(
#     219         passmanager_ir=passmanager_ir,
#     220         state=state,
#     221         callback=callback,
#     222     )
#     223     try:
#     224         # Sending the object through the generator implies the custom controllers
#     225         # can always rely on the latest data to choose the next task to run.
#     226         next_task = task_generator.send(state)
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/basepasses.py:195, in TransformationPass.execute(self, passmanager_ir, state, callback)
#     189 def execute(
#     190     self,
#     191     passmanager_ir: PassManagerIR,
#     192     state: PassManagerState,
#     193     callback: Callable = None,
#     194 ) -> tuple[PassManagerIR, PassManagerState]:
# --> 195     new_dag, state = super().execute(
#     196         passmanager_ir=passmanager_ir,
#     197         state=state,
#     198         callback=callback,
#     199     )
#     201     if state.workflow_status.previous_run == RunState.SUCCESS:
#     202         if isinstance(new_dag, DAGCircuit):
#     203             # Copy calibration data from the original program
#
# File ~/Documents/GitHub/qiskit/qiskit/passmanager/base_tasks.py:98, in GenericPass.execute(self, passmanager_ir, state, callback)
#      96 try:
#      97     if self not in state.workflow_status.completed_passes:
# ---> 98         ret = self.run(passmanager_ir)
#      99         run_state = RunState.SUCCESS
#     100     else:
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v0_20_dive.py:183, in SabreSwap.run(self, dag)
#     181 for state in candidate_states:
#     182     while state.front_layer:
# --> 183         self._apply_swap(state)
#     184         self._update_state(state)
#     186 # Phase 4a: Get list of depths of each candidate state and store the lowest depth
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v0_20_dive.py:463, in SabreSwap._apply_swap(self, state)
#     460 self._update_qubit_depth(DAGOpNode(op=SwapGate(), qargs=swap), trial_qubit_depth)
#     461 trial_state = State(trial_layout, state.front_layer.copy(), state.predecessors.copy(),
#     462                     trial_qubit_depth, None, 0)
# --> 463 self._update_state(trial_state, trial=True)
#     464 depth = max(trial_state.qubit_depth.values())
#     466 if score < best_score or (score == best_score and depth < best_depth):
#
# File ~/Documents/GitHub/qiskit/qiskit/transpiler/passes/routing/sabre_swap_v0_20_dive.py:362, in SabreSwap._update_state(self, state, trial)
#     359         print(f"    {'Node :':<16} {node.name}, {', '.join(map(str, indices))}")
#     360     print(f"{'Gates Count:':<20} {state.gates_count}")
# --> 362 def _update_state(self, state, trial=False):
#     363     """ Update the state by removing as many immediately applicable gates from the front layer,
#     364     until no more gates can be immediately applied. The gates removed are added to the
#     365     gate sequence.
#    (...)
#     374         trial (bool): if true, no gate information is updated
#     375     """
#     376     # While there are still gates in the front layer
#
# KeyboardInterrupt:
