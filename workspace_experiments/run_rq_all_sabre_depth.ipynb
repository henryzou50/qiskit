# %%
from experiment_setup.pass_managers import run_experiment
from experiment_setup.circuits.circuit_files import get_circuits_from_directory
from experiment_setup.coupling_maps.coupling_maps_files import file_to_coupling_map

# %%
# Parameters to change
circuit = "red_queen_all"
rp_str  = "sabre_v0_20_depth"
lp_str  = "sabre_layout"
cp_str  = "heavy_hex_127"

# %%
path = f"results/{circuit}/{rp_str}.csv"
cm_filename = f"experiment_setup/coupling_maps/{cp_str}.txt"

qc_list_directory = f"experiment_setup/circuits/{circuit}/"
qc_list = get_circuits_from_directory(qc_list_directory)
cm = file_to_coupling_map(cm_filename)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       2 cm_filename = f"experiment_setup/coupling_maps/{cp_str}.txt"
#       4 qc_list_directory = f"experiment_setup/circuits/{circuit}/"
# ----> 5 qc_list = get_circuits_from_directory(qc_list_directory)
#       6 cm = file_to_coupling_map(cm_filename)
#
# File ~/Documents/GitHub/qiskit/workspace_experiments/experiment_setup/circuits/circuit_files.py:36, in get_circuits_from_directory(directory)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Documents/GitHub/qiskit/qiskit/circuit/quantumcircuit.py:2901, in QuantumCircuit.from_qasm_str(qasm_str)
#    2898 # pylint: disable=cyclic-import
#    2899 from qiskit import qasm2
# -> 2901 return qasm2.loads(
#    2902     qasm_str,
#    2903     include_path=qasm2.LEGACY_INCLUDE_PATH,
#    2904     custom_instructions=qasm2.LEGACY_CUSTOM_INSTRUCTIONS,
#    2905     custom_classical=qasm2.LEGACY_CUSTOM_CLASSICAL,
#    2906     strict=False,
#    2907 )
#
# File ~/Documents/GitHub/qiskit/qiskit/qasm2/__init__.py:591, in loads(string, include_path, custom_instructions, custom_classical, strict)
#     575 """Parse an OpenQASM 2 program from a string into a :class:`.QuantumCircuit`.
#     576
#     577 Args:
#    (...)
#     588     A circuit object representing the same OpenQASM 2 program.
#     589 """
#     590 custom_instructions = list(custom_instructions)
# --> 591 return _parse.from_bytecode(
#     592     _qasm2.bytecode_from_string(
#     593         string,
#     594         [_normalize_path(path) for path in include_path],
#     595         [
#     596             _qasm2.CustomInstruction(x.name, x.num_params, x.num_qubits, x.builtin)
#     597             for x in custom_instructions
#     598         ],
#     599         tuple(custom_classical),
#     600         strict,
#     601     ),
#     602     custom_instructions,
#     603 )
#
# File ~/Documents/GitHub/qiskit/qiskit/qasm2/parse.py:226, in from_bytecode(bytecode, custom_instructions)
#     223 if opcode == OpCode.Gate:
#     224     gate_id, parameters, op_qubits = op.operands
#     225     qc._append(
# --> 226         CircuitInstruction(gates[gate_id](*parameters), [qubits[q] for q in op_qubits])
#     227     )
#     228 elif opcode == OpCode.ConditionedGate:
#     229     gate_id, parameters, op_qubits, creg, value = op.operands
#
# File ~/Documents/GitHub/qiskit/qiskit/circuit/singleton.py:380, in _SingletonMeta.__call__(cls, _force_mutable, *args, **kwargs)
#     377         cls.__init_subclass__ = _impl_init_subclass(cls, overrides)
#     378     return cls
# --> 380 def __call__(cls, *args, _force_mutable=False, **kwargs):
#     381     if _force_mutable:
#     382         return super().__call__(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
data = run_experiment(path, qc_list, rp_str, lp_str, cm)
# Out:
# Using seed 42 for routing pass.
#     Building Sabre v0.20 depth routing pass
#         Using seed 42 and max iterations 1 for layout pass.
#             Building